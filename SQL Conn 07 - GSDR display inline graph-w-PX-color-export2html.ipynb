# %%
#Program Name: Graphing ODS Databases - SQL Conn 07 - GSDR display inline graph-w-PX-color-export2html
#Purpose:  Chart scatter, line, box, aggr, violin, or bar with table data
#Author:  Greg Turmel, Director, Data Governance 
#Date:    2020.08.30 - 2021.06.30
#Errata:  0.1 Improvements can be made to script using for/looping through the databases

import os, time, datetime
import sqlalchemy as db
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import pyodbc 
import matplotlib
import plotly.express as px

#matplotlib.rcParams['figure.figsize'] = (30,5)
# %config InlineBackend.figure_format = 'retina'
from dotenv import load_dotenv # add this line
load_dotenv() # add this line
user = os.getenv('MySQLeUser')
password = os.getenv('MySQLeUserPass')
host = os.getenv('MySQLeHOST')
db = os.getenv('MySQLeDB')
# %matplotlib inline
# %load_ext sql

dt1 = time.strftime("%d/%m/%Y")
dt2 = time.strftime("%d.%m.%Y")
dt3 = pd.to_datetime('today')
dt4 = pd.Timestamp('today').strftime("%Y%m%d")

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=DEVODSSQL;'
                      'Database=Greg;'
                      'Trusted_Connection=yes;')

sql_query01 = pd.read_sql_query(''' 
select DISTINCT TableName
FROM [dbo].[tableRowCountGSDR]
ORDER BY TableName;     
                              '''
                              ,conn) # Load the list of distinct tables to graph

sql_query02 = pd.read_sql_query(''' 
select *
FROM [dbo].[tableRowCountGSDR]
ORDER BY TableName;     
                              '''
                              ,conn) # Load the list of distinct tables to graph

# %%
df = pd.DataFrame(sql_query02)
#df = df.astype({'TodaysDate':np.int64,'RecordCount':np.int64})
df['TodaysDate'] = pd.to_datetime(df['TodaysDate'].astype(str), format='%Y%m%d')
df = df.sort_values(by=['TableName','SchemaName','DatabaseName','TodaysDate'], ascending=[True,True,True,True])
df = df.reset_index(drop=True)

# %%
dfgsdr0001 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'BUFORD') & (df['TableName'] == 'SDR_STU_C')]
dfgsdr0002 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'BUFORD') & (df['TableName'] == 'SDR_STU_D')]
dfgsdr0003 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'BUFORD') & (df['TableName'] == 'SDR_STU_E')]
dfgsdr0004 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'BUFORD') & (df['TableName'] == 'SDR_STU_F')]
dfgsdr0005 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'BUFORD') & (df['TableName'] == 'SDR_STU_G')]
dfgsdr0006 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'BUFORD') & (df['TableName'] == 'SDR_STU_H')]
dfgsdr0007 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'BUFORD') & (df['TableName'] == 'SDR_STU_K')]
dfgsdr0008 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_AllSchools_Usage')]
dfgsdr0009 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'D2L_Reporting_D2LSessionExport')]
dfgsdr0010 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_OrgRoleCrosswalk')]
dfgsdr0011 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_SchoolPopulation')]
dfgsdr0012 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_SchoolPopulationDtl')]
dfgsdr0013 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_SessionActivity')]
dfgsdr0014 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_Reporting_TeacherSchedule')]
dfgsdr0015 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_Usage')]
dfgsdr0016 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_UsageDtl')]
dfgsdr0017 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == '667errors')]
dfgsdr0018 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AAA_Cohort_Report')]
dfgsdr0019 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AcademicContract')]
dfgsdr0020 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AcademicContractImport')]
dfgsdr0021 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AcademicContractImportErrors')]
dfgsdr0022 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AcademicContractIntervention')]
dfgsdr0023 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ACCESS_Targets')]
dfgsdr0024 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ACHSFILE')]
dfgsdr0025 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ACRSTMP')]
dfgsdr0026 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ActiveEnrollmentReportCache')]
dfgsdr0027 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ActiveEnrollmentReportCacheAllSchools')]
dfgsdr0028 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AdditionalMinutes')]
dfgsdr0029 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'APGM_KS2017')]
dfgsdr0030 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASTU_CHANGES')]
dfgsdr0031 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASTU_KS2017')]
dfgsdr0032 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'astv1819')]
dfgsdr0033 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AttendanceSummary')]
dfgsdr0034 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'BiLiteracyReport 2019')]
dfgsdr0035 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'BlockFile')]
dfgsdr0036 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'BlockFile_BPtest')]
dfgsdr0037 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'BlockFileNewMapNet')]
dfgsdr0038 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'BusPlanner_AddressListing')]
dfgsdr0039 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CALENDAR_CHARLENE')]
dfgsdr0040 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CALENDAR_CHARLENE2')]
dfgsdr0041 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Calendar_Charlene3')]
dfgsdr0042 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Calendar_Charlene4')]
dfgsdr0043 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'cert_codes')]
dfgsdr0044 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'COB_KS')]
dfgsdr0045 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Cohort_Withdrawals')]
dfgsdr0046 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Cohort20170201')]
dfgsdr0047 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CohortAdditionalCourses')]
dfgsdr0048 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CohortAdditionalCoursesFull')]
dfgsdr0049 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Cohorts')]
dfgsdr0050 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Cohorts2')]
dfgsdr0051 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'COUNTRIES')]
dfgsdr0052 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Course_No_EOCT')]
dfgsdr0053 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CourseConversion')]
dfgsdr0054 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CourseEvalType')]
dfgsdr0055 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CourseMerged$')]
dfgsdr0056 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CPI March 2017')]
dfgsdr0057 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CPI_TEMP')]
dfgsdr0058 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Crosswalk SPG Courses')]
dfgsdr0059 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CSVFILE')]
dfgsdr0060 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2L_NON_TEACHING_STAFF')]
dfgsdr0061 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LPortalUtizReport')]
dfgsdr0062 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DavidDoesNotKnow')]
dfgsdr0063 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'dbIEPReview')]
dfgsdr0064 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'dbIEPTransfer')]
dfgsdr0065 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'dbTransfer')]
dfgsdr0066 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'deleteSections')]
dfgsdr0067 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DestinyOutstandingFees')]
dfgsdr0068 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_Courses')]
dfgsdr0069 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_EL_HISTORY')]
dfgsdr0070 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_EL_HISTORY_temp')]
dfgsdr0071 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_SPED_HISTORY')]
dfgsdr0072 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DSCP_TEMP')]
dfgsdr0073 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'E5098_Prim_Area20200324')]
dfgsdr0074 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EL_FORM_1020')]
dfgsdr0075 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EL_Monitor_data')]
dfgsdr0076 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Ellevation_Demographics')]
dfgsdr0077 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ELPP_schedules_tb')]
dfgsdr0078 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ELPP_test_scores_tb')]
dfgsdr0079 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EmployeeEmailIDSource')]
dfgsdr0080 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOC_PRELIM_2019')]
dfgsdr0081 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOC_SCORES')]
dfgsdr0082 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOCT_KAUSHAL')]
dfgsdr0083 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOCT_Unmatched')]
dfgsdr0084 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOG_PRELIM_2017')]
dfgsdr0085 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOG_PRELIM_2018')]
dfgsdr0086 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOG_PRELIM_2019')]
dfgsdr0087 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA Assessments')]
dfgsdr0088 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA Exam Taken')]
dfgsdr0089 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA Pathways')]
dfgsdr0090 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA_Clusters')]
dfgsdr0091 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA_Courses')]
dfgsdr0092 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA_Pathways')]
dfgsdr0093 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA2016')]
dfgsdr0094 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA2017')]
dfgsdr0095 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'error_import')]
dfgsdr0096 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Errors')]
dfgsdr0097 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ESOL_COURSES_JUNE15')]
dfgsdr0098 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ESOL115')]
dfgsdr0099 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ESOL115_FTE')]
dfgsdr0100 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'eTextBook_SchContact')]
dfgsdr0101 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'eTextBook_SchContact_BAK')]
dfgsdr0102 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'eTextBook_SchContact_temp')]
dfgsdr0103 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'fay')]
dfgsdr0104 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'fay2')]
dfgsdr0105 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Feed_Portal_ITAcademyStudents')]
dfgsdr0106 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Feed_Portal_SchoolNetStudents')]
dfgsdr0107 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FineTypes')]
dfgsdr0108 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FLATFILE')]
dfgsdr0109 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FLATFILE_JCS')]
dfgsdr0110 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FLP_Student_Attendance_List_tb')]
dfgsdr0111 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FTE_ERRORS')]
dfgsdr0112 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FTE_IVY_PREP')]
dfgsdr0113 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FTE_REPORT_SCH')]
dfgsdr0114 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FTE2019')]
dfgsdr0115 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FTENUMB UPDATE 20131021')]
dfgsdr0116 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FTENUMB UPDATE 20131024')]
dfgsdr0117 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GA411Data')]
dfgsdr0118 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GCPS_MA_AKS')]
dfgsdr0119 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GSDR_DATA_LOADED')]
dfgsdr0120 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GTID_IMPORTED')]
dfgsdr0121 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HiQ_Courses_20140122')]
dfgsdr0122 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'IEP_Accomondation_View_NewWay')]
dfgsdr0123 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_active_elig_view')]
dfgsdr0124 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_active_plan_view')]
dfgsdr0125 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_bip_intervention_view')]
dfgsdr0126 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'IEP_District_Users')]
dfgsdr0127 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_goals_view')]
dfgsdr0128 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_mods_ints_strengths_view')]
dfgsdr0129 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_objectives_details')]
dfgsdr0130 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_objectives_view')]
dfgsdr0131 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_plan_list_view')]
dfgsdr0132 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_student_casemanager_view')]
dfgsdr0133 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_student_view')]
dfgsdr0134 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'IEPSERVICE')]
dfgsdr0135 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ImportFile')]
dfgsdr0136 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'IOWA_CoGAT_Report')]
dfgsdr0137 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ItemsCheckedOut')]
dfgsdr0138 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'January11pull')]
dfgsdr0139 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'kstemp')]
dfgsdr0140 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'kstemp2')]
dfgsdr0141 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'LA_AVG_Temp')]
dfgsdr0142 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'LDS')]
dfgsdr0143 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'LocalCourseMerged')]
dfgsdr0144 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MA_AVG_Temp')]
dfgsdr0145 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Maxwell')]
dfgsdr0146 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mentees_LOAD_ ALL_Details')]
dfgsdr0147 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mentees_LOAD_ ALL_Details_20210112')]
dfgsdr0148 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mentees_Names_ALL')]
dfgsdr0149 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MYSTUDENT_DATA_RETRIEVAL_HISTORY')]
dfgsdr0150 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MYSTUDENT_DATA_RETRIEVAL_STATUS')]
dfgsdr0151 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'NEW_MYSTUDENT_DATA_RETRIEVAL_HISTORY')]
dfgsdr0152 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'NEW_MYSTUDENT_DATA_RETRIEVAL_STATUS')]
dfgsdr0153 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Organization_Chart')]
dfgsdr0154 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'pa_update2020')]
dfgsdr0155 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PATHWAY_COURSE')]
dfgsdr0156 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Patrons_For_Datamove')]
dfgsdr0157 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PermnumFromRiderByRoute')]
dfgsdr0158 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PHLOTE_AUG')]
dfgsdr0159 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PHLOTE_JUN')]
dfgsdr0160 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PIVOTDATA')]
dfgsdr0161 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'portal_sec_aro_group_mbr_psd')]
dfgsdr0162 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PreK_Entrance')]
dfgsdr0163 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PreK_Exit')]
dfgsdr0164 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PreK_Not_Met')]
dfgsdr0165 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PRIMARY AREA UPDATE FTE20161')]
dfgsdr0166 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'private_school_2014final')]
dfgsdr0167 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'private_schools_2013')]
dfgsdr0168 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'private_schools_2014')]
dfgsdr0169 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'private_schools_2015')]
dfgsdr0170 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PSC_DATA')]
dfgsdr0171 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'psd_activity_2019')]
dfgsdr0172 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'psd_activity_2020')]
dfgsdr0173 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'psd_users_2019')]
dfgsdr0174 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'psd_users_2020')]
dfgsdr0175 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'psd_users_bak')]
dfgsdr0176 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Pseudo FTE Nums')]
dfgsdr0177 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Query2')]
dfgsdr0178 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'RIDER_BY_ROUTE')]
dfgsdr0179 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'RIDER_BY_ROUTE_SNAPSHOT')]
dfgsdr0180 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Rising_6thGrd_Report')]
dfgsdr0181 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Rising_7thGrd_Report')]
dfgsdr0182 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Rising_7thGrd_Report_Bkup')]
dfgsdr0183 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Rising_8thGrd_Report')]
dfgsdr0184 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Rising_8thGrd_Report_Bkup')]
dfgsdr0185 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Rising_9thGrd_Report')]
dfgsdr0186 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SASI_ACHS441')]
dfgsdr0187 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SASI_ASTU')]
dfgsdr0188 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_1_AVG')]
dfgsdr0189 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_1_ELIGIBLE')]
dfgsdr0190 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_2_AVG')]
dfgsdr0191 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_2_ELIGIBLE')]
dfgsdr0192 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_3_AVG')]
dfgsdr0193 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_3_ELIGIBLE')]
dfgsdr0194 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SC_ERRORS')]
dfgsdr0195 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SCHOOLFILE')]
dfgsdr0196 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SchoolFoodNutritionDaily_GSDR_test')]
dfgsdr0197 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SchoolReports_Subscribers')]
dfgsdr0198 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Schools_KS')]
dfgsdr0199 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SchPermnumCode')]
dfgsdr0200 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SemesterDates')]
dfgsdr0201 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SFN_Export')]
dfgsdr0202 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_current_IEP')]
dfgsdr0203 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_error_log')]
dfgsdr0204 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_error_log_ref')]
dfgsdr0205 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_iep_bip_antecedent_intervention_view')]
dfgsdr0206 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_iep_bip_behavior_view')]
dfgsdr0207 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_iep_bip_consequence_intervention_neg_view')]
dfgsdr0208 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_iep_bip_consequence_intervention_pos_view')]
dfgsdr0209 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_iep_bip_demographic_view')]
dfgsdr0210 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_reg_transportation_green_view')]
dfgsdr0211 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SIS_Testing_Accommodations_View')]
dfgsdr0212 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SLO_Corrections')]
dfgsdr0213 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20091031')]
dfgsdr0214 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20131031')]
dfgsdr0215 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20141031')]
dfgsdr0216 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20151031')]
dfgsdr0217 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20161031')]
dfgsdr0218 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_201610312')]
dfgsdr0219 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20171031')]
dfgsdr0220 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20181031')]
dfgsdr0221 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20191031')]
dfgsdr0222 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20201031')]
dfgsdr0223 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'snp_today')]
dfgsdr0224 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Sped_File_Push_data')]
dfgsdr0225 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SpEd_TransGreenListReport')]
dfgsdr0226 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SpEd_TransListReport')]
dfgsdr0227 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SPG Teachers To Validate')]
dfgsdr0228 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SPG Teachers To Validate2')]
dfgsdr0229 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'spg_courses_tests')]
dfgsdr0230 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SPG_Export')]
dfgsdr0231 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SPGCases_June20_2014')]
dfgsdr0232 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SPGJUNE30')]
dfgsdr0233 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SR_Errors')]
dfgsdr0234 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StageStudentPictures')]
dfgsdr0235 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StreetTypeAbbreviations')]
dfgsdr0236 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass')]
dfgsdr0237 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass_Buford')]
dfgsdr0238 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass_Buford_SAVE')]
dfgsdr0239 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass2015')]
dfgsdr0240 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass2015v2')]
dfgsdr0241 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass2016')]
dfgsdr0242 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass2017')]
dfgsdr0243 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass2018')]
dfgsdr0244 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass20190601')]
dfgsdr0245 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClassAppend')]
dfgsdr0246 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentCourseProfile')]
dfgsdr0247 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentCourseProfile2')]
dfgsdr0248 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentIDfromSRTV')]
dfgsdr0249 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentLogin20120827')]
dfgsdr0250 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentLogin20120903')]
dfgsdr0251 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentLogins')]
dfgsdr0252 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerSchoolSites2017')]
dfgsdr0253 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerSchoolSites2018')]
dfgsdr0254 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerSchoolSites2019')]
dfgsdr0255 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerStudentList')]
dfgsdr0256 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerStudentList2017')]
dfgsdr0257 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerStudentListTemp')]
dfgsdr0258 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerStudentListtemp_backup')]
dfgsdr0259 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerStudentListTemp_Bkup')]
dfgsdr0260 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Synergy_ESOL_Status')]
dfgsdr0261 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sysdtslog90')]
dfgsdr0262 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sysssislog')]
dfgsdr0263 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TeacherClass')]
dfgsdr0264 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TeacherClass2')]
dfgsdr0265 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_AD_Data')]
dfgsdr0266 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_ad_groups')]
dfgsdr0267 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_ad_groups_search')]
dfgsdr0268 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_ad_membership')]
dfgsdr0269 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_dscp_event_id_rules')]
dfgsdr0270 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_groups')]
dfgsdr0271 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Temp_MyTable')]
dfgsdr0272 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_SASI_APRN')]
dfgsdr0273 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEMP_TBL')]
dfgsdr0274 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'test_academic_contracts')]
dfgsdr0275 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Timeline 18_19')]
dfgsdr0276 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Title1 Employees')]
dfgsdr0277 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TMP_IEP_EXIT_VIEW')]
dfgsdr0278 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TMP_IEP_SERVICES_SR_VIEW')]
dfgsdr0279 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TranscriptData')]
dfgsdr0280 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TranscriptData_2020Staging')]
dfgsdr0281 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TranscriptSummary')]
dfgsdr0282 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'udtMonths')]
dfgsdr0283 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'UPKE')]
dfgsdr0284 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'UPKX')]
dfgsdr0285 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'USATestPrep_DataFeed')]
dfgsdr0286 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'USATestPrep_DataFeed_2018')]
dfgsdr0287 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'zoned_temp')]
dfgsdr0288 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dx') & (df['TableName'] == 'Households_Import')]
dfgsdr0289 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dx') & (df['TableName'] == 'HouseholdStudentMembers_Import')]
dfgsdr0290 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dx') & (df['TableName'] == 'Locker_Import')]
dfgsdr0291 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dx') & (df['TableName'] == 'MedIncident_Import')]
dfgsdr0292 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dx') & (df['TableName'] == 'StudentContacts_Import')]
dfgsdr0293 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dx') & (df['TableName'] == 'StudentContactsParent_Import')]
dfgsdr0294 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'OverrideStudents')]
dfgsdr0295 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'OverrideStudentSections')]
dfgsdr0296 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'OverrideTeachers')]
dfgsdr0297 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'OverrideTeacherSections')]
dfgsdr0298 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'PqAllTeacherQualifications')]
dfgsdr0299 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'PqNonPqTeacherList')]
dfgsdr0300 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'PqParentNotifications')]
dfgsdr0301 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'PqRptAggDistrict')]
dfgsdr0302 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'PqRptAggSchool')]
dfgsdr0303 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'ReportActions')]
dfgsdr0304 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'Reports')]
dfgsdr0305 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StateCertifications')]
dfgsdr0306 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StateCourseRequirements')]
dfgsdr0307 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgPqPrep')]
dfgsdr0308 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgSchools')]
dfgsdr0309 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgSections')]
dfgsdr0310 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgStudents')]
dfgsdr0311 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgStudentSchedules')]
dfgsdr0312 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgStudentServices')]
dfgsdr0313 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgTeacherCertifications')]
dfgsdr0314 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgTeacherExceptionalities')]
dfgsdr0315 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgTeachers')]
dfgsdr0316 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgTeacherSections')]
dfgsdr0317 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'Assignment')]
dfgsdr0318 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'AssignmentScore')]
dfgsdr0319 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'Calendar')]
dfgsdr0320 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'Gradebook')]
dfgsdr0321 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradebookCategory')]
dfgsdr0322 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradebookCategoryGrade')]
dfgsdr0323 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradebookGradingScale')]
dfgsdr0324 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradebookTerm')]
dfgsdr0325 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradebookTermGrade')]
dfgsdr0326 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradingScale')]
dfgsdr0327 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradingScaleBreakpoint')]
dfgsdr0328 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradingTerm')]
dfgsdr0329 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'SectionEnrollment')]
dfgsdr0330 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'Sections')]
dfgsdr0331 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'Student')]
dfgsdr0332 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'Teacher')]
dfgsdr0333 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'TeacherSection')]
dfgsdr0334 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Assignment')]
dfgsdr0335 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'AssignmentGrades')]
dfgsdr0336 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'AssignmentScore')]
dfgsdr0337 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Calendar')]
dfgsdr0338 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Course')]
dfgsdr0339 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'D2L_CLASS_Import')]
dfgsdr0340 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'D2L_Class_Import_20190410')]
dfgsdr0341 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'D2L_GRADE_IMPORT')]
dfgsdr0342 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'D2L_NOTE_Import')]
dfgsdr0343 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'D2L_SCORE_Import')]
dfgsdr0344 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'D2L_TASK_IMPORT')]
dfgsdr0345 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'FinalGrades')]
dfgsdr0346 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Gradebook')]
dfgsdr0347 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'GradebookCategory')]
dfgsdr0348 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'GradebookCategoryGrade')]
dfgsdr0349 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'GradebookTerm')]
dfgsdr0350 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'GradebookTermGrade')]
dfgsdr0351 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'GradingScaleBreakpoint')]
dfgsdr0352 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'GradingTerm')]
dfgsdr0353 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Organization')]
dfgsdr0354 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Person')]
dfgsdr0355 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'PivotTable')]
dfgsdr0356 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'RptAssignmentScore_CurrentTermFlag')]
dfgsdr0357 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Section')]
dfgsdr0358 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'SectionEnrollment')]
dfgsdr0359 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Student')]
dfgsdr0360 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'SynergyScore')]
dfgsdr0361 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Teacher')]
dfgsdr0362 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ACADEMIC_CONTRACTS')]
dfgsdr0363 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ACHSFILE')]
dfgsdr0364 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ADDRESS_HIST')]
dfgsdr0365 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ADIA')]
dfgsdr0366 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ADIA_ERROR_CODE')]
dfgsdr0367 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ADIA_HISTORY')]
dfgsdr0368 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ADIA_OMG')]
dfgsdr0369 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ADST_ALL_YEARS')]
dfgsdr0370 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'AFTSCH_TRANSP_PGMS')]
dfgsdr0371 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'Applitrack')]
dfgsdr0372 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'Applitrack_RecScore')]
dfgsdr0373 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'Applitrack_Test')]
dfgsdr0374 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ARCHATT')]
dfgsdr0375 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'archatt_2018_restore')]
dfgsdr0376 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ARCHGRD')]
dfgsdr0377 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ASTU_HISTORY')]
dfgsdr0378 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ATTDLET')]
dfgsdr0379 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ATTEND_PARAM')]
dfgsdr0380 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR')]
dfgsdr0381 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_20180530')]
dfgsdr0382 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_GAP')]
dfgsdr0383 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_JIC')]
dfgsdr0384 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_JIC2')]
dfgsdr0385 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_JIC3')]
dfgsdr0386 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_JIC4')]
dfgsdr0387 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_NEWSTUFF')]
dfgsdr0388 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_NEWSTUFF2')]
dfgsdr0389 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CLASSRANK')]
dfgsdr0390 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'COHORT2')]
dfgsdr0391 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'COURSE')]
dfgsdr0392 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'COURSE_REQUESTS')]
dfgsdr0393 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'COURSE_REQUESTS_JIC')]
dfgsdr0394 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'COURSE_REQUESTS_JIC_20170207')]
dfgsdr0395 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'COURSE_REQUESTS_JIC2')]
dfgsdr0396 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'COURSE_SETUP')]
dfgsdr0397 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CPI_A01')]
dfgsdr0398 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CPI_B01')]
dfgsdr0399 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CPI_C01')]
dfgsdr0400 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CPI_D01')]
dfgsdr0401 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CRCT_MATCHED')]
dfgsdr0402 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CRCT_MATCHED_TMP')]
dfgsdr0403 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CRISNET_ARRESTS')]
dfgsdr0404 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_ACTIVITY')]
dfgsdr0405 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_ASSIGNMENTS')]
dfgsdr0406 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_CONTACT_REASONS')]
dfgsdr0407 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_CONTACT_TYPES')]
dfgsdr0408 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_MEETINGS')]
dfgsdr0409 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_OUTCOMES')]
dfgsdr0410 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_REFERRALS')]
dfgsdr0411 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_STUDENT_EDUCATIONS')]
dfgsdr0412 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_STUDENT_HEALTHS')]
dfgsdr0413 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_TRAININGS')]
dfgsdr0414 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'dc_course_file_readonly')]
dfgsdr0415 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'dc_innovator_schedules_readonly')]
dfgsdr0416 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'dc_innovator_students_readonly')]
dfgsdr0417 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'dc_innovator_teachers_readonly')]
dfgsdr0418 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DELETED_GTIDS')]
dfgsdr0419 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DELETED_GTIDS_HISTORY')]
dfgsdr0420 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DESTINY_SCHOOLS')]
dfgsdr0421 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DOE_CLAIMED_SWD')]
dfgsdr0422 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DOE_SPED_NOPRIMARYAREA')]
dfgsdr0423 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DSCP_ADDL_COMMENT')]
dfgsdr0424 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DSCP_PANEL')]
dfgsdr0425 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DSCP_PANEL_RULES')]
dfgsdr0426 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DSCP_PANEL_SPED')]
dfgsdr0427 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DUPLICATES')]
dfgsdr0428 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EDIT_CODES')]
dfgsdr0429 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ELIG_ACTIVITIES')]
dfgsdr0430 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ELIG_LOG')]
dfgsdr0431 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ELIG_PRAM')]
dfgsdr0432 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_pram_bak20190717')]
dfgsdr0433 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_pram_bak20200602')]
dfgsdr0434 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ELIG_PRAM_OBJECT')]
dfgsdr0435 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ELIG_REQUIREMENTS')]
dfgsdr0436 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ELIG_ROSTERS')]
dfgsdr0437 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_rosters_bak20200602')]
dfgsdr0438 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_rosters_lastupdate')]
dfgsdr0439 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_rosters_nodups')]
dfgsdr0440 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_rosters_sy1718_aftersummercalc')]
dfgsdr0441 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_rosters_sy1819_aftersummercalc')]
dfgsdr0442 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ELIG_STUDENTS')]
dfgsdr0443 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_students_bak20190717')]
dfgsdr0444 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_students_bak20190723')]
dfgsdr0445 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_students_bak20200602')]
dfgsdr0446 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_students_bak20200722')]
dfgsdr0447 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_students_procbak')]
dfgsdr0448 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_students_sy1718_aftersummercalc')]
dfgsdr0449 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_students_sy1819_aftersummercalc')]
dfgsdr0450 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EOCT_HIST')]
dfgsdr0451 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ESOL')]
dfgsdr0452 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ESOL_CAT')]
dfgsdr0453 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EXP_REG_STU')]
dfgsdr0454 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EXP_REG_SUM')]
dfgsdr0455 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EXTERNAL_SCHOOLS')]
dfgsdr0456 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'external_schools_all_years')]
dfgsdr0457 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EXTERNAL_STUDENTS')]
dfgsdr0458 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'external_students_all_years')]
dfgsdr0459 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EXTERNAL_STUDENTS_NONDISTRICT')]
dfgsdr0460 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EXTERNAL_STUDENTS_Tim')]
dfgsdr0461 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FAY_RESEARCH')]
dfgsdr0462 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FAY_RESEARCH_EOCT')]
dfgsdr0463 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FORECAST')]
dfgsdr0464 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FREE_REDUCED_LUNCH')]
dfgsdr0465 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE')]
dfgsdr0466 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_COURSES')]
dfgsdr0467 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_ERRORLOAD')]
dfgsdr0468 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_HISTORY')]
dfgsdr0469 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_PARAMS')]
dfgsdr0470 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_REPORT_ROWS')]
dfgsdr0471 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_REPORT_SCH')]
dfgsdr0472 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_REPORT_SCH20130220')]
dfgsdr0473 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_TEMP')]
dfgsdr0474 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_ZONED_SCH')]
dfgsdr0475 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE441')]
dfgsdr0476 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE88')]
dfgsdr0477 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE88_KS')]
dfgsdr0478 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTECRS_MULTI')]
dfgsdr0479 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTEEIP')]
dfgsdr0480 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTEGIFTED_STUDENT')]
dfgsdr0481 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTENUMB_TANK')]
dfgsdr0482 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTEPEOPLE')]
dfgsdr0483 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESPED')]
dfgsdr0484 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT')]
dfgsdr0485 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_APPEND')]
dfgsdr0486 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_BUF')]
dfgsdr0487 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_BUF_KS')]
dfgsdr0488 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_IVY')]
dfgsdr0489 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_KS')]
dfgsdr0490 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_LAST_YEAR')]
dfgsdr0491 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_MAIN')]
dfgsdr0492 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_YEAR')]
dfgsdr0493 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GBATCH')]
dfgsdr0494 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GBATCH_UPD')]
dfgsdr0495 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GTID')]
dfgsdr0496 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GTID_ERRORS')]
dfgsdr0497 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GTID_HISTORY')]
dfgsdr0498 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GTID_IMPORT')]
dfgsdr0499 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GTID_STU_BATCH')]
dfgsdr0500 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GTID_STU_BATCH_UPD')]
dfgsdr0501 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GTID20200813')]
dfgsdr0502 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'GIFTED')]
dfgsdr0503 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'GIFTED_CAT')]
dfgsdr0504 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'GRADETANK')]
dfgsdr0505 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'GRADETANK_HISTORY')]
dfgsdr0506 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'GRADETANK_KS')]
dfgsdr0507 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'GRADETANK3')]
dfgsdr0508 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'GRADETANKTEMP')]
dfgsdr0509 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_EXIT')]
dfgsdr0510 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_EXPORT')]
dfgsdr0511 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_GAA_INFO')]
dfgsdr0512 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_SERVICES')]
dfgsdr0513 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_SERVICES_FTE')]
dfgsdr0514 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_SERVICES_SR')]
dfgsdr0515 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_TIMELINE')]
dfgsdr0516 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_TranspRoster')]
dfgsdr0517 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_TranspRoster_CaseManagerComments')]
dfgsdr0518 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_TranspRoster_OtherSchools')]
dfgsdr0519 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ISC_CONTRACTORS')]
dfgsdr0520 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'LETTER_TEXT')]
dfgsdr0521 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'LETTER_TEXT_SAVE')]
dfgsdr0522 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'LOCATION')]
dfgsdr0523 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'LTS_TNL_Mentor')]
dfgsdr0524 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'MEDICAID')]
dfgsdr0525 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'NEXT_SCHOOL')]
dfgsdr0526 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'NEXT_SCHOOL_Audit')]
dfgsdr0527 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'NON_TEACHERS')]
dfgsdr0528 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'NOSHOWS')]
dfgsdr0529 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'NOSHOWS2012')]
dfgsdr0530 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_CODE_DEFINITIONS')]
dfgsdr0531 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_LOOKUP_CODES')]
dfgsdr0532 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'Portal_lookup_codes_20170131')]
dfgsdr0533 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_lookup_codes_lastupdate')]
dfgsdr0534 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_PARAM_MESSAGES')]
dfgsdr0535 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_PARAMS')]
dfgsdr0536 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ACL')]
dfgsdr0537 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ACO')]
dfgsdr0538 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ACO_MAP')]
dfgsdr0539 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aco_map_lastupdate')]
dfgsdr0540 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ARO')]
dfgsdr0541 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ARO_ACL')]
dfgsdr0542 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_acl_autobackup')]
dfgsdr0543 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_acl_lastupdate')]
dfgsdr0544 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ARO_GROUP_MBR')]
dfgsdr0545 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_group_mbr_bak_20170413_psd')]
dfgsdr0546 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_group_mbr_bak_20180409_psd')]
dfgsdr0547 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_group_mbr_bak_20190411_psd')]
dfgsdr0548 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_group_mbr_bak_20200411_psd')]
dfgsdr0549 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_group_mbr_bak_20210411_psd')]
dfgsdr0550 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ARO_GROUPS')]
dfgsdr0551 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ARO_GROUPS_MAP')]
dfgsdr0552 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_groups_map_lastupdate')]
dfgsdr0553 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ARO_MAP')]
dfgsdr0554 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_map_lastupdate')]
dfgsdr0555 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_AXO')]
dfgsdr0556 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_AXO_GROUP_MBR')]
dfgsdr0557 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_AXO_GROUPS')]
dfgsdr0558 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_AXO_GROUPS_MAP')]
dfgsdr0559 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_axo_groups_map_lastupdate')]
dfgsdr0560 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_AXO_MAP')]
dfgsdr0561 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_axo_map_lastupdate')]
dfgsdr0562 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PREVIOUS_VALUES')]
dfgsdr0563 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_ATTD')]
dfgsdr0564 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_EMP_JOBCD')]
dfgsdr0565 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_EMPLOYEE')]
dfgsdr0566 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_EMPLOYEE_JIC_20170206')]
dfgsdr0567 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GP_ABS_EVENT')]
dfgsdr0568 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GP_ABS_REASON')]
dfgsdr0569 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GP_ABS_REASON2')]
dfgsdr0570 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_CERT')]
dfgsdr0571 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_CERT_DATA')]
dfgsdr0572 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_CERT_DISCREPANCY')]
dfgsdr0573 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_COURSE')]
dfgsdr0574 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_COURSE_CERT')]
dfgsdr0575 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_TNL_COURSE_SLO')]
dfgsdr0576 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_TNL_COURSES')]
dfgsdr0577 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_TNL_PRFL_TGT')]
dfgsdr0578 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_JOBCD')]
dfgsdr0579 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PSD_ACTIVITY')]
dfgsdr0580 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'psd_activity_lastupdate')]
dfgsdr0581 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PSD_APRN_LAST')]
dfgsdr0582 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PSD_USERS')]
dfgsdr0583 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'REGISTER')]
dfgsdr0584 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'REGISTERSUMMARY')]
dfgsdr0585 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'REGSUM')]
dfgsdr0586 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'REGSUM_HISTORY')]
dfgsdr0587 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_A504')]
dfgsdr0588 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AATC')]
dfgsdr0589 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AATC_ROT')]
dfgsdr0590 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AATD')]
dfgsdr0591 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_aatd_TSTAGING')]
dfgsdr0592 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AATO_ROT')]
dfgsdr0593 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AATP')]
dfgsdr0594 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_aatp_TSTAGING')]
dfgsdr0595 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AATT')]
dfgsdr0596 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ABSENCE_CODES')]
dfgsdr0597 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACAM')]
dfgsdr0598 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACHS')]
dfgsdr0599 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACHS_ES')]
dfgsdr0600 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACHS_MS')]
dfgsdr0601 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACHS_MSES')]
dfgsdr0602 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACHS_SDR')]
dfgsdr0603 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACHS9203768')]
dfgsdr0604 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACLH')]
dfgsdr0605 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACLS')]
dfgsdr0606 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACLS_NEXT')]
dfgsdr0607 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_acls_TSTAGING')]
dfgsdr0608 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACNF')]
dfgsdr0609 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACNR')]
dfgsdr0610 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS')]
dfgsdr0611 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS_FTE')]
dfgsdr0612 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS_FTE2')]
dfgsdr0613 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS_HS')]
dfgsdr0614 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS_KS')]
dfgsdr0615 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS_NEXT')]
dfgsdr0616 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS_RAW')]
dfgsdr0617 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS2012')]
dfgsdr0618 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADDITIONAL_TEACHER')]
dfgsdr0619 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADIS')]
dfgsdr0620 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADIS_C')]
dfgsdr0621 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADIS_KS')]
dfgsdr0622 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADPO')]
dfgsdr0623 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADPO_C')]
dfgsdr0624 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADPS')]
dfgsdr0625 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADST')]
dfgsdr0626 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADST_ALL')]
dfgsdr0627 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AELT')]
dfgsdr0628 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AELT_JUST_DATES')]
dfgsdr0629 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AEMG')]
dfgsdr0630 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AEMG_NEXT')]
dfgsdr0631 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AENR')]
dfgsdr0632 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AENR_C')]
dfgsdr0633 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AENR_KS')]
dfgsdr0634 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AENR_NEXT')]
dfgsdr0635 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AENR_NON_ADA_ADM')]
dfgsdr0636 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AENR_SUMMER')]
dfgsdr0637 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AENR2')]
dfgsdr0638 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AFEE')]
dfgsdr0639 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AFID')]
dfgsdr0640 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AGRD')]
dfgsdr0641 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AGRL')]
dfgsdr0642 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AGSU')]
dfgsdr0643 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AHLT')]
dfgsdr0644 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ALKR')]
dfgsdr0645 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ALRT')]
dfgsdr0646 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AMST')]
dfgsdr0647 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AMST_NEXT')]
dfgsdr0648 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AMST_SECT_STF_HIS')]
dfgsdr0649 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AONL')]
dfgsdr0650 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_APGD')]
dfgsdr0651 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_APGL')]
dfgsdr0652 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_APGM')]
dfgsdr0653 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_APRN')]
dfgsdr0654 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_APRN_LAST')]
dfgsdr0655 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'sasi_aprn_sy1718')]
dfgsdr0656 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'sasi_aprn_sy1819')]
dfgsdr0657 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'sasi_aprn_sy1920')]
dfgsdr0658 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'sasi_aprn_sydavid')]
dfgsdr0659 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_APRN2012')]
dfgsdr0660 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASCH')]
dfgsdr0661 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASGR')]
dfgsdr0662 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTI')]
dfgsdr0663 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU')]
dfgsdr0664 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_DEMOG')]
dfgsdr0665 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_DIPLOMA_SEALS')]
dfgsdr0666 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_EMAIL')]
dfgsdr0667 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_GOSA_AUDIT')]
dfgsdr0668 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_MIN')]
dfgsdr0669 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_NEXT')]
dfgsdr0670 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_NON_ADA_ADM')]
dfgsdr0671 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_SDR_2020')]
dfgsdr0672 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_TEMP')]
dfgsdr0673 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTV')]
dfgsdr0674 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTV_BP')]
dfgsdr0675 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTV_NEXT')]
dfgsdr0676 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATBL')]
dfgsdr0677 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'sasi_atbl_BADREL')]
dfgsdr0678 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATBL_KS')]
dfgsdr0679 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATCH')]
dfgsdr0680 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATCH_NEXT')]
dfgsdr0681 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_atch_TSTAGING')]
dfgsdr0682 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATES')]
dfgsdr0683 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATPA')]
dfgsdr0684 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATRM')]
dfgsdr0685 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATRM_NEXT')]
dfgsdr0686 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATRM2016')]
dfgsdr0687 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATRM4')]
dfgsdr0688 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATRMPORT')]
dfgsdr0689 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AUFS')]
dfgsdr0690 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_COUNTRY_OF_BIRTH')]
dfgsdr0691 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_DISCP_RULES')]
dfgsdr0692 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_DISCP_RULES_HIST')]
dfgsdr0693 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_DISCP_RULES051219')]
dfgsdr0694 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_DISPCODES')]
dfgsdr0695 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_DISPCODES_HIST')]
dfgsdr0696 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_DISPCODES051219')]
dfgsdr0697 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ELL_PARENT_CONF')]
dfgsdr0698 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ELL_WAIVER')]
dfgsdr0699 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_FILE_HISTORY')]
dfgsdr0700 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_GAT_HIS')]
dfgsdr0701 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_LOAD_control')]
dfgsdr0702 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_PARAPRO')]
dfgsdr0703 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_SMST')]
dfgsdr0704 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UABN')]
dfgsdr0705 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UATR')]
dfgsdr0706 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UATR_NEXT')]
dfgsdr0707 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_uatr_TSTAGING')]
dfgsdr0708 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UCES')]
dfgsdr0709 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UCMS')]
dfgsdr0710 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UFLP')]
dfgsdr0711 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UGFT')]
dfgsdr0712 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_Upload_Count_Difference')]
dfgsdr0713 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UPLOAD_HISTORY')]
dfgsdr0714 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UPSA')]
dfgsdr0715 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UPSR')]
dfgsdr0716 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UTL1')]
dfgsdr0717 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SCHEDULES_MS_SAVE')]
dfgsdr0718 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SCHOOL_CLUSTER')]
dfgsdr0719 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SCHOOL_ETS_CODES')]
dfgsdr0720 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SCP')]
dfgsdr0721 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_DSCP_ACTIONS')]
dfgsdr0722 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_DSCP_INCDTS')]
dfgsdr0723 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_ENR')]
dfgsdr0724 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_ERRORS')]
dfgsdr0725 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_IEP_SPED')]
dfgsdr0726 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_IEP_SPED2')]
dfgsdr0727 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SCH_EDM')]
dfgsdr0728 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SCH_TITLE1')]
dfgsdr0729 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SCH_TITLE1_CHARLENE')]
dfgsdr0730 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SCHOOL_B')]
dfgsdr0731 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SCHOOL_N')]
dfgsdr0732 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SCHOOL_NCLB')]
dfgsdr0733 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_C')]
dfgsdr0734 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_C_HOST')]
dfgsdr0735 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_D')]
dfgsdr0736 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_D_HOST')]
dfgsdr0737 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_D_T')]
dfgsdr0738 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_E')]
dfgsdr0739 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_E_HOST')]
dfgsdr0740 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_F')]
dfgsdr0741 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_F_HOST')]
dfgsdr0742 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_G')]
dfgsdr0743 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_G_HOST')]
dfgsdr0744 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_G_OLD')]
dfgsdr0745 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_H')]
dfgsdr0746 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_H_HOST')]
dfgsdr0747 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_K')]
dfgsdr0748 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_K_KS')]
dfgsdr0749 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_K2')]
dfgsdr0750 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_TITLE1')]
dfgsdr0751 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SYS_J')]
dfgsdr0752 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SYS_J20150613')]
dfgsdr0753 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRC_HIST')]
dfgsdr0754 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRCTMP')]
dfgsdr0755 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRD_HIST')]
dfgsdr0756 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRD2014')]
dfgsdr0757 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRE_HIST')]
dfgsdr0758 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRF_HIST')]
dfgsdr0759 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRF_TMP')]
dfgsdr0760 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRG_HIST')]
dfgsdr0761 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRK_HIST')]
dfgsdr0762 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRSTUFZ')]
dfgsdr0763 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRSTUK_TMP')]
dfgsdr0764 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SES')]
dfgsdr0765 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SLDS_Teachers')]
dfgsdr0766 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SPED_EXIT')]
dfgsdr0767 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SPED_SCORE_CARD')]
dfgsdr0768 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SPED_SCORE_REP')]
dfgsdr0769 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SPED_SCORE_SUM')]
dfgsdr0770 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SPED_TCH_SCHED')]
dfgsdr0771 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SRO_RULES')]
dfgsdr0772 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_ACTIVITY')]
dfgsdr0773 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_ASSIGNMENTS')]
dfgsdr0774 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_CASES')]
dfgsdr0775 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ssw_cases_bak_20171219_before_code_update')]
dfgsdr0776 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_CONTACT_REASONS')]
dfgsdr0777 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_CONTACT_TYPES')]
dfgsdr0778 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_DOE_CASES')]
dfgsdr0779 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_DOE_REFERRALS')]
dfgsdr0780 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_DOE_SERVICES')]
dfgsdr0781 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_LOOKUP_CODES')]
dfgsdr0782 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_MEETINGS')]
dfgsdr0783 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_REFERRALS')]
dfgsdr0784 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_STUDENTS')]
dfgsdr0785 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'string_translation')]
dfgsdr0786 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STU_FAY')]
dfgsdr0787 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STU_HOPE_GRANT')]
dfgsdr0788 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STU_ZONED_SCH')]
dfgsdr0789 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUD_HOPE_GRANT')]
dfgsdr0790 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUDENT_DISTRICT')]
dfgsdr0791 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUDENT_FTEID')]
dfgsdr0792 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUDENT_FTEID20200813')]
dfgsdr0793 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUDENT_PROFILES')]
dfgsdr0794 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUDENT_SCHEDULE')]
dfgsdr0795 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUDENT_SCHOOLS')]
dfgsdr0796 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUHEADR')]
dfgsdr0797 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'TEACHER_LEAVE')]
dfgsdr0798 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'TEACHER_SCHEDULE')]
dfgsdr0799 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'TEMP_DOE_SPED_NOPRIMARYAREA')]
dfgsdr0800 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'TIME_STAMP')]
dfgsdr0801 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'TITLE1_SWP')]
dfgsdr0802 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'TITLE1_TAS')]
dfgsdr0803 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'USCO_CODES')]
dfgsdr0804 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'XPRT_STUDENTS_NOSHOW')]
dfgsdr0805 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Class')]
dfgsdr0806 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Class_Backup_20170915')]
dfgsdr0807 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Grade')]
dfgsdr0808 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Grade_Backup_20170915')]
dfgsdr0809 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Note')]
dfgsdr0810 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Score')]
dfgsdr0811 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'score_backup')]
dfgsdr0812 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Score_Backup_20170915')]
dfgsdr0813 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Task')]
dfgsdr0814 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'task_backup')]
dfgsdr0815 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Task_Backup_20170915')]
dfgsdr0816 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'guest') & (df['TableName'] == 'FTE_GTID_Updates')]
dfgsdr0817 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'guest') & (df['TableName'] == 'PermnumList')]
dfgsdr0818 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'CALENDAR')]
dfgsdr0819 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'G_GTID')]
dfgsdr0820 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AATC')]
dfgsdr0821 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AATC_ROT')]
dfgsdr0822 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AATD')]
dfgsdr0823 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AATO_ROT')]
dfgsdr0824 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AATP')]
dfgsdr0825 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AATT')]
dfgsdr0826 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_ACLH')]
dfgsdr0827 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_ACLS')]
dfgsdr0828 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_ACRS')]
dfgsdr0829 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_ACRS_RAW')]
dfgsdr0830 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AENR')]
dfgsdr0831 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AMST')]
dfgsdr0832 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_ASTU')]
dfgsdr0833 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_ATCH')]
dfgsdr0834 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_ATRM')]
dfgsdr0835 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_SMST')]
dfgsdr0836 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'STUDENT_FTEID')]
dfgsdr0837 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'TEACHER_LEAVE')]
dfgsdr0838 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'TEACHER_LEAVE2')]
dfgsdr0839 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'Teachers To Validate')]
dfgsdr0840 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'CALENDAR')]
dfgsdr0841 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'G_GTID')]
dfgsdr0842 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_AATC')]
dfgsdr0843 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_AATC_ROT')]
dfgsdr0844 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_AATO_ROT')]
dfgsdr0845 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_ACLH')]
dfgsdr0846 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_ACLS')]
dfgsdr0847 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_ACRS')]
dfgsdr0848 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_ACRS_RAW')]
dfgsdr0849 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_AENR')]
dfgsdr0850 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_AMST')]
dfgsdr0851 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_ASTU')]
dfgsdr0852 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_ATCH')]
dfgsdr0853 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_ATRM')]
dfgsdr0854 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_SMST')]
dfgsdr0855 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'STUDENT_FTEID')]
dfgsdr0856 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'StudentClass')]
dfgsdr0857 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'StudentCourseProfile')]
dfgsdr0858 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'TEACHER_LEAVE')]
dfgsdr0859 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'TEACHER_LEAVE2')]
dfgsdr0860 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'TeacherClass')]
dfgsdr0861 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'Teachers To Validate')]
dfgsdr0862 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'Teachers To Validate20160211')]
dfgsdr0863 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'stage') & (df['TableName'] == 'crisnet_arrests')]
dfgsdr0864 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'stage') & (df['TableName'] == 'psd_input_file')]
dfgsdr0865 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'StudentProfile') & (df['TableName'] == 'FACT_AttendanceByType')]
dfgsdr0866 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'TCAccommodation') & (df['TableName'] == 'ELPP_Notes')]
dfgsdr0867 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'TCAccommodation') & (df['TableName'] == 'IEPAccommodations')]
dfgsdr0868 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'TCAccommodation') & (df['TableName'] == 'S504Accommodations')]
dfgsdr0869 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'TCAccommodation') & (df['TableName'] == 'TPP_Notes')]
dfgsdr0870 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'Attendance')]
dfgsdr0871 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'Courses')]
dfgsdr0872 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'CumGPA')]
dfgsdr0873 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'EOC')]
dfgsdr0874 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'GPA')]
dfgsdr0875 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'School')]
dfgsdr0876 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'SchoolsAttended')]
dfgsdr0877 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'Semesters')]
dfgsdr0878 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'SpecialStudents')]
dfgsdr0879 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'Student')]
dfgsdr0880 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'SUMLA')]
dfgsdr0881 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'TestAssesments')]

# %%
d = dfgsdr0001[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0001, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 54417         GSDR     BUFORD  SDR_STU_C

# %%
d = dfgsdr0002[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0002, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 54699         GSDR     BUFORD  SDR_STU_D

# %%
d = dfgsdr0003[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0003, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 55075         GSDR     BUFORD  SDR_STU_E

# %%
d = dfgsdr0004[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0004, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 55357         GSDR     BUFORD  SDR_STU_F

# %%
d = dfgsdr0005[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0005, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 55639         GSDR     BUFORD  SDR_STU_G

# %%
d = dfgsdr0006[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0006, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 56015         GSDR     BUFORD  SDR_STU_H

# %%
d = dfgsdr0007[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0007, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 56297         GSDR     BUFORD  SDR_STU_K

# %%
d = dfgsdr0008[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0008, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                       TableName
# 72054         GSDR        d2l  d2l_reporting_AllSchools_Usage

# %%
d = dfgsdr0009[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0009, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                       TableName
# 10441         GSDR        d2l  D2L_Reporting_D2LSessionExport

# %%
d = dfgsdr0010[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0010, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                       TableName
# 72148         GSDR        d2l  d2l_reporting_OrgRoleCrosswalk

# %%
d = dfgsdr0011[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0011, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                       TableName
# 72242         GSDR        d2l  d2l_reporting_SchoolPopulation

# %%
d = dfgsdr0012[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0012, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                          TableName
# 72336         GSDR        d2l  d2l_reporting_SchoolPopulationDtl

# %%
d = dfgsdr0013[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0013, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 72430         GSDR        d2l  d2l_reporting_SessionActivity

# %%
d = dfgsdr0014[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0014, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 71960         GSDR        d2l  d2l_Reporting_TeacherSchedule

# %%
d = dfgsdr0015[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0015, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 72524         GSDR        d2l  d2l_reporting_Usage

# %%
d = dfgsdr0016[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0016, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 72618         GSDR        d2l  d2l_reporting_UsageDtl

# %%
d = dfgsdr0017[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0017, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#   DatabaseName SchemaName  TableName
# 0         GSDR        dbo  667errors

# %%
d = dfgsdr0018[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0018, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#    DatabaseName SchemaName          TableName
# 94         GSDR        dbo  AAA_Cohort_Report

# %%
d = dfgsdr0019[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0019, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName         TableName
# 1989         GSDR        dbo  AcademicContract

# %%
d = dfgsdr0020[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0020, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName               TableName
# 2083         GSDR        dbo  AcademicContractImport

# %%
d = dfgsdr0021[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0021, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                     TableName
# 2177         GSDR        dbo  AcademicContractImportErrors

# %%
d = dfgsdr0022[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0022, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                     TableName
# 2271         GSDR        dbo  AcademicContractIntervention

# %%
d = dfgsdr0023[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0023, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName       TableName
# 287         GSDR        dbo  ACCESS_Targets

# %%
d = dfgsdr0024[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0024, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName TableName
# 475         GSDR        dbo  ACHSFILE

# %%
d = dfgsdr0025[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0025, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName TableName
# 569         GSDR        dbo   ACRSTMP

# %%
d = dfgsdr0026[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0026, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                    TableName
# 2365         GSDR        dbo  ActiveEnrollmentReportCache

# %%
d = dfgsdr0027[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0027, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                              TableName
# 2459         GSDR        dbo  ActiveEnrollmentReportCacheAllSchools

# %%
d = dfgsdr0028[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0028, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName          TableName
# 2553         GSDR        dbo  AdditionalMinutes

# %%
d = dfgsdr0029[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0029, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName    TableName
# 1321         GSDR        dbo  APGM_KS2017

# %%
d = dfgsdr0030[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0030, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName     TableName
# 1561         GSDR        dbo  ASTU_CHANGES

# %%
d = dfgsdr0031[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0031, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName    TableName
# 1749         GSDR        dbo  ASTU_KS2017

# %%
d = dfgsdr0032[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0032, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 71678         GSDR        dbo  astv1819

# %%
d = dfgsdr0033[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0033, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName          TableName
# 3493         GSDR        dbo  AttendanceSummary

# %%
d = dfgsdr0034[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0034, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName              TableName
# 3587         GSDR        dbo  BiLiteracyReport 2019

# %%
d = dfgsdr0035[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0035, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName  TableName
# 3681         GSDR        dbo  BlockFile

# %%
d = dfgsdr0036[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0036, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName         TableName
# 3869         GSDR        dbo  BlockFile_BPtest

# %%
d = dfgsdr0037[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0037, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 3775         GSDR        dbo  BlockFileNewMapNet

# %%
d = dfgsdr0038[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0038, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                  TableName
# 3963         GSDR        dbo  BusPlanner_AddressListing

# %%
d = dfgsdr0039[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0039, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName          TableName
# 4433         GSDR        dbo  CALENDAR_CHARLENE

# %%
d = dfgsdr0040[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0040, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 4527         GSDR        dbo  CALENDAR_CHARLENE2

# %%
d = dfgsdr0041[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0041, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 8266         GSDR        dbo  Calendar_Charlene3

# %%
d = dfgsdr0042[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0042, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 8360         GSDR        dbo  Calendar_Charlene4

# %%
d = dfgsdr0043[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0043, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 71772         GSDR        dbo  cert_codes

# %%
d = dfgsdr0044[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0044, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 5373         GSDR        dbo    COB_KS

# %%
d = dfgsdr0045[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0045, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 8843         GSDR        dbo  Cohort_Withdrawals

# %%
d = dfgsdr0046[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0046, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 8642         GSDR        dbo  Cohort20170201

# %%
d = dfgsdr0047[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0047, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                TableName
# 8736         GSDR        dbo  CohortAdditionalCourses

# %%
d = dfgsdr0048[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0048, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                    TableName
# 8830         GSDR        dbo  CohortAdditionalCoursesFull

# %%
d = dfgsdr0049[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0049, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 8937         GSDR        dbo   Cohorts

# %%
d = dfgsdr0050[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0050, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 9031         GSDR        dbo  Cohorts2

# %%
d = dfgsdr0051[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0051, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName  TableName
# 5561         GSDR        dbo  COUNTRIES

# %%
d = dfgsdr0052[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0052, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 9501         GSDR        dbo  Course_No_EOCT

# %%
d = dfgsdr0053[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0053, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName         TableName
# 9219         GSDR        dbo  CourseConversion

# %%
d = dfgsdr0054[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0054, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 9313         GSDR        dbo  CourseEvalType

# %%
d = dfgsdr0055[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0055, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName      TableName
# 9407         GSDR        dbo  CourseMerged$

# %%
d = dfgsdr0056[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0056, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 6219         GSDR        dbo  CPI March 2017

# %%
d = dfgsdr0057[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0057, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 6689         GSDR        dbo  CPI_TEMP

# %%
d = dfgsdr0058[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0058, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName              TableName
# 9689         GSDR        dbo  Crosswalk SPG Courses

# %%
d = dfgsdr0059[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0059, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 8005         GSDR        dbo   CSVFILE

# %%
d = dfgsdr0060[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0060, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 10253         GSDR        dbo  D2L_NON_TEACHING_STAFF

# %%
d = dfgsdr0061[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0061, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName            TableName
# 9877         GSDR        dbo  D2LPortalUtizReport

# %%
d = dfgsdr0062[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0062, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 12133         GSDR        dbo  DavidDoesNotKnow

# %%
d = dfgsdr0063[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0063, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 72712         GSDR        dbo  dbIEPReview

# %%
d = dfgsdr0064[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0064, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 72745         GSDR        dbo  dbIEPTransfer

# %%
d = dfgsdr0065[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0065, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 72778         GSDR        dbo  dbTransfer

# %%
d = dfgsdr0066[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0066, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 73187         GSDR        dbo  deleteSections

# %%
d = dfgsdr0067[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0067, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 12227         GSDR        dbo  DestinyOutstandingFees

# %%
d = dfgsdr0068[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0068, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 11099         GSDR        dbo  DOE_Courses

# %%
d = dfgsdr0069[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0069, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 11193         GSDR        dbo  DOE_EL_HISTORY

# %%
d = dfgsdr0070[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0070, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 11287         GSDR        dbo  DOE_EL_HISTORY_temp

# %%
d = dfgsdr0071[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0071, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 11381         GSDR        dbo  DOE_SPED_HISTORY

# %%
d = dfgsdr0072[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0072, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 11945         GSDR        dbo  DSCP_TEMP

# %%
d = dfgsdr0073[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0073, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 12321         GSDR        dbo  E5098_Prim_Area20200324

# %%
d = dfgsdr0074[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0074, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 13449         GSDR        dbo  EL_FORM_1020

# %%
d = dfgsdr0075[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0075, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 13468         GSDR        dbo  EL_Monitor_data

# %%
d = dfgsdr0076[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0076, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 16114         GSDR        dbo  Ellevation_Demographics

# %%
d = dfgsdr0077[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0077, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 13261         GSDR        dbo  ELPP_schedules_tb

# %%
d = dfgsdr0078[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0078, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 13355         GSDR        dbo  ELPP_test_scores_tb

# %%
d = dfgsdr0079[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0079, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 16208         GSDR        dbo  EmployeeEmailIDSource

# %%
d = dfgsdr0080[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0080, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 13938         GSDR        dbo  EOC_PRELIM_2019

# %%
d = dfgsdr0081[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0081, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 14032         GSDR        dbo  EOC_SCORES

# %%
d = dfgsdr0082[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0082, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 13750         GSDR        dbo  EOCT_KAUSHAL

# %%
d = dfgsdr0083[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0083, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 13844         GSDR        dbo  EOCT_Unmatched

# %%
d = dfgsdr0084[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0084, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 14126         GSDR        dbo  EOG_PRELIM_2017

# %%
d = dfgsdr0085[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0085, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 14220         GSDR        dbo  EOG_PRELIM_2018

# %%
d = dfgsdr0086[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0086, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 14314         GSDR        dbo  EOG_PRELIM_2019

# %%
d = dfgsdr0087[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0087, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 14408         GSDR        dbo  EOPA Assessments

# %%
d = dfgsdr0088[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0088, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 14502         GSDR        dbo  EOPA Exam Taken

# %%
d = dfgsdr0089[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0089, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 14596         GSDR        dbo  EOPA Pathways

# %%
d = dfgsdr0090[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0090, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 14867         GSDR        dbo  EOPA_Clusters

# %%
d = dfgsdr0091[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0091, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 14961         GSDR        dbo  EOPA_Courses

# %%
d = dfgsdr0092[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0092, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 15055         GSDR        dbo  EOPA_Pathways

# %%
d = dfgsdr0093[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0093, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 14679         GSDR        dbo  EOPA2016

# %%
d = dfgsdr0094[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0094, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 14773         GSDR        dbo  EOPA2017

# %%
d = dfgsdr0095[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0095, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 74879         GSDR        dbo  error_import

# %%
d = dfgsdr0096[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0096, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 16304         GSDR        dbo    Errors

# %%
d = dfgsdr0097[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0097, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 15456         GSDR        dbo  ESOL_COURSES_JUNE15

# %%
d = dfgsdr0098[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0098, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 15174         GSDR        dbo   ESOL115

# %%
d = dfgsdr0099[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0099, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 15268         GSDR        dbo  ESOL115_FTE

# %%
d = dfgsdr0100[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0100, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 73281         GSDR        dbo  eTextBook_SchContact

# %%
d = dfgsdr0101[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0101, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 73375         GSDR        dbo  eTextBook_SchContact_BAK

# %%
d = dfgsdr0102[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0102, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 73469         GSDR        dbo  eTextBook_SchContact_temp

# %%
d = dfgsdr0103[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0103, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 75161         GSDR        dbo       fay

# %%
d = dfgsdr0104[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0104, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 75255         GSDR        dbo      fay2

# %%
d = dfgsdr0105[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0105, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 20361         GSDR        dbo  Feed_Portal_ITAcademyStudents

# %%
d = dfgsdr0106[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0106, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 20455         GSDR        dbo  Feed_Portal_SchoolNetStudents

# %%
d = dfgsdr0107[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0107, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 20643         GSDR        dbo  FineTypes

# %%
d = dfgsdr0108[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0108, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 16680         GSDR        dbo  FLATFILE

# %%
d = dfgsdr0109[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0109, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 16695         GSDR        dbo  FLATFILE_JCS

# %%
d = dfgsdr0110[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0110, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                       TableName
# 16789         GSDR        dbo  FLP_Student_Attendance_List_tb

# %%
d = dfgsdr0111[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0111, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 19327         GSDR        dbo  FTE_ERRORS

# %%
d = dfgsdr0112[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0112, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 19609         GSDR        dbo  FTE_IVY_PREP

# %%
d = dfgsdr0113[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0113, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 19985         GSDR        dbo  FTE_REPORT_SCH

# %%
d = dfgsdr0114[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0114, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 17165         GSDR        dbo   FTE2019

# %%
d = dfgsdr0115[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0115, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 17823         GSDR        dbo  FTENUMB UPDATE 20131021

# %%
d = dfgsdr0116[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0116, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 17917         GSDR        dbo  FTENUMB UPDATE 20131024

# %%
d = dfgsdr0117[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0117, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 20737         GSDR        dbo  GA411Data

# %%
d = dfgsdr0118[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0118, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 20831         GSDR        dbo  GCPS_MA_AKS

# %%
d = dfgsdr0119[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0119, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 21677         GSDR        dbo  GSDR_DATA_LOADED

# %%
d = dfgsdr0120[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0120, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 21771         GSDR        dbo  GTID_IMPORTED

# %%
d = dfgsdr0121[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0121, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 24591         GSDR        dbo  HiQ_Courses_20140122

# %%
d = dfgsdr0122[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0122, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 25061         GSDR        dbo  IEP_Accomondation_View_NewWay

# %%
d = dfgsdr0123[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0123, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 75349         GSDR        dbo  iep_active_elig_view

# %%
d = dfgsdr0124[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0124, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 75443         GSDR        dbo  iep_active_plan_view

# %%
d = dfgsdr0125[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0125, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 75537         GSDR        dbo  iep_bip_intervention_view

# %%
d = dfgsdr0126[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0126, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 25155         GSDR        dbo  IEP_District_Users

# %%
d = dfgsdr0127[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0127, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 75631         GSDR        dbo  iep_goals_view

# %%
d = dfgsdr0128[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0128, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 75725         GSDR        dbo  iep_mods_ints_strengths_view

# %%
d = dfgsdr0129[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0129, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 75819         GSDR        dbo  iep_objectives_details

# %%
d = dfgsdr0130[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0130, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 75913         GSDR        dbo  iep_objectives_view

# %%
d = dfgsdr0131[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0131, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 76007         GSDR        dbo  iep_plan_list_view

# %%
d = dfgsdr0132[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0132, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 76101         GSDR        dbo  iep_student_casemanager_view

# %%
d = dfgsdr0133[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0133, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 76195         GSDR        dbo  iep_student_view

# %%
d = dfgsdr0134[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0134, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 24967         GSDR        dbo  IEPSERVICE

# %%
d = dfgsdr0135[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0135, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 26377         GSDR        dbo  ImportFile

# %%
d = dfgsdr0136[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0136, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 26189         GSDR        dbo  IOWA_CoGAT_Report

# %%
d = dfgsdr0137[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0137, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 26471         GSDR        dbo  ItemsCheckedOut

# %%
d = dfgsdr0138[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0138, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 26565         GSDR        dbo  January11pull

# %%
d = dfgsdr0139[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0139, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 76289         GSDR        dbo    kstemp

# %%
d = dfgsdr0140[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0140, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 76383         GSDR        dbo   kstemp2

# %%
d = dfgsdr0141[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0141, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 26643         GSDR        dbo  LA_AVG_Temp

# %%
d = dfgsdr0142[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0142, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 26737         GSDR        dbo       LDS

# %%
d = dfgsdr0143[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0143, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 27207         GSDR        dbo  LocalCourseMerged

# %%
d = dfgsdr0144[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0144, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 27395         GSDR        dbo  MA_AVG_Temp

# %%
d = dfgsdr0145[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0145, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 27771         GSDR        dbo   Maxwell

# %%
d = dfgsdr0146[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0146, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 27923         GSDR        dbo  Mentees_LOAD_ ALL_Details

# %%
d = dfgsdr0147[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0147, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                           TableName
# 28017         GSDR        dbo  Mentees_LOAD_ ALL_Details_20210112

# %%
d = dfgsdr0148[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0148, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 28095         GSDR        dbo  Mentees_Names_ALL

# %%
d = dfgsdr0149[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0149, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                         TableName
# 27583         GSDR        dbo  MYSTUDENT_DATA_RETRIEVAL_HISTORY

# %%
d = dfgsdr0150[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0150, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                        TableName
# 27677         GSDR        dbo  MYSTUDENT_DATA_RETRIEVAL_STATUS

# %%
d = dfgsdr0151[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0151, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                             TableName
# 28189         GSDR        dbo  NEW_MYSTUDENT_DATA_RETRIEVAL_HISTORY

# %%
d = dfgsdr0152[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0152, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                            TableName
# 28283         GSDR        dbo  NEW_MYSTUDENT_DATA_RETRIEVAL_STATUS

# %%
d = dfgsdr0153[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0153, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 29035         GSDR        dbo  Organization_Chart

# %%
d = dfgsdr0154[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0154, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 76477         GSDR        dbo  pa_update2020

# %%
d = dfgsdr0155[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0155, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 29505         GSDR        dbo  PATHWAY_COURSE

# %%
d = dfgsdr0156[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0156, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 33641         GSDR        dbo  Patrons_For_Datamove

# %%
d = dfgsdr0157[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0157, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 33735         GSDR        dbo  PermnumFromRiderByRoute

# %%
d = dfgsdr0158[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0158, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 29599         GSDR        dbo  PHLOTE_AUG

# %%
d = dfgsdr0159[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0159, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 29693         GSDR        dbo  PHLOTE_JUN

# %%
d = dfgsdr0160[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0160, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 29787         GSDR        dbo  PIVOTDATA

# %%
d = dfgsdr0161[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0161, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 77340         GSDR        dbo  portal_sec_aro_group_mbr_psd

# %%
d = dfgsdr0162[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0162, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 34675         GSDR        dbo  PreK_Entrance

# %%
d = dfgsdr0163[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0163, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 34769         GSDR        dbo  PreK_Exit

# %%
d = dfgsdr0164[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0164, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 34863         GSDR        dbo  PreK_Not_Met

# %%
d = dfgsdr0165[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0165, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 31667         GSDR        dbo  PRIMARY AREA UPDATE FTE20161

# %%
d = dfgsdr0166[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0166, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 77810         GSDR        dbo  private_school_2014final

# %%
d = dfgsdr0167[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0167, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 77904         GSDR        dbo  private_schools_2013

# %%
d = dfgsdr0168[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0168, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 77998         GSDR        dbo  private_schools_2014

# %%
d = dfgsdr0169[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0169, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 78092         GSDR        dbo  private_schools_2015

# %%
d = dfgsdr0170[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0170, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 31761         GSDR        dbo  PSC_DATA

# %%
d = dfgsdr0171[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0171, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 78186         GSDR        dbo  psd_activity_2019

# %%
d = dfgsdr0172[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0172, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 78263         GSDR        dbo  psd_activity_2020

# %%
d = dfgsdr0173[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0173, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 78468         GSDR        dbo  psd_users_2019

# %%
d = dfgsdr0174[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0174, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 78562         GSDR        dbo  psd_users_2020

# %%
d = dfgsdr0175[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0175, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 78579         GSDR        dbo  psd_users_bak

# %%
d = dfgsdr0176[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0176, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 34957         GSDR        dbo  Pseudo FTE Nums

# %%
d = dfgsdr0177[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0177, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 35051         GSDR        dbo    Query2

# %%
d = dfgsdr0178[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0178, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 35521         GSDR        dbo  RIDER_BY_ROUTE

# %%
d = dfgsdr0179[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0179, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 35615         GSDR        dbo  RIDER_BY_ROUTE_SNAPSHOT

# %%
d = dfgsdr0180[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0180, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 35897         GSDR        dbo  Rising_6thGrd_Report

# %%
d = dfgsdr0181[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0181, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 35991         GSDR        dbo  Rising_7thGrd_Report

# %%
d = dfgsdr0182[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0182, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 36085         GSDR        dbo  Rising_7thGrd_Report_Bkup

# %%
d = dfgsdr0183[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0183, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 36179         GSDR        dbo  Rising_8thGrd_Report

# %%
d = dfgsdr0184[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0184, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 36273         GSDR        dbo  Rising_8thGrd_Report_Bkup

# %%
d = dfgsdr0185[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0185, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 36367         GSDR        dbo  Rising_9thGrd_Report

# %%
d = dfgsdr0186[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0186, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 38414         GSDR        dbo  SASI_ACHS441

# %%
d = dfgsdr0187[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0187, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 45464         GSDR        dbo  SASI_ASTU

# %%
d = dfgsdr0188[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0188, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 51127         GSDR        dbo  SAT_REPORT_SESSION_1_AVG

# %%
d = dfgsdr0189[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0189, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 51221         GSDR        dbo  SAT_REPORT_SESSION_1_ELIGIBLE

# %%
d = dfgsdr0190[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0190, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 51315         GSDR        dbo  SAT_REPORT_SESSION_2_AVG

# %%
d = dfgsdr0191[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0191, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 51409         GSDR        dbo  SAT_REPORT_SESSION_2_ELIGIBLE

# %%
d = dfgsdr0192[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0192, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 51503         GSDR        dbo  SAT_REPORT_SESSION_3_AVG

# %%
d = dfgsdr0193[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0193, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 51597         GSDR        dbo  SAT_REPORT_SESSION_3_ELIGIBLE

# %%
d = dfgsdr0194[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0194, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 52161         GSDR        dbo  SC_ERRORS

# %%
d = dfgsdr0195[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0195, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 51785         GSDR        dbo  SCHOOLFILE

# %%
d = dfgsdr0196[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0196, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                           TableName
# 62090         GSDR        dbo  SchoolFoodNutritionDaily_GSDR_test

# %%
d = dfgsdr0197[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0197, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 62184         GSDR        dbo  SchoolReports_Subscribers

# %%
d = dfgsdr0198[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0198, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 62372         GSDR        dbo  Schools_KS

# %%
d = dfgsdr0199[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0199, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 61937         GSDR        dbo  SchPermnumCode

# %%
d = dfgsdr0200[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0100, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 63030         GSDR        dbo  SemesterDates

# %%
d = dfgsdr0201[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0201, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 57049         GSDR        dbo  SFN_Export

# %%
d = dfgsdr0202[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0202, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 79090         GSDR        dbo  sis_current_IEP

# %%
d = dfgsdr0203[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0203, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 79184         GSDR        dbo  sis_error_log

# %%
d = dfgsdr0204[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0204, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 79278         GSDR        dbo  sis_error_log_ref

# %%
d = dfgsdr0205[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0205, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                                 TableName
# 79372         GSDR        dbo  sis_iep_bip_antecedent_intervention_view

# %%
d = dfgsdr0206[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0206, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 79466         GSDR        dbo  sis_iep_bip_behavior_view

# %%
d = dfgsdr0207[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0207, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                                      TableName
# 79560         GSDR        dbo  sis_iep_bip_consequence_intervention_neg_view

# %%
d = dfgsdr0208[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0208, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                                      TableName
# 79654         GSDR        dbo  sis_iep_bip_consequence_intervention_pos_view

# %%
d = dfgsdr0209[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0209, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 79748         GSDR        dbo  sis_iep_bip_demographic_view

# %%
d = dfgsdr0210[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0210, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                          TableName
# 79842         GSDR        dbo  sis_reg_transportation_green_view

# %%
d = dfgsdr0211[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0211, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                        TableName
# 57143         GSDR        dbo  SIS_Testing_Accommodations_View

# %%
d = dfgsdr0212[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0212, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 57331         GSDR        dbo  SLO_Corrections

# %%
d = dfgsdr0213[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0213, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 57425         GSDR        dbo  SNP_20091031

# %%
d = dfgsdr0214[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0214, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 57519         GSDR        dbo  SNP_20131031

# %%
d = dfgsdr0215[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0215, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 57613         GSDR        dbo  SNP_20141031

# %%
d = dfgsdr0216[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0216, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 57707         GSDR        dbo  SNP_20151031

# %%
d = dfgsdr0217[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0217, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 57801         GSDR        dbo  SNP_20161031

# %%
d = dfgsdr0218[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0218, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 57895         GSDR        dbo  SNP_201610312

# %%
d = dfgsdr0219[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0219, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 57989         GSDR        dbo  SNP_20171031

# %%
d = dfgsdr0220[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0220, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 58083         GSDR        dbo  SNP_20181031

# %%
d = dfgsdr0221[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0221, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 58177         GSDR        dbo  SNP_20191031

# %%
d = dfgsdr0222[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0222, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 58271         GSDR        dbo  SNP_20201031

# %%
d = dfgsdr0223[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0223, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 79936         GSDR        dbo  snp_today

# %%
d = dfgsdr0224[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0224, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 63500         GSDR        dbo  Sped_File_Push_data

# %%
d = dfgsdr0225[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0225, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 63218         GSDR        dbo  SpEd_TransGreenListReport

# %%
d = dfgsdr0226[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0226, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 63312         GSDR        dbo  SpEd_TransListReport

# %%
d = dfgsdr0227[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0227, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 58835         GSDR        dbo  SPG Teachers To Validate

# %%
d = dfgsdr0228[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0228, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 58929         GSDR        dbo  SPG Teachers To Validate2

# %%
d = dfgsdr0229[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0229, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 80030         GSDR        dbo  spg_courses_tests

# %%
d = dfgsdr0230[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0230, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 59211         GSDR        dbo  SPG_Export

# %%
d = dfgsdr0231[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0231, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 59023         GSDR        dbo  SPGCases_June20_2014

# %%
d = dfgsdr0232[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0232, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 59117         GSDR        dbo  SPGJUNE30

# %%
d = dfgsdr0233[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0233, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 59399         GSDR        dbo  SR_Errors

# %%
d = dfgsdr0234[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0234, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 63594         GSDR        dbo  StageStudentPictures

# %%
d = dfgsdr0235[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0235, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 64816         GSDR        dbo  StreetTypeAbbreviations

# %%
d = dfgsdr0236[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0236, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 65286         GSDR        dbo  StudentClass

# %%
d = dfgsdr0237[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0237, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 66038         GSDR        dbo  StudentClass_Buford

# %%
d = dfgsdr0238[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0238, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 66132         GSDR        dbo  StudentClass_Buford_SAVE

# %%
d = dfgsdr0239[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0239, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 65380         GSDR        dbo  StudentClass2015

# %%
d = dfgsdr0240[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0240, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 65474         GSDR        dbo  StudentClass2015v2

# %%
d = dfgsdr0241[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0241, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 65568         GSDR        dbo  StudentClass2016

# %%
d = dfgsdr0242[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0242, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 65662         GSDR        dbo  StudentClass2017

# %%
d = dfgsdr0243[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0243, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 65756         GSDR        dbo  StudentClass2018

# %%
d = dfgsdr0244[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0244, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 65850         GSDR        dbo  StudentClass20190601

# %%
d = dfgsdr0245[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0245, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 65944         GSDR        dbo  StudentClassAppend

# %%
d = dfgsdr0246[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0246, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 66508         GSDR        dbo  StudentCourseProfile

# %%
d = dfgsdr0247[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0247, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 66602         GSDR        dbo  StudentCourseProfile2

# %%
d = dfgsdr0248[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0248, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 66696         GSDR        dbo  StudentIDfromSRTV

# %%
d = dfgsdr0249[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0249, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 66790         GSDR        dbo  StudentLogin20120827

# %%
d = dfgsdr0250[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0250, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 66884         GSDR        dbo  StudentLogin20120903

# %%
d = dfgsdr0251[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0251, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 66978         GSDR        dbo  StudentLogins

# %%
d = dfgsdr0252[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0252, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 67072         GSDR        dbo  SummerSchoolSites2017

# %%
d = dfgsdr0253[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0253, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 67166         GSDR        dbo  SummerSchoolSites2018

# %%
d = dfgsdr0254[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0254, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 67260         GSDR        dbo  SummerSchoolSites2019

# %%
d = dfgsdr0255[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0255, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 67354         GSDR        dbo  SummerStudentList

# %%
d = dfgsdr0256[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0256, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 67448         GSDR        dbo  SummerStudentList2017

# %%
d = dfgsdr0257[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0257, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 67542         GSDR        dbo  SummerStudentListTemp

# %%
d = dfgsdr0258[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0258, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 67730         GSDR        dbo  SummerStudentListtemp_backup

# %%
d = dfgsdr0259[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0259, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                   TableName
# 67636         GSDR        dbo  SummerStudentListTemp_Bkup

# %%
d = dfgsdr0260[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0260, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 67918         GSDR        dbo  Synergy_ESOL_Status

# %%
d = dfgsdr0261[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0261, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 80312         GSDR        dbo  sysdtslog90

# %%
d = dfgsdr0262[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0262, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 80406         GSDR        dbo  sysssislog

# %%
d = dfgsdr0263[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0263, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 69798         GSDR        dbo  TeacherClass

# %%
d = dfgsdr0264[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0264, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 69892         GSDR        dbo  TeacherClass2

# %%
d = dfgsdr0265[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0265, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 80594         GSDR        dbo  temp_AD_Data

# %%
d = dfgsdr0266[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0266, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 80782         GSDR        dbo  temp_ad_groups

# %%
d = dfgsdr0267[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0267, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 80876         GSDR        dbo  temp_ad_groups_search

# %%
d = dfgsdr0268[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0268, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 80970         GSDR        dbo  temp_ad_membership

# %%
d = dfgsdr0269[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0269, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 81064         GSDR        dbo  temp_dscp_event_id_rules

# %%
d = dfgsdr0270[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0270, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 81158         GSDR        dbo  temp_groups

# %%
d = dfgsdr0271[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0271, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 70362         GSDR        dbo  Temp_MyTable

# %%
d = dfgsdr0272[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0272, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 80688         GSDR        dbo  temp_SASI_APRN

# %%
d = dfgsdr0273[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0273, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 68670         GSDR        dbo  TEMP_TBL

# %%
d = dfgsdr0274[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0274, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 81252         GSDR        dbo  test_academic_contracts

# %%
d = dfgsdr0275[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0275, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 70550         GSDR        dbo  Timeline 18_19

# %%
d = dfgsdr0276[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0276, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 70644         GSDR        dbo  Title1 Employees

# %%
d = dfgsdr0277[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0277, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 69046         GSDR        dbo  TMP_IEP_EXIT_VIEW

# %%
d = dfgsdr0278[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0278, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 69140         GSDR        dbo  TMP_IEP_SERVICES_SR_VIEW

# %%
d = dfgsdr0279[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0279, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 70738         GSDR        dbo  TranscriptData

# %%
d = dfgsdr0280[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0280, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                   TableName
# 70832         GSDR        dbo  TranscriptData_2020Staging

# %%
d = dfgsdr0281[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0281, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 70926         GSDR        dbo  TranscriptSummary

# %%
d = dfgsdr0282[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0282, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 81346         GSDR        dbo  udtMonths

# %%
d = dfgsdr0283[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0283, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 71020         GSDR        dbo      UPKE

# %%
d = dfgsdr0284[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0284, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 71114         GSDR        dbo      UPKX

# %%
d = dfgsdr0285[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0285, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 71208         GSDR        dbo  USATestPrep_DataFeed

# %%
d = dfgsdr0286[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0286, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 71302         GSDR        dbo  USATestPrep_DataFeed_2018

# %%
d = dfgsdr0287[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0287, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 81440         GSDR        dbo  zoned_temp

# %%
d = dfgsdr0288[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0288, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 24779         GSDR         dx  Households_Import

# %%
d = dfgsdr0289[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0289, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                       TableName
# 24685         GSDR         dx  HouseholdStudentMembers_Import

# %%
d = dfgsdr0290[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0290, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 27301         GSDR         dx  Locker_Import

# %%
d = dfgsdr0291[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0291, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 27829         GSDR         dx  MedIncident_Import

# %%
d = dfgsdr0292[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0292, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 66320         GSDR         dx  StudentContacts_Import

# %%
d = dfgsdr0293[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0293, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 66226         GSDR         dx  StudentContactsParent_Import

# %%
d = dfgsdr0294[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0294, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 29223         GSDR       essa  OverrideStudents

# %%
d = dfgsdr0295[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0295, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 29129         GSDR       essa  OverrideStudentSections

# %%
d = dfgsdr0296[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0296, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 29411         GSDR       essa  OverrideTeachers

# %%
d = dfgsdr0297[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0297, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 29317         GSDR       essa  OverrideTeacherSections

# %%
d = dfgsdr0298[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0298, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                   TableName
# 34205         GSDR       essa  PqAllTeacherQualifications

# %%
d = dfgsdr0299[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0299, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 34299         GSDR       essa  PqNonPqTeacherList

# %%
d = dfgsdr0300[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0300, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 34393         GSDR       essa  PqParentNotifications

# %%
d = dfgsdr0301[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0301, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 34487         GSDR       essa  PqRptAggDistrict

# %%
d = dfgsdr0302[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0302, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 34581         GSDR       essa  PqRptAggSchool

# %%
d = dfgsdr0303[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0303, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 35709         GSDR       essa  ReportActions

# %%
d = dfgsdr0304[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0304, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 35803         GSDR       essa   Reports

# %%
d = dfgsdr0305[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0305, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 63688         GSDR       essa  StateCertifications

# %%
d = dfgsdr0306[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0306, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 63782         GSDR       essa  StateCourseRequirements

# %%
d = dfgsdr0307[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0307, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 63876         GSDR       essa  StgPqPrep

# %%
d = dfgsdr0308[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0308, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 63970         GSDR       essa  StgSchools

# %%
d = dfgsdr0309[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0309, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 64064         GSDR       essa  StgSections

# %%
d = dfgsdr0310[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0310, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 64346         GSDR       essa  StgStudents

# %%
d = dfgsdr0311[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0311, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 64158         GSDR       essa  StgStudentSchedules

# %%
d = dfgsdr0312[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0312, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 64252         GSDR       essa  StgStudentServices

# %%
d = dfgsdr0313[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0313, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 64440         GSDR       essa  StgTeacherCertifications

# %%
d = dfgsdr0314[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0314, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                   TableName
# 64534         GSDR       essa  StgTeacherExceptionalities

# %%
d = dfgsdr0315[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0315, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 64722         GSDR       essa  StgTeachers

# %%
d = dfgsdr0316[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0316, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 64628         GSDR       essa  StgTeacherSections

# %%
d = dfgsdr0317[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0317, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName   TableName
# 3023         GSDR      gbOLD  Assignment

# %%
d = dfgsdr0318[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0318, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName        TableName
# 3305         GSDR      gbOLD  AssignmentScore

# %%
d = dfgsdr0319[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0319, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 8172         GSDR      gbOLD  Calendar

# %%
d = dfgsdr0320[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0320, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 23181         GSDR      gbOLD  Gradebook

# %%
d = dfgsdr0321[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0321, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 23369         GSDR      gbOLD  GradebookCategory

# %%
d = dfgsdr0322[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0322, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 23557         GSDR      gbOLD  GradebookCategoryGrade

# %%
d = dfgsdr0323[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0323, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 23651         GSDR      gbOLD  GradebookGradingScale

# %%
d = dfgsdr0324[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0324, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 23839         GSDR      gbOLD  GradebookTerm

# %%
d = dfgsdr0325[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0325, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 24027         GSDR      gbOLD  GradebookTermGrade

# %%
d = dfgsdr0326[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0326, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 24121         GSDR      gbOLD  GradingScale

# %%
d = dfgsdr0327[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0327, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 24309         GSDR      gbOLD  GradingScaleBreakpoint

# %%
d = dfgsdr0328[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0328, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 24497         GSDR      gbOLD  GradingTerm

# %%
d = dfgsdr0329[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0329, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 62842         GSDR      gbOLD  SectionEnrollment

# %%
d = dfgsdr0330[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0330, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 62936         GSDR      gbOLD  Sections

# %%
d = dfgsdr0331[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0331, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 65098         GSDR      gbOLD   Student

# %%
d = dfgsdr0332[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0332, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 69610         GSDR      gbOLD   Teacher

# %%
d = dfgsdr0333[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0333, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 69986         GSDR      gbOLD  TeacherSection

# %%
d = dfgsdr0334[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0334, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName   TableName
# 2929         GSDR  GBStaging  Assignment

# %%
d = dfgsdr0335[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0335, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName         TableName
# 3117         GSDR  GBStaging  AssignmentGrades

# %%
d = dfgsdr0336[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0336, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName        TableName
# 3211         GSDR  GBStaging  AssignmentScore

# %%
d = dfgsdr0337[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0337, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 8078         GSDR  GBStaging  Calendar

# %%
d = dfgsdr0338[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0338, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 9125         GSDR  GBStaging    Course

# %%
d = dfgsdr0339[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0339, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName         TableName
# 9971         GSDR  GBStaging  D2L_CLASS_Import

# %%
d = dfgsdr0340[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0340, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 10065         GSDR  GBStaging  D2L_Class_Import_20190410

# %%
d = dfgsdr0341[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0341, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 10159         GSDR  GBStaging  D2L_GRADE_IMPORT

# %%
d = dfgsdr0342[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0342, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 10347         GSDR  GBStaging  D2L_NOTE_Import

# %%
d = dfgsdr0343[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0343, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 10535         GSDR  GBStaging  D2L_SCORE_Import

# %%
d = dfgsdr0344[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0344, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 10629         GSDR  GBStaging  D2L_TASK_IMPORT

# %%
d = dfgsdr0345[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0345, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 20549         GSDR  GBStaging  FinalGrades

# %%
d = dfgsdr0346[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0346, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 23087         GSDR  GBStaging  Gradebook

# %%
d = dfgsdr0347[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0347, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 23275         GSDR  GBStaging  GradebookCategory

# %%
d = dfgsdr0348[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0348, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 23463         GSDR  GBStaging  GradebookCategoryGrade

# %%
d = dfgsdr0349[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0349, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 23745         GSDR  GBStaging  GradebookTerm

# %%
d = dfgsdr0350[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0350, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 23933         GSDR  GBStaging  GradebookTermGrade

# %%
d = dfgsdr0351[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0351, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 24215         GSDR  GBStaging  GradingScaleBreakpoint

# %%
d = dfgsdr0352[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0352, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 24403         GSDR  GBStaging  GradingTerm

# %%
d = dfgsdr0353[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0353, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 28941         GSDR  GBStaging  Organization

# %%
d = dfgsdr0354[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0354, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 33923         GSDR  GBStaging    Person

# %%
d = dfgsdr0355[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0355, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 34017         GSDR  GBStaging  PivotTable

# %%
d = dfgsdr0356[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0356, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                           TableName
# 36440         GSDR  GBStaging  RptAssignmentScore_CurrentTermFlag

# %%
d = dfgsdr0357[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0357, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 62654         GSDR  GBStaging   Section

# %%
d = dfgsdr0358[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0358, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 62748         GSDR  GBStaging  SectionEnrollment

# %%
d = dfgsdr0359[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0359, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 64910         GSDR  GBStaging   Student

# %%
d = dfgsdr0360[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0360, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 67824         GSDR  GBStaging  SynergyScore

# %%
d = dfgsdr0361[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0361, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 69516         GSDR  GBStaging   Teacher

# %%
d = dfgsdr0362[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0362, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName           TableName
# 193         GSDR       GEMS  ACADEMIC_CONTRACTS

# %%
d = dfgsdr0363[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0363, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName TableName
# 381         GSDR       GEMS  ACHSFILE

# %%
d = dfgsdr0364[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0364, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName     TableName
# 663         GSDR       GEMS  ADDRESS_HIST

# %%
d = dfgsdr0365[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0365, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName TableName
# 757         GSDR       GEMS      ADIA

# %%
d = dfgsdr0366[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0366, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName        TableName
# 851         GSDR       GEMS  ADIA_ERROR_CODE

# %%
d = dfgsdr0367[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0367, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName     TableName
# 945         GSDR       GEMS  ADIA_HISTORY

# %%
d = dfgsdr0368[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0368, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 1039         GSDR       GEMS  ADIA_OMG

# %%
d = dfgsdr0369[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0369, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 1133         GSDR       GEMS  ADST_ALL_YEARS

# %%
d = dfgsdr0370[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0370, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 1227         GSDR       GEMS  AFTSCH_TRANSP_PGMS

# %%
d = dfgsdr0371[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0371, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName   TableName
# 2647         GSDR       GEMS  Applitrack

# %%
d = dfgsdr0372[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0372, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName            TableName
# 2741         GSDR       GEMS  Applitrack_RecScore

# %%
d = dfgsdr0373[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0373, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName        TableName
# 2835         GSDR       GEMS  Applitrack_Test

# %%
d = dfgsdr0374[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0374, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 1373         GSDR       GEMS   ARCHATT

# %%
d = dfgsdr0375[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0375, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 71584         GSDR       GEMS  archatt_2018_restore

# %%
d = dfgsdr0376[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0376, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 1467         GSDR       GEMS   ARCHGRD

# %%
d = dfgsdr0377[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0377, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName     TableName
# 1655         GSDR       GEMS  ASTU_HISTORY

# %%
d = dfgsdr0378[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0378, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 1801         GSDR       GEMS   ATTDLET

# %%
d = dfgsdr0379[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0379, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName     TableName
# 1895         GSDR       GEMS  ATTEND_PARAM

# %%
d = dfgsdr0380[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0380, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 4057         GSDR       GEMS  CALENDAR

# %%
d = dfgsdr0381[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0381, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName          TableName
# 4339         GSDR       GEMS  CALENDAR_20180530

# %%
d = dfgsdr0382[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0382, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName     TableName
# 4621         GSDR       GEMS  CALENDAR_GAP

# %%
d = dfgsdr0383[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0383, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName     TableName
# 4715         GSDR       GEMS  CALENDAR_JIC

# %%
d = dfgsdr0384[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0384, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName      TableName
# 4809         GSDR       GEMS  CALENDAR_JIC2

# %%
d = dfgsdr0385[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0385, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName      TableName
# 4903         GSDR       GEMS  CALENDAR_JIC3

# %%
d = dfgsdr0386[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0386, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName      TableName
# 4997         GSDR       GEMS  CALENDAR_JIC4

# %%
d = dfgsdr0387[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0387, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName          TableName
# 5091         GSDR       GEMS  CALENDAR_NEWSTUFF

# %%
d = dfgsdr0388[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0388, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 5185         GSDR       GEMS  CALENDAR_NEWSTUFF2

# %%
d = dfgsdr0389[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0389, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName  TableName
# 5279         GSDR       GEMS  CLASSRANK

# %%
d = dfgsdr0390[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0390, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 5467         GSDR       GEMS   COHORT2

# %%
d = dfgsdr0391[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0391, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 5655         GSDR       GEMS    COURSE

# %%
d = dfgsdr0392[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0392, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName        TableName
# 5749         GSDR       GEMS  COURSE_REQUESTS

# %%
d = dfgsdr0393[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0393, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName            TableName
# 5843         GSDR       GEMS  COURSE_REQUESTS_JIC

# %%
d = dfgsdr0394[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0394, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                     TableName
# 6031         GSDR       GEMS  COURSE_REQUESTS_JIC_20170207

# %%
d = dfgsdr0395[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0395, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName             TableName
# 5937         GSDR       GEMS  COURSE_REQUESTS_JIC2

# %%
d = dfgsdr0396[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0396, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName     TableName
# 6125         GSDR       GEMS  COURSE_SETUP

# %%
d = dfgsdr0397[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0397, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 6313         GSDR       GEMS   CPI_A01

# %%
d = dfgsdr0398[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0398, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 6407         GSDR       GEMS   CPI_B01

# %%
d = dfgsdr0399[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0399, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 6501         GSDR       GEMS   CPI_C01

# %%
d = dfgsdr0400[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0400, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 6595         GSDR       GEMS   CPI_D01

# %%
d = dfgsdr0401[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0401, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName     TableName
# 6783         GSDR       GEMS  CRCT_MATCHED

# %%
d = dfgsdr0402[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0402, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName         TableName
# 6877         GSDR       GEMS  CRCT_MATCHED_TMP

# %%
d = dfgsdr0403[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0403, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName        TableName
# 6971         GSDR       GEMS  CRISNET_ARRESTS

# %%
d = dfgsdr0404[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0404, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName     TableName
# 7065         GSDR       GEMS  CSN_ACTIVITY

# %%
d = dfgsdr0405[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0405, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName        TableName
# 7159         GSDR       GEMS  CSN_ASSIGNMENTS

# %%
d = dfgsdr0406[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0406, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName            TableName
# 7253         GSDR       GEMS  CSN_CONTACT_REASONS

# %%
d = dfgsdr0407[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0407, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName          TableName
# 7347         GSDR       GEMS  CSN_CONTACT_TYPES

# %%
d = dfgsdr0408[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0408, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName     TableName
# 7441         GSDR       GEMS  CSN_MEETINGS

# %%
d = dfgsdr0409[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0409, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName     TableName
# 7535         GSDR       GEMS  CSN_OUTCOMES

# %%
d = dfgsdr0410[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0410, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName      TableName
# 7629         GSDR       GEMS  CSN_REFERRALS

# %%
d = dfgsdr0411[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0411, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName               TableName
# 7723         GSDR       GEMS  CSN_STUDENT_EDUCATIONS

# %%
d = dfgsdr0412[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0412, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName            TableName
# 7817         GSDR       GEMS  CSN_STUDENT_HEALTHS

# %%
d = dfgsdr0413[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0413, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName      TableName
# 7911         GSDR       GEMS  CSN_TRAININGS

# %%
d = dfgsdr0414[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0414, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 72811         GSDR       GEMS  dc_course_file_readonly

# %%
d = dfgsdr0415[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0415, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                        TableName
# 72905         GSDR       GEMS  dc_innovator_schedules_readonly

# %%
d = dfgsdr0416[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0416, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                       TableName
# 72999         GSDR       GEMS  dc_innovator_students_readonly

# %%
d = dfgsdr0417[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0417, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                       TableName
# 73093         GSDR       GEMS  dc_innovator_teachers_readonly

# %%
d = dfgsdr0418[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0418, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 10723         GSDR       GEMS  DELETED_GTIDS

# %%
d = dfgsdr0419[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0419, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 10817         GSDR       GEMS  DELETED_GTIDS_HISTORY

# %%
d = dfgsdr0420[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0420, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 10911         GSDR       GEMS  DESTINY_SCHOOLS

# %%
d = dfgsdr0421[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0421, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 11005         GSDR       GEMS  DOE_CLAIMED_SWD

# %%
d = dfgsdr0422[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0422, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 11475         GSDR       GEMS  DOE_SPED_NOPRIMARYAREA

# %%
d = dfgsdr0423[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0423, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 11569         GSDR       GEMS  DSCP_ADDL_COMMENT

# %%
d = dfgsdr0424[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0424, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 11663         GSDR       GEMS  DSCP_PANEL

# %%
d = dfgsdr0425[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0425, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 11757         GSDR       GEMS  DSCP_PANEL_RULES

# %%
d = dfgsdr0426[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0426, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 11851         GSDR       GEMS  DSCP_PANEL_SPED

# %%
d = dfgsdr0427[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0427, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 12039         GSDR       GEMS  DUPLICATES

# %%
d = dfgsdr0428[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0428, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 12415         GSDR       GEMS  EDIT_CODES

# %%
d = dfgsdr0429[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0429, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 12509         GSDR       GEMS  ELIG_ACTIVITIES

# %%
d = dfgsdr0430[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0430, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 12603         GSDR       GEMS  ELIG_LOG

# %%
d = dfgsdr0431[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0431, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 12697         GSDR       GEMS  ELIG_PRAM

# %%
d = dfgsdr0432[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0432, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 73563         GSDR       GEMS  elig_pram_bak20190717

# %%
d = dfgsdr0433[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0433, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 73657         GSDR       GEMS  elig_pram_bak20200602

# %%
d = dfgsdr0434[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0434, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 12791         GSDR       GEMS  ELIG_PRAM_OBJECT

# %%
d = dfgsdr0435[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0435, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 12885         GSDR       GEMS  ELIG_REQUIREMENTS

# %%
d = dfgsdr0436[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0436, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 12979         GSDR       GEMS  ELIG_ROSTERS

# %%
d = dfgsdr0437[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0437, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 73751         GSDR       GEMS  elig_rosters_bak20200602

# %%
d = dfgsdr0438[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0438, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 73845         GSDR       GEMS  elig_rosters_lastupdate

# %%
d = dfgsdr0439[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0439, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 73939         GSDR       GEMS  elig_rosters_nodups

# %%
d = dfgsdr0440[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0440, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                            TableName
# 74033         GSDR       GEMS  elig_rosters_sy1718_aftersummercalc

# %%
d = dfgsdr0441[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0441, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                            TableName
# 74127         GSDR       GEMS  elig_rosters_sy1819_aftersummercalc

# %%
d = dfgsdr0442[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0442, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 13073         GSDR       GEMS  ELIG_STUDENTS

# %%
d = dfgsdr0443[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0443, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 74221         GSDR       GEMS  elig_students_bak20190717

# %%
d = dfgsdr0444[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0444, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 74315         GSDR       GEMS  elig_students_bak20190723

# %%
d = dfgsdr0445[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0445, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 74409         GSDR       GEMS  elig_students_bak20200602

# %%
d = dfgsdr0446[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0446, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 74503         GSDR       GEMS  elig_students_bak20200722

# %%
d = dfgsdr0447[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0447, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 74597         GSDR       GEMS  elig_students_procbak

# %%
d = dfgsdr0448[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0448, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                             TableName
# 74691         GSDR       GEMS  elig_students_sy1718_aftersummercalc

# %%
d = dfgsdr0449[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0449, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                             TableName
# 74785         GSDR       GEMS  elig_students_sy1819_aftersummercalc

# %%
d = dfgsdr0450[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0450, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 13656         GSDR       GEMS  EOCT_HIST

# %%
d = dfgsdr0451[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0451, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 15080         GSDR       GEMS      ESOL

# %%
d = dfgsdr0452[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0452, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 15362         GSDR       GEMS  ESOL_CAT

# %%
d = dfgsdr0453[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0453, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 15550         GSDR       GEMS  EXP_REG_STU

# %%
d = dfgsdr0454[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0454, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 15644         GSDR       GEMS  EXP_REG_SUM

# %%
d = dfgsdr0455[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0455, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 15738         GSDR       GEMS  EXTERNAL_SCHOOLS

# %%
d = dfgsdr0456[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0456, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                   TableName
# 74973         GSDR       GEMS  external_schools_all_years

# %%
d = dfgsdr0457[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0457, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 15832         GSDR       GEMS  EXTERNAL_STUDENTS

# %%
d = dfgsdr0458[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0458, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                    TableName
# 75067         GSDR       GEMS  external_students_all_years

# %%
d = dfgsdr0459[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0459, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 15926         GSDR       GEMS  EXTERNAL_STUDENTS_NONDISTRICT

# %%
d = dfgsdr0460[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0460, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 16020         GSDR       GEMS  EXTERNAL_STUDENTS_Tim

# %%
d = dfgsdr0461[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0461, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 16492         GSDR       GEMS  FAY_RESEARCH

# %%
d = dfgsdr0462[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0462, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 16586         GSDR       GEMS  FAY_RESEARCH_EOCT

# %%
d = dfgsdr0463[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0463, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 16883         GSDR       GEMS  FORECAST

# %%
d = dfgsdr0464[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0464, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 16977         GSDR       GEMS  FREE_REDUCED_LUNCH

# %%
d = dfgsdr0465[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0465, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 17071         GSDR       GEMS       FTE

# %%
d = dfgsdr0466[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0466, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 19139         GSDR       GEMS  FTE_COURSES

# %%
d = dfgsdr0467[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0467, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 19233         GSDR       GEMS  FTE_ERRORLOAD

# %%
d = dfgsdr0468[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0468, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 19515         GSDR       GEMS  FTE_HISTORY

# %%
d = dfgsdr0469[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0469, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 19703         GSDR       GEMS  FTE_PARAMS

# %%
d = dfgsdr0470[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0470, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 19797         GSDR       GEMS  FTE_REPORT_ROWS

# %%
d = dfgsdr0471[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0471, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 19891         GSDR       GEMS  FTE_REPORT_SCH

# %%
d = dfgsdr0472[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0472, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 20079         GSDR       GEMS  FTE_REPORT_SCH20130220

# %%
d = dfgsdr0473[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0473, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 20173         GSDR       GEMS  FTE_TEMP

# %%
d = dfgsdr0474[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0474, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 20267         GSDR       GEMS  FTE_ZONED_SCH

# %%
d = dfgsdr0475[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0475, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 17259         GSDR       GEMS    FTE441

# %%
d = dfgsdr0476[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0476, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 17353         GSDR       GEMS     FTE88

# %%
d = dfgsdr0477[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0477, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 17447         GSDR       GEMS  FTE88_KS

# %%
d = dfgsdr0478[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0478, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 17541         GSDR       GEMS  FTECRS_MULTI

# %%
d = dfgsdr0479[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0479, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 17635         GSDR       GEMS    FTEEIP

# %%
d = dfgsdr0480[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0480, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 17729         GSDR       GEMS  FTEGIFTED_STUDENT

# %%
d = dfgsdr0481[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0481, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 18011         GSDR       GEMS  FTENUMB_TANK

# %%
d = dfgsdr0482[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0482, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 18105         GSDR       GEMS  FTEPEOPLE

# %%
d = dfgsdr0483[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0483, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 18199         GSDR       GEMS   FTESPED

# %%
d = dfgsdr0484[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0484, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 18293         GSDR       GEMS   FTESTAT

# %%
d = dfgsdr0485[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0485, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 18387         GSDR       GEMS  FTESTAT_APPEND

# %%
d = dfgsdr0486[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0486, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 18481         GSDR       GEMS  FTESTAT_BUF

# %%
d = dfgsdr0487[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0487, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 18575         GSDR       GEMS  FTESTAT_BUF_KS

# %%
d = dfgsdr0488[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0488, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 18669         GSDR       GEMS  FTESTAT_IVY

# %%
d = dfgsdr0489[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0489, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 18763         GSDR       GEMS  FTESTAT_KS

# %%
d = dfgsdr0490[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0490, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 18857         GSDR       GEMS  FTESTAT_LAST_YEAR

# %%
d = dfgsdr0491[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0491, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 18951         GSDR       GEMS  FTESTAT_MAIN

# %%
d = dfgsdr0492[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0492, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 19045         GSDR       GEMS  FTESTAT_YEAR

# %%
d = dfgsdr0493[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0493, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 21865         GSDR       GEMS  G_GBATCH

# %%
d = dfgsdr0494[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0494, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 21959         GSDR       GEMS  G_GBATCH_UPD

# %%
d = dfgsdr0495[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0495, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 22053         GSDR       GEMS    G_GTID

# %%
d = dfgsdr0496[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0496, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 22429         GSDR       GEMS  G_GTID_ERRORS

# %%
d = dfgsdr0497[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0497, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 22523         GSDR       GEMS  G_GTID_HISTORY

# %%
d = dfgsdr0498[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0498, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 22617         GSDR       GEMS  G_GTID_IMPORT

# %%
d = dfgsdr0499[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0499, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 22711         GSDR       GEMS  G_GTID_STU_BATCH

# %%
d = dfgsdr0500[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0400, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 22805         GSDR       GEMS  G_GTID_STU_BATCH_UPD

# %%
d = dfgsdr0501[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0501, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 22335         GSDR       GEMS  G_GTID20200813

# %%
d = dfgsdr0502[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0502, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 20925         GSDR       GEMS    GIFTED

# %%
d = dfgsdr0503[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0503, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 21019         GSDR       GEMS  GIFTED_CAT

# %%
d = dfgsdr0504[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0504, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 21207         GSDR       GEMS  GRADETANK

# %%
d = dfgsdr0505[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0505, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 21489         GSDR       GEMS  GRADETANK_HISTORY

# %%
d = dfgsdr0506[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0506, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 21583         GSDR       GEMS  GRADETANK_KS

# %%
d = dfgsdr0507[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0507, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 21301         GSDR       GEMS  GRADETANK3

# %%
d = dfgsdr0508[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0508, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 21395         GSDR       GEMS  GRADETANKTEMP

# %%
d = dfgsdr0509[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0509, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 25249         GSDR       GEMS  IEP_EXIT

# %%
d = dfgsdr0510[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0510, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 25343         GSDR       GEMS  IEP_EXPORT

# %%
d = dfgsdr0511[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0511, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 25437         GSDR       GEMS  IEP_GAA_INFO

# %%
d = dfgsdr0512[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0512, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 25531         GSDR       GEMS  IEP_SERVICES

# %%
d = dfgsdr0513[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0513, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 25625         GSDR       GEMS  IEP_SERVICES_FTE

# %%
d = dfgsdr0514[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0514, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 25719         GSDR       GEMS  IEP_SERVICES_SR

# %%
d = dfgsdr0515[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0515, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 25813         GSDR       GEMS  IEP_TIMELINE

# %%
d = dfgsdr0516[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0516, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 25907         GSDR       GEMS  IEP_TranspRoster

# %%
d = dfgsdr0517[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0517, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                             TableName
# 26001         GSDR       GEMS  IEP_TranspRoster_CaseManagerComments

# %%
d = dfgsdr0518[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0518, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 26095         GSDR       GEMS  IEP_TranspRoster_OtherSchools

# %%
d = dfgsdr0519[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0519, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 26283         GSDR       GEMS  ISC_CONTRACTORS

# %%
d = dfgsdr0520[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0520, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 26831         GSDR       GEMS  LETTER_TEXT

# %%
d = dfgsdr0521[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0521, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 26925         GSDR       GEMS  LETTER_TEXT_SAVE

# %%
d = dfgsdr0522[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0522, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 27019         GSDR       GEMS  LOCATION

# %%
d = dfgsdr0523[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0523, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 27113         GSDR       GEMS  LTS_TNL_Mentor

# %%
d = dfgsdr0524[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0524, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 27489         GSDR       GEMS  MEDICAID

# %%
d = dfgsdr0525[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0525, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 28377         GSDR       GEMS  NEXT_SCHOOL

# %%
d = dfgsdr0526[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0526, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 28471         GSDR       GEMS  NEXT_SCHOOL_Audit

# %%
d = dfgsdr0527[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0527, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 28565         GSDR       GEMS  NON_TEACHERS

# %%
d = dfgsdr0528[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0528, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 28659         GSDR       GEMS   NOSHOWS

# %%
d = dfgsdr0529[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0529, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 28753         GSDR       GEMS  NOSHOWS2012

# %%
d = dfgsdr0530[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0530, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 29881         GSDR       GEMS  PORTAL_CODE_DEFINITIONS

# %%
d = dfgsdr0531[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0531, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 29975         GSDR       GEMS  PORTAL_LOOKUP_CODES

# %%
d = dfgsdr0532[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0532, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 34111         GSDR       GEMS  Portal_lookup_codes_20170131

# %%
d = dfgsdr0533[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0533, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                       TableName
# 76571         GSDR       GEMS  portal_lookup_codes_lastupdate

# %%
d = dfgsdr0534[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0534, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 30163         GSDR       GEMS  PORTAL_PARAM_MESSAGES

# %%
d = dfgsdr0535[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0535, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 30069         GSDR       GEMS  PORTAL_PARAMS

# %%
d = dfgsdr0536[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0536, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 30257         GSDR       GEMS  PORTAL_SEC_ACL

# %%
d = dfgsdr0537[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0537, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 30351         GSDR       GEMS  PORTAL_SEC_ACO

# %%
d = dfgsdr0538[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0538, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 30445         GSDR       GEMS  PORTAL_SEC_ACO_MAP

# %%
d = dfgsdr0539[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0539, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 76665         GSDR       GEMS  portal_sec_aco_map_lastupdate

# %%
d = dfgsdr0540[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0540, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 30539         GSDR       GEMS  PORTAL_SEC_ARO

# %%
d = dfgsdr0541[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0541, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 30633         GSDR       GEMS  PORTAL_SEC_ARO_ACL

# %%
d = dfgsdr0542[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0542, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 76759         GSDR       GEMS  portal_sec_aro_acl_autobackup

# %%
d = dfgsdr0543[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0543, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 76853         GSDR       GEMS  portal_sec_aro_acl_lastupdate

# %%
d = dfgsdr0544[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0544, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 30915         GSDR       GEMS  PORTAL_SEC_ARO_GROUP_MBR

# %%
d = dfgsdr0545[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0545, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                                  TableName
# 76947         GSDR       GEMS  portal_sec_aro_group_mbr_bak_20170413_psd

# %%
d = dfgsdr0546[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0546, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                                  TableName
# 77041         GSDR       GEMS  portal_sec_aro_group_mbr_bak_20180409_psd

# %%
d = dfgsdr0547[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0547, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                                  TableName
# 77135         GSDR       GEMS  portal_sec_aro_group_mbr_bak_20190411_psd

# %%
d = dfgsdr0548[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0548, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                                  TableName
# 77229         GSDR       GEMS  portal_sec_aro_group_mbr_bak_20200411_psd

# %%
d = dfgsdr0549[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0549, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                                  TableName
# 77323         GSDR       GEMS  portal_sec_aro_group_mbr_bak_20210411_psd

# %%
d = dfgsdr0550[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0550, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 30727         GSDR       GEMS  PORTAL_SEC_ARO_GROUPS

# %%
d = dfgsdr0551[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0551, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 30821         GSDR       GEMS  PORTAL_SEC_ARO_GROUPS_MAP

# %%
d = dfgsdr0552[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0552, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                             TableName
# 77434         GSDR       GEMS  portal_sec_aro_groups_map_lastupdate

# %%
d = dfgsdr0553[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0553, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 31009         GSDR       GEMS  PORTAL_SEC_ARO_MAP

# %%
d = dfgsdr0554[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0554, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 77528         GSDR       GEMS  portal_sec_aro_map_lastupdate

# %%
d = dfgsdr0555[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0555, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 31103         GSDR       GEMS  PORTAL_SEC_AXO

# %%
d = dfgsdr0556[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0556, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 31385         GSDR       GEMS  PORTAL_SEC_AXO_GROUP_MBR

# %%
d = dfgsdr0557[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0557, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 31197         GSDR       GEMS  PORTAL_SEC_AXO_GROUPS

# %%
d = dfgsdr0558[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0558, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 31291         GSDR       GEMS  PORTAL_SEC_AXO_GROUPS_MAP

# %%
d = dfgsdr0559[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0559, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                             TableName
# 77622         GSDR       GEMS  portal_sec_axo_groups_map_lastupdate

# %%
d = dfgsdr0560[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0560, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 31479         GSDR       GEMS  PORTAL_SEC_AXO_MAP

# %%
d = dfgsdr0561[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0561, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 77716         GSDR       GEMS  portal_sec_axo_map_lastupdate

# %%
d = dfgsdr0562[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0562, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 31573         GSDR       GEMS  PREVIOUS_VALUES

# %%
d = dfgsdr0563[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0563, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 32137         GSDR       GEMS   PS_ATTD

# %%
d = dfgsdr0564[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0564, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 32419         GSDR       GEMS  PS_EMP_JOBCD

# %%
d = dfgsdr0565[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0565, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 32231         GSDR       GEMS  PS_EMPLOYEE

# %%
d = dfgsdr0566[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0566, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 32325         GSDR       GEMS  PS_EMPLOYEE_JIC_20170206

# %%
d = dfgsdr0567[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0567, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 32513         GSDR       GEMS  PS_GP_ABS_EVENT

# %%
d = dfgsdr0568[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0568, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 32607         GSDR       GEMS  PS_GP_ABS_REASON

# %%
d = dfgsdr0569[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0569, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 32701         GSDR       GEMS  PS_GP_ABS_REASON2

# %%
d = dfgsdr0570[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0570, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 32795         GSDR       GEMS  PS_GW_CERT

# %%
d = dfgsdr0571[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0571, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 32889         GSDR       GEMS  PS_GW_CERT_DATA

# %%
d = dfgsdr0572[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0572, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 32983         GSDR       GEMS  PS_GW_CERT_DISCREPANCY

# %%
d = dfgsdr0573[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0573, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 33077         GSDR       GEMS  PS_GW_COURSE

# %%
d = dfgsdr0574[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0574, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 33171         GSDR       GEMS  PS_GW_COURSE_CERT

# %%
d = dfgsdr0575[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0575, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 33359         GSDR       GEMS  PS_GW_TNL_COURSE_SLO

# %%
d = dfgsdr0576[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0576, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 33265         GSDR       GEMS  PS_GW_TNL_COURSES

# %%
d = dfgsdr0577[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0577, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 33453         GSDR       GEMS  PS_GW_TNL_PRFL_TGT

# %%
d = dfgsdr0578[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0578, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 33547         GSDR       GEMS  PS_JOBCD

# %%
d = dfgsdr0579[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0579, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 31855         GSDR       GEMS  PSD_ACTIVITY

# %%
d = dfgsdr0580[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0580, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 78280         GSDR       GEMS  psd_activity_lastupdate

# %%
d = dfgsdr0581[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0581, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 31949         GSDR       GEMS  PSD_APRN_LAST

# %%
d = dfgsdr0582[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0582, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 32043         GSDR       GEMS  PSD_USERS

# %%
d = dfgsdr0583[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0583, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 35145         GSDR       GEMS  REGISTER

# %%
d = dfgsdr0584[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0584, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 35239         GSDR       GEMS  REGISTERSUMMARY

# %%
d = dfgsdr0585[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0585, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 35333         GSDR       GEMS    REGSUM

# %%
d = dfgsdr0586[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0586, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 35427         GSDR       GEMS  REGSUM_HISTORY

# %%
d = dfgsdr0587[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0587, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 36628         GSDR       GEMS  SASI_A504

# %%
d = dfgsdr0588[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0588, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 36722         GSDR       GEMS  SASI_AATC

# %%
d = dfgsdr0589[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0589, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 37004         GSDR       GEMS  SASI_AATC_ROT

# %%
d = dfgsdr0590[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0590, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 37286         GSDR       GEMS  SASI_AATD

# %%
d = dfgsdr0591[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0591, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 50657         GSDR       GEMS  SASI_aatd_TSTAGING

# %%
d = dfgsdr0592[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0592, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 37474         GSDR       GEMS  SASI_AATO_ROT

# %%
d = dfgsdr0593[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0593, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 37756         GSDR       GEMS  SASI_AATP

# %%
d = dfgsdr0594[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0594, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 50751         GSDR       GEMS  SASI_aatp_TSTAGING

# %%
d = dfgsdr0595[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0595, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 37944         GSDR       GEMS  SASI_AATT

# %%
d = dfgsdr0596[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0596, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 38132         GSDR       GEMS  SASI_ABSENCE_CODES

# %%
d = dfgsdr0597[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0597, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 38226         GSDR       GEMS  SASI_ACAM

# %%
d = dfgsdr0598[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0598, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 38320         GSDR       GEMS  SASI_ACHS

# %%
d = dfgsdr0599[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0599, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 38602         GSDR       GEMS  SASI_ACHS_ES

# %%
d = dfgsdr0600[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0600, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 38696         GSDR       GEMS  SASI_ACHS_MS

# %%
d = dfgsdr0601[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0601, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 38790         GSDR       GEMS  SASI_ACHS_MSES

# %%
d = dfgsdr0602[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0602, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 38884         GSDR       GEMS  SASI_ACHS_SDR

# %%
d = dfgsdr0603[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0603, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 38508         GSDR       GEMS  SASI_ACHS9203768

# %%
d = dfgsdr0604[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0604, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 38978         GSDR       GEMS  SASI_ACLH

# %%
d = dfgsdr0605[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0605, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 39260         GSDR       GEMS  SASI_ACLS

# %%
d = dfgsdr0606[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0606, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 39542         GSDR       GEMS  SASI_ACLS_NEXT

# %%
d = dfgsdr0607[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0607, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 50845         GSDR       GEMS  SASI_acls_TSTAGING

# %%
d = dfgsdr0608[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0608, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 39636         GSDR       GEMS  SASI_ACNF

# %%
d = dfgsdr0609[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0609, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 39730         GSDR       GEMS  SASI_ACNR

# %%
d = dfgsdr0610[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0610, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 39824         GSDR       GEMS  SASI_ACRS

# %%
d = dfgsdr0611[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0611, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 40200         GSDR       GEMS  SASI_ACRS_FTE

# %%
d = dfgsdr0612[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0612, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 40294         GSDR       GEMS  SASI_ACRS_FTE2

# %%
d = dfgsdr0613[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0613, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 40388         GSDR       GEMS  SASI_ACRS_HS

# %%
d = dfgsdr0614[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0614, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 40482         GSDR       GEMS  SASI_ACRS_KS

# %%
d = dfgsdr0615[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0615, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 40576         GSDR       GEMS  SASI_ACRS_NEXT

# %%
d = dfgsdr0616[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0616, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 40670         GSDR       GEMS  SASI_ACRS_RAW

# %%
d = dfgsdr0617[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0617, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 40106         GSDR       GEMS  SASI_ACRS2012

# %%
d = dfgsdr0618[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0618, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 40952         GSDR       GEMS  SASI_ADDITIONAL_TEACHER

# %%
d = dfgsdr0619[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0619, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 41046         GSDR       GEMS  SASI_ADIS

# %%
d = dfgsdr0620[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0620, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 41140         GSDR       GEMS  SASI_ADIS_C

# %%
d = dfgsdr0621[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0621, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 41234         GSDR       GEMS  SASI_ADIS_KS

# %%
d = dfgsdr0622[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0622, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 41328         GSDR       GEMS  SASI_ADPO

# %%
d = dfgsdr0623[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0623, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 41422         GSDR       GEMS  SASI_ADPO_C

# %%
d = dfgsdr0624[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0624, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 41516         GSDR       GEMS  SASI_ADPS

# %%
d = dfgsdr0625[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0625, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 41610         GSDR       GEMS  SASI_ADST

# %%
d = dfgsdr0626[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0626, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 41704         GSDR       GEMS  SASI_ADST_ALL

# %%
d = dfgsdr0627[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0627, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 41798         GSDR       GEMS  SASI_AELT

# %%
d = dfgsdr0628[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0628, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 41892         GSDR       GEMS  SASI_AELT_JUST_DATES

# %%
d = dfgsdr0629[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0629, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 41986         GSDR       GEMS  SASI_AEMG

# %%
d = dfgsdr0630[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0630, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 42080         GSDR       GEMS  SASI_AEMG_NEXT

# %%
d = dfgsdr0631[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0631, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 42174         GSDR       GEMS  SASI_AENR

# %%
d = dfgsdr0632[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0632, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 42550         GSDR       GEMS  SASI_AENR_C

# %%
d = dfgsdr0633[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0633, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 42644         GSDR       GEMS  SASI_AENR_KS

# %%
d = dfgsdr0634[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0634, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 42738         GSDR       GEMS  SASI_AENR_NEXT

# %%
d = dfgsdr0635[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0635, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 42832         GSDR       GEMS  SASI_AENR_NON_ADA_ADM

# %%
d = dfgsdr0636[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0636, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 42926         GSDR       GEMS  SASI_AENR_SUMMER

# %%
d = dfgsdr0637[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0637, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 42456         GSDR       GEMS  SASI_AENR2

# %%
d = dfgsdr0638[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0638, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 43020         GSDR       GEMS  SASI_AFEE

# %%
d = dfgsdr0639[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0639, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 43114         GSDR       GEMS  SASI_AFID

# %%
d = dfgsdr0640[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0640, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 43208         GSDR       GEMS  SASI_AGRD

# %%
d = dfgsdr0641[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0641, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 43302         GSDR       GEMS  SASI_AGRL

# %%
d = dfgsdr0642[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0642, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 43396         GSDR       GEMS  SASI_AGSU

# %%
d = dfgsdr0643[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0643, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 43490         GSDR       GEMS  SASI_AHLT

# %%
d = dfgsdr0644[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0644, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 43584         GSDR       GEMS  SASI_ALKR

# %%
d = dfgsdr0645[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0645, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 43678         GSDR       GEMS  SASI_ALRT

# %%
d = dfgsdr0646[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0646, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 43772         GSDR       GEMS  SASI_AMST

# %%
d = dfgsdr0647[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0647, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 44054         GSDR       GEMS  SASI_AMST_NEXT

# %%
d = dfgsdr0648[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0648, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 44148         GSDR       GEMS  SASI_AMST_SECT_STF_HIS

# %%
d = dfgsdr0649[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0649, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 44242         GSDR       GEMS  SASI_AONL

# %%
d = dfgsdr0650[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0650, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 44336         GSDR       GEMS  SASI_APGD

# %%
d = dfgsdr0651[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0651, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 44430         GSDR       GEMS  SASI_APGL

# %%
d = dfgsdr0652[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0652, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 44524         GSDR       GEMS  SASI_APGM

# %%
d = dfgsdr0653[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0653, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 44618         GSDR       GEMS  SASI_APRN

# %%
d = dfgsdr0654[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0654, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 44806         GSDR       GEMS  SASI_APRN_LAST

# %%
d = dfgsdr0655[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0655, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 78673         GSDR       GEMS  sasi_aprn_sy1718

# %%
d = dfgsdr0656[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0656, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 78767         GSDR       GEMS  sasi_aprn_sy1819

# %%
d = dfgsdr0657[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0657, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 78861         GSDR       GEMS  sasi_aprn_sy1920

# %%
d = dfgsdr0658[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0658, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 78891         GSDR       GEMS  sasi_aprn_sydavid

# %%
d = dfgsdr0659[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0659, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 44712         GSDR       GEMS  SASI_APRN2012

# %%
d = dfgsdr0660[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0660, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 44900         GSDR       GEMS  SASI_ASCH

# %%
d = dfgsdr0661[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0661, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 44994         GSDR       GEMS  SASI_ASGR

# %%
d = dfgsdr0662[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0662, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 45088         GSDR       GEMS  SASI_ASTI

# %%
d = dfgsdr0663[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0663, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 45182         GSDR       GEMS  SASI_ASTU

# %%
d = dfgsdr0664[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0664, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 45468         GSDR       GEMS  SASI_ASTU_DEMOG

# %%
d = dfgsdr0665[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0665, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 45562         GSDR       GEMS  SASI_ASTU_DIPLOMA_SEALS

# %%
d = dfgsdr0666[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0666, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 45656         GSDR       GEMS  SASI_ASTU_EMAIL

# %%
d = dfgsdr0667[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0667, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 45750         GSDR       GEMS  SASI_ASTU_GOSA_AUDIT

# %%
d = dfgsdr0668[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0668, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 45844         GSDR       GEMS  SASI_ASTU_MIN

# %%
d = dfgsdr0669[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0669, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 45938         GSDR       GEMS  SASI_ASTU_NEXT

# %%
d = dfgsdr0670[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0670, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 46032         GSDR       GEMS  SASI_ASTU_NON_ADA_ADM

# %%
d = dfgsdr0671[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0671, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 46126         GSDR       GEMS  SASI_ASTU_SDR_2020

# %%
d = dfgsdr0672[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0672, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 46220         GSDR       GEMS  SASI_ASTU_TEMP

# %%
d = dfgsdr0673[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0673, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 46314         GSDR       GEMS  SASI_ASTV

# %%
d = dfgsdr0674[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0674, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 46408         GSDR       GEMS  SASI_ASTV_BP

# %%
d = dfgsdr0675[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0675, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 46502         GSDR       GEMS  SASI_ASTV_NEXT

# %%
d = dfgsdr0676[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0676, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 46596         GSDR       GEMS  SASI_ATBL

# %%
d = dfgsdr0677[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0677, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 78902         GSDR       GEMS  sasi_atbl_BADREL

# %%
d = dfgsdr0678[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0678, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 46690         GSDR       GEMS  SASI_ATBL_KS

# %%
d = dfgsdr0679[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0679, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 46784         GSDR       GEMS  SASI_ATCH

# %%
d = dfgsdr0680[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0680, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 47066         GSDR       GEMS  SASI_ATCH_NEXT

# %%
d = dfgsdr0681[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0681, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 50939         GSDR       GEMS  SASI_atch_TSTAGING

# %%
d = dfgsdr0682[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0682, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 47160         GSDR       GEMS  SASI_ATES

# %%
d = dfgsdr0683[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0683, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 47254         GSDR       GEMS  SASI_ATPA

# %%
d = dfgsdr0684[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0684, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 47348         GSDR       GEMS  SASI_ATRM

# %%
d = dfgsdr0685[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0685, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 47912         GSDR       GEMS  SASI_ATRM_NEXT

# %%
d = dfgsdr0686[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0686, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 47630         GSDR       GEMS  SASI_ATRM2016

# %%
d = dfgsdr0687[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0687, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 47724         GSDR       GEMS  SASI_ATRM4

# %%
d = dfgsdr0688[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0688, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 47818         GSDR       GEMS  SASI_ATRMPORT

# %%
d = dfgsdr0689[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0689, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 47931         GSDR       GEMS  SASI_AUFS

# %%
d = dfgsdr0690[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0690, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 48025         GSDR       GEMS  SASI_COUNTRY_OF_BIRTH

# %%
d = dfgsdr0691[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0691, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 48119         GSDR       GEMS  SASI_DISCP_RULES

# %%
d = dfgsdr0692[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0692, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 48307         GSDR       GEMS  SASI_DISCP_RULES_HIST

# %%
d = dfgsdr0693[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0693, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 48213         GSDR       GEMS  SASI_DISCP_RULES051219

# %%
d = dfgsdr0694[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0694, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 48401         GSDR       GEMS  SASI_DISPCODES

# %%
d = dfgsdr0695[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0695, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 48589         GSDR       GEMS  SASI_DISPCODES_HIST

# %%
d = dfgsdr0696[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0696, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 48495         GSDR       GEMS  SASI_DISPCODES051219

# %%
d = dfgsdr0697[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0697, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 48683         GSDR       GEMS  SASI_ELL_PARENT_CONF

# %%
d = dfgsdr0698[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0698, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 48777         GSDR       GEMS  SASI_ELL_WAIVER

# %%
d = dfgsdr0699[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0699, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 48871         GSDR       GEMS  SASI_FILE_HISTORY

# %%
d = dfgsdr0700[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0700, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 48965         GSDR       GEMS  SASI_GAT_HIS

# %%
d = dfgsdr0701[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0701, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 49059         GSDR       GEMS  SASI_LOAD_control

# %%
d = dfgsdr0702[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0702, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 49153         GSDR       GEMS  SASI_PARAPRO

# %%
d = dfgsdr0703[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0703, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 49247         GSDR       GEMS  SASI_SMST

# %%
d = dfgsdr0704[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0704, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 49529         GSDR       GEMS  SASI_UABN

# %%
d = dfgsdr0705[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0705, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 49623         GSDR       GEMS  SASI_UATR

# %%
d = dfgsdr0706[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0706, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 49717         GSDR       GEMS  SASI_UATR_NEXT

# %%
d = dfgsdr0707[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0707, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 51033         GSDR       GEMS  SASI_uatr_TSTAGING

# %%
d = dfgsdr0708[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0708, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 49811         GSDR       GEMS  SASI_UCES

# %%
d = dfgsdr0709[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0709, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 49905         GSDR       GEMS  SASI_UCMS

# %%
d = dfgsdr0710[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0710, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 49999         GSDR       GEMS  SASI_UFLP

# %%
d = dfgsdr0711[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0711, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 50093         GSDR       GEMS  SASI_UGFT

# %%
d = dfgsdr0712[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0712, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 50563         GSDR       GEMS  SASI_Upload_Count_Difference

# %%
d = dfgsdr0713[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0713, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 50187         GSDR       GEMS  SASI_UPLOAD_HISTORY

# %%
d = dfgsdr0714[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0714, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 50281         GSDR       GEMS  SASI_UPSA

# %%
d = dfgsdr0715[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0715, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 50375         GSDR       GEMS  SASI_UPSR

# %%
d = dfgsdr0716[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0716, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 50469         GSDR       GEMS  SASI_UTL1

# %%
d = dfgsdr0717[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0717, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 51691         GSDR       GEMS  SCHEDULES_MS_SAVE

# %%
d = dfgsdr0718[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0718, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 51879         GSDR       GEMS  SCHOOL_CLUSTER

# %%
d = dfgsdr0719[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0719, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 51973         GSDR       GEMS  SCHOOL_ETS_CODES

# %%
d = dfgsdr0720[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0720, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 52067         GSDR       GEMS       SCP

# %%
d = dfgsdr0721[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0721, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 53289         GSDR       GEMS  SDR_DSCP_ACTIONS

# %%
d = dfgsdr0722[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0722, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 53383         GSDR       GEMS  SDR_DSCP_INCDTS

# %%
d = dfgsdr0723[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0723, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 53477         GSDR       GEMS   SDR_ENR

# %%
d = dfgsdr0724[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0724, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 53571         GSDR       GEMS  SDR_ERRORS

# %%
d = dfgsdr0725[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0725, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 53665         GSDR       GEMS  SDR_IEP_SPED

# %%
d = dfgsdr0726[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0726, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 53759         GSDR       GEMS  SDR_IEP_SPED2

# %%
d = dfgsdr0727[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0727, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 54135         GSDR       GEMS  SDR_SCH_EDM

# %%
d = dfgsdr0728[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0728, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 54229         GSDR       GEMS  SDR_SCH_TITLE1

# %%
d = dfgsdr0729[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0729, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 54323         GSDR       GEMS  SDR_SCH_TITLE1_CHARLENE

# %%
d = dfgsdr0730[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0730, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 53853         GSDR       GEMS  SDR_SCHOOL_B

# %%
d = dfgsdr0731[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0731, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 53947         GSDR       GEMS  SDR_SCHOOL_N

# %%
d = dfgsdr0732[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0732, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 54041         GSDR       GEMS  SDR_SCHOOL_NCLB

# %%
d = dfgsdr0733[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0733, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 54511         GSDR       GEMS  SDR_STU_C

# %%
d = dfgsdr0734[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0734, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 54605         GSDR       GEMS  SDR_STU_C_HOST

# %%
d = dfgsdr0735[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0735, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 54793         GSDR       GEMS  SDR_STU_D

# %%
d = dfgsdr0736[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0736, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 54887         GSDR       GEMS  SDR_STU_D_HOST

# %%
d = dfgsdr0737[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0737, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 54981         GSDR       GEMS  SDR_STU_D_T

# %%
d = dfgsdr0738[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0738, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 55169         GSDR       GEMS  SDR_STU_E

# %%
d = dfgsdr0739[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0739, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 55263         GSDR       GEMS  SDR_STU_E_HOST

# %%
d = dfgsdr0740[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0740, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 55451         GSDR       GEMS  SDR_STU_F

# %%
d = dfgsdr0741[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0741, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 55545         GSDR       GEMS  SDR_STU_F_HOST

# %%
d = dfgsdr0742[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0742, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 55733         GSDR       GEMS  SDR_STU_G

# %%
d = dfgsdr0743[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0743, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 55827         GSDR       GEMS  SDR_STU_G_HOST

# %%
d = dfgsdr0744[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0744, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 55921         GSDR       GEMS  SDR_STU_G_OLD

# %%
d = dfgsdr0745[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0745, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 56109         GSDR       GEMS  SDR_STU_H

# %%
d = dfgsdr0746[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0746, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 56203         GSDR       GEMS  SDR_STU_H_HOST

# %%
d = dfgsdr0747[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0747, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 56391         GSDR       GEMS  SDR_STU_K

# %%
d = dfgsdr0748[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0748, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 56579         GSDR       GEMS  SDR_STU_K_KS

# %%
d = dfgsdr0749[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0749, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 56485         GSDR       GEMS  SDR_STU_K2

# %%
d = dfgsdr0750[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0750, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 56673         GSDR       GEMS  SDR_STU_TITLE1

# %%
d = dfgsdr0751[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0751, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 56767         GSDR       GEMS  SDR_SYS_J

# %%
d = dfgsdr0752[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0752, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 56861         GSDR       GEMS  SDR_SYS_J20150613

# %%
d = dfgsdr0753[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0753, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 52349         GSDR       GEMS  SDRC_HIST

# %%
d = dfgsdr0754[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0754, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 52255         GSDR       GEMS   SDRCTMP

# %%
d = dfgsdr0755[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0755, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 52537         GSDR       GEMS  SDRD_HIST

# %%
d = dfgsdr0756[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0756, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 52443         GSDR       GEMS  SDRD2014

# %%
d = dfgsdr0757[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0757, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 52631         GSDR       GEMS  SDRE_HIST

# %%
d = dfgsdr0758[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0758, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 52725         GSDR       GEMS  SDRF_HIST

# %%
d = dfgsdr0759[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0759, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 52819         GSDR       GEMS  SDRF_TMP

# %%
d = dfgsdr0760[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0760, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 52913         GSDR       GEMS  SDRG_HIST

# %%
d = dfgsdr0761[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0761, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 53007         GSDR       GEMS  SDRK_HIST

# %%
d = dfgsdr0762[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0762, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 53101         GSDR       GEMS  SDRSTUFZ

# %%
d = dfgsdr0763[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0763, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 53195         GSDR       GEMS  SDRSTUK_TMP

# %%
d = dfgsdr0764[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0764, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 56955         GSDR       GEMS       SES

# %%
d = dfgsdr0765[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0765, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 57237         GSDR       GEMS  SLDS_Teachers

# %%
d = dfgsdr0766[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0766, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 58365         GSDR       GEMS  SPED_EXIT

# %%
d = dfgsdr0767[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0767, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 58459         GSDR       GEMS  SPED_SCORE_CARD

# %%
d = dfgsdr0768[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0768, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 58553         GSDR       GEMS  SPED_SCORE_REP

# %%
d = dfgsdr0769[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0769, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 58647         GSDR       GEMS  SPED_SCORE_SUM

# %%
d = dfgsdr0770[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0770, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 58741         GSDR       GEMS  SPED_TCH_SCHED

# %%
d = dfgsdr0771[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0771, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 59305         GSDR       GEMS  SRO_RULES

# %%
d = dfgsdr0772[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0772, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 59493         GSDR       GEMS  SSW_ACTIVITY

# %%
d = dfgsdr0773[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0773, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 59587         GSDR       GEMS  SSW_ASSIGNMENTS

# %%
d = dfgsdr0774[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0774, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 59681         GSDR       GEMS  SSW_CASES

# %%
d = dfgsdr0775[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0775, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                                  TableName
# 80124         GSDR       GEMS  ssw_cases_bak_20171219_before_code_update

# %%
d = dfgsdr0776[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0776, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 59775         GSDR       GEMS  SSW_CONTACT_REASONS

# %%
d = dfgsdr0777[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0777, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 59869         GSDR       GEMS  SSW_CONTACT_TYPES

# %%
d = dfgsdr0778[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0778, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 59963         GSDR       GEMS  SSW_DOE_CASES

# %%
d = dfgsdr0779[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0779, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 60057         GSDR       GEMS  SSW_DOE_REFERRALS

# %%
d = dfgsdr0780[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0780, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 60151         GSDR       GEMS  SSW_DOE_SERVICES

# %%
d = dfgsdr0781[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0781, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 60245         GSDR       GEMS  SSW_LOOKUP_CODES

# %%
d = dfgsdr0782[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0782, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 60339         GSDR       GEMS  SSW_MEETINGS

# %%
d = dfgsdr0783[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0783, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 60433         GSDR       GEMS  SSW_REFERRALS

# %%
d = dfgsdr0784[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0784, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 60527         GSDR       GEMS  SSW_STUDENTS

# %%
d = dfgsdr0785[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0785, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 80218         GSDR       GEMS  string_translation

# %%
d = dfgsdr0786[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0786, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 61561         GSDR       GEMS   STU_FAY

# %%
d = dfgsdr0787[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0787, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 61655         GSDR       GEMS  STU_HOPE_GRANT

# %%
d = dfgsdr0788[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0788, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 61749         GSDR       GEMS  STU_ZONED_SCH

# %%
d = dfgsdr0789[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0789, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 61373         GSDR       GEMS  STUD_HOPE_GRANT

# %%
d = dfgsdr0790[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0790, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 60621         GSDR       GEMS  STUDENT_DISTRICT

# %%
d = dfgsdr0791[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0791, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 60715         GSDR       GEMS  STUDENT_FTEID

# %%
d = dfgsdr0792[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0792, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 60997         GSDR       GEMS  STUDENT_FTEID20200813

# %%
d = dfgsdr0793[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0793, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 61091         GSDR       GEMS  STUDENT_PROFILES

# %%
d = dfgsdr0794[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0794, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 61185         GSDR       GEMS  STUDENT_SCHEDULE

# %%
d = dfgsdr0795[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0795, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 61279         GSDR       GEMS  STUDENT_SCHOOLS

# %%
d = dfgsdr0796[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0796, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 61467         GSDR       GEMS  STUHEADR

# %%
d = dfgsdr0797[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0797, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 68012         GSDR       GEMS  TEACHER_LEAVE

# %%
d = dfgsdr0798[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0798, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 68482         GSDR       GEMS  TEACHER_SCHEDULE

# %%
d = dfgsdr0799[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0799, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                    TableName
# 68576         GSDR       GEMS  TEMP_DOE_SPED_NOPRIMARYAREA

# %%
d = dfgsdr0800[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0800, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 68764         GSDR       GEMS  TIME_STAMP

# %%
d = dfgsdr0801[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0801, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 68858         GSDR       GEMS  TITLE1_SWP

# %%
d = dfgsdr0802[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0802, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 68952         GSDR       GEMS  TITLE1_TAS

# %%
d = dfgsdr0803[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0803, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 71396         GSDR       GEMS  USCO_CODES

# %%
d = dfgsdr0804[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0804, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 71490         GSDR       GEMS  XPRT_STUDENTS_NOSHOW

# %%
d = dfgsdr0805[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0805, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 8454         GSDR  Gradebook     Class

# %%
d = dfgsdr0806[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0806, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName              TableName
# 8548         GSDR  Gradebook  Class_Backup_20170915

# %%
d = dfgsdr0807[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0807, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 22899         GSDR  Gradebook     Grade

# %%
d = dfgsdr0808[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0808, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 22993         GSDR  Gradebook  Grade_Backup_20170915

# %%
d = dfgsdr0809[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0809, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 28847         GSDR  Gradebook      Note

# %%
d = dfgsdr0810[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0810, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 62466         GSDR  Gradebook     Score

# %%
d = dfgsdr0811[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0811, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 78996         GSDR  Gradebook  score_backup

# %%
d = dfgsdr0812[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0812, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 62560         GSDR  Gradebook  Score_Backup_20170915

# %%
d = dfgsdr0813[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0813, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 69328         GSDR  Gradebook      Task

# %%
d = dfgsdr0814[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0814, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 80500         GSDR  Gradebook  task_backup

# %%
d = dfgsdr0815[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0815, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 69422         GSDR  Gradebook  Task_Backup_20170915

# %%
d = dfgsdr0816[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0816, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 19421         GSDR      guest  FTE_GTID_Updates

# %%
d = dfgsdr0817[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0817, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 33829         GSDR      guest  PermnumList

# %%
d = dfgsdr0818[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0818, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 4151         GSDR    SPG2014  CALENDAR

# %%
d = dfgsdr0819[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0819, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 22147         GSDR    SPG2014    G_GTID

# %%
d = dfgsdr0820[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0820, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 36816         GSDR    SPG2014  SASI_AATC

# %%
d = dfgsdr0821[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0821, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 37098         GSDR    SPG2014  SASI_AATC_ROT

# %%
d = dfgsdr0822[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0822, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 37380         GSDR    SPG2014  SASI_AATD

# %%
d = dfgsdr0823[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0823, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 37568         GSDR    SPG2014  SASI_AATO_ROT

# %%
d = dfgsdr0824[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0824, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 37850         GSDR    SPG2014  SASI_AATP

# %%
d = dfgsdr0825[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0825, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 38038         GSDR    SPG2014  SASI_AATT

# %%
d = dfgsdr0826[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0826, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 39072         GSDR    SPG2014  SASI_ACLH

# %%
d = dfgsdr0827[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0827, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 39354         GSDR    SPG2014  SASI_ACLS

# %%
d = dfgsdr0828[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0828, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 39918         GSDR    SPG2014  SASI_ACRS

# %%
d = dfgsdr0829[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0829, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 40764         GSDR    SPG2014  SASI_ACRS_RAW

# %%
d = dfgsdr0830[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0830, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 42268         GSDR    SPG2014  SASI_AENR

# %%
d = dfgsdr0831[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0831, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 43866         GSDR    SPG2014  SASI_AMST

# %%
d = dfgsdr0832[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0832, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 45276         GSDR    SPG2014  SASI_ASTU

# %%
d = dfgsdr0833[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0833, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 46878         GSDR    SPG2014  SASI_ATCH

# %%
d = dfgsdr0834[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0834, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 47442         GSDR    SPG2014  SASI_ATRM

# %%
d = dfgsdr0835[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0835, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 49341         GSDR    SPG2014  SASI_SMST

# %%
d = dfgsdr0836[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0836, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 60809         GSDR    SPG2014  STUDENT_FTEID

# %%
d = dfgsdr0837[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0837, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 68106         GSDR    SPG2014  TEACHER_LEAVE

# %%
d = dfgsdr0838[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0838, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 68294         GSDR    SPG2014  TEACHER_LEAVE2

# %%
d = dfgsdr0839[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0839, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 70080         GSDR    SPG2014  Teachers To Validate

# %%
d = dfgsdr0840[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0840, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 4245         GSDR    SPG2015  CALENDAR

# %%
d = dfgsdr0841[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0841, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 22241         GSDR    SPG2015    G_GTID

# %%
d = dfgsdr0842[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0842, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 36910         GSDR    SPG2015  SASI_AATC

# %%
d = dfgsdr0843[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0843, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 37192         GSDR    SPG2015  SASI_AATC_ROT

# %%
d = dfgsdr0844[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0844, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 37662         GSDR    SPG2015  SASI_AATO_ROT

# %%
d = dfgsdr0845[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0845, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 39166         GSDR    SPG2015  SASI_ACLH

# %%
d = dfgsdr0846[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0846, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 39448         GSDR    SPG2015  SASI_ACLS

# %%
d = dfgsdr0847[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0847, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 40012         GSDR    SPG2015  SASI_ACRS

# %%
d = dfgsdr0848[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0848, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 40858         GSDR    SPG2015  SASI_ACRS_RAW

# %%
d = dfgsdr0849[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0849, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 42362         GSDR    SPG2015  SASI_AENR

# %%
d = dfgsdr0850[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0850, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 43960         GSDR    SPG2015  SASI_AMST

# %%
d = dfgsdr0851[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0851, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 45370         GSDR    SPG2015  SASI_ASTU

# %%
d = dfgsdr0852[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0852, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 46972         GSDR    SPG2015  SASI_ATCH

# %%
d = dfgsdr0853[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0853, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 47536         GSDR    SPG2015  SASI_ATRM

# %%
d = dfgsdr0854[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0854, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 49435         GSDR    SPG2015  SASI_SMST

# %%
d = dfgsdr0855[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0855, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 60903         GSDR    SPG2015  STUDENT_FTEID

# %%
d = dfgsdr0856[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0856, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 65192         GSDR    SPG2015  StudentClass

# %%
d = dfgsdr0857[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0857, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 66414         GSDR    SPG2015  StudentCourseProfile

# %%
d = dfgsdr0858[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0858, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 68200         GSDR    SPG2015  TEACHER_LEAVE

# %%
d = dfgsdr0859[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0859, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 68388         GSDR    SPG2015  TEACHER_LEAVE2

# %%
d = dfgsdr0860[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0860, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 69704         GSDR    SPG2015  TeacherClass

# %%
d = dfgsdr0861[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0861, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 70174         GSDR    SPG2015  Teachers To Validate

# %%
d = dfgsdr0862[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0862, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 70268         GSDR    SPG2015  Teachers To Validate20160211

# %%
d = dfgsdr0863[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0863, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 71866         GSDR      stage  crisnet_arrests

# %%
d = dfgsdr0864[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0864, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 78374         GSDR      stage  psd_input_file

# %%
d = dfgsdr0865[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0865, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName      SchemaName              TableName
# 16398         GSDR  StudentProfile  FACT_AttendanceByType

# %%
d = dfgsdr0866[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0866, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName       SchemaName   TableName
# 13167         GSDR  TCAccommodation  ELPP_Notes

# %%
d = dfgsdr0867[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0867, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName       SchemaName          TableName
# 24873         GSDR  TCAccommodation  IEPAccommodations

# %%
d = dfgsdr0868[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0868, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName       SchemaName           TableName
# 36534         GSDR  TCAccommodation  S504Accommodations

# %%
d = dfgsdr0869[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0869, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName       SchemaName  TableName
# 69234         GSDR  TCAccommodation  TPP_Notes

# %%
d = dfgsdr0870[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0870, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName  SchemaName   TableName
# 3399         GSDR  Transcript  Attendance

# %%
d = dfgsdr0871[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0871, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName  SchemaName TableName
# 9595         GSDR  Transcript   Courses

# %%
d = dfgsdr0872[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0872, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName  SchemaName TableName
# 9783         GSDR  Transcript    CumGPA

# %%
d = dfgsdr0873[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0873, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName  SchemaName TableName
# 13562         GSDR  Transcript       EOC

# %%
d = dfgsdr0874[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0874, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName  SchemaName TableName
# 21113         GSDR  Transcript       GPA

# %%
d = dfgsdr0875[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0875, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName  SchemaName TableName
# 61996         GSDR  Transcript    School

# %%
d = dfgsdr0876[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0876, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName  SchemaName        TableName
# 62278         GSDR  Transcript  SchoolsAttended

# %%
d = dfgsdr0877[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0877, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName  SchemaName  TableName
# 63124         GSDR  Transcript  Semesters

# %%
d = dfgsdr0878[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0878, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName  SchemaName        TableName
# 63406         GSDR  Transcript  SpecialStudents

# %%
d = dfgsdr0879[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0879, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName  SchemaName TableName
# 65004         GSDR  Transcript   Student

# %%
d = dfgsdr0880[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0880, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName  SchemaName TableName
# 61843         GSDR  Transcript     SUMLA

# %%
d = dfgsdr0881[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_{}_{}'.format(f,g))

fig = px.scatter(dfgsdr0881, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName  SchemaName       TableName
# 70456         GSDR  Transcript  TestAssesments

# %%
now01 = datetime.datetime.now()
print('Interactive Chart Creation - Process Complete: ', now01.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Interactive Chart Creation - Process Complete:  2021-05-11 15:23:38
