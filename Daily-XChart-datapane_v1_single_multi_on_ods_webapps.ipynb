# %%
#Program Name: Daily-XChart-datapane_v1_single_multi_on_ods_webapps
#Purpose:  Chart scatter line box aggr table data
#Author:  Greg Turmel, Director, Data Governance 
#Date:    2020.08.30 - 2021.06.30
#Errata:  0.1 Improvements can be made to script using for/looping through the databases

import os, sys, argparse, csv, pyodbc, sql, time, datetime
from datetime import datetime, timedelta
import sqlalchemy as db
from dotenv import load_dotenv # add this line
from matplotlib.backends.backend_pdf import PdfPages
import pandas as pd
import altair as alt
from altair import Chart, X, Y, Axis, SortField
from vega_datasets import data as vega_data
import datapane as dp
#import datatable as dt
import numpy as np
import matplotlib # notebook
import matplotlib.pyplot as plt
import seaborn as sns
#import chart_studio.plotly as py
import plotly.graph_objects as go
load_dotenv() # add this line
user = os.getenv('MySQLeUser')
password = os.getenv('MySQLeUserPass')
host = os.getenv('MySQLeHOST')
db = os.getenv('MySQLeDB')
# %matplotlib inline
# %load_ext sql

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=DEVODSSQL;'
                      'Database=Greg;'
                      'Trusted_Connection=yes;')

sql_query01 = pd.read_sql_query(''' 
select DISTINCT TableName
FROM [dbo].[tableRowCountODS_WebApps]
ORDER BY TableName;     
                              '''
                              ,conn) # Load the list of distinct tables to graph

sql_query02 = pd.read_sql_query(''' 
select *
FROM [dbo].[tableRowCountODS_WebApps]
ORDER BY TableName;     
                              '''
                              ,conn) # Load the list of distinct tables to graph

# %%
df = pd.DataFrame(sql_query02)
#df = df.astype({'TodaysDate':np.int64,'RecordCount':np.int64})
df['TodaysDate'] = pd.to_datetime(df['TodaysDate'].astype(str), format='%Y%m%d')
df = df.sort_values(by=['TableName','SchemaName','DatabaseName','TodaysDate'], ascending=[True,True,True,True])
df = df.reset_index(drop=True)

# %%
dfods_webapps0001 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'ADManagement') & (df['TableName'] == 'InAdNotInODS')]
dfods_webapps0002 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'ADManagement') & (df['TableName'] == 'InAdNotInODS_backup')]
dfods_webapps0003 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'ADManagement') & (df['TableName'] == 'InAdWrongSchool')]
dfods_webapps0004 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'ADManagement') & (df['TableName'] == 'InAdWrongSchool_backup')]
dfods_webapps0005 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'ADManagement') & (df['TableName'] == 'MissingOrWrongSchoolInAD')]
dfods_webapps0006 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'ADManagement') & (df['TableName'] == 'MissingOrWrongSchoolInAD_backup')]
dfods_webapps0007 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'ADManagement') & (df['TableName'] == 'NotInAd')]
dfods_webapps0008 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'ADManagement') & (df['TableName'] == 'NotInAd_backup')]
dfods_webapps0009 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'ADManagement') & (df['TableName'] == 'notinadbackup')]
dfods_webapps0010 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'ADManagement') & (df['TableName'] == 'tbl_acctSchedule')]
dfods_webapps0011 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'ADManagement') & (df['TableName'] == 'tbl_ADGroupObjects')]
dfods_webapps0012 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'ADManagement') & (df['TableName'] == 'tbl_ADUserObjects')]
dfods_webapps0013 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'ADManagement') & (df['TableName'] == 'tbl_ADUserObjects_1011BKUP')]
dfods_webapps0014 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'ADManagement') & (df['TableName'] == 'tbl_ADUserObjects2')]
dfods_webapps0015 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'ADManagement') & (df['TableName'] == 'tbl_ADUserObjectsWithSchool')]
dfods_webapps0016 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'ADManagement') & (df['TableName'] == 'tbl_currentEnrollment')]
dfods_webapps0017 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'ADManagement') & (df['TableName'] == 'tbl_ddlItems')]
dfods_webapps0018 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'ADManagement') & (df['TableName'] == 'tbl_eventLog')]
dfods_webapps0019 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'ADManagement') & (df['TableName'] == 'tbl_gridFields')]
dfods_webapps0020 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'ADManagement') & (df['TableName'] == 'tbl_specialAccess')]
dfods_webapps0021 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'ADManagement') & (df['TableName'] == 'tbl_temp_memberships')]
dfods_webapps0022 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'Config') & (df['TableName'] == 'reports_bak20131126')]
dfods_webapps0023 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'Core') & (df['TableName'] == 'AllYearStudents')]
dfods_webapps0024 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ChartColors')]
dfods_webapps0025 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'chdetails_Backup')]
dfods_webapps0026 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'chdetails_new')]
dfods_webapps0027 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'course_history_200363599')]
dfods_webapps0028 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'dupperms')]
dfods_webapps0029 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'pic200222266')]
dfods_webapps0030 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'savepic')]
dfods_webapps0031 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SMRSCHTRAN')]
dfods_webapps0032 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SmrSchTran_ALOC')]
dfods_webapps0033 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'smrschtran_bkup0527')]
dfods_webapps0034 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'smrschtran_bkupmay23')]
dfods_webapps0035 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SMRSCHTRAN_CONTROL')]
dfods_webapps0036 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SMRSCHTRAN_HIST')]
dfods_webapps0037 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SMRSCHTRAN_JIC')]
dfods_webapps0038 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SMRSCHTRAN_JIC2')]
dfods_webapps0039 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SMRSCHTRAN_JIC20130724')]
dfods_webapps0040 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SMRSCHTRAN_JIC3')]
dfods_webapps0041 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SMRSCHTRAN_JIC4')]
dfods_webapps0042 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SMRSCHTRAN_JIC5')]
dfods_webapps0043 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SMRSCHTRAN_ROSTER')]
dfods_webapps0044 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'smrschtran_students')]
dfods_webapps0045 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SMRSCHTRAN_TS')]
dfods_webapps0046 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SMRSCHTRAN_TS_0815')]
dfods_webapps0047 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'smrschtran_ts_bkupmay23')]
dfods_webapps0048 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StageStudentPictures')]
dfods_webapps0049 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SteveInAdNotInODS')]
dfods_webapps0050 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sysdiagrams')]
dfods_webapps0051 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'tbl_ADStudentCounts')]
dfods_webapps0052 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'tbl_ADStudents')]
dfods_webapps0053 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'tbl_ADUserAccounts')]
dfods_webapps0054 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'tbl_Impersonation')]
dfods_webapps0055 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'tbl_QADMSASI_ActiveStudents')]
dfods_webapps0056 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'tbl_Sample')]
dfods_webapps0057 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'tbl_StudentPictures')]
dfods_webapps0058 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'tbl_StudentPictures_backup20121026')]
dfods_webapps0059 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'tbl_TNL_COURSE')]
dfods_webapps0060 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'tbl_TNL_COURSE_LISTING')]
dfods_webapps0061 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'tbl_TNL_MERGE_RESULT')]
dfods_webapps0062 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'tbl_TNL_RESULT')]
dfods_webapps0063 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'tbl_TNL_RESULT_BKUP')]
dfods_webapps0064 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'tbl_TNL_RESULT_TMP')]
dfods_webapps0065 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'tbl_TNL_SchoolList')]
dfods_webapps0066 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'DISCIPLINE') & (df['TableName'] == 'ReportsConfig')]
dfods_webapps0067 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'logging') & (df['TableName'] == 'AboutStudents_log')]
dfods_webapps0068 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'ODSUtilities') & (df['TableName'] == 'TargetedHistoricalLoadControl')]
dfods_webapps0069 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'Security') & (df['TableName'] == 'Applications')]
dfods_webapps0070 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'Security') & (df['TableName'] == 'Applications_SubNav')]
dfods_webapps0071 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'Security') & (df['TableName'] == 'Role')]
dfods_webapps0072 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'Security') & (df['TableName'] == 'Roles_SubNav')]
dfods_webapps0073 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'Security') & (df['TableName'] == 'SecurityErrors')]
dfods_webapps0074 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'StuProfile') & (df['TableName'] == 'Addendum_Log')]
dfods_webapps0075 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'StuProfile') & (df['TableName'] == 'CRCT_AssesmentData')]
dfods_webapps0076 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'StuProfile') & (df['TableName'] == 'CurrentGrades')]
dfods_webapps0077 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'StuProfile') & (df['TableName'] == 'Dashboard_Class_CRCTAverages')]
dfods_webapps0078 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'StuProfile') & (df['TableName'] == 'Dashboard_Class_CRCTData')]
dfods_webapps0079 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'StuProfile') & (df['TableName'] == 'Dashboard_Class_GuardianInfo')]
dfods_webapps0080 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'StuProfile') & (df['TableName'] == 'Dashboard_Class_SEIData')]
dfods_webapps0081 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'StuProfile') & (df['TableName'] == 'Educator_Student')]
dfods_webapps0082 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'StuProfile') & (df['TableName'] == 'EnrollmentData')]
dfods_webapps0083 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'StuProfile') & (df['TableName'] == 'ParentPortalStats')]
dfods_webapps0084 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'StuProfile') & (df['TableName'] == 'SPortal_LastLogin')]
dfods_webapps0085 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'StuProfile') & (df['TableName'] == 'Student_Schedule')]
dfods_webapps0086 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'StuProfile') & (df['TableName'] == 'StudentAttendance')]
dfods_webapps0087 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'StuProfile') & (df['TableName'] == 'StudentAttendanceByType')]
dfods_webapps0088 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'StuProfile') & (df['TableName'] == 'StudentMetaData')]
dfods_webapps0089 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'StuProfile') & (df['TableName'] == 'StudentSearchData')]
dfods_webapps0090 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'StuProfile') & (df['TableName'] == 'tbl_WarmUp')]
dfods_webapps0091 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'StuProfile') & (df['TableName'] == 'TEST_NAME_MAP')]
dfods_webapps0092 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'StuProfile') & (df['TableName'] == 'TrendingGrades')]
dfods_webapps0093 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'Temp') & (df['TableName'] == 'MedAlertData')]
dfods_webapps0094 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'Temp') & (df['TableName'] == 'tbl_StudentEnrollment')]
dfods_webapps0095 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'UserStats') & (df['TableName'] == 'SearchUsage')]
dfods_webapps0096 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'UserStats') & (df['TableName'] == 'SearchUsage_Errors')]
dfods_webapps0097 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'UserStats') & (df['TableName'] == 'StuProfileUsage')]
dfods_webapps0098 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'UserStats') & (df['TableName'] == 'StuProfileUsageDetail')]
dfods_webapps0099 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'UserStats') & (df['TableName'] == 'VisitorLog')]
dfods_webapps0100 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'UTILITY') & (df['TableName'] == 'ChartColors')]
dfods_webapps0101 = df[(df['DatabaseName'] == 'ODS_WebApps') & (df['SchemaName'] == 'UTILITY') & (df['TableName'] == 'tbl_ADObjects')]

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(df).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='ODS_WebApps All Tables'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(df, title='ODS_WebApps All Tables').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#Individual Tables - graphed with datapane and altair

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfods_webapps0018).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='tbl_eventLog'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfods_webapps0018, title='tbl_eventLog').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfods_webapps0021).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='tbl_temp_memberships'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfods_webapps0021, title='tbl_temp_memberships').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfods_webapps0099).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='VisitorLog'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfods_webapps0099, title='VisitorLog').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# #alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
# alt.data_transformers.enable('json')
# selection = alt.selection_multi();
# alt.Chart(dfx).mark_point(filled=True).encode(
#     alt.X('TodaysDate', scale=alt.Scale(zero=False)),
#     alt.Y('RecordCount', scale=alt.Scale(zero=False)),
#     alt.Size('RecordCount:Q'),
#     alt.OpacityValue(0.5),
#     alt.Order('RecordCount:Q', sort='descending'),
#     tooltip = [alt.Tooltip('TodaysDate:T'),
#                alt.Tooltip('RecordCount:Q'),
#                alt.Tooltip('DatabaseName:N'),
#                alt.Tooltip('SchemaName:N'),
#                alt.Tooltip('TableName:N'),
#               ],
#     color=alt.condition(selection, 'cluster:N', alt.value('grey'))
# ).add_selection(selection).properties(
#     title='x'
# ).properties(
#     width=750,
#     height=300
# ).interactive()

# %% [markdown]
# hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')
#
# base = alt.Chart(dfx, title='x').encode(
#        alt.X('TodaysDate:T')
#        #title.configure_title(fontSize=24)
#
# ).properties(
#     width=750, height=300,
# )
# points = base.mark_point().add_selection(
#     hover
# )
#
# line_A = base.mark_line(color='#5276A7').encode(
#     alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
# )
#
# line_B = base.mark_line(color='#F18727').encode(
#     alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
# )
# alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()

# %% [markdown]
# #alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
# alt.data_transformers.enable('json')
# selection = alt.selection_multi();
# alt.Chart(dfx).mark_point(filled=True).encode(
#     alt.X('TodaysDate', scale=alt.Scale(zero=False)),
#     alt.Y('RecordCount', scale=alt.Scale(zero=False)),
#     alt.Size('RecordCount:Q'),
#     alt.OpacityValue(0.5),
#     alt.Order('RecordCount:Q', sort='descending'),
#     tooltip = [alt.Tooltip('TodaysDate:T'),
#                alt.Tooltip('RecordCount:Q'),
#                alt.Tooltip('DatabaseName:N'),
#                alt.Tooltip('SchemaName:N'),
#                alt.Tooltip('TableName:N'),
#               ],
#     color=alt.condition(selection, 'cluster:N', alt.value('grey'))
# ).add_selection(selection).properties(
#     title='x'
# ).properties(
#     width=750,
#     height=300
# ).interactive()

# %% [markdown]
# hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')
#
# base = alt.Chart(dfx, title='x').encode(
#        alt.X('TodaysDate:T')
#        #title.configure_title(fontSize=24)
#
# ).properties(
#     width=750, height=300,
# )
# points = base.mark_point().add_selection(
#     hover
# )
#
# line_A = base.mark_line(color='#5276A7').encode(
#     alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
# )
#
# line_B = base.mark_line(color='#F18727').encode(
#     alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
# )
# alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()

# %% [markdown]
# #alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
# alt.data_transformers.enable('json')
# selection = alt.selection_multi();
# alt.Chart(dfx).mark_point(filled=True).encode(
#     alt.X('TodaysDate', scale=alt.Scale(zero=False)),
#     alt.Y('RecordCount', scale=alt.Scale(zero=False)),
#     alt.Size('RecordCount:Q'),
#     alt.OpacityValue(0.5),
#     alt.Order('RecordCount:Q', sort='descending'),
#     tooltip = [alt.Tooltip('TodaysDate:T'),
#                alt.Tooltip('RecordCount:Q'),
#                alt.Tooltip('DatabaseName:N'),
#                alt.Tooltip('SchemaName:N'),
#                alt.Tooltip('TableName:N'),
#               ],
#     color=alt.condition(selection, 'cluster:N', alt.value('grey'))
# ).add_selection(selection).properties(
#     title='x'
# ).properties(
#     width=750,
#     height=300
# ).interactive()

# %% [markdown]
# hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')
#
# base = alt.Chart(dfx, title='x').encode(
#        alt.X('TodaysDate:T')
#        #title.configure_title(fontSize=24)
#
# ).properties(
#     width=750, height=300,
# )
# points = base.mark_point().add_selection(
#     hover
# )
#
# line_A = base.mark_line(color='#5276A7').encode(
#     alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
# )
#
# line_B = base.mark_line(color='#F18727').encode(
#     alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
# )
# alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()

# %% [markdown]
# #alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
# alt.data_transformers.enable('json')
# selection = alt.selection_multi();
# alt.Chart(dfx).mark_point(filled=True).encode(
#     alt.X('TodaysDate', scale=alt.Scale(zero=False)),
#     alt.Y('RecordCount', scale=alt.Scale(zero=False)),
#     alt.Size('RecordCount:Q'),
#     alt.OpacityValue(0.5),
#     alt.Order('RecordCount:Q', sort='descending'),
#     tooltip = [alt.Tooltip('TodaysDate:T'),
#                alt.Tooltip('RecordCount:Q'),
#                alt.Tooltip('DatabaseName:N'),
#                alt.Tooltip('SchemaName:N'),
#                alt.Tooltip('TableName:N'),
#               ],
#     color=alt.condition(selection, 'cluster:N', alt.value('grey'))
# ).add_selection(selection).properties(
#     title='x'
# ).properties(
#     width=750,
#     height=300
# ).interactive()

# %% [markdown]
# hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')
#
# base = alt.Chart(dfx, title='x').encode(
#        alt.X('TodaysDate:T')
#        #title.configure_title(fontSize=24)
#
# ).properties(
#     width=750, height=300,
# )
# points = base.mark_point().add_selection(
#     hover
# )
#
# line_A = base.mark_line(color='#5276A7').encode(
#     alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
# )
#
# line_B = base.mark_line(color='#F18727').encode(
#     alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
# )
# alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
