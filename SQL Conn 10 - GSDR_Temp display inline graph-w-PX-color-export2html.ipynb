# %%
#Program Name: Graphing ODS Databases - SQL Conn 10 - GSDR_Temp_Temp display inline graph-w-PX-color-export2html
#Purpose:  Chart scatter, line, box, aggr, violin, or bar with table data
#Author:  Greg Turmel, Director, Data Governance 
#Date:    2020.08.30 - 2021.06.30
#Errata:  0.1 Improvements can be made to script using for/looping through the databases

import os, time, datetime
import sqlalchemy as db
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import pyodbc 
import matplotlib
import plotly.express as px

#matplotlib.rcParams['figure.figsize'] = (30,5)
# %config InlineBackend.figure_format = 'retina'
from dotenv import load_dotenv # add this line
load_dotenv() # add this line
user = os.getenv('MySQLeUser')
password = os.getenv('MySQLeUserPass')
host = os.getenv('MySQLeHOST')
db = os.getenv('MySQLeDB')
# %matplotlib inline
# %load_ext sql

dt1 = time.strftime("%d/%m/%Y")
dt2 = time.strftime("%d.%m.%Y")
dt3 = pd.to_datetime('today')
dt4 = pd.Timestamp('today').strftime("%Y%m%d")
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=DEVODSSQL;'
                      'Database=Greg;'
                      'Trusted_Connection=yes;')

sql_query01 = pd.read_sql_query(''' 
select DISTINCT TableName
FROM [dbo].[tableRowCountGSDR_Temp]
ORDER BY TableName;     
                              '''
                              ,conn) # Load the list of distinct tables to graph

sql_query02 = pd.read_sql_query(''' 
select *
FROM [dbo].[tableRowCountGSDR_Temp]
ORDER BY TableName;     
                              '''
                              ,conn) # Load the list of distinct tables to graph

# %%
df = pd.DataFrame(sql_query02)
#df = df.astype({'TodaysDate':np.int64,'RecordCount':np.int64})
df['TodaysDate'] = pd.to_datetime(df['TodaysDate'].astype(str), format='%Y%m%d')
df = df.sort_values(by=['TableName','SchemaName','DatabaseName','TodaysDate'], ascending=[True,True,True,True])
df = df.reset_index(drop=True)

# %%
dfgsdrtmp0001 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'BUFORD') & (df['TableName'] == 'SDR_STU_C')]
dfgsdrtmp0002 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'BUFORD') & (df['TableName'] == 'SDR_STU_D')]
dfgsdrtmp0003 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'BUFORD') & (df['TableName'] == 'SDR_STU_E')]
dfgsdrtmp0004 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'BUFORD') & (df['TableName'] == 'SDR_STU_F')]
dfgsdrtmp0005 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'BUFORD') & (df['TableName'] == 'SDR_STU_G')]
dfgsdrtmp0006 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'BUFORD') & (df['TableName'] == 'SDR_STU_H')]
dfgsdrtmp0007 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'BUFORD') & (df['TableName'] == 'SDR_STU_K')]
dfgsdrtmp0008 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_AllSchools_Usage')]
dfgsdrtmp0009 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'D2L_Reporting_D2LSessionExport')]
dfgsdrtmp0010 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_OrgRoleCrosswalk')]
dfgsdrtmp0011 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_SchoolPopulation')]
dfgsdrtmp0012 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_SchoolPopulationDtl')]
dfgsdrtmp0013 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_SessionActivity')]
dfgsdrtmp0014 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_Reporting_TeacherSchedule')]
dfgsdrtmp0015 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_Usage')]
dfgsdrtmp0016 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_UsageDtl')]
dfgsdrtmp0017 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == '667errors')]
dfgsdrtmp0018 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AAA_Cohort_Report')]
dfgsdrtmp0019 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AcademicContract')]
dfgsdrtmp0020 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AcademicContractImport')]
dfgsdrtmp0021 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AcademicContractImportErrors')]
dfgsdrtmp0022 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AcademicContractIntervention')]
dfgsdrtmp0023 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ACCESS_Targets')]
dfgsdrtmp0024 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ACHSFILE')]
dfgsdrtmp0025 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ACRSTMP')]
dfgsdrtmp0026 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ActiveEnrollmentReportCache')]
dfgsdrtmp0027 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ActiveEnrollmentReportCacheAllSchools')]
dfgsdrtmp0028 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASTU_CHANGES')]
dfgsdrtmp0029 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'astv1819')]
dfgsdrtmp0030 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AttendanceSummary')]
dfgsdrtmp0031 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'BiLiteracyReport 2019')]
dfgsdrtmp0032 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'BlockFile')]
dfgsdrtmp0033 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'BlockFile_BPtest')]
dfgsdrtmp0034 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'BlockFileNewMapNet')]
dfgsdrtmp0035 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'BusPlanner_AddressListing')]
dfgsdrtmp0036 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CALENDAR_CHARLENE')]
dfgsdrtmp0037 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CALENDAR_CHARLENE2')]
dfgsdrtmp0038 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Calendar_Charlene3')]
dfgsdrtmp0039 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Calendar_Charlene4')]
dfgsdrtmp0040 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'cert_codes')]
dfgsdrtmp0041 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'COB_KS')]
dfgsdrtmp0042 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Cohort_Withdrawals')]
dfgsdrtmp0043 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Cohort20170201')]
dfgsdrtmp0044 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CohortAdditionalCourses')]
dfgsdrtmp0045 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Cohorts')]
dfgsdrtmp0046 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Cohorts2')]
dfgsdrtmp0047 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'COUNTRIES')]
dfgsdrtmp0048 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Course_No_EOCT')]
dfgsdrtmp0049 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CourseConversion')]
dfgsdrtmp0050 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CourseEvalType')]
dfgsdrtmp0051 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CourseMerged$')]
dfgsdrtmp0052 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CPI March 2017')]
dfgsdrtmp0053 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CPI_TEMP')]
dfgsdrtmp0054 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Crosswalk SPG Courses')]
dfgsdrtmp0055 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2L_NON_TEACHING_STAFF')]
dfgsdrtmp0056 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DavidDoesNotKnow')]
dfgsdrtmp0057 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'deleteSections')]
dfgsdrtmp0058 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DestinyOutstandingFees')]
dfgsdrtmp0059 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_Courses')]
dfgsdrtmp0060 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_EL_HISTORY')]
dfgsdrtmp0061 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_EL_HISTORY_temp')]
dfgsdrtmp0062 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_SPED_HISTORY')]
dfgsdrtmp0063 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DSCP_TEMP')]
dfgsdrtmp0064 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'E5098_Prim_Area20200324')]
dfgsdrtmp0065 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EL_Monitor_data')]
dfgsdrtmp0066 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Ellevation_Demographics')]
dfgsdrtmp0067 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ELPP_schedules_tb')]
dfgsdrtmp0068 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ELPP_test_scores_tb')]
dfgsdrtmp0069 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EmployeeEmailIDSource')]
dfgsdrtmp0070 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOC_PRELIM_2019')]
dfgsdrtmp0071 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOC_SCORES')]
dfgsdrtmp0072 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOCT_KAUSHAL')]
dfgsdrtmp0073 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOCT_Unmatched')]
dfgsdrtmp0074 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOG_PRELIM_2017')]
dfgsdrtmp0075 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOG_PRELIM_2018')]
dfgsdrtmp0076 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOG_PRELIM_2019')]
dfgsdrtmp0077 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA Assessments')]
dfgsdrtmp0078 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA Exam Taken')]
dfgsdrtmp0079 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA Pathways')]
dfgsdrtmp0080 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA_Clusters')]
dfgsdrtmp0081 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA_Courses')]
dfgsdrtmp0082 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA_Pathways')]
dfgsdrtmp0083 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA2016')]
dfgsdrtmp0084 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA2017')]
dfgsdrtmp0085 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'error_import')]
dfgsdrtmp0086 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Errors')]
dfgsdrtmp0087 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ESOL_COURSES_JUNE15')]
dfgsdrtmp0088 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ESOL115')]
dfgsdrtmp0089 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ESOL115_FTE')]
dfgsdrtmp0090 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'eTextBook_SchContact')]
dfgsdrtmp0091 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'eTextBook_SchContact_BAK')]
dfgsdrtmp0092 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'eTextBook_SchContact_temp')]
dfgsdrtmp0093 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'fay')]
dfgsdrtmp0094 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'fay2')]
dfgsdrtmp0095 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Feed_Portal_ITAcademyStudents')]
dfgsdrtmp0096 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Feed_Portal_SchoolNetStudents')]
dfgsdrtmp0097 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FineTypes')]
dfgsdrtmp0098 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FLATFILE_JCS')]
dfgsdrtmp0099 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FLP_Student_Attendance_List_tb')]
dfgsdrtmp0100 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FTE_ERRORS')]
dfgsdrtmp0101 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FTE_IVY_PREP')]
dfgsdrtmp0102 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FTE_REPORT_SCH')]
dfgsdrtmp0103 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FTE2019')]
dfgsdrtmp0104 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FTENUMB UPDATE 20131021')]
dfgsdrtmp0105 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FTENUMB UPDATE 20131024')]
dfgsdrtmp0106 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GA411Data')]
dfgsdrtmp0107 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GCPS_MA_AKS')]
dfgsdrtmp0108 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GSDR_DATA_LOADED')]
dfgsdrtmp0109 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GTID_IMPORTED')]
dfgsdrtmp0110 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HiQ_Courses_20140122')]
dfgsdrtmp0111 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'IEP_Accomondation_View_NewWay')]
dfgsdrtmp0112 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_active_elig_view')]
dfgsdrtmp0113 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_active_plan_view')]
dfgsdrtmp0114 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_bip_intervention_view')]
dfgsdrtmp0115 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'IEP_District_Users')]
dfgsdrtmp0116 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_goals_view')]
dfgsdrtmp0117 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_mods_ints_strengths_view')]
dfgsdrtmp0118 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_objectives_details')]
dfgsdrtmp0119 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_objectives_view')]
dfgsdrtmp0120 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_plan_list_view')]
dfgsdrtmp0121 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_student_casemanager_view')]
dfgsdrtmp0122 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_student_view')]
dfgsdrtmp0123 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ImportFile')]
dfgsdrtmp0124 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'IOWA_CoGAT_Report')]
dfgsdrtmp0125 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ItemsCheckedOut')]
dfgsdrtmp0126 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'kstemp')]
dfgsdrtmp0127 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'kstemp2')]
dfgsdrtmp0128 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'LA_AVG_Temp')]
dfgsdrtmp0129 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'LDS')]
dfgsdrtmp0130 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'LocalCourseMerged')]
dfgsdrtmp0131 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MA_AVG_Temp')]
dfgsdrtmp0132 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MYSTUDENT_DATA_RETRIEVAL_HISTORY')]
dfgsdrtmp0133 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MYSTUDENT_DATA_RETRIEVAL_STATUS')]
dfgsdrtmp0134 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'NEW_MYSTUDENT_DATA_RETRIEVAL_HISTORY')]
dfgsdrtmp0135 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'NEW_MYSTUDENT_DATA_RETRIEVAL_STATUS')]
dfgsdrtmp0136 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Organization_Chart')]
dfgsdrtmp0137 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PATHWAY_COURSE')]
dfgsdrtmp0138 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Patrons_For_Datamove')]
dfgsdrtmp0139 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PermnumFromRiderByRoute')]
dfgsdrtmp0140 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PHLOTE_AUG')]
dfgsdrtmp0141 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PHLOTE_JUN')]
dfgsdrtmp0142 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PIVOTDATA')]
dfgsdrtmp0143 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'portal_sec_aro_group_mbr_psd')]
dfgsdrtmp0144 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PreK_Entrance')]
dfgsdrtmp0145 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PreK_Exit')]
dfgsdrtmp0146 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PreK_Not_Met')]
dfgsdrtmp0147 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PRIMARY AREA UPDATE FTE20161')]
dfgsdrtmp0148 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'private_school_2014final')]
dfgsdrtmp0149 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'private_schools_2013')]
dfgsdrtmp0150 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'private_schools_2014')]
dfgsdrtmp0151 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'private_schools_2015')]
dfgsdrtmp0152 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'psd_activity_2019')]
dfgsdrtmp0153 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'psd_users_2019')]
dfgsdrtmp0154 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'psd_users_bak')]
dfgsdrtmp0155 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Pseudo FTE Nums')]
dfgsdrtmp0156 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Query2')]
dfgsdrtmp0157 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'RIDER_BY_ROUTE')]
dfgsdrtmp0158 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'RIDER_BY_ROUTE_SNAPSHOT')]
dfgsdrtmp0159 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Rising_6thGrd_Report')]
dfgsdrtmp0160 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Rising_7thGrd_Report')]
dfgsdrtmp0161 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Rising_7thGrd_Report_Bkup')]
dfgsdrtmp0162 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Rising_8thGrd_Report')]
dfgsdrtmp0163 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Rising_8thGrd_Report_Bkup')]
dfgsdrtmp0164 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SASI_ACHS441')]
dfgsdrtmp0165 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_1_AVG')]
dfgsdrtmp0166 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_1_ELIGIBLE')]
dfgsdrtmp0167 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_2_AVG')]
dfgsdrtmp0168 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_2_ELIGIBLE')]
dfgsdrtmp0169 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_3_AVG')]
dfgsdrtmp0170 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_3_ELIGIBLE')]
dfgsdrtmp0171 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SC_ERRORS')]
dfgsdrtmp0172 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SCHOOLFILE')]
dfgsdrtmp0173 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SchoolFoodNutritionDaily_GSDR_test')]
dfgsdrtmp0174 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SchoolReports_Subscribers')]
dfgsdrtmp0175 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Schools_KS')]
dfgsdrtmp0176 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SemesterDates')]
dfgsdrtmp0177 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SFN_Export')]
dfgsdrtmp0178 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_current_IEP')]
dfgsdrtmp0179 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_error_log')]
dfgsdrtmp0180 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_error_log_ref')]
dfgsdrtmp0181 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_iep_bip_antecedent_intervention_view')]
dfgsdrtmp0182 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_iep_bip_behavior_view')]
dfgsdrtmp0183 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_iep_bip_consequence_intervention_neg_view')]
dfgsdrtmp0184 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_iep_bip_consequence_intervention_pos_view')]
dfgsdrtmp0185 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_iep_bip_demographic_view')]
dfgsdrtmp0186 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_reg_transportation_green_view')]
dfgsdrtmp0187 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SIS_Testing_Accommodations_View')]
dfgsdrtmp0188 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SLO_Corrections')]
dfgsdrtmp0189 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20091031')]
dfgsdrtmp0190 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20131031')]
dfgsdrtmp0191 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20141031')]
dfgsdrtmp0192 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20151031')]
dfgsdrtmp0193 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20161031')]
dfgsdrtmp0194 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_201610312')]
dfgsdrtmp0195 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20171031')]
dfgsdrtmp0196 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20181031')]
dfgsdrtmp0197 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20191031')]
dfgsdrtmp0198 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'snp_today')]
dfgsdrtmp0199 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Sped_File_Push_data')]
dfgsdrtmp0200 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SpEd_TransListReport')]
dfgsdrtmp0201 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SPG Teachers To Validate')]
dfgsdrtmp0202 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SPG Teachers To Validate2')]
dfgsdrtmp0203 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'spg_courses_tests')]
dfgsdrtmp0204 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SPG_Export')]
dfgsdrtmp0205 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SPGCases_June20_2014')]
dfgsdrtmp0206 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SPGJUNE30')]
dfgsdrtmp0207 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'srfile')]
dfgsdrtmp0208 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StageStudentPictures')]
dfgsdrtmp0209 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StreetTypeAbbreviations')]
dfgsdrtmp0210 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass')]
dfgsdrtmp0211 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass_Buford')]
dfgsdrtmp0212 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass_Buford_SAVE')]
dfgsdrtmp0213 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass2015')]
dfgsdrtmp0214 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass2015v2')]
dfgsdrtmp0215 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass2016')]
dfgsdrtmp0216 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass2017')]
dfgsdrtmp0217 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass2018')]
dfgsdrtmp0218 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass20190601')]
dfgsdrtmp0219 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClassAppend')]
dfgsdrtmp0220 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentCourseProfile')]
dfgsdrtmp0221 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentCourseProfile2')]
dfgsdrtmp0222 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentIDfromSRTV')]
dfgsdrtmp0223 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentLogin20120827')]
dfgsdrtmp0224 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentLogin20120903')]
dfgsdrtmp0225 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentLogins')]
dfgsdrtmp0226 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerSchoolSites2017')]
dfgsdrtmp0227 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerSchoolSites2018')]
dfgsdrtmp0228 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerSchoolSites2019')]
dfgsdrtmp0229 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerStudentList')]
dfgsdrtmp0230 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerStudentList2017')]
dfgsdrtmp0231 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerStudentListTemp')]
dfgsdrtmp0232 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerStudentListtemp_backup')]
dfgsdrtmp0233 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerStudentListTemp_Bkup')]
dfgsdrtmp0234 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Synergy_ESOL_Status')]
dfgsdrtmp0235 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sysdtslog90')]
dfgsdrtmp0236 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sysssislog')]
dfgsdrtmp0237 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TeacherClass')]
dfgsdrtmp0238 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TeacherClass2')]
dfgsdrtmp0239 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_AD_Data')]
dfgsdrtmp0240 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_ad_groups')]
dfgsdrtmp0241 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_ad_groups_search')]
dfgsdrtmp0242 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_ad_membership')]
dfgsdrtmp0243 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_dscp_event_id_rules')]
dfgsdrtmp0244 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_groups')]
dfgsdrtmp0245 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Temp_MyTable')]
dfgsdrtmp0246 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_SASI_APRN')]
dfgsdrtmp0247 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEMP_TBL')]
dfgsdrtmp0248 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'test_academic_contracts')]
dfgsdrtmp0249 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Timeline 18_19')]
dfgsdrtmp0250 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Title1 Employees')]
dfgsdrtmp0251 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TMP_IEP_EXIT_VIEW')]
dfgsdrtmp0252 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TMP_IEP_SERVICES_SR_VIEW')]
dfgsdrtmp0253 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TranscriptData')]
dfgsdrtmp0254 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TranscriptSummary')]
dfgsdrtmp0255 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'udtMonths')]
dfgsdrtmp0256 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'UPKE')]
dfgsdrtmp0257 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'UPKX')]
dfgsdrtmp0258 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'USATestPrep_DataFeed')]
dfgsdrtmp0259 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'USATestPrep_DataFeed_2018')]
dfgsdrtmp0260 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'zoned_temp')]
dfgsdrtmp0261 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dx') & (df['TableName'] == 'Households_Import')]
dfgsdrtmp0262 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dx') & (df['TableName'] == 'HouseholdStudentMembers_Import')]
dfgsdrtmp0263 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dx') & (df['TableName'] == 'Locker_Import')]
dfgsdrtmp0264 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dx') & (df['TableName'] == 'MedIncident_Import')]
dfgsdrtmp0265 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dx') & (df['TableName'] == 'StudentContacts_Import')]
dfgsdrtmp0266 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'dx') & (df['TableName'] == 'StudentContactsParent_Import')]
dfgsdrtmp0267 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'OverrideStudents')]
dfgsdrtmp0268 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'OverrideStudentSections')]
dfgsdrtmp0269 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'OverrideTeachers')]
dfgsdrtmp0270 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'OverrideTeacherSections')]
dfgsdrtmp0271 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'PqAllTeacherQualifications')]
dfgsdrtmp0272 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'PqNonPqTeacherList')]
dfgsdrtmp0273 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'PqParentNotifications')]
dfgsdrtmp0274 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'PqRptAggDistrict')]
dfgsdrtmp0275 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'PqRptAggSchool')]
dfgsdrtmp0276 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'ReportActions')]
dfgsdrtmp0277 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'Reports')]
dfgsdrtmp0278 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StateCertifications')]
dfgsdrtmp0279 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StateCourseRequirements')]
dfgsdrtmp0280 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgPqPrep')]
dfgsdrtmp0281 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgSchools')]
dfgsdrtmp0282 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgSections')]
dfgsdrtmp0283 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgStudents')]
dfgsdrtmp0284 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgStudentSchedules')]
dfgsdrtmp0285 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgStudentServices')]
dfgsdrtmp0286 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgTeacherCertifications')]
dfgsdrtmp0287 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgTeacherExceptionalities')]
dfgsdrtmp0288 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgTeachers')]
dfgsdrtmp0289 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgTeacherSections')]
dfgsdrtmp0290 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'Assignment')]
dfgsdrtmp0291 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'AssignmentScore')]
dfgsdrtmp0292 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'Calendar')]
dfgsdrtmp0293 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'Gradebook')]
dfgsdrtmp0294 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradebookCategory')]
dfgsdrtmp0295 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradebookCategoryGrade')]
dfgsdrtmp0296 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradebookGradingScale')]
dfgsdrtmp0297 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradebookTerm')]
dfgsdrtmp0298 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradebookTermGrade')]
dfgsdrtmp0299 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradingScale')]
dfgsdrtmp0300 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradingScaleBreakpoint')]
dfgsdrtmp0301 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradingTerm')]
dfgsdrtmp0302 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'SectionEnrollment')]
dfgsdrtmp0303 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'Sections')]
dfgsdrtmp0304 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'Student')]
dfgsdrtmp0305 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'Teacher')]
dfgsdrtmp0306 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'TeacherSection')]
dfgsdrtmp0307 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Assignment')]
dfgsdrtmp0308 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'AssignmentGrades')]
dfgsdrtmp0309 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'AssignmentScore')]
dfgsdrtmp0310 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Calendar')]
dfgsdrtmp0311 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Course')]
dfgsdrtmp0312 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'D2L_CLASS_Import')]
dfgsdrtmp0313 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'D2L_Class_Import_20190410')]
dfgsdrtmp0314 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'D2L_GRADE_IMPORT')]
dfgsdrtmp0315 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'D2L_NOTE_Import')]
dfgsdrtmp0316 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'D2L_SCORE_Import')]
dfgsdrtmp0317 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'D2L_TASK_IMPORT')]
dfgsdrtmp0318 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'FinalGrades')]
dfgsdrtmp0319 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Gradebook')]
dfgsdrtmp0320 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'GradebookCategory')]
dfgsdrtmp0321 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'GradebookCategoryGrade')]
dfgsdrtmp0322 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'GradebookTerm')]
dfgsdrtmp0323 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'GradebookTermGrade')]
dfgsdrtmp0324 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'GradingScaleBreakpoint')]
dfgsdrtmp0325 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'GradingTerm')]
dfgsdrtmp0326 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Organization')]
dfgsdrtmp0327 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Person')]
dfgsdrtmp0328 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'PivotTable')]
dfgsdrtmp0329 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'RptAssignmentScore_CurrentTermFlag')]
dfgsdrtmp0330 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Section')]
dfgsdrtmp0331 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'SectionEnrollment')]
dfgsdrtmp0332 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Student')]
dfgsdrtmp0333 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'SynergyScore')]
dfgsdrtmp0334 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Teacher')]
dfgsdrtmp0335 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ACADEMIC_CONTRACTS')]
dfgsdrtmp0336 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ACHSFILE')]
dfgsdrtmp0337 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ADDRESS_HIST')]
dfgsdrtmp0338 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ADIA')]
dfgsdrtmp0339 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ADIA_ERROR_CODE')]
dfgsdrtmp0340 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ADIA_HISTORY')]
dfgsdrtmp0341 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ADIA_OMG')]
dfgsdrtmp0342 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ADST_ALL_YEARS')]
dfgsdrtmp0343 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'AFTSCH_TRANSP_PGMS')]
dfgsdrtmp0344 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'Applitrack')]
dfgsdrtmp0345 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'Applitrack_RecScore')]
dfgsdrtmp0346 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'Applitrack_Test')]
dfgsdrtmp0347 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ARCHATT')]
dfgsdrtmp0348 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'archatt_2018_restore')]
dfgsdrtmp0349 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ARCHGRD')]
dfgsdrtmp0350 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ASTU_HISTORY')]
dfgsdrtmp0351 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ATTDLET')]
dfgsdrtmp0352 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ATTEND_PARAM')]
dfgsdrtmp0353 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR')]
dfgsdrtmp0354 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_20180530')]
dfgsdrtmp0355 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_GAP')]
dfgsdrtmp0356 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_JIC')]
dfgsdrtmp0357 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_JIC2')]
dfgsdrtmp0358 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_JIC3')]
dfgsdrtmp0359 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_JIC4')]
dfgsdrtmp0360 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_NEWSTUFF')]
dfgsdrtmp0361 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_NEWSTUFF2')]
dfgsdrtmp0362 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CLASSRANK')]
dfgsdrtmp0363 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'COHORT2')]
dfgsdrtmp0364 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'COURSE')]
dfgsdrtmp0365 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'COURSE_REQUESTS')]
dfgsdrtmp0366 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'COURSE_REQUESTS_JIC')]
dfgsdrtmp0367 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'COURSE_REQUESTS_JIC_20170207')]
dfgsdrtmp0368 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'COURSE_REQUESTS_JIC2')]
dfgsdrtmp0369 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'COURSE_SETUP')]
dfgsdrtmp0370 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CPI_A01')]
dfgsdrtmp0371 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CPI_B01')]
dfgsdrtmp0372 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CPI_C01')]
dfgsdrtmp0373 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CPI_D01')]
dfgsdrtmp0374 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CRCT_MATCHED')]
dfgsdrtmp0375 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CRCT_MATCHED_TMP')]
dfgsdrtmp0376 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CRISNET_ARRESTS')]
dfgsdrtmp0377 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_ACTIVITY')]
dfgsdrtmp0378 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_ASSIGNMENTS')]
dfgsdrtmp0379 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_CONTACT_REASONS')]
dfgsdrtmp0380 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_CONTACT_TYPES')]
dfgsdrtmp0381 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_MEETINGS')]
dfgsdrtmp0382 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_OUTCOMES')]
dfgsdrtmp0383 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_REFERRALS')]
dfgsdrtmp0384 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_STUDENT_EDUCATIONS')]
dfgsdrtmp0385 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_STUDENT_HEALTHS')]
dfgsdrtmp0386 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_TRAININGS')]
dfgsdrtmp0387 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'dc_course_file_readonly')]
dfgsdrtmp0388 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'dc_innovator_schedules_readonly')]
dfgsdrtmp0389 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'dc_innovator_students_readonly')]
dfgsdrtmp0390 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'dc_innovator_teachers_readonly')]
dfgsdrtmp0391 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DELETED_GTIDS')]
dfgsdrtmp0392 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DELETED_GTIDS_HISTORY')]
dfgsdrtmp0393 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DESTINY_SCHOOLS')]
dfgsdrtmp0394 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DOE_CLAIMED_SWD')]
dfgsdrtmp0395 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DOE_SPED_NOPRIMARYAREA')]
dfgsdrtmp0396 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DSCP_ADDL_COMMENT')]
dfgsdrtmp0397 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DSCP_PANEL')]
dfgsdrtmp0398 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DSCP_PANEL_RULES')]
dfgsdrtmp0399 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DSCP_PANEL_SPED')]
dfgsdrtmp0400 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DUPLICATES')]
dfgsdrtmp0401 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EDIT_CODES')]
dfgsdrtmp0402 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ELIG_ACTIVITIES')]
dfgsdrtmp0403 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ELIG_LOG')]
dfgsdrtmp0404 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ELIG_PRAM')]
dfgsdrtmp0405 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_pram_bak20190717')]
dfgsdrtmp0406 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ELIG_PRAM_OBJECT')]
dfgsdrtmp0407 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ELIG_REQUIREMENTS')]
dfgsdrtmp0408 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ELIG_ROSTERS')]
dfgsdrtmp0409 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_rosters_lastupdate')]
dfgsdrtmp0410 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_rosters_nodups')]
dfgsdrtmp0411 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_rosters_sy1718_aftersummercalc')]
dfgsdrtmp0412 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_rosters_sy1819_aftersummercalc')]
dfgsdrtmp0413 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ELIG_STUDENTS')]
dfgsdrtmp0414 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_students_bak20190717')]
dfgsdrtmp0415 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_students_bak20190723')]
dfgsdrtmp0416 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_students_procbak')]
dfgsdrtmp0417 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_students_sy1718_aftersummercalc')]
dfgsdrtmp0418 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_students_sy1819_aftersummercalc')]
dfgsdrtmp0419 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EOCT_HIST')]
dfgsdrtmp0420 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ESOL')]
dfgsdrtmp0421 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ESOL_CAT')]
dfgsdrtmp0422 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EXP_REG_STU')]
dfgsdrtmp0423 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EXP_REG_SUM')]
dfgsdrtmp0424 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EXTERNAL_SCHOOLS')]
dfgsdrtmp0425 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'external_schools_all_years')]
dfgsdrtmp0426 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EXTERNAL_STUDENTS')]
dfgsdrtmp0427 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'external_students_all_years')]
dfgsdrtmp0428 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EXTERNAL_STUDENTS_NONDISTRICT')]
dfgsdrtmp0429 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EXTERNAL_STUDENTS_Tim')]
dfgsdrtmp0430 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FAY_RESEARCH')]
dfgsdrtmp0431 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FAY_RESEARCH_EOCT')]
dfgsdrtmp0432 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FORECAST')]
dfgsdrtmp0433 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FREE_REDUCED_LUNCH')]
dfgsdrtmp0434 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE')]
dfgsdrtmp0435 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_COURSES')]
dfgsdrtmp0436 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_ERRORLOAD')]
dfgsdrtmp0437 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_HISTORY')]
dfgsdrtmp0438 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_PARAMS')]
dfgsdrtmp0439 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_REPORT_ROWS')]
dfgsdrtmp0440 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_REPORT_SCH')]
dfgsdrtmp0441 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_REPORT_SCH20130220')]
dfgsdrtmp0442 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_TEMP')]
dfgsdrtmp0443 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_ZONED_SCH')]
dfgsdrtmp0444 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE441')]
dfgsdrtmp0445 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE88')]
dfgsdrtmp0446 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE88_KS')]
dfgsdrtmp0447 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTECRS_MULTI')]
dfgsdrtmp0448 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTEEIP')]
dfgsdrtmp0449 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTEGIFTED_STUDENT')]
dfgsdrtmp0450 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTENUMB_TANK')]
dfgsdrtmp0451 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTEPEOPLE')]
dfgsdrtmp0452 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESPED')]
dfgsdrtmp0453 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT')]
dfgsdrtmp0454 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_APPEND')]
dfgsdrtmp0455 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_BUF')]
dfgsdrtmp0456 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_BUF_KS')]
dfgsdrtmp0457 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_IVY')]
dfgsdrtmp0458 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_KS')]
dfgsdrtmp0459 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_LAST_YEAR')]
dfgsdrtmp0460 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_MAIN')]
dfgsdrtmp0461 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_YEAR')]
dfgsdrtmp0462 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GBATCH')]
dfgsdrtmp0463 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GBATCH_UPD')]
dfgsdrtmp0464 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GTID')]
dfgsdrtmp0465 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GTID_ERRORS')]
dfgsdrtmp0466 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GTID_HISTORY')]
dfgsdrtmp0467 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GTID_IMPORT')]
dfgsdrtmp0468 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GTID_STU_BATCH')]
dfgsdrtmp0469 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GTID_STU_BATCH_UPD')]
dfgsdrtmp0470 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'GIFTED')]
dfgsdrtmp0471 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'GIFTED_CAT')]
dfgsdrtmp0472 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'GRADETANK')]
dfgsdrtmp0473 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'GRADETANK_HISTORY')]
dfgsdrtmp0474 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'GRADETANK_KS')]
dfgsdrtmp0475 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'GRADETANK3')]
dfgsdrtmp0476 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'GRADETANKTEMP')]
dfgsdrtmp0477 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_EXIT')]
dfgsdrtmp0478 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_EXPORT')]
dfgsdrtmp0479 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_GAA_INFO')]
dfgsdrtmp0480 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_SERVICES')]
dfgsdrtmp0481 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_SERVICES_FTE')]
dfgsdrtmp0482 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_SERVICES_SR')]
dfgsdrtmp0483 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_TIMELINE')]
dfgsdrtmp0484 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_TranspRoster')]
dfgsdrtmp0485 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_TranspRoster_CaseManagerComments')]
dfgsdrtmp0486 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_TranspRoster_OtherSchools')]
dfgsdrtmp0487 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ISC_CONTRACTORS')]
dfgsdrtmp0488 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'LETTER_TEXT')]
dfgsdrtmp0489 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'LETTER_TEXT_SAVE')]
dfgsdrtmp0490 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'LOCATION')]
dfgsdrtmp0491 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'LTS_TNL_Mentor')]
dfgsdrtmp0492 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'MEDICAID')]
dfgsdrtmp0493 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'NEXT_SCHOOL')]
dfgsdrtmp0494 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'NEXT_SCHOOL_Audit')]
dfgsdrtmp0495 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'NON_TEACHERS')]
dfgsdrtmp0496 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'NOSHOWS')]
dfgsdrtmp0497 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'NOSHOWS2012')]
dfgsdrtmp0498 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_CODE_DEFINITIONS')]
dfgsdrtmp0499 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_LOOKUP_CODES')]
dfgsdrtmp0500 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'Portal_lookup_codes_20170131')]
dfgsdrtmp0501 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_lookup_codes_lastupdate')]
dfgsdrtmp0502 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_PARAM_MESSAGES')]
dfgsdrtmp0503 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_PARAMS')]
dfgsdrtmp0504 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ACL')]
dfgsdrtmp0505 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ACO')]
dfgsdrtmp0506 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ACO_MAP')]
dfgsdrtmp0507 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aco_map_lastupdate')]
dfgsdrtmp0508 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ARO')]
dfgsdrtmp0509 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ARO_ACL')]
dfgsdrtmp0510 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_acl_autobackup')]
dfgsdrtmp0511 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_acl_lastupdate')]
dfgsdrtmp0512 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ARO_GROUP_MBR')]
dfgsdrtmp0513 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_group_mbr_bak_20170413_psd')]
dfgsdrtmp0514 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_group_mbr_bak_20180409_psd')]
dfgsdrtmp0515 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_group_mbr_bak_20190411_psd')]
dfgsdrtmp0516 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_group_mbr_bak_20200411_psd')]
dfgsdrtmp0517 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ARO_GROUPS')]
dfgsdrtmp0518 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ARO_GROUPS_MAP')]
dfgsdrtmp0519 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_groups_map_lastupdate')]
dfgsdrtmp0520 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ARO_MAP')]
dfgsdrtmp0521 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_map_lastupdate')]
dfgsdrtmp0522 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_AXO')]
dfgsdrtmp0523 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_AXO_GROUP_MBR')]
dfgsdrtmp0524 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_AXO_GROUPS')]
dfgsdrtmp0525 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_AXO_GROUPS_MAP')]
dfgsdrtmp0526 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_axo_groups_map_lastupdate')]
dfgsdrtmp0527 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_AXO_MAP')]
dfgsdrtmp0528 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_axo_map_lastupdate')]
dfgsdrtmp0529 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PREVIOUS_VALUES')]
dfgsdrtmp0530 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_ATTD')]
dfgsdrtmp0531 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_EMP_JOBCD')]
dfgsdrtmp0532 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_EMPLOYEE')]
dfgsdrtmp0533 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_EMPLOYEE_JIC_20170206')]
dfgsdrtmp0534 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GP_ABS_EVENT')]
dfgsdrtmp0535 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GP_ABS_REASON')]
dfgsdrtmp0536 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GP_ABS_REASON2')]
dfgsdrtmp0537 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_CERT')]
dfgsdrtmp0538 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_CERT_DATA')]
dfgsdrtmp0539 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_CERT_DISCREPANCY')]
dfgsdrtmp0540 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_COURSE')]
dfgsdrtmp0541 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_COURSE_CERT')]
dfgsdrtmp0542 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_TNL_COURSE_SLO')]
dfgsdrtmp0543 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_TNL_COURSES')]
dfgsdrtmp0544 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_TNL_PRFL_TGT')]
dfgsdrtmp0545 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_JOBCD')]
dfgsdrtmp0546 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PSD_ACTIVITY')]
dfgsdrtmp0547 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'psd_activity_lastupdate')]
dfgsdrtmp0548 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PSD_APRN_LAST')]
dfgsdrtmp0549 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PSD_USERS')]
dfgsdrtmp0550 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'REGISTER')]
dfgsdrtmp0551 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'REGISTERSUMMARY')]
dfgsdrtmp0552 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'REGSUM')]
dfgsdrtmp0553 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'REGSUM_HISTORY')]
dfgsdrtmp0554 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_A504')]
dfgsdrtmp0555 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AATC')]
dfgsdrtmp0556 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AATC_ROT')]
dfgsdrtmp0557 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AATD')]
dfgsdrtmp0558 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_aatd_TSTAGING')]
dfgsdrtmp0559 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AATO_ROT')]
dfgsdrtmp0560 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AATP')]
dfgsdrtmp0561 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_aatp_TSTAGING')]
dfgsdrtmp0562 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AATT')]
dfgsdrtmp0563 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ABSENCE_CODES')]
dfgsdrtmp0564 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACAM')]
dfgsdrtmp0565 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACHS')]
dfgsdrtmp0566 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACHS_ES')]
dfgsdrtmp0567 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACHS_MS')]
dfgsdrtmp0568 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACHS_MSES')]
dfgsdrtmp0569 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACHS_SDR')]
dfgsdrtmp0570 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACHS9203768')]
dfgsdrtmp0571 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACLH')]
dfgsdrtmp0572 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACLS')]
dfgsdrtmp0573 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACLS_NEXT')]
dfgsdrtmp0574 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_acls_TSTAGING')]
dfgsdrtmp0575 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACNF')]
dfgsdrtmp0576 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACNR')]
dfgsdrtmp0577 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS')]
dfgsdrtmp0578 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS_FTE')]
dfgsdrtmp0579 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS_FTE2')]
dfgsdrtmp0580 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS_HS')]
dfgsdrtmp0581 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS_KS')]
dfgsdrtmp0582 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS_NEXT')]
dfgsdrtmp0583 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS_RAW')]
dfgsdrtmp0584 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS2012')]
dfgsdrtmp0585 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADIS')]
dfgsdrtmp0586 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADIS_C')]
dfgsdrtmp0587 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADIS_KS')]
dfgsdrtmp0588 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADPO')]
dfgsdrtmp0589 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADPO_C')]
dfgsdrtmp0590 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADPS')]
dfgsdrtmp0591 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADST')]
dfgsdrtmp0592 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADST_ALL')]
dfgsdrtmp0593 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AELT')]
dfgsdrtmp0594 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AELT_JUST_DATES')]
dfgsdrtmp0595 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AEMG')]
dfgsdrtmp0596 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AEMG_NEXT')]
dfgsdrtmp0597 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AENR')]
dfgsdrtmp0598 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AENR_C')]
dfgsdrtmp0599 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AENR_KS')]
dfgsdrtmp0600 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AENR_NEXT')]
dfgsdrtmp0601 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AENR_SUMMER')]
dfgsdrtmp0602 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AENR2')]
dfgsdrtmp0603 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AFEE')]
dfgsdrtmp0604 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AFID')]
dfgsdrtmp0605 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AGRD')]
dfgsdrtmp0606 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AGRL')]
dfgsdrtmp0607 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AGSU')]
dfgsdrtmp0608 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AHLT')]
dfgsdrtmp0609 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ALKR')]
dfgsdrtmp0610 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ALRT')]
dfgsdrtmp0611 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AMST')]
dfgsdrtmp0612 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AMST_NEXT')]
dfgsdrtmp0613 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AONL')]
dfgsdrtmp0614 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_APGD')]
dfgsdrtmp0615 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_APGL')]
dfgsdrtmp0616 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_APGM')]
dfgsdrtmp0617 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_APRN')]
dfgsdrtmp0618 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_APRN_LAST')]
dfgsdrtmp0619 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'sasi_aprn_sy1718')]
dfgsdrtmp0620 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'sasi_aprn_sy1819')]
dfgsdrtmp0621 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_APRN2012')]
dfgsdrtmp0622 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASCH')]
dfgsdrtmp0623 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASGR')]
dfgsdrtmp0624 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTI')]
dfgsdrtmp0625 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU')]
dfgsdrtmp0626 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_DEMOG')]
dfgsdrtmp0627 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_DIPLOMA_SEALS')]
dfgsdrtmp0628 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_EMAIL')]
dfgsdrtmp0629 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_GOSA_AUDIT')]
dfgsdrtmp0630 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_MIN')]
dfgsdrtmp0631 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_NEXT')]
dfgsdrtmp0632 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_TEMP')]
dfgsdrtmp0633 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTV')]
dfgsdrtmp0634 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTV_BP')]
dfgsdrtmp0635 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTV_NEXT')]
dfgsdrtmp0636 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATBL')]
dfgsdrtmp0637 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'sasi_atbl_BADREL')]
dfgsdrtmp0638 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATBL_KS')]
dfgsdrtmp0639 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATCH')]
dfgsdrtmp0640 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATCH_NEXT')]
dfgsdrtmp0641 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_atch_TSTAGING')]
dfgsdrtmp0642 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATES')]
dfgsdrtmp0643 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATPA')]
dfgsdrtmp0644 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATRM')]
dfgsdrtmp0645 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATRM2016')]
dfgsdrtmp0646 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATRM4')]
dfgsdrtmp0647 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATRMPORT')]
dfgsdrtmp0648 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AUFS')]
dfgsdrtmp0649 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_COUNTRY_OF_BIRTH')]
dfgsdrtmp0650 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_DISCP_RULES')]
dfgsdrtmp0651 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_DISCP_RULES_HIST')]
dfgsdrtmp0652 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_DISCP_RULES051219')]
dfgsdrtmp0653 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_DISPCODES')]
dfgsdrtmp0654 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_DISPCODES_HIST')]
dfgsdrtmp0655 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_DISPCODES051219')]
dfgsdrtmp0656 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ELL_PARENT_CONF')]
dfgsdrtmp0657 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ELL_WAIVER')]
dfgsdrtmp0658 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_FILE_HISTORY')]
dfgsdrtmp0659 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_GAT_HIS')]
dfgsdrtmp0660 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_LOAD_control')]
dfgsdrtmp0661 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_PARAPRO')]
dfgsdrtmp0662 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_SMST')]
dfgsdrtmp0663 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UABN')]
dfgsdrtmp0664 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UATR')]
dfgsdrtmp0665 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UATR_NEXT')]
dfgsdrtmp0666 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_uatr_TSTAGING')]
dfgsdrtmp0667 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UCES')]
dfgsdrtmp0668 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UCMS')]
dfgsdrtmp0669 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UFLP')]
dfgsdrtmp0670 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UGFT')]
dfgsdrtmp0671 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_Upload_Count_Difference')]
dfgsdrtmp0672 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UPLOAD_HISTORY')]
dfgsdrtmp0673 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UPSA')]
dfgsdrtmp0674 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UPSR')]
dfgsdrtmp0675 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UTL1')]
dfgsdrtmp0676 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SCHEDULES_MS_SAVE')]
dfgsdrtmp0677 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SCHOOL_CLUSTER')]
dfgsdrtmp0678 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SCHOOL_ETS_CODES')]
dfgsdrtmp0679 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SCP')]
dfgsdrtmp0680 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_DSCP_ACTIONS')]
dfgsdrtmp0681 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_DSCP_INCDTS')]
dfgsdrtmp0682 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_ENR')]
dfgsdrtmp0683 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_ERRORS')]
dfgsdrtmp0684 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_IEP_SPED')]
dfgsdrtmp0685 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_IEP_SPED2')]
dfgsdrtmp0686 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SCH_EDM')]
dfgsdrtmp0687 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SCH_TITLE1')]
dfgsdrtmp0688 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SCH_TITLE1_CHARLENE')]
dfgsdrtmp0689 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SCHOOL_B')]
dfgsdrtmp0690 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SCHOOL_N')]
dfgsdrtmp0691 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SCHOOL_NCLB')]
dfgsdrtmp0692 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_C')]
dfgsdrtmp0693 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_C_HOST')]
dfgsdrtmp0694 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_D')]
dfgsdrtmp0695 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_D_HOST')]
dfgsdrtmp0696 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_D_T')]
dfgsdrtmp0697 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_E')]
dfgsdrtmp0698 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_E_HOST')]
dfgsdrtmp0699 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_F')]
dfgsdrtmp0700 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_F_HOST')]
dfgsdrtmp0701 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_G')]
dfgsdrtmp0702 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_G_HOST')]
dfgsdrtmp0703 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_G_OLD')]
dfgsdrtmp0704 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_H')]
dfgsdrtmp0705 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_H_HOST')]
dfgsdrtmp0706 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_K')]
dfgsdrtmp0707 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_K_KS')]
dfgsdrtmp0708 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_K2')]
dfgsdrtmp0709 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_TITLE1')]
dfgsdrtmp0710 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SYS_J')]
dfgsdrtmp0711 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SYS_J20150613')]
dfgsdrtmp0712 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRC_HIST')]
dfgsdrtmp0713 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRCTMP')]
dfgsdrtmp0714 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRD_HIST')]
dfgsdrtmp0715 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRD2014')]
dfgsdrtmp0716 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRE_HIST')]
dfgsdrtmp0717 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRF_HIST')]
dfgsdrtmp0718 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRF_TMP')]
dfgsdrtmp0719 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRG_HIST')]
dfgsdrtmp0720 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRK_HIST')]
dfgsdrtmp0721 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRSTUFZ')]
dfgsdrtmp0722 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRSTUK_TMP')]
dfgsdrtmp0723 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SES')]
dfgsdrtmp0724 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SLDS_Teachers')]
dfgsdrtmp0725 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SPED_EXIT')]
dfgsdrtmp0726 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SPED_SCORE_CARD')]
dfgsdrtmp0727 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SPED_SCORE_REP')]
dfgsdrtmp0728 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SPED_SCORE_SUM')]
dfgsdrtmp0729 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SPED_TCH_SCHED')]
dfgsdrtmp0730 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SRO_RULES')]
dfgsdrtmp0731 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_ACTIVITY')]
dfgsdrtmp0732 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_ASSIGNMENTS')]
dfgsdrtmp0733 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_CASES')]
dfgsdrtmp0734 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ssw_cases_bak_20171219_before_code_update')]
dfgsdrtmp0735 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_CONTACT_REASONS')]
dfgsdrtmp0736 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_CONTACT_TYPES')]
dfgsdrtmp0737 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_DOE_CASES')]
dfgsdrtmp0738 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_DOE_REFERRALS')]
dfgsdrtmp0739 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_DOE_SERVICES')]
dfgsdrtmp0740 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_LOOKUP_CODES')]
dfgsdrtmp0741 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_MEETINGS')]
dfgsdrtmp0742 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_REFERRALS')]
dfgsdrtmp0743 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_STUDENTS')]
dfgsdrtmp0744 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'string_translation')]
dfgsdrtmp0745 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STU_FAY')]
dfgsdrtmp0746 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STU_HOPE_GRANT')]
dfgsdrtmp0747 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STU_ZONED_SCH')]
dfgsdrtmp0748 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUD_HOPE_GRANT')]
dfgsdrtmp0749 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUDENT_DISTRICT')]
dfgsdrtmp0750 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUDENT_FTEID')]
dfgsdrtmp0751 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUDENT_PROFILES')]
dfgsdrtmp0752 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUDENT_SCHEDULE')]
dfgsdrtmp0753 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUDENT_SCHOOLS')]
dfgsdrtmp0754 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUHEADR')]
dfgsdrtmp0755 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'TEACHER_LEAVE')]
dfgsdrtmp0756 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'TEACHER_SCHEDULE')]
dfgsdrtmp0757 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'TEMP_DOE_SPED_NOPRIMARYAREA')]
dfgsdrtmp0758 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'TIME_STAMP')]
dfgsdrtmp0759 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'TITLE1_SWP')]
dfgsdrtmp0760 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'TITLE1_TAS')]
dfgsdrtmp0761 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'USCO_CODES')]
dfgsdrtmp0762 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'XPRT_STUDENTS_NOSHOW')]
dfgsdrtmp0763 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Class')]
dfgsdrtmp0764 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Class_Backup_20170915')]
dfgsdrtmp0765 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Grade')]
dfgsdrtmp0766 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Grade_Backup_20170915')]
dfgsdrtmp0767 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Note')]
dfgsdrtmp0768 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Score')]
dfgsdrtmp0769 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'score_backup')]
dfgsdrtmp0770 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Score_Backup_20170915')]
dfgsdrtmp0771 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Task')]
dfgsdrtmp0772 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'task_backup')]
dfgsdrtmp0773 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Task_Backup_20170915')]
dfgsdrtmp0774 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'guest') & (df['TableName'] == 'FTE_GTID_Updates')]
dfgsdrtmp0775 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'guest') & (df['TableName'] == 'PermnumList')]
dfgsdrtmp0776 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'CALENDAR')]
dfgsdrtmp0777 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'G_GTID')]
dfgsdrtmp0778 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AATC')]
dfgsdrtmp0779 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AATC_ROT')]
dfgsdrtmp0780 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AATD')]
dfgsdrtmp0781 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AATO_ROT')]
dfgsdrtmp0782 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AATP')]
dfgsdrtmp0783 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AATT')]
dfgsdrtmp0784 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_ACLH')]
dfgsdrtmp0785 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_ACLS')]
dfgsdrtmp0786 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_ACRS')]
dfgsdrtmp0787 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_ACRS_RAW')]
dfgsdrtmp0788 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AENR')]
dfgsdrtmp0789 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AMST')]
dfgsdrtmp0790 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_ASTU')]
dfgsdrtmp0791 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_ATCH')]
dfgsdrtmp0792 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_ATRM')]
dfgsdrtmp0793 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_SMST')]
dfgsdrtmp0794 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'STUDENT_FTEID')]
dfgsdrtmp0795 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'TEACHER_LEAVE')]
dfgsdrtmp0796 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'TEACHER_LEAVE2')]
dfgsdrtmp0797 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'Teachers To Validate')]
dfgsdrtmp0798 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'CALENDAR')]
dfgsdrtmp0799 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'G_GTID')]
dfgsdrtmp0800 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_AATC')]
dfgsdrtmp0801 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_AATC_ROT')]
dfgsdrtmp0802 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_AATO_ROT')]
dfgsdrtmp0803 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_ACLH')]
dfgsdrtmp0804 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_ACLS')]
dfgsdrtmp0805 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_ACRS')]
dfgsdrtmp0806 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_ACRS_RAW')]
dfgsdrtmp0807 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_AENR')]
dfgsdrtmp0808 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_AMST')]
dfgsdrtmp0809 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_ASTU')]
dfgsdrtmp0810 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_ATCH')]
dfgsdrtmp0811 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_ATRM')]
dfgsdrtmp0812 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_SMST')]
dfgsdrtmp0813 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'STUDENT_FTEID')]
dfgsdrtmp0814 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'StudentClass')]
dfgsdrtmp0815 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'StudentCourseProfile')]
dfgsdrtmp0816 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'TEACHER_LEAVE')]
dfgsdrtmp0817 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'TEACHER_LEAVE2')]
dfgsdrtmp0818 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'TeacherClass')]
dfgsdrtmp0819 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'Teachers To Validate')]
dfgsdrtmp0820 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'Teachers To Validate20160211')]
dfgsdrtmp0821 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'stage') & (df['TableName'] == 'crisnet_arrests')]
dfgsdrtmp0822 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'stage') & (df['TableName'] == 'psd_input_file')]
dfgsdrtmp0823 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'StudentProfile') & (df['TableName'] == 'FACT_AttendanceByType')]
dfgsdrtmp0824 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'TCAccommodation') & (df['TableName'] == 'ELPP_Notes')]
dfgsdrtmp0825 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'TCAccommodation') & (df['TableName'] == 'IEPAccommodations')]
dfgsdrtmp0826 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'TCAccommodation') & (df['TableName'] == 'S504Accommodations')]
dfgsdrtmp0827 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'TCAccommodation') & (df['TableName'] == 'TPP_Notes')]
dfgsdrtmp0828 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'Attendance')]
dfgsdrtmp0829 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'Courses')]
dfgsdrtmp0830 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'CumGPA')]
dfgsdrtmp0831 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'EOC')]
dfgsdrtmp0832 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'GPA')]
dfgsdrtmp0833 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'School')]
dfgsdrtmp0834 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'SchoolsAttended')]
dfgsdrtmp0835 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'Semesters')]
dfgsdrtmp0836 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'SpecialStudents')]
dfgsdrtmp0837 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'Student')]
dfgsdrtmp0838 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'SUMLA')]
dfgsdrtmp0839 = df[(df['DatabaseName'] == 'GSDR_Temp') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'TestAssesments')]

# %%
d = dfgsdrtmp0001[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0001, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 52828    GSDR_Temp     BUFORD  SDR_STU_C

# %%
d = dfgsdrtmp0002[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0002, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 53110    GSDR_Temp     BUFORD  SDR_STU_D

# %%
d = dfgsdrtmp0003[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0003, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 53486    GSDR_Temp     BUFORD  SDR_STU_E

# %%
d = dfgsdrtmp0004[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0004, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 53768    GSDR_Temp     BUFORD  SDR_STU_F

# %%
d = dfgsdrtmp0005[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0005, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 54050    GSDR_Temp     BUFORD  SDR_STU_G

# %%
d = dfgsdrtmp0006[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0006, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 54426    GSDR_Temp     BUFORD  SDR_STU_H

# %%
d = dfgsdrtmp0007[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0007, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 54708    GSDR_Temp     BUFORD  SDR_STU_K

# %%
d = dfgsdrtmp0008[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0008, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                       TableName
# 69936    GSDR_Temp        d2l  d2l_reporting_AllSchools_Usage

# %%
d = dfgsdrtmp0009[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0009, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                       TableName
# 10058    GSDR_Temp        d2l  D2L_Reporting_D2LSessionExport

# %%
d = dfgsdrtmp0010[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0010, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                       TableName
# 70030    GSDR_Temp        d2l  d2l_reporting_OrgRoleCrosswalk

# %%
d = dfgsdrtmp0011[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0011, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                       TableName
# 70124    GSDR_Temp        d2l  d2l_reporting_SchoolPopulation

# %%
d = dfgsdrtmp0012[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0012, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                          TableName
# 70218    GSDR_Temp        d2l  d2l_reporting_SchoolPopulationDtl

# %%
d = dfgsdrtmp0013[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0013, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 70312    GSDR_Temp        d2l  d2l_reporting_SessionActivity

# %%
d = dfgsdrtmp0014[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0014, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 69842    GSDR_Temp        d2l  d2l_Reporting_TeacherSchedule

# %%
d = dfgsdrtmp0015[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0015, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 70406    GSDR_Temp        d2l  d2l_reporting_Usage

# %%
d = dfgsdrtmp0016[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0016, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 70500    GSDR_Temp        d2l  d2l_reporting_UsageDtl

# %%
d = dfgsdrtmp0017[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0017, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#   DatabaseName SchemaName  TableName
# 0    GSDR_Temp        dbo  667errors

# %%
d = dfgsdrtmp0018[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0018, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#    DatabaseName SchemaName          TableName
# 94    GSDR_Temp        dbo  AAA_Cohort_Report

# %%
d = dfgsdrtmp0019[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0019, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName         TableName
# 1880    GSDR_Temp        dbo  AcademicContract

# %%
d = dfgsdrtmp0020[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0020, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName               TableName
# 1974    GSDR_Temp        dbo  AcademicContractImport

# %%
d = dfgsdrtmp0021[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0021, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                     TableName
# 2068    GSDR_Temp        dbo  AcademicContractImportErrors

# %%
d = dfgsdrtmp0022[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0022, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                     TableName
# 2162    GSDR_Temp        dbo  AcademicContractIntervention

# %%
d = dfgsdrtmp0023[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0023, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName       TableName
# 282    GSDR_Temp        dbo  ACCESS_Targets

# %%
d = dfgsdrtmp0024[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0024, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName TableName
# 470    GSDR_Temp        dbo  ACHSFILE

# %%
d = dfgsdrtmp0025[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0025, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName TableName
# 564    GSDR_Temp        dbo   ACRSTMP

# %%
d = dfgsdrtmp0026[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0026, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                    TableName
# 2256    GSDR_Temp        dbo  ActiveEnrollmentReportCache

# %%
d = dfgsdrtmp0027[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0027, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                              TableName
# 2350    GSDR_Temp        dbo  ActiveEnrollmentReportCacheAllSchools

# %%
d = dfgsdrtmp0028[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0028, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName     TableName
# 1504    GSDR_Temp        dbo  ASTU_CHANGES

# %%
d = dfgsdrtmp0029[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0029, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 69560    GSDR_Temp        dbo  astv1819

# %%
d = dfgsdrtmp0030[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0030, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName          TableName
# 3290    GSDR_Temp        dbo  AttendanceSummary

# %%
d = dfgsdrtmp0031[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0031, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName              TableName
# 3384    GSDR_Temp        dbo  BiLiteracyReport 2019

# %%
d = dfgsdrtmp0032[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0032, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName  TableName
# 3478    GSDR_Temp        dbo  BlockFile

# %%
d = dfgsdrtmp0033[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0033, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName         TableName
# 3666    GSDR_Temp        dbo  BlockFile_BPtest

# %%
d = dfgsdrtmp0034[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0034, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 3572    GSDR_Temp        dbo  BlockFileNewMapNet

# %%
d = dfgsdrtmp0035[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0035, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                  TableName
# 3760    GSDR_Temp        dbo  BusPlanner_AddressListing

# %%
d = dfgsdrtmp0036[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0036, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName          TableName
# 4230    GSDR_Temp        dbo  CALENDAR_CHARLENE

# %%
d = dfgsdrtmp0037[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0037, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 4324    GSDR_Temp        dbo  CALENDAR_CHARLENE2

# %%
d = dfgsdrtmp0038[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0038, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 7990    GSDR_Temp        dbo  Calendar_Charlene3

# %%
d = dfgsdrtmp0039[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0039, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 8084    GSDR_Temp        dbo  Calendar_Charlene4

# %%
d = dfgsdrtmp0040[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0040, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 69654    GSDR_Temp        dbo  cert_codes

# %%
d = dfgsdrtmp0041[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0041, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 5170    GSDR_Temp        dbo    COB_KS

# %%
d = dfgsdrtmp0042[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0042, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 8554    GSDR_Temp        dbo  Cohort_Withdrawals

# %%
d = dfgsdrtmp0043[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0043, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 8366    GSDR_Temp        dbo  Cohort20170201

# %%
d = dfgsdrtmp0044[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0044, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                TableName
# 8460    GSDR_Temp        dbo  CohortAdditionalCourses

# %%
d = dfgsdrtmp0045[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0045, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 8648    GSDR_Temp        dbo   Cohorts

# %%
d = dfgsdrtmp0046[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0046, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 8742    GSDR_Temp        dbo  Cohorts2

# %%
d = dfgsdrtmp0047[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0047, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName  TableName
# 5358    GSDR_Temp        dbo  COUNTRIES

# %%
d = dfgsdrtmp0048[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0048, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 9212    GSDR_Temp        dbo  Course_No_EOCT

# %%
d = dfgsdrtmp0049[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0049, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName         TableName
# 8930    GSDR_Temp        dbo  CourseConversion

# %%
d = dfgsdrtmp0050[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0050, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 9024    GSDR_Temp        dbo  CourseEvalType

# %%
d = dfgsdrtmp0051[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0051, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName      TableName
# 9118    GSDR_Temp        dbo  CourseMerged$

# %%
d = dfgsdrtmp0052[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0052, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 6016    GSDR_Temp        dbo  CPI March 2017

# %%
d = dfgsdrtmp0053[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0053, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 6486    GSDR_Temp        dbo  CPI_TEMP

# %%
d = dfgsdrtmp0054[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0054, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName              TableName
# 9400    GSDR_Temp        dbo  Crosswalk SPG Courses

# %%
d = dfgsdrtmp0055[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0055, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName               TableName
# 9870    GSDR_Temp        dbo  D2L_NON_TEACHING_STAFF

# %%
d = dfgsdrtmp0056[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0056, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 11750    GSDR_Temp        dbo  DavidDoesNotKnow

# %%
d = dfgsdrtmp0057[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0057, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 70970    GSDR_Temp        dbo  deleteSections

# %%
d = dfgsdrtmp0058[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0058, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 11844    GSDR_Temp        dbo  DestinyOutstandingFees

# %%
d = dfgsdrtmp0059[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0059, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 10716    GSDR_Temp        dbo  DOE_Courses

# %%
d = dfgsdrtmp0060[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0060, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 10810    GSDR_Temp        dbo  DOE_EL_HISTORY

# %%
d = dfgsdrtmp0061[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0061, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 10904    GSDR_Temp        dbo  DOE_EL_HISTORY_temp

# %%
d = dfgsdrtmp0062[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0062, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 10998    GSDR_Temp        dbo  DOE_SPED_HISTORY

# %%
d = dfgsdrtmp0063[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0063, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 11562    GSDR_Temp        dbo  DSCP_TEMP

# %%
d = dfgsdrtmp0064[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0064, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 11938    GSDR_Temp        dbo  E5098_Prim_Area20200324

# %%
d = dfgsdrtmp0065[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0065, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 13066    GSDR_Temp        dbo  EL_Monitor_data

# %%
d = dfgsdrtmp0066[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0066, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 15792    GSDR_Temp        dbo  Ellevation_Demographics

# %%
d = dfgsdrtmp0067[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0067, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 12878    GSDR_Temp        dbo  ELPP_schedules_tb

# %%
d = dfgsdrtmp0068[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0068, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 12972    GSDR_Temp        dbo  ELPP_test_scores_tb

# %%
d = dfgsdrtmp0069[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0069, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 15886    GSDR_Temp        dbo  EmployeeEmailIDSource

# %%
d = dfgsdrtmp0070[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0070, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 13536    GSDR_Temp        dbo  EOC_PRELIM_2019

# %%
d = dfgsdrtmp0071[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0071, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 13630    GSDR_Temp        dbo  EOC_SCORES

# %%
d = dfgsdrtmp0072[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0072, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 13348    GSDR_Temp        dbo  EOCT_KAUSHAL

# %%
d = dfgsdrtmp0073[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0073, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 13442    GSDR_Temp        dbo  EOCT_Unmatched

# %%
d = dfgsdrtmp0074[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0074, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 13724    GSDR_Temp        dbo  EOG_PRELIM_2017

# %%
d = dfgsdrtmp0075[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0075, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 13818    GSDR_Temp        dbo  EOG_PRELIM_2018

# %%
d = dfgsdrtmp0076[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0076, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 13912    GSDR_Temp        dbo  EOG_PRELIM_2019

# %%
d = dfgsdrtmp0077[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0077, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 14006    GSDR_Temp        dbo  EOPA Assessments

# %%
d = dfgsdrtmp0078[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0078, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 14100    GSDR_Temp        dbo  EOPA Exam Taken

# %%
d = dfgsdrtmp0079[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0079, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 14194    GSDR_Temp        dbo  EOPA Pathways

# %%
d = dfgsdrtmp0080[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0080, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 14476    GSDR_Temp        dbo  EOPA_Clusters

# %%
d = dfgsdrtmp0081[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0081, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 14570    GSDR_Temp        dbo  EOPA_Courses

# %%
d = dfgsdrtmp0082[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0082, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 14664    GSDR_Temp        dbo  EOPA_Pathways

# %%
d = dfgsdrtmp0083[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0083, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 14288    GSDR_Temp        dbo  EOPA2016

# %%
d = dfgsdrtmp0084[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0084, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 14382    GSDR_Temp        dbo  EOPA2017

# %%
d = dfgsdrtmp0085[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0085, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 72286    GSDR_Temp        dbo  error_import

# %%
d = dfgsdrtmp0086[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0086, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 15980    GSDR_Temp        dbo    Errors

# %%
d = dfgsdrtmp0087[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0087, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 15134    GSDR_Temp        dbo  ESOL_COURSES_JUNE15

# %%
d = dfgsdrtmp0088[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0088, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 14852    GSDR_Temp        dbo   ESOL115

# %%
d = dfgsdrtmp0089[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0089, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 14946    GSDR_Temp        dbo  ESOL115_FTE

# %%
d = dfgsdrtmp0090[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0090, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 71064    GSDR_Temp        dbo  eTextBook_SchContact

# %%
d = dfgsdrtmp0091[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0091, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 71158    GSDR_Temp        dbo  eTextBook_SchContact_BAK

# %%
d = dfgsdrtmp0092[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0092, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 71252    GSDR_Temp        dbo  eTextBook_SchContact_temp

# %%
d = dfgsdrtmp0093[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0093, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 72568    GSDR_Temp        dbo       fay

# %%
d = dfgsdrtmp0094[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0094, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 72662    GSDR_Temp        dbo      fay2

# %%
d = dfgsdrtmp0095[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0095, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 20022    GSDR_Temp        dbo  Feed_Portal_ITAcademyStudents

# %%
d = dfgsdrtmp0096[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0096, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 20116    GSDR_Temp        dbo  Feed_Portal_SchoolNetStudents

# %%
d = dfgsdrtmp0097[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0097, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 20304    GSDR_Temp        dbo  FineTypes

# %%
d = dfgsdrtmp0098[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0098, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 16356    GSDR_Temp        dbo  FLATFILE_JCS

# %%
d = dfgsdrtmp0099[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0099, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                       TableName
# 16450    GSDR_Temp        dbo  FLP_Student_Attendance_List_tb

# %%
d = dfgsdrtmp0100[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0100, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 18988    GSDR_Temp        dbo  FTE_ERRORS

# %%
d = dfgsdrtmp0101[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0101, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 19270    GSDR_Temp        dbo  FTE_IVY_PREP

# %%
d = dfgsdrtmp0102[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0102, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 19646    GSDR_Temp        dbo  FTE_REPORT_SCH

# %%
d = dfgsdrtmp0103[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0103, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 16826    GSDR_Temp        dbo   FTE2019

# %%
d = dfgsdrtmp0104[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0104, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 17484    GSDR_Temp        dbo  FTENUMB UPDATE 20131021

# %%
d = dfgsdrtmp0105[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0105, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 17578    GSDR_Temp        dbo  FTENUMB UPDATE 20131024

# %%
d = dfgsdrtmp0106[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0106, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 20398    GSDR_Temp        dbo  GA411Data

# %%
d = dfgsdrtmp0107[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0107, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 20492    GSDR_Temp        dbo  GCPS_MA_AKS

# %%
d = dfgsdrtmp0108[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0108, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 21338    GSDR_Temp        dbo  GSDR_DATA_LOADED

# %%
d = dfgsdrtmp0109[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0109, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 21432    GSDR_Temp        dbo  GTID_IMPORTED

# %%
d = dfgsdrtmp0110[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0110, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 24158    GSDR_Temp        dbo  HiQ_Courses_20140122

# %%
d = dfgsdrtmp0111[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0111, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 24534    GSDR_Temp        dbo  IEP_Accomondation_View_NewWay

# %%
d = dfgsdrtmp0112[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0112, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 72756    GSDR_Temp        dbo  iep_active_elig_view

# %%
d = dfgsdrtmp0113[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0113, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 72850    GSDR_Temp        dbo  iep_active_plan_view

# %%
d = dfgsdrtmp0114[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0114, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 72944    GSDR_Temp        dbo  iep_bip_intervention_view

# %%
d = dfgsdrtmp0115[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0115, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 24628    GSDR_Temp        dbo  IEP_District_Users

# %%
d = dfgsdrtmp0116[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0116, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 73038    GSDR_Temp        dbo  iep_goals_view

# %%
d = dfgsdrtmp0117[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0117, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 73132    GSDR_Temp        dbo  iep_mods_ints_strengths_view

# %%
d = dfgsdrtmp0118[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0118, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 73226    GSDR_Temp        dbo  iep_objectives_details

# %%
d = dfgsdrtmp0119[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0119, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 73320    GSDR_Temp        dbo  iep_objectives_view

# %%
d = dfgsdrtmp0120[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0120, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 73414    GSDR_Temp        dbo  iep_plan_list_view

# %%
d = dfgsdrtmp0121[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0121, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 73508    GSDR_Temp        dbo  iep_student_casemanager_view

# %%
d = dfgsdrtmp0122[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0122, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 73602    GSDR_Temp        dbo  iep_student_view

# %%
d = dfgsdrtmp0123[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0123, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 25850    GSDR_Temp        dbo  ImportFile

# %%
d = dfgsdrtmp0124[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0124, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 25662    GSDR_Temp        dbo  IOWA_CoGAT_Report

# %%
d = dfgsdrtmp0125[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0125, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 25944    GSDR_Temp        dbo  ItemsCheckedOut

# %%
d = dfgsdrtmp0126[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0126, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 73696    GSDR_Temp        dbo    kstemp

# %%
d = dfgsdrtmp0127[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0127, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 73790    GSDR_Temp        dbo   kstemp2

# %%
d = dfgsdrtmp0128[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0128, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 26038    GSDR_Temp        dbo  LA_AVG_Temp

# %%
d = dfgsdrtmp0129[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0129, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 26132    GSDR_Temp        dbo       LDS

# %%
d = dfgsdrtmp0130[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0130, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 26602    GSDR_Temp        dbo  LocalCourseMerged

# %%
d = dfgsdrtmp0131[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0131, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 26790    GSDR_Temp        dbo  MA_AVG_Temp

# %%
d = dfgsdrtmp0132[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0132, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                         TableName
# 26978    GSDR_Temp        dbo  MYSTUDENT_DATA_RETRIEVAL_HISTORY

# %%
d = dfgsdrtmp0133[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0133, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                        TableName
# 27072    GSDR_Temp        dbo  MYSTUDENT_DATA_RETRIEVAL_STATUS

# %%
d = dfgsdrtmp0134[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0134, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                             TableName
# 27260    GSDR_Temp        dbo  NEW_MYSTUDENT_DATA_RETRIEVAL_HISTORY

# %%
d = dfgsdrtmp0135[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0135, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                            TableName
# 27354    GSDR_Temp        dbo  NEW_MYSTUDENT_DATA_RETRIEVAL_STATUS

# %%
d = dfgsdrtmp0136[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0136, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 28106    GSDR_Temp        dbo  Organization_Chart

# %%
d = dfgsdrtmp0137[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0137, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 28576    GSDR_Temp        dbo  PATHWAY_COURSE

# %%
d = dfgsdrtmp0138[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0138, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 32618    GSDR_Temp        dbo  Patrons_For_Datamove

# %%
d = dfgsdrtmp0139[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0139, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 32712    GSDR_Temp        dbo  PermnumFromRiderByRoute

# %%
d = dfgsdrtmp0140[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0140, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 28670    GSDR_Temp        dbo  PHLOTE_AUG

# %%
d = dfgsdrtmp0141[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0141, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 28764    GSDR_Temp        dbo  PHLOTE_JUN

# %%
d = dfgsdrtmp0142[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0142, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 28858    GSDR_Temp        dbo  PIVOTDATA

# %%
d = dfgsdrtmp0143[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0143, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 74636    GSDR_Temp        dbo  portal_sec_aro_group_mbr_psd

# %%
d = dfgsdrtmp0144[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0144, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 33652    GSDR_Temp        dbo  PreK_Entrance

# %%
d = dfgsdrtmp0145[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0145, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 33746    GSDR_Temp        dbo  PreK_Exit

# %%
d = dfgsdrtmp0146[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0146, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 33840    GSDR_Temp        dbo  PreK_Not_Met

# %%
d = dfgsdrtmp0147[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0147, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 30738    GSDR_Temp        dbo  PRIMARY AREA UPDATE FTE20161

# %%
d = dfgsdrtmp0148[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0148, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 75106    GSDR_Temp        dbo  private_school_2014final

# %%
d = dfgsdrtmp0149[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0149, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 75200    GSDR_Temp        dbo  private_schools_2013

# %%
d = dfgsdrtmp0150[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0150, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 75294    GSDR_Temp        dbo  private_schools_2014

# %%
d = dfgsdrtmp0151[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0151, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 75388    GSDR_Temp        dbo  private_schools_2015

# %%
d = dfgsdrtmp0152[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0152, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 75482    GSDR_Temp        dbo  psd_activity_2019

# %%
d = dfgsdrtmp0153[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0153, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 75764    GSDR_Temp        dbo  psd_users_2019

# %%
d = dfgsdrtmp0154[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0154, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 75858    GSDR_Temp        dbo  psd_users_bak

# %%
d = dfgsdrtmp0155[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0155, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 33934    GSDR_Temp        dbo  Pseudo FTE Nums

# %%
d = dfgsdrtmp0156[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0156, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 34028    GSDR_Temp        dbo    Query2

# %%
d = dfgsdrtmp0157[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0157, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 34498    GSDR_Temp        dbo  RIDER_BY_ROUTE

# %%
d = dfgsdrtmp0158[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0158, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 34592    GSDR_Temp        dbo  RIDER_BY_ROUTE_SNAPSHOT

# %%
d = dfgsdrtmp0159[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0159, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 34874    GSDR_Temp        dbo  Rising_6thGrd_Report

# %%
d = dfgsdrtmp0160[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0160, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 34968    GSDR_Temp        dbo  Rising_7thGrd_Report

# %%
d = dfgsdrtmp0161[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0161, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 35062    GSDR_Temp        dbo  Rising_7thGrd_Report_Bkup

# %%
d = dfgsdrtmp0162[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0162, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 35156    GSDR_Temp        dbo  Rising_8thGrd_Report

# %%
d = dfgsdrtmp0163[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0163, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 35250    GSDR_Temp        dbo  Rising_8thGrd_Report_Bkup

# %%
d = dfgsdrtmp0164[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0164, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 37318    GSDR_Temp        dbo  SASI_ACHS441

# %%
d = dfgsdrtmp0165[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0165, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 49538    GSDR_Temp        dbo  SAT_REPORT_SESSION_1_AVG

# %%
d = dfgsdrtmp0166[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0166, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 49632    GSDR_Temp        dbo  SAT_REPORT_SESSION_1_ELIGIBLE

# %%
d = dfgsdrtmp0167[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0167, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 49726    GSDR_Temp        dbo  SAT_REPORT_SESSION_2_AVG

# %%
d = dfgsdrtmp0168[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0168, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 49820    GSDR_Temp        dbo  SAT_REPORT_SESSION_2_ELIGIBLE

# %%
d = dfgsdrtmp0169[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0169, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 49914    GSDR_Temp        dbo  SAT_REPORT_SESSION_3_AVG

# %%
d = dfgsdrtmp0170[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0170, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 50008    GSDR_Temp        dbo  SAT_REPORT_SESSION_3_ELIGIBLE

# %%
d = dfgsdrtmp0171[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0171, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 50572    GSDR_Temp        dbo  SC_ERRORS

# %%
d = dfgsdrtmp0172[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0172, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 50196    GSDR_Temp        dbo  SCHOOLFILE

# %%
d = dfgsdrtmp0173[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0173, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                           TableName
# 60160    GSDR_Temp        dbo  SchoolFoodNutritionDaily_GSDR_test

# %%
d = dfgsdrtmp0174[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0174, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 60254    GSDR_Temp        dbo  SchoolReports_Subscribers

# %%
d = dfgsdrtmp0175[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0175, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 60442    GSDR_Temp        dbo  Schools_KS

# %%
d = dfgsdrtmp0176[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0176, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 61100    GSDR_Temp        dbo  SemesterDates

# %%
d = dfgsdrtmp0177[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0177, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 55460    GSDR_Temp        dbo  SFN_Export

# %%
d = dfgsdrtmp0178[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0178, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 76328    GSDR_Temp        dbo  sis_current_IEP

# %%
d = dfgsdrtmp0179[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0179, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 76422    GSDR_Temp        dbo  sis_error_log

# %%
d = dfgsdrtmp0180[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0180, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 76516    GSDR_Temp        dbo  sis_error_log_ref

# %%
d = dfgsdrtmp0181[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0181, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                                 TableName
# 76610    GSDR_Temp        dbo  sis_iep_bip_antecedent_intervention_view

# %%
d = dfgsdrtmp0182[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0182, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 76704    GSDR_Temp        dbo  sis_iep_bip_behavior_view

# %%
d = dfgsdrtmp0183[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0183, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                                      TableName
# 76798    GSDR_Temp        dbo  sis_iep_bip_consequence_intervention_neg_view

# %%
d = dfgsdrtmp0184[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0184, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                                      TableName
# 76892    GSDR_Temp        dbo  sis_iep_bip_consequence_intervention_pos_view

# %%
d = dfgsdrtmp0185[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0185, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 76986    GSDR_Temp        dbo  sis_iep_bip_demographic_view

# %%
d = dfgsdrtmp0186[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0186, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                          TableName
# 77080    GSDR_Temp        dbo  sis_reg_transportation_green_view

# %%
d = dfgsdrtmp0187[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0187, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                        TableName
# 55554    GSDR_Temp        dbo  SIS_Testing_Accommodations_View

# %%
d = dfgsdrtmp0188[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0188, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 55742    GSDR_Temp        dbo  SLO_Corrections

# %%
d = dfgsdrtmp0189[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0189, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 55836    GSDR_Temp        dbo  SNP_20091031

# %%
d = dfgsdrtmp0190[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0190, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 55930    GSDR_Temp        dbo  SNP_20131031

# %%
d = dfgsdrtmp0191[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0191, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 56024    GSDR_Temp        dbo  SNP_20141031

# %%
d = dfgsdrtmp0192[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0192, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 56118    GSDR_Temp        dbo  SNP_20151031

# %%
d = dfgsdrtmp0193[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0193, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 56212    GSDR_Temp        dbo  SNP_20161031

# %%
d = dfgsdrtmp0194[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0194, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 56306    GSDR_Temp        dbo  SNP_201610312

# %%
d = dfgsdrtmp0195[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0195, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 56400    GSDR_Temp        dbo  SNP_20171031

# %%
d = dfgsdrtmp0196[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0196, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 56494    GSDR_Temp        dbo  SNP_20181031

# %%
d = dfgsdrtmp0197[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0197, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 56588    GSDR_Temp        dbo  SNP_20191031

# %%
d = dfgsdrtmp0198[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0198, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 77174    GSDR_Temp        dbo  snp_today

# %%
d = dfgsdrtmp0199[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0199, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 61476    GSDR_Temp        dbo  Sped_File_Push_data

# %%
d = dfgsdrtmp0200[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0100, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 61288    GSDR_Temp        dbo  SpEd_TransListReport

# %%
d = dfgsdrtmp0201[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0201, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 57152    GSDR_Temp        dbo  SPG Teachers To Validate

# %%
d = dfgsdrtmp0202[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0202, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 57246    GSDR_Temp        dbo  SPG Teachers To Validate2

# %%
d = dfgsdrtmp0203[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0203, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 77268    GSDR_Temp        dbo  spg_courses_tests

# %%
d = dfgsdrtmp0204[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0204, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 57528    GSDR_Temp        dbo  SPG_Export

# %%
d = dfgsdrtmp0205[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0205, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 57340    GSDR_Temp        dbo  SPGCases_June20_2014

# %%
d = dfgsdrtmp0206[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0206, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 57434    GSDR_Temp        dbo  SPGJUNE30

# %%
d = dfgsdrtmp0207[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0207, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 77362    GSDR_Temp        dbo    srfile

# %%
d = dfgsdrtmp0208[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0208, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 61570    GSDR_Temp        dbo  StageStudentPictures

# %%
d = dfgsdrtmp0209[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0209, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 62792    GSDR_Temp        dbo  StreetTypeAbbreviations

# %%
d = dfgsdrtmp0210[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0210, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 63262    GSDR_Temp        dbo  StudentClass

# %%
d = dfgsdrtmp0211[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0211, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 64014    GSDR_Temp        dbo  StudentClass_Buford

# %%
d = dfgsdrtmp0212[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0212, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 64108    GSDR_Temp        dbo  StudentClass_Buford_SAVE

# %%
d = dfgsdrtmp0213[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0213, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 63356    GSDR_Temp        dbo  StudentClass2015

# %%
d = dfgsdrtmp0214[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0214, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 63450    GSDR_Temp        dbo  StudentClass2015v2

# %%
d = dfgsdrtmp0215[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0215, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 63544    GSDR_Temp        dbo  StudentClass2016

# %%
d = dfgsdrtmp0216[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0216, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 63638    GSDR_Temp        dbo  StudentClass2017

# %%
d = dfgsdrtmp0217[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0217, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 63732    GSDR_Temp        dbo  StudentClass2018

# %%
d = dfgsdrtmp0218[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0218, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 63826    GSDR_Temp        dbo  StudentClass20190601

# %%
d = dfgsdrtmp0219[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0219, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 63920    GSDR_Temp        dbo  StudentClassAppend

# %%
d = dfgsdrtmp0220[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0220, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 64484    GSDR_Temp        dbo  StudentCourseProfile

# %%
d = dfgsdrtmp0221[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0221, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 64578    GSDR_Temp        dbo  StudentCourseProfile2

# %%
d = dfgsdrtmp0222[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0222, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 64672    GSDR_Temp        dbo  StudentIDfromSRTV

# %%
d = dfgsdrtmp0223[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0223, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 64766    GSDR_Temp        dbo  StudentLogin20120827

# %%
d = dfgsdrtmp0224[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0224, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 64860    GSDR_Temp        dbo  StudentLogin20120903

# %%
d = dfgsdrtmp0225[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0225, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 64954    GSDR_Temp        dbo  StudentLogins

# %%
d = dfgsdrtmp0226[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0226, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 65048    GSDR_Temp        dbo  SummerSchoolSites2017

# %%
d = dfgsdrtmp0227[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0227, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 65142    GSDR_Temp        dbo  SummerSchoolSites2018

# %%
d = dfgsdrtmp0228[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0228, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 65236    GSDR_Temp        dbo  SummerSchoolSites2019

# %%
d = dfgsdrtmp0229[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0229, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 65330    GSDR_Temp        dbo  SummerStudentList

# %%
d = dfgsdrtmp0230[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0230, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 65424    GSDR_Temp        dbo  SummerStudentList2017

# %%
d = dfgsdrtmp0231[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0231, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 65518    GSDR_Temp        dbo  SummerStudentListTemp

# %%
d = dfgsdrtmp0232[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0232, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 65706    GSDR_Temp        dbo  SummerStudentListtemp_backup

# %%
d = dfgsdrtmp0233[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0233, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                   TableName
# 65612    GSDR_Temp        dbo  SummerStudentListTemp_Bkup

# %%
d = dfgsdrtmp0234[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0234, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 65894    GSDR_Temp        dbo  Synergy_ESOL_Status

# %%
d = dfgsdrtmp0235[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0235, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 77644    GSDR_Temp        dbo  sysdtslog90

# %%
d = dfgsdrtmp0236[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0236, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 77738    GSDR_Temp        dbo  sysssislog

# %%
d = dfgsdrtmp0237[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0237, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 67774    GSDR_Temp        dbo  TeacherClass

# %%
d = dfgsdrtmp0238[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0238, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 67868    GSDR_Temp        dbo  TeacherClass2

# %%
d = dfgsdrtmp0239[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0239, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 77926    GSDR_Temp        dbo  temp_AD_Data

# %%
d = dfgsdrtmp0240[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0240, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 78114    GSDR_Temp        dbo  temp_ad_groups

# %%
d = dfgsdrtmp0241[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0241, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 78208    GSDR_Temp        dbo  temp_ad_groups_search

# %%
d = dfgsdrtmp0242[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0242, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 78302    GSDR_Temp        dbo  temp_ad_membership

# %%
d = dfgsdrtmp0243[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0243, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 78396    GSDR_Temp        dbo  temp_dscp_event_id_rules

# %%
d = dfgsdrtmp0244[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0244, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 78490    GSDR_Temp        dbo  temp_groups

# %%
d = dfgsdrtmp0245[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0245, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 68338    GSDR_Temp        dbo  Temp_MyTable

# %%
d = dfgsdrtmp0246[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0246, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 78020    GSDR_Temp        dbo  temp_SASI_APRN

# %%
d = dfgsdrtmp0247[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0247, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 66646    GSDR_Temp        dbo  TEMP_TBL

# %%
d = dfgsdrtmp0248[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0248, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 78584    GSDR_Temp        dbo  test_academic_contracts

# %%
d = dfgsdrtmp0249[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0249, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 68526    GSDR_Temp        dbo  Timeline 18_19

# %%
d = dfgsdrtmp0250[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0250, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 68620    GSDR_Temp        dbo  Title1 Employees

# %%
d = dfgsdrtmp0251[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0251, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 67022    GSDR_Temp        dbo  TMP_IEP_EXIT_VIEW

# %%
d = dfgsdrtmp0252[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0252, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 67116    GSDR_Temp        dbo  TMP_IEP_SERVICES_SR_VIEW

# %%
d = dfgsdrtmp0253[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0253, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 68714    GSDR_Temp        dbo  TranscriptData

# %%
d = dfgsdrtmp0254[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0254, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 68808    GSDR_Temp        dbo  TranscriptSummary

# %%
d = dfgsdrtmp0255[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0255, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 78678    GSDR_Temp        dbo  udtMonths

# %%
d = dfgsdrtmp0256[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0256, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 68902    GSDR_Temp        dbo      UPKE

# %%
d = dfgsdrtmp0257[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0257, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 68996    GSDR_Temp        dbo      UPKX

# %%
d = dfgsdrtmp0258[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0258, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 69090    GSDR_Temp        dbo  USATestPrep_DataFeed

# %%
d = dfgsdrtmp0259[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0259, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 69184    GSDR_Temp        dbo  USATestPrep_DataFeed_2018

# %%
d = dfgsdrtmp0260[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0260, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 78772    GSDR_Temp        dbo  zoned_temp

# %%
d = dfgsdrtmp0261[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0261, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 24346    GSDR_Temp         dx  Households_Import

# %%
d = dfgsdrtmp0262[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0262, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                       TableName
# 24252    GSDR_Temp         dx  HouseholdStudentMembers_Import

# %%
d = dfgsdrtmp0263[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0263, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 26696    GSDR_Temp         dx  Locker_Import

# %%
d = dfgsdrtmp0264[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0264, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 27166    GSDR_Temp         dx  MedIncident_Import

# %%
d = dfgsdrtmp0265[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0265, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 64296    GSDR_Temp         dx  StudentContacts_Import

# %%
d = dfgsdrtmp0266[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0266, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 64202    GSDR_Temp         dx  StudentContactsParent_Import

# %%
d = dfgsdrtmp0267[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0267, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 28294    GSDR_Temp       essa  OverrideStudents

# %%
d = dfgsdrtmp0268[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0268, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 28200    GSDR_Temp       essa  OverrideStudentSections

# %%
d = dfgsdrtmp0269[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0269, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 28482    GSDR_Temp       essa  OverrideTeachers

# %%
d = dfgsdrtmp0270[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0270, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 28388    GSDR_Temp       essa  OverrideTeacherSections

# %%
d = dfgsdrtmp0271[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0271, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                   TableName
# 33182    GSDR_Temp       essa  PqAllTeacherQualifications

# %%
d = dfgsdrtmp0272[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0272, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 33276    GSDR_Temp       essa  PqNonPqTeacherList

# %%
d = dfgsdrtmp0273[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0273, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 33370    GSDR_Temp       essa  PqParentNotifications

# %%
d = dfgsdrtmp0274[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0274, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 33464    GSDR_Temp       essa  PqRptAggDistrict

# %%
d = dfgsdrtmp0275[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0275, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 33558    GSDR_Temp       essa  PqRptAggSchool

# %%
d = dfgsdrtmp0276[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0276, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 34686    GSDR_Temp       essa  ReportActions

# %%
d = dfgsdrtmp0277[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0277, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 34780    GSDR_Temp       essa   Reports

# %%
d = dfgsdrtmp0278[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0278, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 61664    GSDR_Temp       essa  StateCertifications

# %%
d = dfgsdrtmp0279[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0279, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 61758    GSDR_Temp       essa  StateCourseRequirements

# %%
d = dfgsdrtmp0280[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0280, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 61852    GSDR_Temp       essa  StgPqPrep

# %%
d = dfgsdrtmp0281[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0281, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 61946    GSDR_Temp       essa  StgSchools

# %%
d = dfgsdrtmp0282[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0282, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 62040    GSDR_Temp       essa  StgSections

# %%
d = dfgsdrtmp0283[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0283, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 62322    GSDR_Temp       essa  StgStudents

# %%
d = dfgsdrtmp0284[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0284, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 62134    GSDR_Temp       essa  StgStudentSchedules

# %%
d = dfgsdrtmp0285[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0285, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 62228    GSDR_Temp       essa  StgStudentServices

# %%
d = dfgsdrtmp0286[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0286, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 62416    GSDR_Temp       essa  StgTeacherCertifications

# %%
d = dfgsdrtmp0287[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0287, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                   TableName
# 62510    GSDR_Temp       essa  StgTeacherExceptionalities

# %%
d = dfgsdrtmp0288[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0288, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 62698    GSDR_Temp       essa  StgTeachers

# %%
d = dfgsdrtmp0289[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0289, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 62604    GSDR_Temp       essa  StgTeacherSections

# %%
d = dfgsdrtmp0290[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0290, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName   TableName
# 2820    GSDR_Temp      gbOLD  Assignment

# %%
d = dfgsdrtmp0291[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0291, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName        TableName
# 3102    GSDR_Temp      gbOLD  AssignmentScore

# %%
d = dfgsdrtmp0292[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0292, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 7896    GSDR_Temp      gbOLD  Calendar

# %%
d = dfgsdrtmp0293[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0293, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 22748    GSDR_Temp      gbOLD  Gradebook

# %%
d = dfgsdrtmp0294[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0294, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 22936    GSDR_Temp      gbOLD  GradebookCategory

# %%
d = dfgsdrtmp0295[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0295, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 23124    GSDR_Temp      gbOLD  GradebookCategoryGrade

# %%
d = dfgsdrtmp0296[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0296, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 23218    GSDR_Temp      gbOLD  GradebookGradingScale

# %%
d = dfgsdrtmp0297[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0297, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 23406    GSDR_Temp      gbOLD  GradebookTerm

# %%
d = dfgsdrtmp0298[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0298, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 23594    GSDR_Temp      gbOLD  GradebookTermGrade

# %%
d = dfgsdrtmp0299[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0299, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 23688    GSDR_Temp      gbOLD  GradingScale

# %%
d = dfgsdrtmp0300[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0300, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 23876    GSDR_Temp      gbOLD  GradingScaleBreakpoint

# %%
d = dfgsdrtmp0301[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0301, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 24064    GSDR_Temp      gbOLD  GradingTerm

# %%
d = dfgsdrtmp0302[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0302, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 60912    GSDR_Temp      gbOLD  SectionEnrollment

# %%
d = dfgsdrtmp0303[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0303, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 61006    GSDR_Temp      gbOLD  Sections

# %%
d = dfgsdrtmp0304[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0304, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 63074    GSDR_Temp      gbOLD   Student

# %%
d = dfgsdrtmp0305[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0305, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 67586    GSDR_Temp      gbOLD   Teacher

# %%
d = dfgsdrtmp0306[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0306, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 67962    GSDR_Temp      gbOLD  TeacherSection

# %%
d = dfgsdrtmp0307[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0307, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName   TableName
# 2726    GSDR_Temp  GBStaging  Assignment

# %%
d = dfgsdrtmp0308[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0308, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName         TableName
# 2914    GSDR_Temp  GBStaging  AssignmentGrades

# %%
d = dfgsdrtmp0309[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0309, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName        TableName
# 3008    GSDR_Temp  GBStaging  AssignmentScore

# %%
d = dfgsdrtmp0310[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0310, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 7802    GSDR_Temp  GBStaging  Calendar

# %%
d = dfgsdrtmp0311[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0311, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 8836    GSDR_Temp  GBStaging    Course

# %%
d = dfgsdrtmp0312[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0312, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName         TableName
# 9588    GSDR_Temp  GBStaging  D2L_CLASS_Import

# %%
d = dfgsdrtmp0313[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0313, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                  TableName
# 9682    GSDR_Temp  GBStaging  D2L_Class_Import_20190410

# %%
d = dfgsdrtmp0314[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0314, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName         TableName
# 9776    GSDR_Temp  GBStaging  D2L_GRADE_IMPORT

# %%
d = dfgsdrtmp0315[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0315, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName        TableName
# 9964    GSDR_Temp  GBStaging  D2L_NOTE_Import

# %%
d = dfgsdrtmp0316[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0316, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 10152    GSDR_Temp  GBStaging  D2L_SCORE_Import

# %%
d = dfgsdrtmp0317[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0317, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 10246    GSDR_Temp  GBStaging  D2L_TASK_IMPORT

# %%
d = dfgsdrtmp0318[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0318, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 20210    GSDR_Temp  GBStaging  FinalGrades

# %%
d = dfgsdrtmp0319[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0319, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 22654    GSDR_Temp  GBStaging  Gradebook

# %%
d = dfgsdrtmp0320[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0320, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 22842    GSDR_Temp  GBStaging  GradebookCategory

# %%
d = dfgsdrtmp0321[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0321, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 23030    GSDR_Temp  GBStaging  GradebookCategoryGrade

# %%
d = dfgsdrtmp0322[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0322, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 23312    GSDR_Temp  GBStaging  GradebookTerm

# %%
d = dfgsdrtmp0323[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0323, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 23500    GSDR_Temp  GBStaging  GradebookTermGrade

# %%
d = dfgsdrtmp0324[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0324, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 23782    GSDR_Temp  GBStaging  GradingScaleBreakpoint

# %%
d = dfgsdrtmp0325[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0325, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 23970    GSDR_Temp  GBStaging  GradingTerm

# %%
d = dfgsdrtmp0326[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0326, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 28012    GSDR_Temp  GBStaging  Organization

# %%
d = dfgsdrtmp0327[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0327, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 32900    GSDR_Temp  GBStaging    Person

# %%
d = dfgsdrtmp0328[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0328, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 32994    GSDR_Temp  GBStaging  PivotTable

# %%
d = dfgsdrtmp0329[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0329, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                           TableName
# 35344    GSDR_Temp  GBStaging  RptAssignmentScore_CurrentTermFlag

# %%
d = dfgsdrtmp0330[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0330, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 60724    GSDR_Temp  GBStaging   Section

# %%
d = dfgsdrtmp0331[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0331, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 60818    GSDR_Temp  GBStaging  SectionEnrollment

# %%
d = dfgsdrtmp0332[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0332, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 62886    GSDR_Temp  GBStaging   Student

# %%
d = dfgsdrtmp0333[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0333, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 65800    GSDR_Temp  GBStaging  SynergyScore

# %%
d = dfgsdrtmp0334[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0334, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 67492    GSDR_Temp  GBStaging   Teacher

# %%
d = dfgsdrtmp0335[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0335, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName           TableName
# 188    GSDR_Temp       GEMS  ACADEMIC_CONTRACTS

# %%
d = dfgsdrtmp0336[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0336, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName TableName
# 376    GSDR_Temp       GEMS  ACHSFILE

# %%
d = dfgsdrtmp0337[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0337, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName     TableName
# 658    GSDR_Temp       GEMS  ADDRESS_HIST

# %%
d = dfgsdrtmp0338[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0338, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName TableName
# 752    GSDR_Temp       GEMS      ADIA

# %%
d = dfgsdrtmp0339[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0339, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName        TableName
# 846    GSDR_Temp       GEMS  ADIA_ERROR_CODE

# %%
d = dfgsdrtmp0340[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0340, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName     TableName
# 940    GSDR_Temp       GEMS  ADIA_HISTORY

# %%
d = dfgsdrtmp0341[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0341, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 1034    GSDR_Temp       GEMS  ADIA_OMG

# %%
d = dfgsdrtmp0342[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0342, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 1128    GSDR_Temp       GEMS  ADST_ALL_YEARS

# %%
d = dfgsdrtmp0343[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0343, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 1222    GSDR_Temp       GEMS  AFTSCH_TRANSP_PGMS

# %%
d = dfgsdrtmp0344[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0344, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName   TableName
# 2444    GSDR_Temp       GEMS  Applitrack

# %%
d = dfgsdrtmp0345[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0345, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName            TableName
# 2538    GSDR_Temp       GEMS  Applitrack_RecScore

# %%
d = dfgsdrtmp0346[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0346, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName        TableName
# 2632    GSDR_Temp       GEMS  Applitrack_Test

# %%
d = dfgsdrtmp0347[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0347, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 1316    GSDR_Temp       GEMS   ARCHATT

# %%
d = dfgsdrtmp0348[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0348, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 69466    GSDR_Temp       GEMS  archatt_2018_restore

# %%
d = dfgsdrtmp0349[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0349, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 1410    GSDR_Temp       GEMS   ARCHGRD

# %%
d = dfgsdrtmp0350[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0350, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName     TableName
# 1598    GSDR_Temp       GEMS  ASTU_HISTORY

# %%
d = dfgsdrtmp0351[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0351, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 1692    GSDR_Temp       GEMS   ATTDLET

# %%
d = dfgsdrtmp0352[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0352, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName     TableName
# 1786    GSDR_Temp       GEMS  ATTEND_PARAM

# %%
d = dfgsdrtmp0353[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0353, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 3854    GSDR_Temp       GEMS  CALENDAR

# %%
d = dfgsdrtmp0354[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0354, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName          TableName
# 4136    GSDR_Temp       GEMS  CALENDAR_20180530

# %%
d = dfgsdrtmp0355[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0355, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName     TableName
# 4418    GSDR_Temp       GEMS  CALENDAR_GAP

# %%
d = dfgsdrtmp0356[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0356, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName     TableName
# 4512    GSDR_Temp       GEMS  CALENDAR_JIC

# %%
d = dfgsdrtmp0357[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0357, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName      TableName
# 4606    GSDR_Temp       GEMS  CALENDAR_JIC2

# %%
d = dfgsdrtmp0358[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0358, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName      TableName
# 4700    GSDR_Temp       GEMS  CALENDAR_JIC3

# %%
d = dfgsdrtmp0359[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0359, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName      TableName
# 4794    GSDR_Temp       GEMS  CALENDAR_JIC4

# %%
d = dfgsdrtmp0360[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0360, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName          TableName
# 4888    GSDR_Temp       GEMS  CALENDAR_NEWSTUFF

# %%
d = dfgsdrtmp0361[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0361, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 4982    GSDR_Temp       GEMS  CALENDAR_NEWSTUFF2

# %%
d = dfgsdrtmp0362[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0362, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName  TableName
# 5076    GSDR_Temp       GEMS  CLASSRANK

# %%
d = dfgsdrtmp0363[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0363, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 5264    GSDR_Temp       GEMS   COHORT2

# %%
d = dfgsdrtmp0364[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0364, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 5452    GSDR_Temp       GEMS    COURSE

# %%
d = dfgsdrtmp0365[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0365, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName        TableName
# 5546    GSDR_Temp       GEMS  COURSE_REQUESTS

# %%
d = dfgsdrtmp0366[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0366, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName            TableName
# 5640    GSDR_Temp       GEMS  COURSE_REQUESTS_JIC

# %%
d = dfgsdrtmp0367[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0367, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                     TableName
# 5828    GSDR_Temp       GEMS  COURSE_REQUESTS_JIC_20170207

# %%
d = dfgsdrtmp0368[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0368, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName             TableName
# 5734    GSDR_Temp       GEMS  COURSE_REQUESTS_JIC2

# %%
d = dfgsdrtmp0369[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0369, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName     TableName
# 5922    GSDR_Temp       GEMS  COURSE_SETUP

# %%
d = dfgsdrtmp0370[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0370, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 6110    GSDR_Temp       GEMS   CPI_A01

# %%
d = dfgsdrtmp0371[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0371, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 6204    GSDR_Temp       GEMS   CPI_B01

# %%
d = dfgsdrtmp0372[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0372, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 6298    GSDR_Temp       GEMS   CPI_C01

# %%
d = dfgsdrtmp0373[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0373, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 6392    GSDR_Temp       GEMS   CPI_D01

# %%
d = dfgsdrtmp0374[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0374, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName     TableName
# 6580    GSDR_Temp       GEMS  CRCT_MATCHED

# %%
d = dfgsdrtmp0375[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0375, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName         TableName
# 6674    GSDR_Temp       GEMS  CRCT_MATCHED_TMP

# %%
d = dfgsdrtmp0376[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0376, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName        TableName
# 6768    GSDR_Temp       GEMS  CRISNET_ARRESTS

# %%
d = dfgsdrtmp0377[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0377, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName     TableName
# 6862    GSDR_Temp       GEMS  CSN_ACTIVITY

# %%
d = dfgsdrtmp0378[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0378, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName        TableName
# 6956    GSDR_Temp       GEMS  CSN_ASSIGNMENTS

# %%
d = dfgsdrtmp0379[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0379, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName            TableName
# 7050    GSDR_Temp       GEMS  CSN_CONTACT_REASONS

# %%
d = dfgsdrtmp0380[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0380, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName          TableName
# 7144    GSDR_Temp       GEMS  CSN_CONTACT_TYPES

# %%
d = dfgsdrtmp0381[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0381, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName     TableName
# 7238    GSDR_Temp       GEMS  CSN_MEETINGS

# %%
d = dfgsdrtmp0382[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0382, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName     TableName
# 7332    GSDR_Temp       GEMS  CSN_OUTCOMES

# %%
d = dfgsdrtmp0383[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0383, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName      TableName
# 7426    GSDR_Temp       GEMS  CSN_REFERRALS

# %%
d = dfgsdrtmp0384[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0384, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName               TableName
# 7520    GSDR_Temp       GEMS  CSN_STUDENT_EDUCATIONS

# %%
d = dfgsdrtmp0385[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0385, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName            TableName
# 7614    GSDR_Temp       GEMS  CSN_STUDENT_HEALTHS

# %%
d = dfgsdrtmp0386[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0386, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName      TableName
# 7708    GSDR_Temp       GEMS  CSN_TRAININGS

# %%
d = dfgsdrtmp0387[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0387, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 70594    GSDR_Temp       GEMS  dc_course_file_readonly

# %%
d = dfgsdrtmp0388[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0388, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                        TableName
# 70688    GSDR_Temp       GEMS  dc_innovator_schedules_readonly

# %%
d = dfgsdrtmp0389[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0389, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                       TableName
# 70782    GSDR_Temp       GEMS  dc_innovator_students_readonly

# %%
d = dfgsdrtmp0390[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0390, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                       TableName
# 70876    GSDR_Temp       GEMS  dc_innovator_teachers_readonly

# %%
d = dfgsdrtmp0391[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0391, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 10340    GSDR_Temp       GEMS  DELETED_GTIDS

# %%
d = dfgsdrtmp0392[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0392, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 10434    GSDR_Temp       GEMS  DELETED_GTIDS_HISTORY

# %%
d = dfgsdrtmp0393[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0393, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 10528    GSDR_Temp       GEMS  DESTINY_SCHOOLS

# %%
d = dfgsdrtmp0394[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0394, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 10622    GSDR_Temp       GEMS  DOE_CLAIMED_SWD

# %%
d = dfgsdrtmp0395[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0395, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 11092    GSDR_Temp       GEMS  DOE_SPED_NOPRIMARYAREA

# %%
d = dfgsdrtmp0396[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0396, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 11186    GSDR_Temp       GEMS  DSCP_ADDL_COMMENT

# %%
d = dfgsdrtmp0397[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0397, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 11280    GSDR_Temp       GEMS  DSCP_PANEL

# %%
d = dfgsdrtmp0398[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0398, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 11374    GSDR_Temp       GEMS  DSCP_PANEL_RULES

# %%
d = dfgsdrtmp0399[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0399, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 11468    GSDR_Temp       GEMS  DSCP_PANEL_SPED

# %%
d = dfgsdrtmp0400[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0400, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 11656    GSDR_Temp       GEMS  DUPLICATES

# %%
d = dfgsdrtmp0401[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0401, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 12032    GSDR_Temp       GEMS  EDIT_CODES

# %%
d = dfgsdrtmp0402[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0402, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 12126    GSDR_Temp       GEMS  ELIG_ACTIVITIES

# %%
d = dfgsdrtmp0403[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0403, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 12220    GSDR_Temp       GEMS  ELIG_LOG

# %%
d = dfgsdrtmp0404[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0404, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 12314    GSDR_Temp       GEMS  ELIG_PRAM

# %%
d = dfgsdrtmp0405[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0405, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 71346    GSDR_Temp       GEMS  elig_pram_bak20190717

# %%
d = dfgsdrtmp0406[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0406, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 12408    GSDR_Temp       GEMS  ELIG_PRAM_OBJECT

# %%
d = dfgsdrtmp0407[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0407, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 12502    GSDR_Temp       GEMS  ELIG_REQUIREMENTS

# %%
d = dfgsdrtmp0408[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0408, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 12596    GSDR_Temp       GEMS  ELIG_ROSTERS

# %%
d = dfgsdrtmp0409[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0409, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 71440    GSDR_Temp       GEMS  elig_rosters_lastupdate

# %%
d = dfgsdrtmp0410[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0410, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 71534    GSDR_Temp       GEMS  elig_rosters_nodups

# %%
d = dfgsdrtmp0411[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0411, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                            TableName
# 71628    GSDR_Temp       GEMS  elig_rosters_sy1718_aftersummercalc

# %%
d = dfgsdrtmp0412[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0412, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                            TableName
# 71722    GSDR_Temp       GEMS  elig_rosters_sy1819_aftersummercalc

# %%
d = dfgsdrtmp0413[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0413, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 12690    GSDR_Temp       GEMS  ELIG_STUDENTS

# %%
d = dfgsdrtmp0414[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0414, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 71816    GSDR_Temp       GEMS  elig_students_bak20190717

# %%
d = dfgsdrtmp0415[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0415, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 71910    GSDR_Temp       GEMS  elig_students_bak20190723

# %%
d = dfgsdrtmp0416[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0416, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 72004    GSDR_Temp       GEMS  elig_students_procbak

# %%
d = dfgsdrtmp0417[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0417, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                             TableName
# 72098    GSDR_Temp       GEMS  elig_students_sy1718_aftersummercalc

# %%
d = dfgsdrtmp0418[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0418, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                             TableName
# 72192    GSDR_Temp       GEMS  elig_students_sy1819_aftersummercalc

# %%
d = dfgsdrtmp0419[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0419, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 13254    GSDR_Temp       GEMS  EOCT_HIST

# %%
d = dfgsdrtmp0420[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0420, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 14758    GSDR_Temp       GEMS      ESOL

# %%
d = dfgsdrtmp0421[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0421, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 15040    GSDR_Temp       GEMS  ESOL_CAT

# %%
d = dfgsdrtmp0422[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0422, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 15228    GSDR_Temp       GEMS  EXP_REG_STU

# %%
d = dfgsdrtmp0423[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0423, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 15322    GSDR_Temp       GEMS  EXP_REG_SUM

# %%
d = dfgsdrtmp0424[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0424, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 15416    GSDR_Temp       GEMS  EXTERNAL_SCHOOLS

# %%
d = dfgsdrtmp0425[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0425, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                   TableName
# 72380    GSDR_Temp       GEMS  external_schools_all_years

# %%
d = dfgsdrtmp0426[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0426, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 15510    GSDR_Temp       GEMS  EXTERNAL_STUDENTS

# %%
d = dfgsdrtmp0427[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0427, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                    TableName
# 72474    GSDR_Temp       GEMS  external_students_all_years

# %%
d = dfgsdrtmp0428[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0428, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 15604    GSDR_Temp       GEMS  EXTERNAL_STUDENTS_NONDISTRICT

# %%
d = dfgsdrtmp0429[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0429, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 15698    GSDR_Temp       GEMS  EXTERNAL_STUDENTS_Tim

# %%
d = dfgsdrtmp0430[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0430, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 16168    GSDR_Temp       GEMS  FAY_RESEARCH

# %%
d = dfgsdrtmp0431[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0431, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 16262    GSDR_Temp       GEMS  FAY_RESEARCH_EOCT

# %%
d = dfgsdrtmp0432[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0432, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 16544    GSDR_Temp       GEMS  FORECAST

# %%
d = dfgsdrtmp0433[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0433, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 16638    GSDR_Temp       GEMS  FREE_REDUCED_LUNCH

# %%
d = dfgsdrtmp0434[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0434, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 16732    GSDR_Temp       GEMS       FTE

# %%
d = dfgsdrtmp0435[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0435, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 18800    GSDR_Temp       GEMS  FTE_COURSES

# %%
d = dfgsdrtmp0436[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0436, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 18894    GSDR_Temp       GEMS  FTE_ERRORLOAD

# %%
d = dfgsdrtmp0437[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0437, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 19176    GSDR_Temp       GEMS  FTE_HISTORY

# %%
d = dfgsdrtmp0438[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0438, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 19364    GSDR_Temp       GEMS  FTE_PARAMS

# %%
d = dfgsdrtmp0439[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0439, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 19458    GSDR_Temp       GEMS  FTE_REPORT_ROWS

# %%
d = dfgsdrtmp0440[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0440, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 19552    GSDR_Temp       GEMS  FTE_REPORT_SCH

# %%
d = dfgsdrtmp0441[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0441, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 19740    GSDR_Temp       GEMS  FTE_REPORT_SCH20130220

# %%
d = dfgsdrtmp0442[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0442, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 19834    GSDR_Temp       GEMS  FTE_TEMP

# %%
d = dfgsdrtmp0443[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0443, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 19928    GSDR_Temp       GEMS  FTE_ZONED_SCH

# %%
d = dfgsdrtmp0444[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0444, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 16920    GSDR_Temp       GEMS    FTE441

# %%
d = dfgsdrtmp0445[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0445, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 17014    GSDR_Temp       GEMS     FTE88

# %%
d = dfgsdrtmp0446[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0446, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 17108    GSDR_Temp       GEMS  FTE88_KS

# %%
d = dfgsdrtmp0447[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0447, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 17202    GSDR_Temp       GEMS  FTECRS_MULTI

# %%
d = dfgsdrtmp0448[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0448, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 17296    GSDR_Temp       GEMS    FTEEIP

# %%
d = dfgsdrtmp0449[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0449, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 17390    GSDR_Temp       GEMS  FTEGIFTED_STUDENT

# %%
d = dfgsdrtmp0450[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0450, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 17672    GSDR_Temp       GEMS  FTENUMB_TANK

# %%
d = dfgsdrtmp0451[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0451, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 17766    GSDR_Temp       GEMS  FTEPEOPLE

# %%
d = dfgsdrtmp0452[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0452, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 17860    GSDR_Temp       GEMS   FTESPED

# %%
d = dfgsdrtmp0453[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0453, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 17954    GSDR_Temp       GEMS   FTESTAT

# %%
d = dfgsdrtmp0454[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0454, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 18048    GSDR_Temp       GEMS  FTESTAT_APPEND

# %%
d = dfgsdrtmp0455[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0455, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 18142    GSDR_Temp       GEMS  FTESTAT_BUF

# %%
d = dfgsdrtmp0456[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0456, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 18236    GSDR_Temp       GEMS  FTESTAT_BUF_KS

# %%
d = dfgsdrtmp0457[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0457, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 18330    GSDR_Temp       GEMS  FTESTAT_IVY

# %%
d = dfgsdrtmp0458[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0458, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 18424    GSDR_Temp       GEMS  FTESTAT_KS

# %%
d = dfgsdrtmp0459[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0459, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 18518    GSDR_Temp       GEMS  FTESTAT_LAST_YEAR

# %%
d = dfgsdrtmp0460[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0460, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 18612    GSDR_Temp       GEMS  FTESTAT_MAIN

# %%
d = dfgsdrtmp0461[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0461, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 18706    GSDR_Temp       GEMS  FTESTAT_YEAR

# %%
d = dfgsdrtmp0462[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0462, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 21526    GSDR_Temp       GEMS  G_GBATCH

# %%
d = dfgsdrtmp0463[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0463, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 21620    GSDR_Temp       GEMS  G_GBATCH_UPD

# %%
d = dfgsdrtmp0464[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0464, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 21714    GSDR_Temp       GEMS    G_GTID

# %%
d = dfgsdrtmp0465[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0465, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 21996    GSDR_Temp       GEMS  G_GTID_ERRORS

# %%
d = dfgsdrtmp0466[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0466, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 22090    GSDR_Temp       GEMS  G_GTID_HISTORY

# %%
d = dfgsdrtmp0467[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0467, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 22184    GSDR_Temp       GEMS  G_GTID_IMPORT

# %%
d = dfgsdrtmp0468[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0468, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 22278    GSDR_Temp       GEMS  G_GTID_STU_BATCH

# %%
d = dfgsdrtmp0469[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0469, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 22372    GSDR_Temp       GEMS  G_GTID_STU_BATCH_UPD

# %%
d = dfgsdrtmp0470[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0470, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 20586    GSDR_Temp       GEMS    GIFTED

# %%
d = dfgsdrtmp0471[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0471, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 20680    GSDR_Temp       GEMS  GIFTED_CAT

# %%
d = dfgsdrtmp0472[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0472, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 20868    GSDR_Temp       GEMS  GRADETANK

# %%
d = dfgsdrtmp0473[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0473, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 21150    GSDR_Temp       GEMS  GRADETANK_HISTORY

# %%
d = dfgsdrtmp0474[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0474, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 21244    GSDR_Temp       GEMS  GRADETANK_KS

# %%
d = dfgsdrtmp0475[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0475, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 20962    GSDR_Temp       GEMS  GRADETANK3

# %%
d = dfgsdrtmp0476[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0476, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 21056    GSDR_Temp       GEMS  GRADETANKTEMP

# %%
d = dfgsdrtmp0477[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0477, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 24722    GSDR_Temp       GEMS  IEP_EXIT

# %%
d = dfgsdrtmp0478[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0478, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 24816    GSDR_Temp       GEMS  IEP_EXPORT

# %%
d = dfgsdrtmp0479[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0479, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 24910    GSDR_Temp       GEMS  IEP_GAA_INFO

# %%
d = dfgsdrtmp0480[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0480, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 25004    GSDR_Temp       GEMS  IEP_SERVICES

# %%
d = dfgsdrtmp0481[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0481, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 25098    GSDR_Temp       GEMS  IEP_SERVICES_FTE

# %%
d = dfgsdrtmp0482[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0482, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 25192    GSDR_Temp       GEMS  IEP_SERVICES_SR

# %%
d = dfgsdrtmp0483[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0483, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 25286    GSDR_Temp       GEMS  IEP_TIMELINE

# %%
d = dfgsdrtmp0484[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0484, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 25380    GSDR_Temp       GEMS  IEP_TranspRoster

# %%
d = dfgsdrtmp0485[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0485, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                             TableName
# 25474    GSDR_Temp       GEMS  IEP_TranspRoster_CaseManagerComments

# %%
d = dfgsdrtmp0486[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0486, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 25568    GSDR_Temp       GEMS  IEP_TranspRoster_OtherSchools

# %%
d = dfgsdrtmp0487[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0487, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 25756    GSDR_Temp       GEMS  ISC_CONTRACTORS

# %%
d = dfgsdrtmp0488[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0488, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 26226    GSDR_Temp       GEMS  LETTER_TEXT

# %%
d = dfgsdrtmp0489[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0489, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 26320    GSDR_Temp       GEMS  LETTER_TEXT_SAVE

# %%
d = dfgsdrtmp0490[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0490, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 26414    GSDR_Temp       GEMS  LOCATION

# %%
d = dfgsdrtmp0491[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0491, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 26508    GSDR_Temp       GEMS  LTS_TNL_Mentor

# %%
d = dfgsdrtmp0492[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0492, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 26884    GSDR_Temp       GEMS  MEDICAID

# %%
d = dfgsdrtmp0493[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0493, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 27448    GSDR_Temp       GEMS  NEXT_SCHOOL

# %%
d = dfgsdrtmp0494[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0494, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 27542    GSDR_Temp       GEMS  NEXT_SCHOOL_Audit

# %%
d = dfgsdrtmp0495[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0495, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 27636    GSDR_Temp       GEMS  NON_TEACHERS

# %%
d = dfgsdrtmp0496[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0496, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 27730    GSDR_Temp       GEMS   NOSHOWS

# %%
d = dfgsdrtmp0497[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0497, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 27824    GSDR_Temp       GEMS  NOSHOWS2012

# %%
d = dfgsdrtmp0498[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0498, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 28952    GSDR_Temp       GEMS  PORTAL_CODE_DEFINITIONS

# %%
d = dfgsdrtmp0499[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0499, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 29046    GSDR_Temp       GEMS  PORTAL_LOOKUP_CODES

# %%
d = dfgsdrtmp0500[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0400, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 33088    GSDR_Temp       GEMS  Portal_lookup_codes_20170131

# %%
d = dfgsdrtmp0501[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0501, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                       TableName
# 73884    GSDR_Temp       GEMS  portal_lookup_codes_lastupdate

# %%
d = dfgsdrtmp0502[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0502, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 29234    GSDR_Temp       GEMS  PORTAL_PARAM_MESSAGES

# %%
d = dfgsdrtmp0503[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0503, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 29140    GSDR_Temp       GEMS  PORTAL_PARAMS

# %%
d = dfgsdrtmp0504[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0504, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 29328    GSDR_Temp       GEMS  PORTAL_SEC_ACL

# %%
d = dfgsdrtmp0505[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0505, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 29422    GSDR_Temp       GEMS  PORTAL_SEC_ACO

# %%
d = dfgsdrtmp0506[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0506, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 29516    GSDR_Temp       GEMS  PORTAL_SEC_ACO_MAP

# %%
d = dfgsdrtmp0507[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0507, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 73978    GSDR_Temp       GEMS  portal_sec_aco_map_lastupdate

# %%
d = dfgsdrtmp0508[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0508, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 29610    GSDR_Temp       GEMS  PORTAL_SEC_ARO

# %%
d = dfgsdrtmp0509[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0509, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 29704    GSDR_Temp       GEMS  PORTAL_SEC_ARO_ACL

# %%
d = dfgsdrtmp0510[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0510, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 74072    GSDR_Temp       GEMS  portal_sec_aro_acl_autobackup

# %%
d = dfgsdrtmp0511[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0511, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 74166    GSDR_Temp       GEMS  portal_sec_aro_acl_lastupdate

# %%
d = dfgsdrtmp0512[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0512, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 29986    GSDR_Temp       GEMS  PORTAL_SEC_ARO_GROUP_MBR

# %%
d = dfgsdrtmp0513[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0513, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                                  TableName
# 74260    GSDR_Temp       GEMS  portal_sec_aro_group_mbr_bak_20170413_psd

# %%
d = dfgsdrtmp0514[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0514, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                                  TableName
# 74354    GSDR_Temp       GEMS  portal_sec_aro_group_mbr_bak_20180409_psd

# %%
d = dfgsdrtmp0515[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0515, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                                  TableName
# 74448    GSDR_Temp       GEMS  portal_sec_aro_group_mbr_bak_20190411_psd

# %%
d = dfgsdrtmp0516[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0516, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                                  TableName
# 74542    GSDR_Temp       GEMS  portal_sec_aro_group_mbr_bak_20200411_psd

# %%
d = dfgsdrtmp0517[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0517, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 29798    GSDR_Temp       GEMS  PORTAL_SEC_ARO_GROUPS

# %%
d = dfgsdrtmp0518[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0518, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 29892    GSDR_Temp       GEMS  PORTAL_SEC_ARO_GROUPS_MAP

# %%
d = dfgsdrtmp0519[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0519, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                             TableName
# 74730    GSDR_Temp       GEMS  portal_sec_aro_groups_map_lastupdate

# %%
d = dfgsdrtmp0520[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0520, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 30080    GSDR_Temp       GEMS  PORTAL_SEC_ARO_MAP

# %%
d = dfgsdrtmp0521[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0521, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 74824    GSDR_Temp       GEMS  portal_sec_aro_map_lastupdate

# %%
d = dfgsdrtmp0522[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0522, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 30174    GSDR_Temp       GEMS  PORTAL_SEC_AXO

# %%
d = dfgsdrtmp0523[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0523, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 30456    GSDR_Temp       GEMS  PORTAL_SEC_AXO_GROUP_MBR

# %%
d = dfgsdrtmp0524[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0524, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 30268    GSDR_Temp       GEMS  PORTAL_SEC_AXO_GROUPS

# %%
d = dfgsdrtmp0525[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0525, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 30362    GSDR_Temp       GEMS  PORTAL_SEC_AXO_GROUPS_MAP

# %%
d = dfgsdrtmp0526[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0526, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                             TableName
# 74918    GSDR_Temp       GEMS  portal_sec_axo_groups_map_lastupdate

# %%
d = dfgsdrtmp0527[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0527, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 30550    GSDR_Temp       GEMS  PORTAL_SEC_AXO_MAP

# %%
d = dfgsdrtmp0528[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0528, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 75012    GSDR_Temp       GEMS  portal_sec_axo_map_lastupdate

# %%
d = dfgsdrtmp0529[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0529, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 30644    GSDR_Temp       GEMS  PREVIOUS_VALUES

# %%
d = dfgsdrtmp0530[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0530, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 31114    GSDR_Temp       GEMS   PS_ATTD

# %%
d = dfgsdrtmp0531[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0531, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 31396    GSDR_Temp       GEMS  PS_EMP_JOBCD

# %%
d = dfgsdrtmp0532[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0532, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 31208    GSDR_Temp       GEMS  PS_EMPLOYEE

# %%
d = dfgsdrtmp0533[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0533, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 31302    GSDR_Temp       GEMS  PS_EMPLOYEE_JIC_20170206

# %%
d = dfgsdrtmp0534[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0534, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 31490    GSDR_Temp       GEMS  PS_GP_ABS_EVENT

# %%
d = dfgsdrtmp0535[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0535, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 31584    GSDR_Temp       GEMS  PS_GP_ABS_REASON

# %%
d = dfgsdrtmp0536[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0536, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 31678    GSDR_Temp       GEMS  PS_GP_ABS_REASON2

# %%
d = dfgsdrtmp0537[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0537, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 31772    GSDR_Temp       GEMS  PS_GW_CERT

# %%
d = dfgsdrtmp0538[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0538, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 31866    GSDR_Temp       GEMS  PS_GW_CERT_DATA

# %%
d = dfgsdrtmp0539[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0539, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 31960    GSDR_Temp       GEMS  PS_GW_CERT_DISCREPANCY

# %%
d = dfgsdrtmp0540[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0540, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 32054    GSDR_Temp       GEMS  PS_GW_COURSE

# %%
d = dfgsdrtmp0541[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0541, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 32148    GSDR_Temp       GEMS  PS_GW_COURSE_CERT

# %%
d = dfgsdrtmp0542[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0542, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 32336    GSDR_Temp       GEMS  PS_GW_TNL_COURSE_SLO

# %%
d = dfgsdrtmp0543[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0543, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 32242    GSDR_Temp       GEMS  PS_GW_TNL_COURSES

# %%
d = dfgsdrtmp0544[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0544, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 32430    GSDR_Temp       GEMS  PS_GW_TNL_PRFL_TGT

# %%
d = dfgsdrtmp0545[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0545, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 32524    GSDR_Temp       GEMS  PS_JOBCD

# %%
d = dfgsdrtmp0546[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0546, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 30832    GSDR_Temp       GEMS  PSD_ACTIVITY

# %%
d = dfgsdrtmp0547[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0547, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 75576    GSDR_Temp       GEMS  psd_activity_lastupdate

# %%
d = dfgsdrtmp0548[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0548, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 30926    GSDR_Temp       GEMS  PSD_APRN_LAST

# %%
d = dfgsdrtmp0549[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0549, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 31020    GSDR_Temp       GEMS  PSD_USERS

# %%
d = dfgsdrtmp0550[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0550, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 34122    GSDR_Temp       GEMS  REGISTER

# %%
d = dfgsdrtmp0551[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0551, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 34216    GSDR_Temp       GEMS  REGISTERSUMMARY

# %%
d = dfgsdrtmp0552[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0552, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 34310    GSDR_Temp       GEMS    REGSUM

# %%
d = dfgsdrtmp0553[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0553, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 34404    GSDR_Temp       GEMS  REGSUM_HISTORY

# %%
d = dfgsdrtmp0554[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0554, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 35532    GSDR_Temp       GEMS  SASI_A504

# %%
d = dfgsdrtmp0555[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0555, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 35626    GSDR_Temp       GEMS  SASI_AATC

# %%
d = dfgsdrtmp0556[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0556, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 35908    GSDR_Temp       GEMS  SASI_AATC_ROT

# %%
d = dfgsdrtmp0557[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0557, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 36190    GSDR_Temp       GEMS  SASI_AATD

# %%
d = dfgsdrtmp0558[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0558, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 49068    GSDR_Temp       GEMS  SASI_aatd_TSTAGING

# %%
d = dfgsdrtmp0559[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0559, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 36378    GSDR_Temp       GEMS  SASI_AATO_ROT

# %%
d = dfgsdrtmp0560[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0560, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 36660    GSDR_Temp       GEMS  SASI_AATP

# %%
d = dfgsdrtmp0561[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0561, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 49162    GSDR_Temp       GEMS  SASI_aatp_TSTAGING

# %%
d = dfgsdrtmp0562[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0562, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 36848    GSDR_Temp       GEMS  SASI_AATT

# %%
d = dfgsdrtmp0563[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0563, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 37036    GSDR_Temp       GEMS  SASI_ABSENCE_CODES

# %%
d = dfgsdrtmp0564[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0564, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 37130    GSDR_Temp       GEMS  SASI_ACAM

# %%
d = dfgsdrtmp0565[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0565, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 37224    GSDR_Temp       GEMS  SASI_ACHS

# %%
d = dfgsdrtmp0566[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0566, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 37506    GSDR_Temp       GEMS  SASI_ACHS_ES

# %%
d = dfgsdrtmp0567[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0567, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 37600    GSDR_Temp       GEMS  SASI_ACHS_MS

# %%
d = dfgsdrtmp0568[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0568, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 37694    GSDR_Temp       GEMS  SASI_ACHS_MSES

# %%
d = dfgsdrtmp0569[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0569, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 37788    GSDR_Temp       GEMS  SASI_ACHS_SDR

# %%
d = dfgsdrtmp0570[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0570, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 37412    GSDR_Temp       GEMS  SASI_ACHS9203768

# %%
d = dfgsdrtmp0571[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0571, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 37882    GSDR_Temp       GEMS  SASI_ACLH

# %%
d = dfgsdrtmp0572[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0572, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 38164    GSDR_Temp       GEMS  SASI_ACLS

# %%
d = dfgsdrtmp0573[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0573, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 38446    GSDR_Temp       GEMS  SASI_ACLS_NEXT

# %%
d = dfgsdrtmp0574[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0574, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 49256    GSDR_Temp       GEMS  SASI_acls_TSTAGING

# %%
d = dfgsdrtmp0575[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0575, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 38540    GSDR_Temp       GEMS  SASI_ACNF

# %%
d = dfgsdrtmp0576[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0576, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 38634    GSDR_Temp       GEMS  SASI_ACNR

# %%
d = dfgsdrtmp0577[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0577, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 38728    GSDR_Temp       GEMS  SASI_ACRS

# %%
d = dfgsdrtmp0578[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0578, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 39104    GSDR_Temp       GEMS  SASI_ACRS_FTE

# %%
d = dfgsdrtmp0579[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0579, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 39198    GSDR_Temp       GEMS  SASI_ACRS_FTE2

# %%
d = dfgsdrtmp0580[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0580, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 39292    GSDR_Temp       GEMS  SASI_ACRS_HS

# %%
d = dfgsdrtmp0581[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0581, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 39386    GSDR_Temp       GEMS  SASI_ACRS_KS

# %%
d = dfgsdrtmp0582[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0582, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 39480    GSDR_Temp       GEMS  SASI_ACRS_NEXT

# %%
d = dfgsdrtmp0583[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0583, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 39574    GSDR_Temp       GEMS  SASI_ACRS_RAW

# %%
d = dfgsdrtmp0584[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0584, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 39010    GSDR_Temp       GEMS  SASI_ACRS2012

# %%
d = dfgsdrtmp0585[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0585, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 39856    GSDR_Temp       GEMS  SASI_ADIS

# %%
d = dfgsdrtmp0586[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0586, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 39950    GSDR_Temp       GEMS  SASI_ADIS_C

# %%
d = dfgsdrtmp0587[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0587, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 40044    GSDR_Temp       GEMS  SASI_ADIS_KS

# %%
d = dfgsdrtmp0588[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0588, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 40138    GSDR_Temp       GEMS  SASI_ADPO

# %%
d = dfgsdrtmp0589[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0589, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 40232    GSDR_Temp       GEMS  SASI_ADPO_C

# %%
d = dfgsdrtmp0590[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0590, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 40326    GSDR_Temp       GEMS  SASI_ADPS

# %%
d = dfgsdrtmp0591[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0591, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 40420    GSDR_Temp       GEMS  SASI_ADST

# %%
d = dfgsdrtmp0592[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0592, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 40514    GSDR_Temp       GEMS  SASI_ADST_ALL

# %%
d = dfgsdrtmp0593[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0593, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 40608    GSDR_Temp       GEMS  SASI_AELT

# %%
d = dfgsdrtmp0594[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0594, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 40702    GSDR_Temp       GEMS  SASI_AELT_JUST_DATES

# %%
d = dfgsdrtmp0595[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0595, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 40796    GSDR_Temp       GEMS  SASI_AEMG

# %%
d = dfgsdrtmp0596[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0596, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 40890    GSDR_Temp       GEMS  SASI_AEMG_NEXT

# %%
d = dfgsdrtmp0597[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0597, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 40984    GSDR_Temp       GEMS  SASI_AENR

# %%
d = dfgsdrtmp0598[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0598, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 41360    GSDR_Temp       GEMS  SASI_AENR_C

# %%
d = dfgsdrtmp0599[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0599, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 41454    GSDR_Temp       GEMS  SASI_AENR_KS

# %%
d = dfgsdrtmp0600[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0600, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 41548    GSDR_Temp       GEMS  SASI_AENR_NEXT

# %%
d = dfgsdrtmp0601[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0601, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 41642    GSDR_Temp       GEMS  SASI_AENR_SUMMER

# %%
d = dfgsdrtmp0602[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0602, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 41266    GSDR_Temp       GEMS  SASI_AENR2

# %%
d = dfgsdrtmp0603[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0603, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 41736    GSDR_Temp       GEMS  SASI_AFEE

# %%
d = dfgsdrtmp0604[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0604, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 41830    GSDR_Temp       GEMS  SASI_AFID

# %%
d = dfgsdrtmp0605[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0605, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 41924    GSDR_Temp       GEMS  SASI_AGRD

# %%
d = dfgsdrtmp0606[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0606, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 42018    GSDR_Temp       GEMS  SASI_AGRL

# %%
d = dfgsdrtmp0607[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0607, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 42112    GSDR_Temp       GEMS  SASI_AGSU

# %%
d = dfgsdrtmp0608[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0608, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 42206    GSDR_Temp       GEMS  SASI_AHLT

# %%
d = dfgsdrtmp0609[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0609, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 42300    GSDR_Temp       GEMS  SASI_ALKR

# %%
d = dfgsdrtmp0610[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0610, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 42394    GSDR_Temp       GEMS  SASI_ALRT

# %%
d = dfgsdrtmp0611[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0611, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 42488    GSDR_Temp       GEMS  SASI_AMST

# %%
d = dfgsdrtmp0612[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0612, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 42770    GSDR_Temp       GEMS  SASI_AMST_NEXT

# %%
d = dfgsdrtmp0613[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0613, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 42864    GSDR_Temp       GEMS  SASI_AONL

# %%
d = dfgsdrtmp0614[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0614, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 42958    GSDR_Temp       GEMS  SASI_APGD

# %%
d = dfgsdrtmp0615[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0615, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 43052    GSDR_Temp       GEMS  SASI_APGL

# %%
d = dfgsdrtmp0616[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0616, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 43146    GSDR_Temp       GEMS  SASI_APGM

# %%
d = dfgsdrtmp0617[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0617, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 43240    GSDR_Temp       GEMS  SASI_APRN

# %%
d = dfgsdrtmp0618[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0618, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 43428    GSDR_Temp       GEMS  SASI_APRN_LAST

# %%
d = dfgsdrtmp0619[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0619, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 75952    GSDR_Temp       GEMS  sasi_aprn_sy1718

# %%
d = dfgsdrtmp0620[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0620, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 76046    GSDR_Temp       GEMS  sasi_aprn_sy1819

# %%
d = dfgsdrtmp0621[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0621, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 43334    GSDR_Temp       GEMS  SASI_APRN2012

# %%
d = dfgsdrtmp0622[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0622, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 43522    GSDR_Temp       GEMS  SASI_ASCH

# %%
d = dfgsdrtmp0623[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0623, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 43616    GSDR_Temp       GEMS  SASI_ASGR

# %%
d = dfgsdrtmp0624[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0624, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 43710    GSDR_Temp       GEMS  SASI_ASTI

# %%
d = dfgsdrtmp0625[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0625, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 43804    GSDR_Temp       GEMS  SASI_ASTU

# %%
d = dfgsdrtmp0626[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0626, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 44086    GSDR_Temp       GEMS  SASI_ASTU_DEMOG

# %%
d = dfgsdrtmp0627[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0627, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 44180    GSDR_Temp       GEMS  SASI_ASTU_DIPLOMA_SEALS

# %%
d = dfgsdrtmp0628[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0628, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 44274    GSDR_Temp       GEMS  SASI_ASTU_EMAIL

# %%
d = dfgsdrtmp0629[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0629, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 44368    GSDR_Temp       GEMS  SASI_ASTU_GOSA_AUDIT

# %%
d = dfgsdrtmp0630[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0630, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 44462    GSDR_Temp       GEMS  SASI_ASTU_MIN

# %%
d = dfgsdrtmp0631[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0631, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 44556    GSDR_Temp       GEMS  SASI_ASTU_NEXT

# %%
d = dfgsdrtmp0632[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0632, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 44650    GSDR_Temp       GEMS  SASI_ASTU_TEMP

# %%
d = dfgsdrtmp0633[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0633, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 44744    GSDR_Temp       GEMS  SASI_ASTV

# %%
d = dfgsdrtmp0634[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0634, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 44838    GSDR_Temp       GEMS  SASI_ASTV_BP

# %%
d = dfgsdrtmp0635[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0635, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 44932    GSDR_Temp       GEMS  SASI_ASTV_NEXT

# %%
d = dfgsdrtmp0636[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0636, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 45026    GSDR_Temp       GEMS  SASI_ATBL

# %%
d = dfgsdrtmp0637[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0637, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 76140    GSDR_Temp       GEMS  sasi_atbl_BADREL

# %%
d = dfgsdrtmp0638[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0638, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 45120    GSDR_Temp       GEMS  SASI_ATBL_KS

# %%
d = dfgsdrtmp0639[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0639, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 45214    GSDR_Temp       GEMS  SASI_ATCH

# %%
d = dfgsdrtmp0640[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0640, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 45496    GSDR_Temp       GEMS  SASI_ATCH_NEXT

# %%
d = dfgsdrtmp0641[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0641, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 49350    GSDR_Temp       GEMS  SASI_atch_TSTAGING

# %%
d = dfgsdrtmp0642[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0642, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 45590    GSDR_Temp       GEMS  SASI_ATES

# %%
d = dfgsdrtmp0643[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0643, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 45684    GSDR_Temp       GEMS  SASI_ATPA

# %%
d = dfgsdrtmp0644[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0644, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 45778    GSDR_Temp       GEMS  SASI_ATRM

# %%
d = dfgsdrtmp0645[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0645, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 46060    GSDR_Temp       GEMS  SASI_ATRM2016

# %%
d = dfgsdrtmp0646[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0646, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 46154    GSDR_Temp       GEMS  SASI_ATRM4

# %%
d = dfgsdrtmp0647[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0647, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 46248    GSDR_Temp       GEMS  SASI_ATRMPORT

# %%
d = dfgsdrtmp0648[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0648, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 46342    GSDR_Temp       GEMS  SASI_AUFS

# %%
d = dfgsdrtmp0649[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0649, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 46436    GSDR_Temp       GEMS  SASI_COUNTRY_OF_BIRTH

# %%
d = dfgsdrtmp0650[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0650, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 46530    GSDR_Temp       GEMS  SASI_DISCP_RULES

# %%
d = dfgsdrtmp0651[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0651, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 46718    GSDR_Temp       GEMS  SASI_DISCP_RULES_HIST

# %%
d = dfgsdrtmp0652[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0652, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 46624    GSDR_Temp       GEMS  SASI_DISCP_RULES051219

# %%
d = dfgsdrtmp0653[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0653, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 46812    GSDR_Temp       GEMS  SASI_DISPCODES

# %%
d = dfgsdrtmp0654[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0654, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 47000    GSDR_Temp       GEMS  SASI_DISPCODES_HIST

# %%
d = dfgsdrtmp0655[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0655, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 46906    GSDR_Temp       GEMS  SASI_DISPCODES051219

# %%
d = dfgsdrtmp0656[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0656, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 47094    GSDR_Temp       GEMS  SASI_ELL_PARENT_CONF

# %%
d = dfgsdrtmp0657[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0657, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 47188    GSDR_Temp       GEMS  SASI_ELL_WAIVER

# %%
d = dfgsdrtmp0658[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0658, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 47282    GSDR_Temp       GEMS  SASI_FILE_HISTORY

# %%
d = dfgsdrtmp0659[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0659, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 47376    GSDR_Temp       GEMS  SASI_GAT_HIS

# %%
d = dfgsdrtmp0660[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0660, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 47470    GSDR_Temp       GEMS  SASI_LOAD_control

# %%
d = dfgsdrtmp0661[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0661, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 47564    GSDR_Temp       GEMS  SASI_PARAPRO

# %%
d = dfgsdrtmp0662[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0662, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 47658    GSDR_Temp       GEMS  SASI_SMST

# %%
d = dfgsdrtmp0663[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0663, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 47940    GSDR_Temp       GEMS  SASI_UABN

# %%
d = dfgsdrtmp0664[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0664, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 48034    GSDR_Temp       GEMS  SASI_UATR

# %%
d = dfgsdrtmp0665[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0665, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 48128    GSDR_Temp       GEMS  SASI_UATR_NEXT

# %%
d = dfgsdrtmp0666[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0666, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 49444    GSDR_Temp       GEMS  SASI_uatr_TSTAGING

# %%
d = dfgsdrtmp0667[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0667, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 48222    GSDR_Temp       GEMS  SASI_UCES

# %%
d = dfgsdrtmp0668[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0668, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 48316    GSDR_Temp       GEMS  SASI_UCMS

# %%
d = dfgsdrtmp0669[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0669, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 48410    GSDR_Temp       GEMS  SASI_UFLP

# %%
d = dfgsdrtmp0670[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0670, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 48504    GSDR_Temp       GEMS  SASI_UGFT

# %%
d = dfgsdrtmp0671[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0671, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 48974    GSDR_Temp       GEMS  SASI_Upload_Count_Difference

# %%
d = dfgsdrtmp0672[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0672, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 48598    GSDR_Temp       GEMS  SASI_UPLOAD_HISTORY

# %%
d = dfgsdrtmp0673[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0673, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 48692    GSDR_Temp       GEMS  SASI_UPSA

# %%
d = dfgsdrtmp0674[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0674, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 48786    GSDR_Temp       GEMS  SASI_UPSR

# %%
d = dfgsdrtmp0675[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0675, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 48880    GSDR_Temp       GEMS  SASI_UTL1

# %%
d = dfgsdrtmp0676[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0676, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 50102    GSDR_Temp       GEMS  SCHEDULES_MS_SAVE

# %%
d = dfgsdrtmp0677[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0677, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 50290    GSDR_Temp       GEMS  SCHOOL_CLUSTER

# %%
d = dfgsdrtmp0678[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0678, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 50384    GSDR_Temp       GEMS  SCHOOL_ETS_CODES

# %%
d = dfgsdrtmp0679[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0679, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 50478    GSDR_Temp       GEMS       SCP

# %%
d = dfgsdrtmp0680[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0680, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 51700    GSDR_Temp       GEMS  SDR_DSCP_ACTIONS

# %%
d = dfgsdrtmp0681[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0681, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 51794    GSDR_Temp       GEMS  SDR_DSCP_INCDTS

# %%
d = dfgsdrtmp0682[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0682, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 51888    GSDR_Temp       GEMS   SDR_ENR

# %%
d = dfgsdrtmp0683[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0683, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 51982    GSDR_Temp       GEMS  SDR_ERRORS

# %%
d = dfgsdrtmp0684[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0684, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 52076    GSDR_Temp       GEMS  SDR_IEP_SPED

# %%
d = dfgsdrtmp0685[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0685, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 52170    GSDR_Temp       GEMS  SDR_IEP_SPED2

# %%
d = dfgsdrtmp0686[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0686, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 52546    GSDR_Temp       GEMS  SDR_SCH_EDM

# %%
d = dfgsdrtmp0687[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0687, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 52640    GSDR_Temp       GEMS  SDR_SCH_TITLE1

# %%
d = dfgsdrtmp0688[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0688, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 52734    GSDR_Temp       GEMS  SDR_SCH_TITLE1_CHARLENE

# %%
d = dfgsdrtmp0689[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0689, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 52264    GSDR_Temp       GEMS  SDR_SCHOOL_B

# %%
d = dfgsdrtmp0690[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0690, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 52358    GSDR_Temp       GEMS  SDR_SCHOOL_N

# %%
d = dfgsdrtmp0691[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0691, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 52452    GSDR_Temp       GEMS  SDR_SCHOOL_NCLB

# %%
d = dfgsdrtmp0692[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0692, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 52922    GSDR_Temp       GEMS  SDR_STU_C

# %%
d = dfgsdrtmp0693[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0693, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 53016    GSDR_Temp       GEMS  SDR_STU_C_HOST

# %%
d = dfgsdrtmp0694[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0694, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 53204    GSDR_Temp       GEMS  SDR_STU_D

# %%
d = dfgsdrtmp0695[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0695, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 53298    GSDR_Temp       GEMS  SDR_STU_D_HOST

# %%
d = dfgsdrtmp0696[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0696, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 53392    GSDR_Temp       GEMS  SDR_STU_D_T

# %%
d = dfgsdrtmp0697[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0697, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 53580    GSDR_Temp       GEMS  SDR_STU_E

# %%
d = dfgsdrtmp0698[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0698, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 53674    GSDR_Temp       GEMS  SDR_STU_E_HOST

# %%
d = dfgsdrtmp0699[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0699, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 53862    GSDR_Temp       GEMS  SDR_STU_F

# %%
d = dfgsdrtmp0700[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0700, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 53956    GSDR_Temp       GEMS  SDR_STU_F_HOST

# %%
d = dfgsdrtmp0701[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0701, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 54144    GSDR_Temp       GEMS  SDR_STU_G

# %%
d = dfgsdrtmp0702[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0702, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 54238    GSDR_Temp       GEMS  SDR_STU_G_HOST

# %%
d = dfgsdrtmp0703[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0703, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 54332    GSDR_Temp       GEMS  SDR_STU_G_OLD

# %%
d = dfgsdrtmp0704[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0704, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 54520    GSDR_Temp       GEMS  SDR_STU_H

# %%
d = dfgsdrtmp0705[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0705, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 54614    GSDR_Temp       GEMS  SDR_STU_H_HOST

# %%
d = dfgsdrtmp0706[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0706, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 54802    GSDR_Temp       GEMS  SDR_STU_K

# %%
d = dfgsdrtmp0707[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0707, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 54990    GSDR_Temp       GEMS  SDR_STU_K_KS

# %%
d = dfgsdrtmp0708[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0708, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 54896    GSDR_Temp       GEMS  SDR_STU_K2

# %%
d = dfgsdrtmp0709[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0709, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 55084    GSDR_Temp       GEMS  SDR_STU_TITLE1

# %%
d = dfgsdrtmp0710[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0710, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 55178    GSDR_Temp       GEMS  SDR_SYS_J

# %%
d = dfgsdrtmp0711[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0711, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 55272    GSDR_Temp       GEMS  SDR_SYS_J20150613

# %%
d = dfgsdrtmp0712[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0712, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 50760    GSDR_Temp       GEMS  SDRC_HIST

# %%
d = dfgsdrtmp0713[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0713, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 50666    GSDR_Temp       GEMS   SDRCTMP

# %%
d = dfgsdrtmp0714[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0714, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 50948    GSDR_Temp       GEMS  SDRD_HIST

# %%
d = dfgsdrtmp0715[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0715, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 50854    GSDR_Temp       GEMS  SDRD2014

# %%
d = dfgsdrtmp0716[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0716, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 51042    GSDR_Temp       GEMS  SDRE_HIST

# %%
d = dfgsdrtmp0717[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0717, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 51136    GSDR_Temp       GEMS  SDRF_HIST

# %%
d = dfgsdrtmp0718[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0718, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 51230    GSDR_Temp       GEMS  SDRF_TMP

# %%
d = dfgsdrtmp0719[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0719, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 51324    GSDR_Temp       GEMS  SDRG_HIST

# %%
d = dfgsdrtmp0720[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0720, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 51418    GSDR_Temp       GEMS  SDRK_HIST

# %%
d = dfgsdrtmp0721[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0721, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 51512    GSDR_Temp       GEMS  SDRSTUFZ

# %%
d = dfgsdrtmp0722[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0722, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 51606    GSDR_Temp       GEMS  SDRSTUK_TMP

# %%
d = dfgsdrtmp0723[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0723, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 55366    GSDR_Temp       GEMS       SES

# %%
d = dfgsdrtmp0724[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0724, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 55648    GSDR_Temp       GEMS  SLDS_Teachers

# %%
d = dfgsdrtmp0725[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0725, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 56682    GSDR_Temp       GEMS  SPED_EXIT

# %%
d = dfgsdrtmp0726[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0726, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 56776    GSDR_Temp       GEMS  SPED_SCORE_CARD

# %%
d = dfgsdrtmp0727[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0727, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 56870    GSDR_Temp       GEMS  SPED_SCORE_REP

# %%
d = dfgsdrtmp0728[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0728, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 56964    GSDR_Temp       GEMS  SPED_SCORE_SUM

# %%
d = dfgsdrtmp0729[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0729, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 57058    GSDR_Temp       GEMS  SPED_TCH_SCHED

# %%
d = dfgsdrtmp0730[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0730, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 57622    GSDR_Temp       GEMS  SRO_RULES

# %%
d = dfgsdrtmp0731[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0731, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 57716    GSDR_Temp       GEMS  SSW_ACTIVITY

# %%
d = dfgsdrtmp0732[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0732, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 57810    GSDR_Temp       GEMS  SSW_ASSIGNMENTS

# %%
d = dfgsdrtmp0733[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0733, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 57904    GSDR_Temp       GEMS  SSW_CASES

# %%
d = dfgsdrtmp0734[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0734, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                                  TableName
# 77456    GSDR_Temp       GEMS  ssw_cases_bak_20171219_before_code_update

# %%
d = dfgsdrtmp0735[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0735, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 57998    GSDR_Temp       GEMS  SSW_CONTACT_REASONS

# %%
d = dfgsdrtmp0736[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0736, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 58092    GSDR_Temp       GEMS  SSW_CONTACT_TYPES

# %%
d = dfgsdrtmp0737[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0737, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 58186    GSDR_Temp       GEMS  SSW_DOE_CASES

# %%
d = dfgsdrtmp0738[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0738, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 58280    GSDR_Temp       GEMS  SSW_DOE_REFERRALS

# %%
d = dfgsdrtmp0739[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0739, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 58374    GSDR_Temp       GEMS  SSW_DOE_SERVICES

# %%
d = dfgsdrtmp0740[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0740, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 58468    GSDR_Temp       GEMS  SSW_LOOKUP_CODES

# %%
d = dfgsdrtmp0741[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0741, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 58562    GSDR_Temp       GEMS  SSW_MEETINGS

# %%
d = dfgsdrtmp0742[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0742, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 58656    GSDR_Temp       GEMS  SSW_REFERRALS

# %%
d = dfgsdrtmp0743[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0743, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 58750    GSDR_Temp       GEMS  SSW_STUDENTS

# %%
d = dfgsdrtmp0744[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0744, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 77550    GSDR_Temp       GEMS  string_translation

# %%
d = dfgsdrtmp0745[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0745, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 59690    GSDR_Temp       GEMS   STU_FAY

# %%
d = dfgsdrtmp0746[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0746, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 59784    GSDR_Temp       GEMS  STU_HOPE_GRANT

# %%
d = dfgsdrtmp0747[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0747, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 59878    GSDR_Temp       GEMS  STU_ZONED_SCH

# %%
d = dfgsdrtmp0748[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0748, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 59502    GSDR_Temp       GEMS  STUD_HOPE_GRANT

# %%
d = dfgsdrtmp0749[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0749, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 58844    GSDR_Temp       GEMS  STUDENT_DISTRICT

# %%
d = dfgsdrtmp0750[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0750, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 58938    GSDR_Temp       GEMS  STUDENT_FTEID

# %%
d = dfgsdrtmp0751[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0751, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 59220    GSDR_Temp       GEMS  STUDENT_PROFILES

# %%
d = dfgsdrtmp0752[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0752, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 59314    GSDR_Temp       GEMS  STUDENT_SCHEDULE

# %%
d = dfgsdrtmp0753[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0753, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 59408    GSDR_Temp       GEMS  STUDENT_SCHOOLS

# %%
d = dfgsdrtmp0754[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0754, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 59596    GSDR_Temp       GEMS  STUHEADR

# %%
d = dfgsdrtmp0755[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0755, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 65988    GSDR_Temp       GEMS  TEACHER_LEAVE

# %%
d = dfgsdrtmp0756[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0756, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 66458    GSDR_Temp       GEMS  TEACHER_SCHEDULE

# %%
d = dfgsdrtmp0757[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0757, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                    TableName
# 66552    GSDR_Temp       GEMS  TEMP_DOE_SPED_NOPRIMARYAREA

# %%
d = dfgsdrtmp0758[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0758, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 66740    GSDR_Temp       GEMS  TIME_STAMP

# %%
d = dfgsdrtmp0759[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0759, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 66834    GSDR_Temp       GEMS  TITLE1_SWP

# %%
d = dfgsdrtmp0760[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0760, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 66928    GSDR_Temp       GEMS  TITLE1_TAS

# %%
d = dfgsdrtmp0761[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0761, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 69278    GSDR_Temp       GEMS  USCO_CODES

# %%
d = dfgsdrtmp0762[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0762, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 69372    GSDR_Temp       GEMS  XPRT_STUDENTS_NOSHOW

# %%
d = dfgsdrtmp0763[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0763, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 8178    GSDR_Temp  Gradebook     Class

# %%
d = dfgsdrtmp0764[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0764, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName              TableName
# 8272    GSDR_Temp  Gradebook  Class_Backup_20170915

# %%
d = dfgsdrtmp0765[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0765, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 22466    GSDR_Temp  Gradebook     Grade

# %%
d = dfgsdrtmp0766[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0766, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 22560    GSDR_Temp  Gradebook  Grade_Backup_20170915

# %%
d = dfgsdrtmp0767[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0767, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 27918    GSDR_Temp  Gradebook      Note

# %%
d = dfgsdrtmp0768[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0768, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 60536    GSDR_Temp  Gradebook     Score

# %%
d = dfgsdrtmp0769[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0769, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 76234    GSDR_Temp  Gradebook  score_backup

# %%
d = dfgsdrtmp0770[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0770, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 60630    GSDR_Temp  Gradebook  Score_Backup_20170915

# %%
d = dfgsdrtmp0771[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0771, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 67304    GSDR_Temp  Gradebook      Task

# %%
d = dfgsdrtmp0772[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0772, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 77832    GSDR_Temp  Gradebook  task_backup

# %%
d = dfgsdrtmp0773[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0773, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 67398    GSDR_Temp  Gradebook  Task_Backup_20170915

# %%
d = dfgsdrtmp0774[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0774, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 19082    GSDR_Temp      guest  FTE_GTID_Updates

# %%
d = dfgsdrtmp0775[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0775, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 32806    GSDR_Temp      guest  PermnumList

# %%
d = dfgsdrtmp0776[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0776, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 3948    GSDR_Temp    SPG2014  CALENDAR

# %%
d = dfgsdrtmp0777[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0777, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 21808    GSDR_Temp    SPG2014    G_GTID

# %%
d = dfgsdrtmp0778[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0778, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 35720    GSDR_Temp    SPG2014  SASI_AATC

# %%
d = dfgsdrtmp0779[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0779, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 36002    GSDR_Temp    SPG2014  SASI_AATC_ROT

# %%
d = dfgsdrtmp0780[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0780, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 36284    GSDR_Temp    SPG2014  SASI_AATD

# %%
d = dfgsdrtmp0781[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0781, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 36472    GSDR_Temp    SPG2014  SASI_AATO_ROT

# %%
d = dfgsdrtmp0782[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0782, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 36754    GSDR_Temp    SPG2014  SASI_AATP

# %%
d = dfgsdrtmp0783[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0783, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 36942    GSDR_Temp    SPG2014  SASI_AATT

# %%
d = dfgsdrtmp0784[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0784, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 37976    GSDR_Temp    SPG2014  SASI_ACLH

# %%
d = dfgsdrtmp0785[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0785, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 38258    GSDR_Temp    SPG2014  SASI_ACLS

# %%
d = dfgsdrtmp0786[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0786, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 38822    GSDR_Temp    SPG2014  SASI_ACRS

# %%
d = dfgsdrtmp0787[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0787, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 39668    GSDR_Temp    SPG2014  SASI_ACRS_RAW

# %%
d = dfgsdrtmp0788[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0788, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 41078    GSDR_Temp    SPG2014  SASI_AENR

# %%
d = dfgsdrtmp0789[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0789, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 42582    GSDR_Temp    SPG2014  SASI_AMST

# %%
d = dfgsdrtmp0790[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0790, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 43898    GSDR_Temp    SPG2014  SASI_ASTU

# %%
d = dfgsdrtmp0791[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0791, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 45308    GSDR_Temp    SPG2014  SASI_ATCH

# %%
d = dfgsdrtmp0792[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0792, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 45872    GSDR_Temp    SPG2014  SASI_ATRM

# %%
d = dfgsdrtmp0793[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0793, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 47752    GSDR_Temp    SPG2014  SASI_SMST

# %%
d = dfgsdrtmp0794[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0794, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 59032    GSDR_Temp    SPG2014  STUDENT_FTEID

# %%
d = dfgsdrtmp0795[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0795, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 66082    GSDR_Temp    SPG2014  TEACHER_LEAVE

# %%
d = dfgsdrtmp0796[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0796, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 66270    GSDR_Temp    SPG2014  TEACHER_LEAVE2

# %%
d = dfgsdrtmp0797[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0797, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 68056    GSDR_Temp    SPG2014  Teachers To Validate

# %%
d = dfgsdrtmp0798[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0798, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 4042    GSDR_Temp    SPG2015  CALENDAR

# %%
d = dfgsdrtmp0799[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0799, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 21902    GSDR_Temp    SPG2015    G_GTID

# %%
d = dfgsdrtmp0800[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0800, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 35814    GSDR_Temp    SPG2015  SASI_AATC

# %%
d = dfgsdrtmp0801[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0801, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 36096    GSDR_Temp    SPG2015  SASI_AATC_ROT

# %%
d = dfgsdrtmp0802[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0802, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 36566    GSDR_Temp    SPG2015  SASI_AATO_ROT

# %%
d = dfgsdrtmp0803[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0803, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 38070    GSDR_Temp    SPG2015  SASI_ACLH

# %%
d = dfgsdrtmp0804[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0804, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 38352    GSDR_Temp    SPG2015  SASI_ACLS

# %%
d = dfgsdrtmp0805[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0805, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 38916    GSDR_Temp    SPG2015  SASI_ACRS

# %%
d = dfgsdrtmp0806[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0806, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 39762    GSDR_Temp    SPG2015  SASI_ACRS_RAW

# %%
d = dfgsdrtmp0807[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0807, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 41172    GSDR_Temp    SPG2015  SASI_AENR

# %%
d = dfgsdrtmp0808[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0808, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 42676    GSDR_Temp    SPG2015  SASI_AMST

# %%
d = dfgsdrtmp0809[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0809, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 43992    GSDR_Temp    SPG2015  SASI_ASTU

# %%
d = dfgsdrtmp0810[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0810, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 45402    GSDR_Temp    SPG2015  SASI_ATCH

# %%
d = dfgsdrtmp0811[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0811, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 45966    GSDR_Temp    SPG2015  SASI_ATRM

# %%
d = dfgsdrtmp0812[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0812, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 47846    GSDR_Temp    SPG2015  SASI_SMST

# %%
d = dfgsdrtmp0813[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0813, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 59126    GSDR_Temp    SPG2015  STUDENT_FTEID

# %%
d = dfgsdrtmp0814[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0814, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 63168    GSDR_Temp    SPG2015  StudentClass

# %%
d = dfgsdrtmp0815[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0815, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 64390    GSDR_Temp    SPG2015  StudentCourseProfile

# %%
d = dfgsdrtmp0816[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0816, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 66176    GSDR_Temp    SPG2015  TEACHER_LEAVE

# %%
d = dfgsdrtmp0817[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0817, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 66364    GSDR_Temp    SPG2015  TEACHER_LEAVE2

# %%
d = dfgsdrtmp0818[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0818, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 67680    GSDR_Temp    SPG2015  TeacherClass

# %%
d = dfgsdrtmp0819[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0819, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 68150    GSDR_Temp    SPG2015  Teachers To Validate

# %%
d = dfgsdrtmp0820[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0820, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 68244    GSDR_Temp    SPG2015  Teachers To Validate20160211

# %%
d = dfgsdrtmp0821[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0821, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 69748    GSDR_Temp      stage  crisnet_arrests

# %%
d = dfgsdrtmp0822[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0822, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 75670    GSDR_Temp      stage  psd_input_file

# %%
d = dfgsdrtmp0823[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0823, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName      SchemaName              TableName
# 16074    GSDR_Temp  StudentProfile  FACT_AttendanceByType

# %%
d = dfgsdrtmp0824[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0824, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName       SchemaName   TableName
# 12784    GSDR_Temp  TCAccommodation  ELPP_Notes

# %%
d = dfgsdrtmp0825[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0825, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName       SchemaName          TableName
# 24440    GSDR_Temp  TCAccommodation  IEPAccommodations

# %%
d = dfgsdrtmp0826[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0826, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName       SchemaName           TableName
# 35438    GSDR_Temp  TCAccommodation  S504Accommodations

# %%
d = dfgsdrtmp0827[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0827, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName       SchemaName  TableName
# 67210    GSDR_Temp  TCAccommodation  TPP_Notes

# %%
d = dfgsdrtmp0828[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0828, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName  SchemaName   TableName
# 3196    GSDR_Temp  Transcript  Attendance

# %%
d = dfgsdrtmp0829[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0829, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName  SchemaName TableName
# 9306    GSDR_Temp  Transcript   Courses

# %%
d = dfgsdrtmp0830[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0830, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName  SchemaName TableName
# 9494    GSDR_Temp  Transcript    CumGPA

# %%
d = dfgsdrtmp0831[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0831, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName  SchemaName TableName
# 13160    GSDR_Temp  Transcript       EOC

# %%
d = dfgsdrtmp0832[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0832, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName  SchemaName TableName
# 20774    GSDR_Temp  Transcript       GPA

# %%
d = dfgsdrtmp0833[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0833, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName  SchemaName TableName
# 60066    GSDR_Temp  Transcript    School

# %%
d = dfgsdrtmp0834[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0834, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName  SchemaName        TableName
# 60348    GSDR_Temp  Transcript  SchoolsAttended

# %%
d = dfgsdrtmp0835[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0835, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName  SchemaName  TableName
# 61194    GSDR_Temp  Transcript  Semesters

# %%
d = dfgsdrtmp0836[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0836, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName  SchemaName        TableName
# 61382    GSDR_Temp  Transcript  SpecialStudents

# %%
d = dfgsdrtmp0837[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0837, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName  SchemaName TableName
# 62980    GSDR_Temp  Transcript   Student

# %%
d = dfgsdrtmp0838[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0838, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName  SchemaName TableName
# 59972    GSDR_Temp  Transcript     SUMLA

# %%
d = dfgsdrtmp0839[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('GSDR_Temp_{}_{}'.format(f,g))

fig = px.scatter(dfgsdrtmp0839, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\GSDR_Temp\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName  SchemaName       TableName
# 68432    GSDR_Temp  Transcript  TestAssesments

# %%
now01 = datetime.datetime.now()
print('Interactive Chart Creation - Process Complete: ', now01.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Interactive Chart Creation - Process Complete:  2021-05-11 15:54:43
