# %%
#Program Name: Daily-XChart-datapane_v1_single_multi_on_gsdr
#Purpose:  Chart scatter line box aggr table data
#Author:  Greg Turmel, Director, Data Governance 
#Date:    2020.08.30 - 2021.06.30
#Errata:  0.1 Improvements can be made to script using for/looping through the databases

import os, sys, argparse, csv, pyodbc, sql, time, datetime
from datetime import datetime, timedelta
import sqlalchemy as db
from dotenv import load_dotenv # add this line
from matplotlib.backends.backend_pdf import PdfPages
import pandas as pd
import altair as alt
from altair import Chart, X, Y, Axis, SortField
from vega_datasets import data as vega_data
import datapane as dp
#import datatable as dt
import numpy as np
import matplotlib # notebook
import matplotlib.pyplot as plt
import seaborn as sns
#import chart_studio.plotly as py
import plotly.graph_objects as go
load_dotenv() # add this line
user = os.getenv('MySQLeUser')
password = os.getenv('MySQLeUserPass')
host = os.getenv('MySQLeHOST')
db = os.getenv('MySQLeDB')
# %matplotlib inline
# %load_ext sql

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=DEVODSSQL;'
                      'Database=Greg;'
                      'Trusted_Connection=yes;')

sql_query01 = pd.read_sql_query(''' 
select DISTINCT TableName
FROM [dbo].[tableRowCountGSDR]
ORDER BY TableName;     
                              '''
                              ,conn) # Load the list of distinct tables to graph

sql_query02 = pd.read_sql_query(''' 
select *
FROM [dbo].[tableRowCountGSDR]
ORDER BY TableName;     
                              '''
                              ,conn) # Load the list of distinct tables to graph

# %%
df = pd.DataFrame(sql_query02)
#df = df.astype({'TodaysDate':np.int64,'RecordCount':np.int64})
df['TodaysDate'] = pd.to_datetime(df['TodaysDate'].astype(str), format='%Y%m%d')
df = df.sort_values(by=['TableName','SchemaName','DatabaseName','TodaysDate'], ascending=[True,True,True,True])
df = df.reset_index(drop=True)

# %%
dfgsdr0001 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'BUFORD') & (df['TableName'] == 'SDR_STU_C')]
dfgsdr0002 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'BUFORD') & (df['TableName'] == 'SDR_STU_D')]
dfgsdr0003 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'BUFORD') & (df['TableName'] == 'SDR_STU_E')]
dfgsdr0004 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'BUFORD') & (df['TableName'] == 'SDR_STU_F')]
dfgsdr0005 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'BUFORD') & (df['TableName'] == 'SDR_STU_G')]
dfgsdr0006 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'BUFORD') & (df['TableName'] == 'SDR_STU_H')]
dfgsdr0007 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'BUFORD') & (df['TableName'] == 'SDR_STU_K')]
dfgsdr0008 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_AllSchools_Usage')]
dfgsdr0009 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'D2L_Reporting_D2LSessionExport')]
dfgsdr0010 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_OrgRoleCrosswalk')]
dfgsdr0011 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_SchoolPopulation')]
dfgsdr0012 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_SchoolPopulationDtl')]
dfgsdr0013 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_SessionActivity')]
dfgsdr0014 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_Reporting_TeacherSchedule')]
dfgsdr0015 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_Usage')]
dfgsdr0016 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_UsageDtl')]
dfgsdr0017 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == '667errors')]
dfgsdr0018 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AAA_Cohort_Report')]
dfgsdr0019 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AcademicContract')]
dfgsdr0020 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AcademicContractImport')]
dfgsdr0021 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AcademicContractImportErrors')]
dfgsdr0022 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AcademicContractIntervention')]
dfgsdr0023 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ACCESS_Targets')]
dfgsdr0024 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ACHSFILE')]
dfgsdr0025 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ACRSTMP')]
dfgsdr0026 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ActiveEnrollmentReportCache')]
dfgsdr0027 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ActiveEnrollmentReportCacheAllSchools')]
dfgsdr0028 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AdditionalMinutes')]
dfgsdr0029 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'APGM_KS2017')]
dfgsdr0030 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASTU_CHANGES')]
dfgsdr0031 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASTU_KS2017')]
dfgsdr0032 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'astv1819')]
dfgsdr0033 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AttendanceSummary')]
dfgsdr0034 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'BiLiteracyReport 2019')]
dfgsdr0035 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'BlockFile')]
dfgsdr0036 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'BlockFile_BPtest')]
dfgsdr0037 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'BlockFileNewMapNet')]
dfgsdr0038 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'BusPlanner_AddressListing')]
dfgsdr0039 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CALENDAR_CHARLENE')]
dfgsdr0040 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CALENDAR_CHARLENE2')]
dfgsdr0041 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Calendar_Charlene3')]
dfgsdr0042 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Calendar_Charlene4')]
dfgsdr0043 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'cert_codes')]
dfgsdr0044 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'COB_KS')]
dfgsdr0045 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Cohort_Withdrawals')]
dfgsdr0046 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Cohort20170201')]
dfgsdr0047 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CohortAdditionalCourses')]
dfgsdr0048 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Cohorts')]
dfgsdr0049 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Cohorts2')]
dfgsdr0050 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'COUNTRIES')]
dfgsdr0051 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Course_No_EOCT')]
dfgsdr0052 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CourseConversion')]
dfgsdr0053 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CourseEvalType')]
dfgsdr0054 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CourseMerged$')]
dfgsdr0055 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CPI March 2017')]
dfgsdr0056 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CPI_TEMP')]
dfgsdr0057 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Crosswalk SPG Courses')]
dfgsdr0058 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CSVFILE')]
dfgsdr0059 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2L_NON_TEACHING_STAFF')]
dfgsdr0060 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LPortalUtizReport')]
dfgsdr0061 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DavidDoesNotKnow')]
dfgsdr0062 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'dbIEPReview')]
dfgsdr0063 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'dbIEPTransfer')]
dfgsdr0064 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'dbTransfer')]
dfgsdr0065 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'deleteSections')]
dfgsdr0066 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DestinyOutstandingFees')]
dfgsdr0067 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_Courses')]
dfgsdr0068 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_EL_HISTORY')]
dfgsdr0069 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_EL_HISTORY_temp')]
dfgsdr0070 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_SPED_HISTORY')]
dfgsdr0071 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DSCP_TEMP')]
dfgsdr0072 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'E5098_Prim_Area20200324')]
dfgsdr0073 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EL_FORM_1020')]
dfgsdr0074 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EL_Monitor_data')]
dfgsdr0075 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Ellevation_Demographics')]
dfgsdr0076 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ELPP_schedules_tb')]
dfgsdr0077 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ELPP_test_scores_tb')]
dfgsdr0078 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EmployeeEmailIDSource')]
dfgsdr0079 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOC_PRELIM_2019')]
dfgsdr0080 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOC_SCORES')]
dfgsdr0081 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOCT_KAUSHAL')]
dfgsdr0082 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOCT_Unmatched')]
dfgsdr0083 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOG_PRELIM_2017')]
dfgsdr0084 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOG_PRELIM_2018')]
dfgsdr0085 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOG_PRELIM_2019')]
dfgsdr0086 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA Assessments')]
dfgsdr0087 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA Exam Taken')]
dfgsdr0088 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA Pathways')]
dfgsdr0089 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA_Clusters')]
dfgsdr0090 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA_Courses')]
dfgsdr0091 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA_Pathways')]
dfgsdr0092 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA2016')]
dfgsdr0093 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOPA2017')]
dfgsdr0094 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'error_import')]
dfgsdr0095 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Errors')]
dfgsdr0096 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ESOL_COURSES_JUNE15')]
dfgsdr0097 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ESOL115')]
dfgsdr0098 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ESOL115_FTE')]
dfgsdr0099 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'eTextBook_SchContact')]
dfgsdr0100 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'eTextBook_SchContact_BAK')]
dfgsdr0101 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'eTextBook_SchContact_temp')]
dfgsdr0102 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'fay')]
dfgsdr0103 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'fay2')]
dfgsdr0104 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Feed_Portal_ITAcademyStudents')]
dfgsdr0105 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Feed_Portal_SchoolNetStudents')]
dfgsdr0106 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FineTypes')]
dfgsdr0107 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FLATFILE')]
dfgsdr0108 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FLATFILE_JCS')]
dfgsdr0109 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FLP_Student_Attendance_List_tb')]
dfgsdr0110 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FTE_ERRORS')]
dfgsdr0111 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FTE_IVY_PREP')]
dfgsdr0112 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FTE_REPORT_SCH')]
dfgsdr0113 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FTE2019')]
dfgsdr0114 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FTENUMB UPDATE 20131021')]
dfgsdr0115 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FTENUMB UPDATE 20131024')]
dfgsdr0116 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GA411Data')]
dfgsdr0117 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GCPS_MA_AKS')]
dfgsdr0118 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GSDR_DATA_LOADED')]
dfgsdr0119 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GTID_IMPORTED')]
dfgsdr0120 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HiQ_Courses_20140122')]
dfgsdr0121 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'IEP_Accomondation_View_NewWay')]
dfgsdr0122 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_active_elig_view')]
dfgsdr0123 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_active_plan_view')]
dfgsdr0124 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_bip_intervention_view')]
dfgsdr0125 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'IEP_District_Users')]
dfgsdr0126 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_goals_view')]
dfgsdr0127 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_mods_ints_strengths_view')]
dfgsdr0128 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_objectives_details')]
dfgsdr0129 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_objectives_view')]
dfgsdr0130 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_plan_list_view')]
dfgsdr0131 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_student_casemanager_view')]
dfgsdr0132 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'iep_student_view')]
dfgsdr0133 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'IEPSERVICE')]
dfgsdr0134 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ImportFile')]
dfgsdr0135 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'IOWA_CoGAT_Report')]
dfgsdr0136 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ItemsCheckedOut')]
dfgsdr0137 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'January11pull')]
dfgsdr0138 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'kstemp')]
dfgsdr0139 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'kstemp2')]
dfgsdr0140 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'LA_AVG_Temp')]
dfgsdr0141 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'LDS')]
dfgsdr0142 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'LocalCourseMerged')]
dfgsdr0143 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MA_AVG_Temp')]
dfgsdr0144 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Maxwell')]
dfgsdr0145 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mentees_LOAD_ ALL_Details')]
dfgsdr0146 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mentees_LOAD_ ALL_Details_20210112')]
dfgsdr0147 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mentees_Names_ALL')]
dfgsdr0148 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MYSTUDENT_DATA_RETRIEVAL_HISTORY')]
dfgsdr0149 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MYSTUDENT_DATA_RETRIEVAL_STATUS')]
dfgsdr0150 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'NEW_MYSTUDENT_DATA_RETRIEVAL_HISTORY')]
dfgsdr0151 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'NEW_MYSTUDENT_DATA_RETRIEVAL_STATUS')]
dfgsdr0152 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Organization_Chart')]
dfgsdr0153 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'pa_update2020')]
dfgsdr0154 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PATHWAY_COURSE')]
dfgsdr0155 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Patrons_For_Datamove')]
dfgsdr0156 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PermnumFromRiderByRoute')]
dfgsdr0157 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PHLOTE_AUG')]
dfgsdr0158 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PHLOTE_JUN')]
dfgsdr0159 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PIVOTDATA')]
dfgsdr0160 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'portal_sec_aro_group_mbr_psd')]
dfgsdr0161 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PreK_Entrance')]
dfgsdr0162 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PreK_Exit')]
dfgsdr0163 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PreK_Not_Met')]
dfgsdr0164 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PRIMARY AREA UPDATE FTE20161')]
dfgsdr0165 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'private_school_2014final')]
dfgsdr0166 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'private_schools_2013')]
dfgsdr0167 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'private_schools_2014')]
dfgsdr0168 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'private_schools_2015')]
dfgsdr0169 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PSC_DATA')]
dfgsdr0170 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'psd_activity_2019')]
dfgsdr0171 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'psd_activity_2020')]
dfgsdr0172 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'psd_users_2019')]
dfgsdr0173 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'psd_users_2020')]
dfgsdr0174 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'psd_users_bak')]
dfgsdr0175 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Pseudo FTE Nums')]
dfgsdr0176 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Query2')]
dfgsdr0177 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'RIDER_BY_ROUTE')]
dfgsdr0178 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'RIDER_BY_ROUTE_SNAPSHOT')]
dfgsdr0179 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Rising_6thGrd_Report')]
dfgsdr0180 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Rising_7thGrd_Report')]
dfgsdr0181 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Rising_7thGrd_Report_Bkup')]
dfgsdr0182 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Rising_8thGrd_Report')]
dfgsdr0183 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Rising_8thGrd_Report_Bkup')]
dfgsdr0184 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Rising_9thGrd_Report')]
dfgsdr0185 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SASI_ACHS441')]
dfgsdr0186 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SASI_ASTU')]
dfgsdr0187 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_1_AVG')]
dfgsdr0188 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_1_ELIGIBLE')]
dfgsdr0189 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_2_AVG')]
dfgsdr0190 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_2_ELIGIBLE')]
dfgsdr0191 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_3_AVG')]
dfgsdr0192 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_3_ELIGIBLE')]
dfgsdr0193 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SC_ERRORS')]
dfgsdr0194 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SCHOOLFILE')]
dfgsdr0195 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SchoolFoodNutritionDaily_GSDR_test')]
dfgsdr0196 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SchoolReports_Subscribers')]
dfgsdr0197 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Schools_KS')]
dfgsdr0198 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SchPermnumCode')]
dfgsdr0199 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SemesterDates')]
dfgsdr0200 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SFN_Export')]
dfgsdr0201 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_current_IEP')]
dfgsdr0202 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_error_log')]
dfgsdr0203 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_error_log_ref')]
dfgsdr0204 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_iep_bip_antecedent_intervention_view')]
dfgsdr0205 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_iep_bip_behavior_view')]
dfgsdr0206 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_iep_bip_consequence_intervention_neg_view')]
dfgsdr0207 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_iep_bip_consequence_intervention_pos_view')]
dfgsdr0208 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_iep_bip_demographic_view')]
dfgsdr0209 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sis_reg_transportation_green_view')]
dfgsdr0210 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SIS_Testing_Accommodations_View')]
dfgsdr0211 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SLO_Corrections')]
dfgsdr0212 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20091031')]
dfgsdr0213 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20131031')]
dfgsdr0214 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20141031')]
dfgsdr0215 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20151031')]
dfgsdr0216 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20161031')]
dfgsdr0217 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_201610312')]
dfgsdr0218 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20171031')]
dfgsdr0219 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20181031')]
dfgsdr0220 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20191031')]
dfgsdr0221 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SNP_20201031')]
dfgsdr0222 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'snp_today')]
dfgsdr0223 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Sped_File_Push_data')]
dfgsdr0224 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SpEd_TransGreenListReport')]
dfgsdr0225 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SpEd_TransListReport')]
dfgsdr0226 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SPG Teachers To Validate')]
dfgsdr0227 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SPG Teachers To Validate2')]
dfgsdr0228 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'spg_courses_tests')]
dfgsdr0229 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SPG_Export')]
dfgsdr0230 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SPGCases_June20_2014')]
dfgsdr0231 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SPGJUNE30')]
dfgsdr0232 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SR_Errors')]
dfgsdr0233 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StageStudentPictures')]
dfgsdr0234 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StreetTypeAbbreviations')]
dfgsdr0235 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass')]
dfgsdr0236 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass_Buford')]
dfgsdr0237 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass_Buford_SAVE')]
dfgsdr0238 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass2015')]
dfgsdr0239 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass2015v2')]
dfgsdr0240 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass2016')]
dfgsdr0241 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass2017')]
dfgsdr0242 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass2018')]
dfgsdr0243 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClass20190601')]
dfgsdr0244 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentClassAppend')]
dfgsdr0245 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentCourseProfile')]
dfgsdr0246 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentCourseProfile2')]
dfgsdr0247 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentIDfromSRTV')]
dfgsdr0248 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentLogin20120827')]
dfgsdr0249 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentLogin20120903')]
dfgsdr0250 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentLogins')]
dfgsdr0251 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerSchoolSites2017')]
dfgsdr0252 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerSchoolSites2018')]
dfgsdr0253 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerSchoolSites2019')]
dfgsdr0254 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerStudentList')]
dfgsdr0255 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerStudentList2017')]
dfgsdr0256 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerStudentListTemp')]
dfgsdr0257 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerStudentListtemp_backup')]
dfgsdr0258 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerStudentListTemp_Bkup')]
dfgsdr0259 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Synergy_ESOL_Status')]
dfgsdr0260 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sysdtslog90')]
dfgsdr0261 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sysssislog')]
dfgsdr0262 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TeacherClass')]
dfgsdr0263 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TeacherClass2')]
dfgsdr0264 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_AD_Data')]
dfgsdr0265 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_ad_groups')]
dfgsdr0266 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_ad_groups_search')]
dfgsdr0267 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_ad_membership')]
dfgsdr0268 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_dscp_event_id_rules')]
dfgsdr0269 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_groups')]
dfgsdr0270 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Temp_MyTable')]
dfgsdr0271 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_SASI_APRN')]
dfgsdr0272 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEMP_TBL')]
dfgsdr0273 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'test_academic_contracts')]
dfgsdr0274 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Timeline 18_19')]
dfgsdr0275 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Title1 Employees')]
dfgsdr0276 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TMP_IEP_EXIT_VIEW')]
dfgsdr0277 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TMP_IEP_SERVICES_SR_VIEW')]
dfgsdr0278 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TranscriptData')]
dfgsdr0279 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TranscriptData_2020Staging')]
dfgsdr0280 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TranscriptSummary')]
dfgsdr0281 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'udtMonths')]
dfgsdr0282 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'UPKE')]
dfgsdr0283 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'UPKX')]
dfgsdr0284 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'USATestPrep_DataFeed')]
dfgsdr0285 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'USATestPrep_DataFeed_2018')]
dfgsdr0286 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'zoned_temp')]
dfgsdr0287 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dx') & (df['TableName'] == 'Households_Import')]
dfgsdr0288 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dx') & (df['TableName'] == 'HouseholdStudentMembers_Import')]
dfgsdr0289 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dx') & (df['TableName'] == 'Locker_Import')]
dfgsdr0290 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dx') & (df['TableName'] == 'MedIncident_Import')]
dfgsdr0291 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dx') & (df['TableName'] == 'StudentContacts_Import')]
dfgsdr0292 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'dx') & (df['TableName'] == 'StudentContactsParent_Import')]
dfgsdr0293 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'OverrideStudents')]
dfgsdr0294 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'OverrideStudentSections')]
dfgsdr0295 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'OverrideTeachers')]
dfgsdr0296 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'OverrideTeacherSections')]
dfgsdr0297 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'PqAllTeacherQualifications')]
dfgsdr0298 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'PqNonPqTeacherList')]
dfgsdr0299 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'PqParentNotifications')]
dfgsdr0300 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'PqRptAggDistrict')]
dfgsdr0301 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'PqRptAggSchool')]
dfgsdr0302 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'ReportActions')]
dfgsdr0303 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'Reports')]
dfgsdr0304 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StateCertifications')]
dfgsdr0305 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StateCourseRequirements')]
dfgsdr0306 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgPqPrep')]
dfgsdr0307 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgSchools')]
dfgsdr0308 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgSections')]
dfgsdr0309 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgStudents')]
dfgsdr0310 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgStudentSchedules')]
dfgsdr0311 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgStudentServices')]
dfgsdr0312 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgTeacherCertifications')]
dfgsdr0313 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgTeacherExceptionalities')]
dfgsdr0314 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgTeachers')]
dfgsdr0315 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'essa') & (df['TableName'] == 'StgTeacherSections')]
dfgsdr0316 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'Assignment')]
dfgsdr0317 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'AssignmentScore')]
dfgsdr0318 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'Calendar')]
dfgsdr0319 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'Gradebook')]
dfgsdr0320 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradebookCategory')]
dfgsdr0321 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradebookCategoryGrade')]
dfgsdr0322 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradebookGradingScale')]
dfgsdr0323 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradebookTerm')]
dfgsdr0324 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradebookTermGrade')]
dfgsdr0325 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradingScale')]
dfgsdr0326 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradingScaleBreakpoint')]
dfgsdr0327 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'GradingTerm')]
dfgsdr0328 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'SectionEnrollment')]
dfgsdr0329 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'Sections')]
dfgsdr0330 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'Student')]
dfgsdr0331 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'Teacher')]
dfgsdr0332 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'gbOLD') & (df['TableName'] == 'TeacherSection')]
dfgsdr0333 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Assignment')]
dfgsdr0334 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'AssignmentGrades')]
dfgsdr0335 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'AssignmentScore')]
dfgsdr0336 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Calendar')]
dfgsdr0337 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Course')]
dfgsdr0338 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'D2L_CLASS_Import')]
dfgsdr0339 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'D2L_Class_Import_20190410')]
dfgsdr0340 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'D2L_GRADE_IMPORT')]
dfgsdr0341 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'D2L_NOTE_Import')]
dfgsdr0342 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'D2L_SCORE_Import')]
dfgsdr0343 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'D2L_TASK_IMPORT')]
dfgsdr0344 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'FinalGrades')]
dfgsdr0345 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Gradebook')]
dfgsdr0346 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'GradebookCategory')]
dfgsdr0347 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'GradebookCategoryGrade')]
dfgsdr0348 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'GradebookTerm')]
dfgsdr0349 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'GradebookTermGrade')]
dfgsdr0350 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'GradingScaleBreakpoint')]
dfgsdr0351 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'GradingTerm')]
dfgsdr0352 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Organization')]
dfgsdr0353 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Person')]
dfgsdr0354 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'PivotTable')]
dfgsdr0355 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'RptAssignmentScore_CurrentTermFlag')]
dfgsdr0356 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Section')]
dfgsdr0357 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'SectionEnrollment')]
dfgsdr0358 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Student')]
dfgsdr0359 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'SynergyScore')]
dfgsdr0360 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GBStaging') & (df['TableName'] == 'Teacher')]
dfgsdr0361 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ACADEMIC_CONTRACTS')]
dfgsdr0362 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ACHSFILE')]
dfgsdr0363 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ADDRESS_HIST')]
dfgsdr0364 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ADIA')]
dfgsdr0365 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ADIA_ERROR_CODE')]
dfgsdr0366 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ADIA_HISTORY')]
dfgsdr0367 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ADIA_OMG')]
dfgsdr0368 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ADST_ALL_YEARS')]
dfgsdr0369 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'AFTSCH_TRANSP_PGMS')]
dfgsdr0370 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'Applitrack')]
dfgsdr0371 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'Applitrack_RecScore')]
dfgsdr0372 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'Applitrack_Test')]
dfgsdr0373 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ARCHATT')]
dfgsdr0374 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'archatt_2018_restore')]
dfgsdr0375 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ARCHGRD')]
dfgsdr0376 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ASTU_HISTORY')]
dfgsdr0377 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ATTDLET')]
dfgsdr0378 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ATTEND_PARAM')]
dfgsdr0379 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR')]
dfgsdr0380 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_20180530')]
dfgsdr0381 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_GAP')]
dfgsdr0382 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_JIC')]
dfgsdr0383 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_JIC2')]
dfgsdr0384 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_JIC3')]
dfgsdr0385 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_JIC4')]
dfgsdr0386 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_NEWSTUFF')]
dfgsdr0387 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CALENDAR_NEWSTUFF2')]
dfgsdr0388 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CLASSRANK')]
dfgsdr0389 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'COHORT2')]
dfgsdr0390 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'COURSE')]
dfgsdr0391 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'COURSE_REQUESTS')]
dfgsdr0392 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'COURSE_REQUESTS_JIC')]
dfgsdr0393 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'COURSE_REQUESTS_JIC_20170207')]
dfgsdr0394 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'COURSE_REQUESTS_JIC2')]
dfgsdr0395 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'COURSE_SETUP')]
dfgsdr0396 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CPI_A01')]
dfgsdr0397 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CPI_B01')]
dfgsdr0398 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CPI_C01')]
dfgsdr0399 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CPI_D01')]
dfgsdr0400 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CRCT_MATCHED')]
dfgsdr0401 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CRCT_MATCHED_TMP')]
dfgsdr0402 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CRISNET_ARRESTS')]
dfgsdr0403 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_ACTIVITY')]
dfgsdr0404 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_ASSIGNMENTS')]
dfgsdr0405 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_CONTACT_REASONS')]
dfgsdr0406 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_CONTACT_TYPES')]
dfgsdr0407 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_MEETINGS')]
dfgsdr0408 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_OUTCOMES')]
dfgsdr0409 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_REFERRALS')]
dfgsdr0410 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_STUDENT_EDUCATIONS')]
dfgsdr0411 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_STUDENT_HEALTHS')]
dfgsdr0412 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'CSN_TRAININGS')]
dfgsdr0413 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'dc_course_file_readonly')]
dfgsdr0414 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'dc_innovator_schedules_readonly')]
dfgsdr0415 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'dc_innovator_students_readonly')]
dfgsdr0416 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'dc_innovator_teachers_readonly')]
dfgsdr0417 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DELETED_GTIDS')]
dfgsdr0418 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DELETED_GTIDS_HISTORY')]
dfgsdr0419 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DESTINY_SCHOOLS')]
dfgsdr0420 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DOE_CLAIMED_SWD')]
dfgsdr0421 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DOE_SPED_NOPRIMARYAREA')]
dfgsdr0422 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DSCP_ADDL_COMMENT')]
dfgsdr0423 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DSCP_PANEL')]
dfgsdr0424 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DSCP_PANEL_RULES')]
dfgsdr0425 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DSCP_PANEL_SPED')]
dfgsdr0426 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'DUPLICATES')]
dfgsdr0427 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EDIT_CODES')]
dfgsdr0428 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ELIG_ACTIVITIES')]
dfgsdr0429 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ELIG_LOG')]
dfgsdr0430 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ELIG_PRAM')]
dfgsdr0431 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_pram_bak20190717')]
dfgsdr0432 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_pram_bak20200602')]
dfgsdr0433 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ELIG_PRAM_OBJECT')]
dfgsdr0434 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ELIG_REQUIREMENTS')]
dfgsdr0435 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ELIG_ROSTERS')]
dfgsdr0436 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_rosters_bak20200602')]
dfgsdr0437 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_rosters_lastupdate')]
dfgsdr0438 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_rosters_nodups')]
dfgsdr0439 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_rosters_sy1718_aftersummercalc')]
dfgsdr0440 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_rosters_sy1819_aftersummercalc')]
dfgsdr0441 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ELIG_STUDENTS')]
dfgsdr0442 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_students_bak20190717')]
dfgsdr0443 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_students_bak20190723')]
dfgsdr0444 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_students_bak20200602')]
dfgsdr0445 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_students_bak20200722')]
dfgsdr0446 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_students_procbak')]
dfgsdr0447 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_students_sy1718_aftersummercalc')]
dfgsdr0448 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'elig_students_sy1819_aftersummercalc')]
dfgsdr0449 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EOCT_HIST')]
dfgsdr0450 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ESOL')]
dfgsdr0451 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ESOL_CAT')]
dfgsdr0452 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EXP_REG_STU')]
dfgsdr0453 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EXP_REG_SUM')]
dfgsdr0454 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EXTERNAL_SCHOOLS')]
dfgsdr0455 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'external_schools_all_years')]
dfgsdr0456 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EXTERNAL_STUDENTS')]
dfgsdr0457 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'external_students_all_years')]
dfgsdr0458 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EXTERNAL_STUDENTS_NONDISTRICT')]
dfgsdr0459 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'EXTERNAL_STUDENTS_Tim')]
dfgsdr0460 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FAY_RESEARCH')]
dfgsdr0461 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FAY_RESEARCH_EOCT')]
dfgsdr0462 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FORECAST')]
dfgsdr0463 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FREE_REDUCED_LUNCH')]
dfgsdr0464 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE')]
dfgsdr0465 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_COURSES')]
dfgsdr0466 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_ERRORLOAD')]
dfgsdr0467 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_HISTORY')]
dfgsdr0468 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_PARAMS')]
dfgsdr0469 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_REPORT_ROWS')]
dfgsdr0470 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_REPORT_SCH')]
dfgsdr0471 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_REPORT_SCH20130220')]
dfgsdr0472 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_TEMP')]
dfgsdr0473 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE_ZONED_SCH')]
dfgsdr0474 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE441')]
dfgsdr0475 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE88')]
dfgsdr0476 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTE88_KS')]
dfgsdr0477 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTECRS_MULTI')]
dfgsdr0478 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTEEIP')]
dfgsdr0479 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTEGIFTED_STUDENT')]
dfgsdr0480 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTENUMB_TANK')]
dfgsdr0481 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTEPEOPLE')]
dfgsdr0482 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESPED')]
dfgsdr0483 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT')]
dfgsdr0484 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_APPEND')]
dfgsdr0485 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_BUF')]
dfgsdr0486 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_BUF_KS')]
dfgsdr0487 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_IVY')]
dfgsdr0488 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_KS')]
dfgsdr0489 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_LAST_YEAR')]
dfgsdr0490 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_MAIN')]
dfgsdr0491 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'FTESTAT_YEAR')]
dfgsdr0492 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GBATCH')]
dfgsdr0493 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GBATCH_UPD')]
dfgsdr0494 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GTID')]
dfgsdr0495 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GTID_ERRORS')]
dfgsdr0496 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GTID_HISTORY')]
dfgsdr0497 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GTID_IMPORT')]
dfgsdr0498 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GTID_STU_BATCH')]
dfgsdr0499 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GTID_STU_BATCH_UPD')]
dfgsdr0500 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'G_GTID20200813')]
dfgsdr0501 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'GIFTED')]
dfgsdr0502 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'GIFTED_CAT')]
dfgsdr0503 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'GRADETANK')]
dfgsdr0504 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'GRADETANK_HISTORY')]
dfgsdr0505 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'GRADETANK_KS')]
dfgsdr0506 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'GRADETANK3')]
dfgsdr0507 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'GRADETANKTEMP')]
dfgsdr0508 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_EXIT')]
dfgsdr0509 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_EXPORT')]
dfgsdr0510 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_GAA_INFO')]
dfgsdr0511 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_SERVICES')]
dfgsdr0512 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_SERVICES_FTE')]
dfgsdr0513 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_SERVICES_SR')]
dfgsdr0514 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_TIMELINE')]
dfgsdr0515 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_TranspRoster')]
dfgsdr0516 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_TranspRoster_CaseManagerComments')]
dfgsdr0517 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'IEP_TranspRoster_OtherSchools')]
dfgsdr0518 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ISC_CONTRACTORS')]
dfgsdr0519 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'LETTER_TEXT')]
dfgsdr0520 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'LETTER_TEXT_SAVE')]
dfgsdr0521 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'LOCATION')]
dfgsdr0522 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'LTS_TNL_Mentor')]
dfgsdr0523 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'MEDICAID')]
dfgsdr0524 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'NEXT_SCHOOL')]
dfgsdr0525 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'NEXT_SCHOOL_Audit')]
dfgsdr0526 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'NON_TEACHERS')]
dfgsdr0527 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'NOSHOWS')]
dfgsdr0528 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'NOSHOWS2012')]
dfgsdr0529 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_CODE_DEFINITIONS')]
dfgsdr0530 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_LOOKUP_CODES')]
dfgsdr0531 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'Portal_lookup_codes_20170131')]
dfgsdr0532 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_lookup_codes_lastupdate')]
dfgsdr0533 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_PARAM_MESSAGES')]
dfgsdr0534 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_PARAMS')]
dfgsdr0535 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ACL')]
dfgsdr0536 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ACO')]
dfgsdr0537 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ACO_MAP')]
dfgsdr0538 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aco_map_lastupdate')]
dfgsdr0539 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ARO')]
dfgsdr0540 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ARO_ACL')]
dfgsdr0541 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_acl_autobackup')]
dfgsdr0542 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_acl_lastupdate')]
dfgsdr0543 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ARO_GROUP_MBR')]
dfgsdr0544 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_group_mbr_bak_20170413_psd')]
dfgsdr0545 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_group_mbr_bak_20180409_psd')]
dfgsdr0546 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_group_mbr_bak_20190411_psd')]
dfgsdr0547 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_group_mbr_bak_20200411_psd')]
dfgsdr0548 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_group_mbr_bak_20210411_psd')]
dfgsdr0549 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ARO_GROUPS')]
dfgsdr0550 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ARO_GROUPS_MAP')]
dfgsdr0551 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_groups_map_lastupdate')]
dfgsdr0552 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_ARO_MAP')]
dfgsdr0553 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_aro_map_lastupdate')]
dfgsdr0554 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_AXO')]
dfgsdr0555 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_AXO_GROUP_MBR')]
dfgsdr0556 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_AXO_GROUPS')]
dfgsdr0557 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_AXO_GROUPS_MAP')]
dfgsdr0558 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_axo_groups_map_lastupdate')]
dfgsdr0559 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PORTAL_SEC_AXO_MAP')]
dfgsdr0560 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'portal_sec_axo_map_lastupdate')]
dfgsdr0561 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PREVIOUS_VALUES')]
dfgsdr0562 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_ATTD')]
dfgsdr0563 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_EMP_JOBCD')]
dfgsdr0564 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_EMPLOYEE')]
dfgsdr0565 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_EMPLOYEE_JIC_20170206')]
dfgsdr0566 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GP_ABS_EVENT')]
dfgsdr0567 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GP_ABS_REASON')]
dfgsdr0568 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GP_ABS_REASON2')]
dfgsdr0569 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_CERT')]
dfgsdr0570 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_CERT_DATA')]
dfgsdr0571 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_CERT_DISCREPANCY')]
dfgsdr0572 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_COURSE')]
dfgsdr0573 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_COURSE_CERT')]
dfgsdr0574 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_TNL_COURSE_SLO')]
dfgsdr0575 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_TNL_COURSES')]
dfgsdr0576 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_GW_TNL_PRFL_TGT')]
dfgsdr0577 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PS_JOBCD')]
dfgsdr0578 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PSD_ACTIVITY')]
dfgsdr0579 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'psd_activity_lastupdate')]
dfgsdr0580 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PSD_APRN_LAST')]
dfgsdr0581 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'PSD_USERS')]
dfgsdr0582 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'REGISTER')]
dfgsdr0583 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'REGISTERSUMMARY')]
dfgsdr0584 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'REGSUM')]
dfgsdr0585 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'REGSUM_HISTORY')]
dfgsdr0586 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_A504')]
dfgsdr0587 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AATC')]
dfgsdr0588 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AATC_ROT')]
dfgsdr0589 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AATD')]
dfgsdr0590 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_aatd_TSTAGING')]
dfgsdr0591 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AATO_ROT')]
dfgsdr0592 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AATP')]
dfgsdr0593 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_aatp_TSTAGING')]
dfgsdr0594 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AATT')]
dfgsdr0595 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ABSENCE_CODES')]
dfgsdr0596 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACAM')]
dfgsdr0597 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACHS')]
dfgsdr0598 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACHS_ES')]
dfgsdr0599 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACHS_MS')]
dfgsdr0600 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACHS_MSES')]
dfgsdr0601 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACHS_SDR')]
dfgsdr0602 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACHS9203768')]
dfgsdr0603 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACLH')]
dfgsdr0604 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACLS')]
dfgsdr0605 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACLS_NEXT')]
dfgsdr0606 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_acls_TSTAGING')]
dfgsdr0607 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACNF')]
dfgsdr0608 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACNR')]
dfgsdr0609 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS')]
dfgsdr0610 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS_FTE')]
dfgsdr0611 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS_FTE2')]
dfgsdr0612 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS_HS')]
dfgsdr0613 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS_KS')]
dfgsdr0614 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS_NEXT')]
dfgsdr0615 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS_RAW')]
dfgsdr0616 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ACRS2012')]
dfgsdr0617 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADDITIONAL_TEACHER')]
dfgsdr0618 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADIS')]
dfgsdr0619 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADIS_C')]
dfgsdr0620 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADIS_KS')]
dfgsdr0621 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADPO')]
dfgsdr0622 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADPO_C')]
dfgsdr0623 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADPS')]
dfgsdr0624 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADST')]
dfgsdr0625 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ADST_ALL')]
dfgsdr0626 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AELT')]
dfgsdr0627 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AELT_JUST_DATES')]
dfgsdr0628 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AEMG')]
dfgsdr0629 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AEMG_NEXT')]
dfgsdr0630 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AENR')]
dfgsdr0631 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AENR_C')]
dfgsdr0632 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AENR_KS')]
dfgsdr0633 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AENR_NEXT')]
dfgsdr0634 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AENR_NON_ADA_ADM')]
dfgsdr0635 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AENR_SUMMER')]
dfgsdr0636 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AENR2')]
dfgsdr0637 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AFEE')]
dfgsdr0638 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AFID')]
dfgsdr0639 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AGRD')]
dfgsdr0640 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AGRL')]
dfgsdr0641 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AGSU')]
dfgsdr0642 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AHLT')]
dfgsdr0643 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ALKR')]
dfgsdr0644 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ALRT')]
dfgsdr0645 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AMST')]
dfgsdr0646 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AMST_NEXT')]
dfgsdr0647 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AMST_SECT_STF_HIS')]
dfgsdr0648 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AONL')]
dfgsdr0649 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_APGD')]
dfgsdr0650 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_APGL')]
dfgsdr0651 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_APGM')]
dfgsdr0652 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_APRN')]
dfgsdr0653 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_APRN_LAST')]
dfgsdr0654 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'sasi_aprn_sy1718')]
dfgsdr0655 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'sasi_aprn_sy1819')]
dfgsdr0656 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'sasi_aprn_sy1920')]
dfgsdr0657 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_APRN2012')]
dfgsdr0658 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASCH')]
dfgsdr0659 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASGR')]
dfgsdr0660 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTI')]
dfgsdr0661 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU')]
dfgsdr0662 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_DEMOG')]
dfgsdr0663 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_DIPLOMA_SEALS')]
dfgsdr0664 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_EMAIL')]
dfgsdr0665 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_GOSA_AUDIT')]
dfgsdr0666 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_MIN')]
dfgsdr0667 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_NEXT')]
dfgsdr0668 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_NON_ADA_ADM')]
dfgsdr0669 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_SDR_2020')]
dfgsdr0670 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTU_TEMP')]
dfgsdr0671 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTV')]
dfgsdr0672 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTV_BP')]
dfgsdr0673 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ASTV_NEXT')]
dfgsdr0674 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATBL')]
dfgsdr0675 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'sasi_atbl_BADREL')]
dfgsdr0676 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATBL_KS')]
dfgsdr0677 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATCH')]
dfgsdr0678 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATCH_NEXT')]
dfgsdr0679 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_atch_TSTAGING')]
dfgsdr0680 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATES')]
dfgsdr0681 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATPA')]
dfgsdr0682 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATRM')]
dfgsdr0683 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATRM_NEXT')]
dfgsdr0684 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATRM2016')]
dfgsdr0685 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATRM4')]
dfgsdr0686 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ATRMPORT')]
dfgsdr0687 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_AUFS')]
dfgsdr0688 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_COUNTRY_OF_BIRTH')]
dfgsdr0689 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_DISCP_RULES')]
dfgsdr0690 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_DISCP_RULES_HIST')]
dfgsdr0691 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_DISCP_RULES051219')]
dfgsdr0692 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_DISPCODES')]
dfgsdr0693 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_DISPCODES_HIST')]
dfgsdr0694 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_DISPCODES051219')]
dfgsdr0695 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ELL_PARENT_CONF')]
dfgsdr0696 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_ELL_WAIVER')]
dfgsdr0697 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_FILE_HISTORY')]
dfgsdr0698 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_GAT_HIS')]
dfgsdr0699 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_LOAD_control')]
dfgsdr0700 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_PARAPRO')]
dfgsdr0701 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_SMST')]
dfgsdr0702 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UABN')]
dfgsdr0703 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UATR')]
dfgsdr0704 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UATR_NEXT')]
dfgsdr0705 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_uatr_TSTAGING')]
dfgsdr0706 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UCES')]
dfgsdr0707 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UCMS')]
dfgsdr0708 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UFLP')]
dfgsdr0709 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UGFT')]
dfgsdr0710 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_Upload_Count_Difference')]
dfgsdr0711 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UPLOAD_HISTORY')]
dfgsdr0712 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UPSA')]
dfgsdr0713 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UPSR')]
dfgsdr0714 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SASI_UTL1')]
dfgsdr0715 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SCHEDULES_MS_SAVE')]
dfgsdr0716 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SCHOOL_CLUSTER')]
dfgsdr0717 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SCHOOL_ETS_CODES')]
dfgsdr0718 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SCP')]
dfgsdr0719 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_DSCP_ACTIONS')]
dfgsdr0720 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_DSCP_INCDTS')]
dfgsdr0721 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_ENR')]
dfgsdr0722 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_ERRORS')]
dfgsdr0723 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_IEP_SPED')]
dfgsdr0724 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_IEP_SPED2')]
dfgsdr0725 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SCH_EDM')]
dfgsdr0726 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SCH_TITLE1')]
dfgsdr0727 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SCH_TITLE1_CHARLENE')]
dfgsdr0728 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SCHOOL_B')]
dfgsdr0729 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SCHOOL_N')]
dfgsdr0730 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SCHOOL_NCLB')]
dfgsdr0731 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_C')]
dfgsdr0732 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_C_HOST')]
dfgsdr0733 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_D')]
dfgsdr0734 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_D_HOST')]
dfgsdr0735 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_D_T')]
dfgsdr0736 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_E')]
dfgsdr0737 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_E_HOST')]
dfgsdr0738 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_F')]
dfgsdr0739 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_F_HOST')]
dfgsdr0740 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_G')]
dfgsdr0741 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_G_HOST')]
dfgsdr0742 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_G_OLD')]
dfgsdr0743 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_H')]
dfgsdr0744 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_H_HOST')]
dfgsdr0745 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_K')]
dfgsdr0746 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_K_KS')]
dfgsdr0747 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_K2')]
dfgsdr0748 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_STU_TITLE1')]
dfgsdr0749 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SYS_J')]
dfgsdr0750 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDR_SYS_J20150613')]
dfgsdr0751 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRC_HIST')]
dfgsdr0752 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRCTMP')]
dfgsdr0753 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRD_HIST')]
dfgsdr0754 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRD2014')]
dfgsdr0755 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRE_HIST')]
dfgsdr0756 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRF_HIST')]
dfgsdr0757 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRF_TMP')]
dfgsdr0758 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRG_HIST')]
dfgsdr0759 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRK_HIST')]
dfgsdr0760 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRSTUFZ')]
dfgsdr0761 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SDRSTUK_TMP')]
dfgsdr0762 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SES')]
dfgsdr0763 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SLDS_Teachers')]
dfgsdr0764 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SPED_EXIT')]
dfgsdr0765 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SPED_SCORE_CARD')]
dfgsdr0766 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SPED_SCORE_REP')]
dfgsdr0767 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SPED_SCORE_SUM')]
dfgsdr0768 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SPED_TCH_SCHED')]
dfgsdr0769 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SRO_RULES')]
dfgsdr0770 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_ACTIVITY')]
dfgsdr0771 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_ASSIGNMENTS')]
dfgsdr0772 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_CASES')]
dfgsdr0773 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'ssw_cases_bak_20171219_before_code_update')]
dfgsdr0774 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_CONTACT_REASONS')]
dfgsdr0775 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_CONTACT_TYPES')]
dfgsdr0776 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_DOE_CASES')]
dfgsdr0777 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_DOE_REFERRALS')]
dfgsdr0778 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_DOE_SERVICES')]
dfgsdr0779 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_LOOKUP_CODES')]
dfgsdr0780 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_MEETINGS')]
dfgsdr0781 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_REFERRALS')]
dfgsdr0782 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'SSW_STUDENTS')]
dfgsdr0783 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'string_translation')]
dfgsdr0784 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STU_FAY')]
dfgsdr0785 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STU_HOPE_GRANT')]
dfgsdr0786 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STU_ZONED_SCH')]
dfgsdr0787 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUD_HOPE_GRANT')]
dfgsdr0788 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUDENT_DISTRICT')]
dfgsdr0789 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUDENT_FTEID')]
dfgsdr0790 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUDENT_FTEID20200813')]
dfgsdr0791 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUDENT_PROFILES')]
dfgsdr0792 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUDENT_SCHEDULE')]
dfgsdr0793 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUDENT_SCHOOLS')]
dfgsdr0794 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'STUHEADR')]
dfgsdr0795 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'TEACHER_LEAVE')]
dfgsdr0796 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'TEACHER_SCHEDULE')]
dfgsdr0797 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'TEMP_DOE_SPED_NOPRIMARYAREA')]
dfgsdr0798 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'TIME_STAMP')]
dfgsdr0799 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'TITLE1_SWP')]
dfgsdr0800 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'TITLE1_TAS')]
dfgsdr0801 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'USCO_CODES')]
dfgsdr0802 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'GEMS') & (df['TableName'] == 'XPRT_STUDENTS_NOSHOW')]
dfgsdr0803 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Class')]
dfgsdr0804 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Class_Backup_20170915')]
dfgsdr0805 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Grade')]
dfgsdr0806 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Grade_Backup_20170915')]
dfgsdr0807 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Note')]
dfgsdr0808 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Score')]
dfgsdr0809 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'score_backup')]
dfgsdr0810 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Score_Backup_20170915')]
dfgsdr0811 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Task')]
dfgsdr0812 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'task_backup')]
dfgsdr0813 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Gradebook') & (df['TableName'] == 'Task_Backup_20170915')]
dfgsdr0814 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'guest') & (df['TableName'] == 'FTE_GTID_Updates')]
dfgsdr0815 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'guest') & (df['TableName'] == 'PermnumList')]
dfgsdr0816 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'CALENDAR')]
dfgsdr0817 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'G_GTID')]
dfgsdr0818 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AATC')]
dfgsdr0819 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AATC_ROT')]
dfgsdr0820 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AATD')]
dfgsdr0821 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AATO_ROT')]
dfgsdr0822 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AATP')]
dfgsdr0823 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AATT')]
dfgsdr0824 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_ACLH')]
dfgsdr0825 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_ACLS')]
dfgsdr0826 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_ACRS')]
dfgsdr0827 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_ACRS_RAW')]
dfgsdr0828 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AENR')]
dfgsdr0829 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_AMST')]
dfgsdr0830 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_ASTU')]
dfgsdr0831 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_ATCH')]
dfgsdr0832 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_ATRM')]
dfgsdr0833 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'SASI_SMST')]
dfgsdr0834 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'STUDENT_FTEID')]
dfgsdr0835 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'TEACHER_LEAVE')]
dfgsdr0836 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'TEACHER_LEAVE2')]
dfgsdr0837 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2014') & (df['TableName'] == 'Teachers To Validate')]
dfgsdr0838 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'CALENDAR')]
dfgsdr0839 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'G_GTID')]
dfgsdr0840 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_AATC')]
dfgsdr0841 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_AATC_ROT')]
dfgsdr0842 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_AATO_ROT')]
dfgsdr0843 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_ACLH')]
dfgsdr0844 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_ACLS')]
dfgsdr0845 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_ACRS')]
dfgsdr0846 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_ACRS_RAW')]
dfgsdr0847 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_AENR')]
dfgsdr0848 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_AMST')]
dfgsdr0849 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_ASTU')]
dfgsdr0850 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_ATCH')]
dfgsdr0851 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_ATRM')]
dfgsdr0852 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'SASI_SMST')]
dfgsdr0853 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'STUDENT_FTEID')]
dfgsdr0854 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'StudentClass')]
dfgsdr0855 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'StudentCourseProfile')]
dfgsdr0856 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'TEACHER_LEAVE')]
dfgsdr0857 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'TEACHER_LEAVE2')]
dfgsdr0858 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'TeacherClass')]
dfgsdr0859 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'Teachers To Validate')]
dfgsdr0860 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'SPG2015') & (df['TableName'] == 'Teachers To Validate20160211')]
dfgsdr0861 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'stage') & (df['TableName'] == 'crisnet_arrests')]
dfgsdr0862 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'stage') & (df['TableName'] == 'psd_input_file')]
dfgsdr0863 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'StudentProfile') & (df['TableName'] == 'FACT_AttendanceByType')]
dfgsdr0864 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'TCAccommodation') & (df['TableName'] == 'ELPP_Notes')]
dfgsdr0865 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'TCAccommodation') & (df['TableName'] == 'IEPAccommodations')]
dfgsdr0866 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'TCAccommodation') & (df['TableName'] == 'S504Accommodations')]
dfgsdr0867 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'TCAccommodation') & (df['TableName'] == 'TPP_Notes')]
dfgsdr0868 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'Attendance')]
dfgsdr0869 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'Courses')]
dfgsdr0870 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'CumGPA')]
dfgsdr0871 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'EOC')]
dfgsdr0872 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'GPA')]
dfgsdr0873 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'School')]
dfgsdr0874 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'SchoolsAttended')]
dfgsdr0875 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'Semesters')]
dfgsdr0876 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'SpecialStudents')]
dfgsdr0877 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'Student')]
dfgsdr0878 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'SUMLA')]
dfgsdr0879 = df[(df['DatabaseName'] == 'GSDR') & (df['SchemaName'] == 'Transcript') & (df['TableName'] == 'TestAssesments')]

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(df).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='GSDR All Tables'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(df, title='GSDR All Tables').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#Individual Tables - graphed with datapane and altair

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfgsdr0019).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='AcademicContract'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfgsdr0019, title='AcademicContract').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfgsdr0022).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='AcademicContractIntervention'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfgsdr0022, title='AcademicContractIntervention').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfgsdr0066).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='DestinyOutstandingFees'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfgsdr0066, title='DestinyOutstandingFees').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfgsdr0121).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='IEP_Accomondation_View_NewWay'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfgsdr0121, title='IEP_Accomondation_View_NewWay').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfgsdr0123).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='iep_active_plan_view'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfgsdr0123, title='iep_active_plan_view').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfgsdr0368).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='ADST_ALL_YEARS'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfgsdr0368, title='ADST_ALL_YEARS').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfgsdr0377).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='ATTDLET'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfgsdr0377, title='ATTDLET').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)
