# %%
#Program Name: Graphing ODS Databases - SQL Conn 02 - Assmnt display inline graph-w-PX-color-export2html
#Purpose:  Chart scatter, line, box, aggr, violin, or bar with table data
#Author:  Greg Turmel, Director, Data Governance 
#Date:    2020.08.30 - 2021.06.30
#Errata:  0.1 Improvements can be made to script using for/looping through the databases

import os, time, datetime
import sqlalchemy as db
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import pyodbc 
import matplotlib
import plotly.express as px

#matplotlib.rcParams['figure.figsize'] = (30,5)
# %config InlineBackend.figure_format = 'retina'
from dotenv import load_dotenv # add this line
load_dotenv() # add this line
user = os.getenv('MySQLeUser')
password = os.getenv('MySQLeUserPass')
host = os.getenv('MySQLeHOST')
db = os.getenv('MySQLeDB')
# %matplotlib inline
# %load_ext sql

dt1 = time.strftime("%d/%m/%Y")
dt2 = time.strftime("%d.%m.%Y")
dt3 = pd.to_datetime('today')
dt4 = pd.Timestamp('today').strftime("%Y%m%d")
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=DEVODSSQL;'
                      'Database=Greg;'
                      'Trusted_Connection=yes;')

sql_query01 = pd.read_sql_query(''' 
select DISTINCT TableName
FROM [dbo].[tableRowCountAssessment]
ORDER BY TableName;     
                              '''
                              ,conn) # Load the list of distinct tables to graph

sql_query02 = pd.read_sql_query(''' 
select *
FROM [dbo].[tableRowCountAssessment]
ORDER BY TableName;     
                              '''
                              ,conn) # Load the list of distinct tables to graph

# %%
df = pd.DataFrame(sql_query02)
#df = df.astype({'TodaysDate':np.int64,'RecordCount':np.int64})
df['TodaysDate'] = pd.to_datetime(df['TodaysDate'].astype(str), format='%Y%m%d')
df = df.sort_values(by=['TableName','SchemaName','DatabaseName','TodaysDate'], ascending=[True,True,True,True])
df = df.reset_index(drop=True)

# %%
dfasmnt0001 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AA_BioChem_CRS_List')]
dfasmnt0002 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'aaaa')]
dfasmnt0003 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'aaaUpform')]
dfasmnt0004 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ACCESS_2016_2017')]
dfasmnt0005 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ACCESS_ELL_StrandPossibleScores')]
dfasmnt0006 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ACCESS_SUBTEST_DIM')]
dfasmnt0007 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ACCESS_SUBTEST_FACT')]
dfasmnt0008 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_ASSESSMENT_REPORT')]
dfasmnt0009 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_ASSESSMENT_REPORT_2')]
dfasmnt0010 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_ASSESSMENT_REPORT_240119')]
dfasmnt0011 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_ASSESSMENT_REPORT_GRD5')]
dfasmnt0012 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_ASSESSMENT_REPORT_GRD7')]
dfasmnt0013 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_ASSESSMENT_REPORT_GRD9')]
dfasmnt0014 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_ELA_AVG')]
dfasmnt0015 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_EOC_ALG1516')]
dfasmnt0016 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_EOC_ALG1617')]
dfasmnt0017 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_EOC_REPORT_1516')]
dfasmnt0018 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_EOC_REPORT_1617')]
dfasmnt0019 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_INTERIM_REPORT')]
dfasmnt0020 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_PHONE_INFO')]
dfasmnt0021 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_SAT_REPORT')]
dfasmnt0022 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_SAT_REPORT_2')]
dfasmnt0023 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_SAT_REPORT_3')]
dfasmnt0024 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_SAT_REPORT_3_WITHCONTACT')]
dfasmnt0025 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_SPECIALED_REPORT')]
dfasmnt0026 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_SPECIALED_REPORT_1718')]
dfasmnt0027 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADMIN_TEST_DATE_DESC')]
dfasmnt0028 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Advisement')]
dfasmnt0029 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS')]
dfasmnt0030 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_20180622')]
dfasmnt0031 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_Archive')]
dfasmnt0032 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_GEMS_Comments')]
dfasmnt0033 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_GEMS_Comments_Archive')]
dfasmnt0034 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_GEMS_Review')]
dfasmnt0035 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_GEMS_Review_Archive')]
dfasmnt0036 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_GEMS_Review_BK112017')]
dfasmnt0037 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_GEMS_Schools')]
dfasmnt0038 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_Rev_Subject_Course')]
dfasmnt0039 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_Rev_Subject_Course_BKP')]
dfasmnt0040 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_Rev_Subject_Course_BKP2')]
dfasmnt0041 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_Rev_Subject_Course_BKP20150706')]
dfasmnt0042 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_Rev_Subject_Course_BKP3')]
dfasmnt0043 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_Rev_Subject_Course_T1')]
dfasmnt0044 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_Rev_Subject_Course_T1_BKP')]
dfasmnt0045 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_Rev_Subject_Course_T1_BKP2')]
dfasmnt0046 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_Rev_Subject_Course_T1_BKP20150706')]
dfasmnt0047 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_Rev_Subject_Course_Temp')]
dfasmnt0048 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Analytics_Roster')]
dfasmnt0049 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AP_COURSE_TEST_MAP')]
dfasmnt0050 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'APP_CODE_COURSE')]
dfasmnt0051 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'APP_CODE_COURSE_12092019')]
dfasmnt0052 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'APP_CODE_NAME')]
dfasmnt0053 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'APP_GROUP_OLD')]
dfasmnt0054 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ARTICULATION_DATA')]
dfasmnt0055 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ACC')]
dfasmnt0056 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ACC_ALT')]
dfasmnt0057 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ACC_ALT_RAW')]
dfasmnt0058 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ACC_ALT_REP')]
dfasmnt0059 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ACC_RAW')]
dfasmnt0060 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ACC_REP')]
dfasmnt0061 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ACT')]
dfasmnt0062 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ACT_RAW')]
dfasmnt0063 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ACT_RAW_JIC')]
dfasmnt0064 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ACT_REP')]
dfasmnt0065 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_COG')]
dfasmnt0066 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_COG_BKP')]
dfasmnt0067 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_COG_RAW')]
dfasmnt0068 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_COG_RAW_BKP_II')]
dfasmnt0069 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_COG_RAW_BKP_III')]
dfasmnt0070 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_COG_REP')]
dfasmnt0071 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_COG_REP_BKP')]
dfasmnt0072 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_CRM')]
dfasmnt0073 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_CRM_RAW')]
dfasmnt0074 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_CRM_REP')]
dfasmnt0075 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_EOC')]
dfasmnt0076 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_EOC_CopyJan212020')]
dfasmnt0077 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_EOC_Jul24')]
dfasmnt0078 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_EOC_RAW')]
dfasmnt0079 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_EOC_REP')]
dfasmnt0080 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_EOG')]
dfasmnt0081 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_EOG_CopyJan212020')]
dfasmnt0082 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_EOG_RAW')]
dfasmnt0083 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_EOG_REP')]
dfasmnt0084 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_G10')]
dfasmnt0085 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_G10_RAW')]
dfasmnt0086 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_G10_RAW_BC')]
dfasmnt0087 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_G10_REP')]
dfasmnt0088 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_G10_SUM')]
dfasmnt0089 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_G10_SUM_05Aug2020')]
dfasmnt0090 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_G10_SUM_BKUP')]
dfasmnt0091 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_G10_WAIVER')]
dfasmnt0092 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_GAA')]
dfasmnt0093 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_GAA_2_0')]
dfasmnt0094 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_GAA_RAW')]
dfasmnt0095 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_GAA_RAW_2_0')]
dfasmnt0096 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_GAA_REP')]
dfasmnt0097 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SC')]
dfasmnt0098 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SC_RAW')]
dfasmnt0099 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SC_RAW_SCORES')]
dfasmnt0100 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SC_REP')]
dfasmnt0101 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SCORES_KNO_TEMP')]
dfasmnt0102 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SCORES_ORG_CON_TEMP')]
dfasmnt0103 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SCORES_SS_TEMP')]
dfasmnt0104 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SCORES_TEMP')]
dfasmnt0105 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SS')]
dfasmnt0106 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SS_286')]
dfasmnt0107 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SS_RAW')]
dfasmnt0108 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SS_RAW_SCORES')]
dfasmnt0109 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SS_REP')]
dfasmnt0110 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ITB')]
dfasmnt0111 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ITB_RAW')]
dfasmnt0112 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ITB_RAW_RON')]
dfasmnt0113 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ITB_REP')]
dfasmnt0114 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_PSAT_89')]
dfasmnt0115 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_PSAT_89_RAW')]
dfasmnt0116 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_PSAT_89_RAW_REP')]
dfasmnt0117 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_PSAT_NMSQT')]
dfasmnt0118 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_PSAT_NMSQT_RAW')]
dfasmnt0119 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_PSAT_NMSQT_RAW_REP')]
dfasmnt0120 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_SAT')]
dfasmnt0121 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_SAT_RAW')]
dfasmnt0122 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_SAT_RAW_REP')]
dfasmnt0123 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'assess_temp')]
dfasmnt0124 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_TEMP_EOG')]
dfasmnt0125 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_WR5')]
dfasmnt0126 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_WR5_RAW')]
dfasmnt0127 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_WR5_REP')]
dfasmnt0128 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_WR8')]
dfasmnt0129 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_WR8_RAW')]
dfasmnt0130 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_WR8_REP')]
dfasmnt0131 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_WRI')]
dfasmnt0132 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_WRI_RAW')]
dfasmnt0133 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_WRI_REP')]
dfasmnt0134 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AssessedSubject_FromSynergy')]
dfasmnt0135 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESSMENT_APP_SECURITY_OLD')]
dfasmnt0136 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESSMENT_JOB_PARM')]
dfasmnt0137 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_PP_List')]
dfasmnt0138 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report')]
dfasmnt0139 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_Avg')]
dfasmnt0140 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_HS')]
dfasmnt0141 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_MS')]
dfasmnt0142 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_MSHS')]
dfasmnt0143 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_PP')]
dfasmnt0144 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_PP_Count')]
dfasmnt0145 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_Special')]
dfasmnt0146 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_StuCls_BySch')]
dfasmnt0147 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_StuCls_BySch_MS')]
dfasmnt0148 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_StuCls_BySch_WithZero')]
dfasmnt0149 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_StuCls_Count')]
dfasmnt0150 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_StuCls_Count_HS')]
dfasmnt0151 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_StuCls_Count_MS')]
dfasmnt0152 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_StuCls_Count_WithZero')]
dfasmnt0153 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_StuCls_Summary')]
dfasmnt0154 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_WithZero')]
dfasmnt0155 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Totals_By_Grade')]
dfasmnt0156 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Totals_By_Grade_HS')]
dfasmnt0157 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Totals_By_Grade_MS')]
dfasmnt0158 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Totals_By_Grade_WithZero')]
dfasmnt0159 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Classworks')]
dfasmnt0160 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassworksClass')]
dfasmnt0161 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassworksExtra')]
dfasmnt0162 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassworksMaster')]
dfasmnt0163 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassworksMasterAdd')]
dfasmnt0164 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassworksMasterFile')]
dfasmnt0165 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassworksSurvey')]
dfasmnt0166 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassworksTSTList')]
dfasmnt0167 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassworksUpdate')]
dfasmnt0168 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CommonCoreFT_Parm')]
dfasmnt0169 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ConnectEd_GCPSAdmin')]
dfasmnt0170 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ConnectEd_Schools_old')]
dfasmnt0171 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ConnectEd_Textbooks_blah')]
dfasmnt0172 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CRCT_DATA_VIEW')]
dfasmnt0173 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CRCT_SUBTEST_MAP')]
dfasmnt0174 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CRCT_VIEW_ATTEMPT_NO')]
dfasmnt0175 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CRCT_VIEW_SCALE_SCORE')]
dfasmnt0176 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CRCTM_PREID_FILE_FROMSCH')]
dfasmnt0177 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CRCTPermnumMatch20110520')]
dfasmnt0178 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_AKSDataStage')]
dfasmnt0179 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_AKSExcelDataStage')]
dfasmnt0180 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_AKSExcelLoad')]
dfasmnt0181 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_AKSLoad')]
dfasmnt0182 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_AKSReportData')]
dfasmnt0183 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_AKSStrand')]
dfasmnt0184 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_CourseAssgnment')]
dfasmnt0185 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_CourseNos')]
dfasmnt0186 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_DataStage')]
dfasmnt0187 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_GetMasterID')]
dfasmnt0188 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_GetMatchingID')]
dfasmnt0189 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_NEnrolled')]
dfasmnt0190 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_Report_Data')]
dfasmnt0191 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_Report_Dim')]
dfasmnt0192 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_ReportData')]
dfasmnt0193 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_ReportDim')]
dfasmnt0194 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_SchoolDim')]
dfasmnt0195 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_ScrGrpExcelLoad')]
dfasmnt0196 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_ScrGrpLoad')]
dfasmnt0197 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_TestCourseNos')]
dfasmnt0198 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_TestCourseNosNew')]
dfasmnt0199 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LLogReport_Week8')]
dfasmnt0200 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LLogSummary_Week8')]
dfasmnt0201 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LPortalSpedReport')]
dfasmnt0202 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LPortalSpedSummary')]
dfasmnt0203 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LPortalUsageReport')]
dfasmnt0204 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LPortalUtizPgmLvlSummary')]
dfasmnt0205 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LPortalUtizReport')]
dfasmnt0206 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LPortalUtizSummary')]
dfasmnt0207 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LUsage')]
dfasmnt0208 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LUsage_Num')]
dfasmnt0209 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_ANALYSIS_REPORT')]
dfasmnt0210 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_ANALYSIS_REPORT_FINAL')]
dfasmnt0211 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_Avg_2020')]
dfasmnt0212 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_LOWEST_THREE')]
dfasmnt0213 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_REPORT_DIM')]
dfasmnt0214 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_REPORT_DIM_2018')]
dfasmnt0215 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_REPORT_DIM_2019')]
dfasmnt0216 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_REPORT_DIM_Temp')]
dfasmnt0217 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_ScoreGroup_2018')]
dfasmnt0218 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_ScoreGroup_2019')]
dfasmnt0219 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_ScoreGroup_2020')]
dfasmnt0220 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_ScoreGroup_2020_Old')]
dfasmnt0221 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_SCOREGROUP_REPORT')]
dfasmnt0222 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_SCOREGROUP_REPORT_2018')]
dfasmnt0223 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_SCOREGROUP_REPORT_2019')]
dfasmnt0224 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_SCOREGROUP_REPORT_FINAL')]
dfasmnt0225 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_SCOREGROUP_REPORT_FINAL_2018')]
dfasmnt0226 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_SCOREGROUP_REPORT_FINAL_2019')]
dfasmnt0227 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_SCOREGROUP_REPORT_FINAL_old')]
dfasmnt0228 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_SCOREGROUP_REPORT_Old')]
dfasmnt0229 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_Standard_2018')]
dfasmnt0230 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_Standard_2019')]
dfasmnt0231 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_Standard_2020')]
dfasmnt0232 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_Standard_2020_Temp')]
dfasmnt0233 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_Standard_Items_2020')]
dfasmnt0234 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_STANDARD_REPORT')]
dfasmnt0235 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_STANDARD_REPORT_2018')]
dfasmnt0236 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_STANDARD_REPORT_2019')]
dfasmnt0237 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_STANDARD_REPORT_FINAL')]
dfasmnt0238 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_STANDARD_REPORT_FINAL_2018')]
dfasmnt0239 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_STANDARD_REPORT_FINAL_2019')]
dfasmnt0240 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_STANDARD_REPORT_FINAL_old')]
dfasmnt0241 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_TOP_THREE')]
dfasmnt0242 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_Cluster_Avg')]
dfasmnt0243 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_Cluster_Schools')]
dfasmnt0244 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_District_Avg')]
dfasmnt0245 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_PERMNUM')]
dfasmnt0246 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_REPORT_DATA')]
dfasmnt0247 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_REPORT_DATA_1st_2020')]
dfasmnt0248 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_REPORT_DATA_2nd_PreTest_2020')]
dfasmnt0249 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_REPORT_DATA_BOY_2020')]
dfasmnt0250 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_REPORT_DATA_ERIC')]
dfasmnt0251 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_REPORT_DATA_MidYear_2020')]
dfasmnt0252 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_REPORT_DIM')]
dfasmnt0253 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_REPORT_DIM_2020')]
dfasmnt0254 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_REPORT_DIM_TEMP')]
dfasmnt0255 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_REQUEST_GRACE')]
dfasmnt0256 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DATE_G10_TEMP')]
dfasmnt0257 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS')]
dfasmnt0258 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_ACCESS')]
dfasmnt0259 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_ACCESS_010518')]
dfasmnt0260 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_ACCESS_070119')]
dfasmnt0261 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_ACCESS_281116')]
dfasmnt0262 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_ACCESS_281117')]
dfasmnt0263 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_ACCESS_281118')]
dfasmnt0264 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_CRCT')]
dfasmnt0265 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_CRCTM')]
dfasmnt0266 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOC')]
dfasmnt0267 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOC_012517')]
dfasmnt0268 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOC_012918')]
dfasmnt0269 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOC_033018')]
dfasmnt0270 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOC_041217')]
dfasmnt0271 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOC_091918')]
dfasmnt0272 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOC_092117')]
dfasmnt0273 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOC_111518')]
dfasmnt0274 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOC_TEMP_2019')]
dfasmnt0275 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOCT')]
dfasmnt0276 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOG')]
dfasmnt0277 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOG_012918')]
dfasmnt0278 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOG_032318')]
dfasmnt0279 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOG_032417')]
dfasmnt0280 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOG_041217')]
dfasmnt0281 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOG_SUMMER')]
dfasmnt0282 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10')]
dfasmnt0283 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_011020')]
dfasmnt0284 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_011520')]
dfasmnt0285 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_0130')]
dfasmnt0286 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_0130,18')]
dfasmnt0287 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_020520')]
dfasmnt0288 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_021120')]
dfasmnt0289 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_022017')]
dfasmnt0290 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_RETEST')]
dfasmnt0291 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_RETEST_011020')]
dfasmnt0292 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_RETEST_020419')]
dfasmnt0293 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_RETEST_081219')]
dfasmnt0294 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_RETEST_082018')]
dfasmnt0295 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_RETEST_082317')]
dfasmnt0296 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_RETEST_111218')]
dfasmnt0297 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_RETEST_111517')]
dfasmnt0298 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_GRD3RD')]
dfasmnt0299 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_HSGT')]
dfasmnt0300 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_KGARTEN')]
dfasmnt0301 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_WR58')]
dfasmnt0302 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ECT_Duplicates_ECT201206LOAD')]
dfasmnt0303 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Import_BM_EXTRACT_032519')]
dfasmnt0304 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Import_BM_EXTRACT_1st_2020')]
dfasmnt0305 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Import_BM_EXTRACT_EOY1718')]
dfasmnt0306 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Import_BM_EXTRACT_EOY1718_NUM')]
dfasmnt0307 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Import_BM_EXTRACT_EOY1819')]
dfasmnt0308 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Import_BM_EXTRACT_EOY1819_NUM')]
dfasmnt0309 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Import_BM_EXTRACT_Session2')]
dfasmnt0310 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOC_PRELIM_2018')]
dfasmnt0311 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOC_PRELIM_2019')]
dfasmnt0312 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOC_REQUEST')]
dfasmnt0313 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOCT_DOE_TEMP')]
dfasmnt0314 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'eoct_doe_temp2')]
dfasmnt0315 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOCT_NT')]
dfasmnt0316 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOCT_NT_TEMP')]
dfasmnt0317 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOG_PRELIM_2018')]
dfasmnt0318 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOG_PRELIM_2019')]
dfasmnt0319 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOGOnlineIndicator2018')]
dfasmnt0320 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOGTestMode_2017')]
dfasmnt0321 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EXAM_AUX_AUTH')]
dfasmnt0322 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EXAM_AUX_LOG')]
dfasmnt0323 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EXAM_STUDENT_AUX')]
dfasmnt0324 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EXAM_VERSIONS')]
dfasmnt0325 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FTE_ROSTER_HGT')]
dfasmnt0326 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'g10_temp')]
dfasmnt0327 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GAA_SUBTEST_DIM')]
dfasmnt0328 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GAA_SUBTEST_FACT')]
dfasmnt0329 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GAA_SUBTEST_PERF_DIM')]
dfasmnt0330 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GATEWAY_STRAND')]
dfasmnt0331 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GATEWAY_STU_HGH')]
dfasmnt0332 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GCPS AKS Social Studies 20202021')]
dfasmnt0333 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GRADUATION_SUMMARY')]
dfasmnt0334 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GRADUATION_SUMMARY_BKUP')]
dfasmnt0335 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_2019_SS_FieldTest_RawScores')]
dfasmnt0336 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_BARCODE_FILE')]
dfasmnt0337 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_INTERVENTION')]
dfasmnt0338 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_INTERVENTION_BKUP')]
dfasmnt0339 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_INTERVENTION_FROMSYNERGY')]
dfasmnt0340 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_OBJ_REF')]
dfasmnt0341 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_RETEST_ROSTER')]
dfasmnt0342 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_Scaling_Table')]
dfasmnt0343 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_SCANNER_FILE')]
dfasmnt0344 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_SCANNER_FILE_OLD')]
dfasmnt0345 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_SCANNER_SC_ALT_TEMP')]
dfasmnt0346 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_SCANNER_SS_ALT_TEMP')]
dfasmnt0347 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_Science_and_SocialStudies_ISR')]
dfasmnt0348 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_Science_and_SocialStudies_ISR_GWY202001RET')]
dfasmnt0349 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_Science_and_SocialStudies_ISR_GWY202003LOAD')]
dfasmnt0350 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_Writing_In_USHistory_ISR')]
dfasmnt0351 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY10_DOMN_REF')]
dfasmnt0352 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY10_STRAND_SCORES')]
dfasmnt0353 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GwyRosterNinthGrdSci')]
dfasmnt0354 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GwyRosterNinthGrdSoc')]
dfasmnt0355 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HB91_STUDENT_LIST')]
dfasmnt0356 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_Classes')]
dfasmnt0357 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_Classes_0728')]
dfasmnt0358 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_Classes_BKUP20160725')]
dfasmnt0359 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_Classes_DailyFix')]
dfasmnt0360 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_Classes_Temp')]
dfasmnt0361 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'hrw_classesbkup0807')]
dfasmnt0362 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_Schools')]
dfasmnt0363 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_TBooks')]
dfasmnt0364 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_TextBooks_old')]
dfasmnt0365 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_Users')]
dfasmnt0366 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_Users_0728')]
dfasmnt0367 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_Users_BKUP20160725')]
dfasmnt0368 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_Users_dailyfix')]
dfasmnt0369 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_Users_Temp')]
dfasmnt0370 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'hrw_usersbkup0807')]
dfasmnt0371 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HSR')]
dfasmnt0372 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HSWR_DOE_LABELS')]
dfasmnt0373 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'IOWA_CoGAT_Report')]
dfasmnt0374 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'IOWA_CoGAT_Report_090320')]
dfasmnt0375 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'IOWA_CoGAT_Report_1216')]
dfasmnt0376 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'IOWA_CoGAT_Report_121619')]
dfasmnt0377 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'IOWA_CoGAT_Report_Bkup')]
dfasmnt0378 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ITBSCogAT_PreID')]
dfasmnt0379 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ITBSCogAT_PreID_CODES')]
dfasmnt0380 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ITBSCogAT_PreID_LOCATIONS')]
dfasmnt0381 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'junk')]
dfasmnt0382 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'KREP_OLR')]
dfasmnt0383 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'KREP_Report')]
dfasmnt0384 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'KREP_Report_Cluster')]
dfasmnt0385 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'KREP_Sch_Averages')]
dfasmnt0386 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'KREP_Scores')]
dfasmnt0387 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'KREP_Stu_70Plus')]
dfasmnt0388 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'LA_AVG_Temp')]
dfasmnt0389 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Load_Key')]
dfasmnt0390 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MA_AVG_Temp')]
dfasmnt0391 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MikeTempLoadEOC')]
dfasmnt0392 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MilestonesReport')]
dfasmnt0393 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MilestonesReport_2016')]
dfasmnt0394 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MirandaRequest')]
dfasmnt0395 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Muntemp')]
dfasmnt0396 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'NewForm')]
dfasmnt0397 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Nightly_CommonCoreFT')]
dfasmnt0398 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'nt_temp')]
dfasmnt0399 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PEARSON_LABELS_EOCT')]
dfasmnt0400 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PEARSON_LABELS_EOCT_ARCHIVE')]
dfasmnt0401 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'permnum_mun')]
dfasmnt0402 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Portal_Log_Permnum')]
dfasmnt0403 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PortalDevices')]
dfasmnt0404 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PortalDevicesReport')]
dfasmnt0405 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PortalDevicesUpdate')]
dfasmnt0406 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PortalDNLReport')]
dfasmnt0407 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PortalEL_Report')]
dfasmnt0408 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PortalLogReport_Week8')]
dfasmnt0409 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PortalLogSummary_Week8')]
dfasmnt0410 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PS_EMPLOYEES')]
dfasmnt0411 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PS_EMPLOYEES_2021')]
dfasmnt0412 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PS_EMPLOYEES_VICKIE')]
dfasmnt0413 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PS_EMPLOYMENT')]
dfasmnt0414 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PSAT_STRAND')]
dfasmnt0415 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'response')]
dfasmnt0416 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Rising_12thGrd_Report')]
dfasmnt0417 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Rising_9thGrd_Report')]
dfasmnt0418 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_ACCESS')]
dfasmnt0419 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_ARCHIVE_WR58')]
dfasmnt0420 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_CAR_FILE')]
dfasmnt0421 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_CAR_SUMMER')]
dfasmnt0422 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_COGAT')]
dfasmnt0423 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_CRCT')]
dfasmnt0424 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_CRCT_SUMMER')]
dfasmnt0425 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_CRCT_TCHNAME')]
dfasmnt0426 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_ENR_WR5')]
dfasmnt0427 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_ENR_WR8')]
dfasmnt0428 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GRAD')]
dfasmnt0429 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GRAD_FOR_SUMMARY')]
dfasmnt0430 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GSC')]
dfasmnt0431 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GSS')]
dfasmnt0432 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GWY')]
dfasmnt0433 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GWY_ALL')]
dfasmnt0434 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GWY_CRS_LIST')]
dfasmnt0435 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GWY_NINTHGRD')]
dfasmnt0436 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GWY_OLD')]
dfasmnt0437 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GWY_SC')]
dfasmnt0438 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GWY_SS')]
dfasmnt0439 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GWY_STATUS')]
dfasmnt0440 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_HGT')]
dfasmnt0441 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_IOWA')]
dfasmnt0442 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_ITBS')]
dfasmnt0443 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_MENU')]
dfasmnt0444 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_SUMMER_SCH')]
dfasmnt0445 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_WR58')]
dfasmnt0446 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_WR58_SUMMER')]
dfasmnt0447 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_WRI')]
dfasmnt0448 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_WRI3')]
dfasmnt0449 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'S2S_ATES')]
dfasmnt0450 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'S2S_ATES_APPEND')]
dfasmnt0451 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'S2S_ATES_DELETE')]
dfasmnt0452 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'S2S_ATPA')]
dfasmnt0453 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'S2S_ATPA_APPEND')]
dfasmnt0454 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'S2S_ATPA_DELETE')]
dfasmnt0455 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_1')]
dfasmnt0456 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_1_AVG')]
dfasmnt0457 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_1_ELIGIBLE')]
dfasmnt0458 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_2')]
dfasmnt0459 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_2_AVG')]
dfasmnt0460 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_2_ELIGIBLE')]
dfasmnt0461 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_3')]
dfasmnt0462 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_3_AVG')]
dfasmnt0463 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_3_ELIGIBLE')]
dfasmnt0464 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SaturdayInterventionPermnum')]
dfasmnt0465 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SCHOOL_ETS_CODES')]
dfasmnt0466 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SEI')]
dfasmnt0467 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Self_Contained')]
dfasmnt0468 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Session3Eligible')]
dfasmnt0469 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Session3FromSchool')]
dfasmnt0470 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Session3Master')]
dfasmnt0471 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Session3Temp')]
dfasmnt0472 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SPG_Planning_EmpNOs')]
dfasmnt0473 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SPGTestID')]
dfasmnt0474 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SSATTD')]
dfasmnt0475 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StaffSurvey')]
dfasmnt0476 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StaffSurveyDNM')]
dfasmnt0477 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StaffSurveyDNM_1')]
dfasmnt0478 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StaffSurveyDNM_2')]
dfasmnt0479 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StaffSurveyDNM_3')]
dfasmnt0480 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StaffSurveyDNM_4')]
dfasmnt0481 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StaffSurveyDNM_5')]
dfasmnt0482 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StaffSurveyReport')]
dfasmnt0483 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StaffSurveyUpdate')]
dfasmnt0484 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STEM_Permnum')]
dfasmnt0485 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_ACC_TASK_SCR')]
dfasmnt0486 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_ACC_TEST_SCR')]
dfasmnt0487 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_ACT_STRND_SCR')]
dfasmnt0488 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_ACT_TEST_SCR')]
dfasmnt0489 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_AP_TEST_SCR')]
dfasmnt0490 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_CAR_STRND_SCR')]
dfasmnt0491 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_CAR_TEST_SCR')]
dfasmnt0492 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_COGAT_TEST_SCR')]
dfasmnt0493 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_CRCT_DOMN_SCR')]
dfasmnt0494 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_CRCT_TEST_SCR')]
dfasmnt0495 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_EOCT_STRND_SCR')]
dfasmnt0496 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_EOCT_TEST_SCR')]
dfasmnt0497 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWA5_DOMN_SCR')]
dfasmnt0498 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWA5_TEST_SCR')]
dfasmnt0499 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWA5_TEST_SCR_STG')]
dfasmnt0500 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWA8_DOMN_SCR')]
dfasmnt0501 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWA8_DOMN_SCR_STG')]
dfasmnt0502 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWA8_TEST_SCR')]
dfasmnt0503 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWA8_TEST_SCR_STG')]
dfasmnt0504 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWY10_DOMN_SCR')]
dfasmnt0505 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWY10_SUB_SCR')]
dfasmnt0506 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWY4_OBJ_SCR')]
dfasmnt0507 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWY4_TEST_SCR')]
dfasmnt0508 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWY7_OBJ_SCR')]
dfasmnt0509 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWY7_TEST_SCR')]
dfasmnt0510 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_HSGT_STRND_SCR')]
dfasmnt0511 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_HSGT_TEST_SCR')]
dfasmnt0512 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_HSWT_DOMN_SCR')]
dfasmnt0513 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_HSWT_TEST_SCR')]
dfasmnt0514 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_ITBS_TEST_SCR')]
dfasmnt0515 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_PSAT_STRND_SCR')]
dfasmnt0516 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_PSAT_TEST_SCR')]
dfasmnt0517 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_SAT_STRAND_SCR')]
dfasmnt0518 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_SAT_TEST_SCR')]
dfasmnt0519 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_ZONED_SCH')]
dfasmnt0520 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StuDetail_Daily_Bkup')]
dfasmnt0521 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_DATA')]
dfasmnt0522 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_DIM')]
dfasmnt0523 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_DIM_BKUP')]
dfasmnt0524 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_FACT')]
dfasmnt0525 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_FACT_121119')]
dfasmnt0526 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_FACT_BKUP')]
dfasmnt0527 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_MAP')]
dfasmnt0528 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_PERF_DIM')]
dfasmnt0529 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_PERF_DIM_BKUP')]
dfasmnt0530 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_PERF_MAP')]
dfasmnt0531 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_STRAND_DATA')]
dfasmnt0532 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_STRAND_MAP')]
dfasmnt0533 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_STRAND_PERF_MAP')]
dfasmnt0534 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerStudentList')]
dfasmnt0535 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Survey_Report_Codes')]
dfasmnt0536 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Survey_Report_Codes_Old')]
dfasmnt0537 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Survey_Report_Summary')]
dfasmnt0538 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Survey_Respondent_Report')]
dfasmnt0539 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Survey_Respondent_Status')]
dfasmnt0540 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'survey_responses')]
dfasmnt0541 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Synergy_HomeTeacher_2019')]
dfasmnt0542 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sysdiagrams')]
dfasmnt0543 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sysssislog')]
dfasmnt0544 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'tempconnected_0603')]
dfasmnt0545 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEMPHRWCLASSES')]
dfasmnt0546 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEMPHRWUSERS')]
dfasmnt0547 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_DEMO_ACC')]
dfasmnt0548 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_DEMO_ACC_2017')]
dfasmnt0549 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_DEMO_ACC_2017_RAW')]
dfasmnt0550 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_DEMO_CAR')]
dfasmnt0551 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_DEMO_G10')]
dfasmnt0552 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_DEMO_G10_MUNISH')]
dfasmnt0553 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_DEMO_G10_OLD')]
dfasmnt0554 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_DEMO_WR58')]
dfasmnt0555 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_DIM')]
dfasmnt0556 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'test_dim_bkup')]
dfasmnt0557 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_GWY_REP')]
dfasmnt0558 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_INP_G10')]
dfasmnt0559 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_MAP')]
dfasmnt0560 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ACC_OLD')]
dfasmnt0561 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ACC_OOD')]
dfasmnt0562 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ACC_Temp')]
dfasmnt0563 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ACT')]
dfasmnt0564 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ACT_OLD')]
dfasmnt0565 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ACT_Temp')]
dfasmnt0566 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_APP')]
dfasmnt0567 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_APP_Temp')]
dfasmnt0568 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_CAR')]
dfasmnt0569 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_CAR_Temp')]
dfasmnt0570 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_COG')]
dfasmnt0571 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_COG_STG')]
dfasmnt0572 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_COG_Temp')]
dfasmnt0573 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_CRCT_STRAND')]
dfasmnt0574 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_CRT')]
dfasmnt0575 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_CRT_BKP')]
dfasmnt0576 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_CRT_JIC')]
dfasmnt0577 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_CRT_JIC2')]
dfasmnt0578 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_CRT_MAINFRAME')]
dfasmnt0579 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_CRT_SP')]
dfasmnt0580 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_CRT_Temp')]
dfasmnt0581 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ECT')]
dfasmnt0582 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ECT_JIC20130304')]
dfasmnt0583 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ECT_SUMMARY')]
dfasmnt0584 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ECT_Temp')]
dfasmnt0585 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_EOC')]
dfasmnt0586 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_G10')]
dfasmnt0587 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_G10_FIELDTEST')]
dfasmnt0588 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_G10_SUM')]
dfasmnt0589 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_G4')]
dfasmnt0590 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_G7')]
dfasmnt0591 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_GWY10_Temp')]
dfasmnt0592 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_GWY4_Temp')]
dfasmnt0593 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_GWY7_Temp')]
dfasmnt0594 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_HGT')]
dfasmnt0595 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_HGT_Temp')]
dfasmnt0596 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ITB')]
dfasmnt0597 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_PSA')]
dfasmnt0598 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_PSAT_Temp')]
dfasmnt0599 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_SAT')]
dfasmnt0600 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_SAT_Temp')]
dfasmnt0601 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_WR5')]
dfasmnt0602 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_WR58_DEM')]
dfasmnt0603 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_WR8')]
dfasmnt0604 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_WRI')]
dfasmnt0605 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_ACC')]
dfasmnt0606 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_ACC_REP')]
dfasmnt0607 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_ACT')]
dfasmnt0608 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_ACT_REP')]
dfasmnt0609 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_APP')]
dfasmnt0610 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_APP_REP')]
dfasmnt0611 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_CAR')]
dfasmnt0612 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_COG')]
dfasmnt0613 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_CRT')]
dfasmnt0614 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_CRT_BKP2012')]
dfasmnt0615 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_CRT_PERMNUM')]
dfasmnt0616 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_CRT_REP')]
dfasmnt0617 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_ECT')]
dfasmnt0618 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_ECT_BKP')]
dfasmnt0619 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_ECT_REP')]
dfasmnt0620 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_EOC')]
dfasmnt0621 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_EOG')]
dfasmnt0622 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_G10')]
dfasmnt0623 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_G4')]
dfasmnt0624 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_G7')]
dfasmnt0625 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_HGT')]
dfasmnt0626 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_HGT_REP')]
dfasmnt0627 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_ITB')]
dfasmnt0628 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_PSA')]
dfasmnt0629 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_PSA_REP')]
dfasmnt0630 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_SAT')]
dfasmnt0631 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_SAT_REP')]
dfasmnt0632 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_WR5')]
dfasmnt0633 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_WR58_DEM')]
dfasmnt0634 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_WR8')]
dfasmnt0635 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_WRI')]
dfasmnt0636 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TEMP_ECT_DELETES')]
dfasmnt0637 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TEMP_ECT_LEX1')]
dfasmnt0638 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TEMP_ECT_LEX2')]
dfasmnt0639 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TEMP_ECT_LEX3')]
dfasmnt0640 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TEMP_ECT_LEXALL')]
dfasmnt0641 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TEMP_EOC_DELETES')]
dfasmnt0642 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TEMP_GWY')]
dfasmnt0643 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Testing_Accom')]
dfasmnt0644 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Testing_Accommodation_2018')]
dfasmnt0645 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ZONED_NEW_REPORT')]
dfasmnt0646 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ZONED_SCH_REPORT')]
dfasmnt0647 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ETLREF') & (df['TableName'] == 'AP_COURSE_TEST_MAP')]
dfasmnt0648 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ETLREF') & (df['TableName'] == 'CRCT_SUBTEST_MAP')]
dfasmnt0649 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ETLREF') & (df['TableName'] == 'EOCT_TEST_MAP')]
dfasmnt0650 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ETLREF') & (df['TableName'] == 'HSGT_TOTAL_RAW_POSSIBLE')]
dfasmnt0651 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ETLREF') & (df['TableName'] == 'PSA_SCR')]
dfasmnt0652 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ETLREF') & (df['TableName'] == 'STU_SAT')]
dfasmnt0653 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ETLREF') & (df['TableName'] == 'SUBTEST_DIM')]
dfasmnt0654 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ETLREF') & (df['TableName'] == 'SUBTEST_PERF_DIM')]
dfasmnt0655 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'ACC_TASK_REF')]
dfasmnt0656 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'AP_TEST_SUBJ_CD')]
dfasmnt0657 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'CAR_STRAND_MAP')]
dfasmnt0658 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'CAR_SUB_REF')]
dfasmnt0659 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'CRCT_PERFRMNC_LVL')]
dfasmnt0660 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'CRCT_STRAND_MAP')]
dfasmnt0661 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'DATE_MAPPING')]
dfasmnt0662 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'EOCT_STRND_REF')]
dfasmnt0663 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'EXAM_VERSIONS')]
dfasmnt0664 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'GATEWAY_STRAND')]
dfasmnt0665 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'GWY_SUB_REF')]
dfasmnt0666 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'GWY10_SUB_REF')]
dfasmnt0667 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'STU_TEST_CAR_CUT_SCR')]
dfasmnt0668 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'Test')]
dfasmnt0669 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'res') & (df['TableName'] == 'Grad_Survey')]
dfasmnt0670 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'res') & (df['TableName'] == 'Military_Scholarships')]
dfasmnt0671 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'res') & (df['TableName'] == 'Potential_Graduates')]
dfasmnt0672 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'Temp') & (df['TableName'] == 'SUBTEST_FACT_ACT')]

# %% [markdown]
# dfasmnt0001.head()

# %% [markdown]
# #Loop with format dataframe as z
# #title line works
# #html line for filename works
# #pulling in df and assign to d does not
# #assign df as z to scatter does not

# %% [markdown]
# #Import CSV
# data = pd.read_csv (r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\Assmnt.csv', header = None)
# #data.head()
# for z in data:
#     try:
#         a = ('{}'.format(z))
#         d = a[['DatabaseName', 'SchemaName','TableName']]
#         d = d.drop_duplicates()
#         e = d['DatabaseName'].values[0]
#         f = d['SchemaName'].values[0]
#         g = d['TableName'].values[0]
#         #print (d)
#         print (a)
#         FileName = ('Assmnt_{}_{}'.format(f,g))
#         print (FileName)
#         #fig = px.scatter(dfasmnt0001, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
#         #fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
#         #fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
#         #fig.update_xaxes(title_font=dict(size=18, color='crimson'))
#         #fig.update_yaxes(title_font=dict(size=18, color='crimson'))
#         #fig.update_xaxes(ticks="inside")
#         #fig.update_yaxes(ticks="inside")
#         #fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
#         #fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
#         #fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#         #fig.show()
#         #fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
#         #plt.close()
#     except:
#         continue
#     finally:
#         continue
#
# now01 = datetime.datetime.now()
# print('Assessment HTML create process is Complete: ', now01.strftime("%Y-%m-%d %H:%M:%S"))

# %%
d = dfasmnt0001[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0001, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#   DatabaseName SchemaName            TableName
# 0   Assessment        dbo  AA_BioChem_CRS_List

# %%
d = dfasmnt0002[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0002, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 59300   Assessment        dbo      aaaa

# %%
d = dfasmnt0003[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0003, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 59207   Assessment        dbo  aaaUpform

# %%
d = dfasmnt0004[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0004, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#    DatabaseName SchemaName         TableName
# 93   Assessment        dbo  ACCESS_2016_2017

# %%
d = dfasmnt0005[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0005, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName                        TableName
# 186   Assessment        dbo  ACCESS_ELL_StrandPossibleScores

# %%
d = dfasmnt0006[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0006, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName           TableName
# 279   Assessment        dbo  ACCESS_SUBTEST_DIM

# %%
d = dfasmnt0007[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0007, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName            TableName
# 372   Assessment        dbo  ACCESS_SUBTEST_FACT

# %%
d = dfasmnt0008[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0008, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName                TableName
# 558   Assessment        dbo  ADHOC_ASSESSMENT_REPORT

# %%
d = dfasmnt0009[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0009, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName                  TableName
# 651   Assessment        dbo  ADHOC_ASSESSMENT_REPORT_2

# %%
d = dfasmnt0010[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0010, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName                       TableName
# 744   Assessment        dbo  ADHOC_ASSESSMENT_REPORT_240119

# %%
d = dfasmnt0011[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0011, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName                     TableName
# 837   Assessment        dbo  ADHOC_ASSESSMENT_REPORT_GRD5

# %%
d = dfasmnt0012[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0012, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName                     TableName
# 930   Assessment        dbo  ADHOC_ASSESSMENT_REPORT_GRD7

# %%
d = dfasmnt0013[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0013, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                     TableName
# 1023   Assessment        dbo  ADHOC_ASSESSMENT_REPORT_GRD9

# %%
d = dfasmnt0014[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0014, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName      TableName
# 1116   Assessment        dbo  ADHOC_ELA_AVG

# %%
d = dfasmnt0015[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0015, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName          TableName
# 1209   Assessment        dbo  ADHOC_EOC_ALG1516

# %%
d = dfasmnt0016[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0016, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName          TableName
# 1302   Assessment        dbo  ADHOC_EOC_ALG1617

# %%
d = dfasmnt0017[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0017, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName              TableName
# 1395   Assessment        dbo  ADHOC_EOC_REPORT_1516

# %%
d = dfasmnt0018[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0018, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName              TableName
# 1488   Assessment        dbo  ADHOC_EOC_REPORT_1617

# %%
d = dfasmnt0019[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0019, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName             TableName
# 1581   Assessment        dbo  ADHOC_INTERIM_REPORT

# %%
d = dfasmnt0020[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0020, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName         TableName
# 1674   Assessment        dbo  ADHOC_PHONE_INFO

# %%
d = dfasmnt0021[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0021, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName         TableName
# 1767   Assessment        dbo  ADHOC_SAT_REPORT

# %%
d = dfasmnt0022[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0022, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 1860   Assessment        dbo  ADHOC_SAT_REPORT_2

# %%
d = dfasmnt0023[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0023, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 1953   Assessment        dbo  ADHOC_SAT_REPORT_3

# %%
d = dfasmnt0024[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0024, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                       TableName
# 2046   Assessment        dbo  ADHOC_SAT_REPORT_3_WITHCONTACT

# %%
d = dfasmnt0025[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0025, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName               TableName
# 2139   Assessment        dbo  ADHOC_SPECIALED_REPORT

# %%
d = dfasmnt0026[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0026, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                    TableName
# 2232   Assessment        dbo  ADHOC_SPECIALED_REPORT_1718

# %%
d = dfasmnt0027[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0027, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName             TableName
# 2325   Assessment        dbo  ADMIN_TEST_DATE_DESC

# %%
d = dfasmnt0028[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0028, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 12369   Assessment        dbo  Advisement

# %%
d = dfasmnt0029[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0029, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName TableName
# 2418   Assessment        dbo       AKS

# %%
d = dfasmnt0030[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0030, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName     TableName
# 2511   Assessment        dbo  AKS_20180622

# %%
d = dfasmnt0031[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0031, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName    TableName
# 2604   Assessment        dbo  AKS_Archive

# %%
d = dfasmnt0032[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0032, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName          TableName
# 2697   Assessment        dbo  AKS_GEMS_Comments

# %%
d = dfasmnt0033[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0033, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                  TableName
# 2790   Assessment        dbo  AKS_GEMS_Comments_Archive

# %%
d = dfasmnt0034[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0034, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName        TableName
# 2883   Assessment        dbo  AKS_GEMS_Review

# %%
d = dfasmnt0035[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0035, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                TableName
# 2976   Assessment        dbo  AKS_GEMS_Review_Archive

# %%
d = dfasmnt0036[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0036, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                 TableName
# 3069   Assessment        dbo  AKS_GEMS_Review_BK112017

# %%
d = dfasmnt0037[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0037, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName         TableName
# 3162   Assessment        dbo  AKS_GEMS_Schools

# %%
d = dfasmnt0038[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0038, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName               TableName
# 3255   Assessment        dbo  AKS_Rev_Subject_Course

# %%
d = dfasmnt0039[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0039, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                   TableName
# 3348   Assessment        dbo  AKS_Rev_Subject_Course_BKP

# %%
d = dfasmnt0040[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0040, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                    TableName
# 3441   Assessment        dbo  AKS_Rev_Subject_Course_BKP2

# %%
d = dfasmnt0041[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0041, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                           TableName
# 3534   Assessment        dbo  AKS_Rev_Subject_Course_BKP20150706

# %%
d = dfasmnt0042[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0042, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                    TableName
# 3627   Assessment        dbo  AKS_Rev_Subject_Course_BKP3

# %%
d = dfasmnt0043[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0043, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                  TableName
# 3720   Assessment        dbo  AKS_Rev_Subject_Course_T1

# %%
d = dfasmnt0044[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0044, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                      TableName
# 3813   Assessment        dbo  AKS_Rev_Subject_Course_T1_BKP

# %%
d = dfasmnt0045[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0045, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                       TableName
# 3906   Assessment        dbo  AKS_Rev_Subject_Course_T1_BKP2

# %%
d = dfasmnt0046[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0046, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                              TableName
# 3999   Assessment        dbo  AKS_Rev_Subject_Course_T1_BKP20150706

# %%
d = dfasmnt0047[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0047, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                    TableName
# 4092   Assessment        dbo  AKS_Rev_Subject_Course_Temp

# %%
d = dfasmnt0048[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0048, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 12462   Assessment        dbo  Analytics_Roster

# %%
d = dfasmnt0049[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0049, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 4650   Assessment        dbo  AP_COURSE_TEST_MAP

# %%
d = dfasmnt0050[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0050, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName        TableName
# 4185   Assessment        dbo  APP_CODE_COURSE

# %%
d = dfasmnt0051[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0051, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                 TableName
# 4278   Assessment        dbo  APP_CODE_COURSE_12092019

# %%
d = dfasmnt0052[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0052, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName      TableName
# 4371   Assessment        dbo  APP_CODE_NAME

# %%
d = dfasmnt0053[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0053, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName      TableName
# 4464   Assessment        dbo  APP_GROUP_OLD

# %%
d = dfasmnt0054[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0054, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName          TableName
# 4836   Assessment        dbo  ARTICULATION_DATA

# %%
d = dfasmnt0055[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0055, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName   TableName
# 5115   Assessment        dbo  ASSESS_ACC

# %%
d = dfasmnt0056[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0056, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 5208   Assessment        dbo  ASSESS_ACC_ALT

# %%
d = dfasmnt0057[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0057, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 5301   Assessment        dbo  ASSESS_ACC_ALT_RAW

# %%
d = dfasmnt0058[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0058, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 5394   Assessment        dbo  ASSESS_ACC_ALT_REP

# %%
d = dfasmnt0059[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0059, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 5487   Assessment        dbo  ASSESS_ACC_RAW

# %%
d = dfasmnt0060[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0060, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 5580   Assessment        dbo  ASSESS_ACC_REP

# %%
d = dfasmnt0061[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0061, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName   TableName
# 5673   Assessment        dbo  ASSESS_ACT

# %%
d = dfasmnt0062[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0062, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 5766   Assessment        dbo  ASSESS_ACT_RAW

# %%
d = dfasmnt0063[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0063, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 5859   Assessment        dbo  ASSESS_ACT_RAW_JIC

# %%
d = dfasmnt0064[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0064, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 5952   Assessment        dbo  ASSESS_ACT_REP

# %%
d = dfasmnt0065[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0065, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName   TableName
# 6045   Assessment        dbo  ASSESS_COG

# %%
d = dfasmnt0066[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0066, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 6138   Assessment        dbo  ASSESS_COG_BKP

# %%
d = dfasmnt0067[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0067, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 6231   Assessment        dbo  ASSESS_COG_RAW

# %%
d = dfasmnt0068[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0068, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName              TableName
# 6324   Assessment        dbo  ASSESS_COG_RAW_BKP_II

# %%
d = dfasmnt0069[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0069, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName               TableName
# 6417   Assessment        dbo  ASSESS_COG_RAW_BKP_III

# %%
d = dfasmnt0070[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0070, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 6510   Assessment        dbo  ASSESS_COG_REP

# %%
d = dfasmnt0071[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0071, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 6603   Assessment        dbo  ASSESS_COG_REP_BKP

# %%
d = dfasmnt0072[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0072, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName   TableName
# 6696   Assessment        dbo  ASSESS_CRM

# %%
d = dfasmnt0073[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0073, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 6789   Assessment        dbo  ASSESS_CRM_RAW

# %%
d = dfasmnt0074[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0074, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 6882   Assessment        dbo  ASSESS_CRM_REP

# %%
d = dfasmnt0075[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0075, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName   TableName
# 6975   Assessment        dbo  ASSESS_EOC

# %%
d = dfasmnt0076[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0076, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                 TableName
# 7068   Assessment        dbo  ASSESS_EOC_CopyJan212020

# %%
d = dfasmnt0077[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0077, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName         TableName
# 7161   Assessment        dbo  ASSESS_EOC_Jul24

# %%
d = dfasmnt0078[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0078, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 7254   Assessment        dbo  ASSESS_EOC_RAW

# %%
d = dfasmnt0079[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0079, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 7347   Assessment        dbo  ASSESS_EOC_REP

# %%
d = dfasmnt0080[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0080, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName   TableName
# 7440   Assessment        dbo  ASSESS_EOG

# %%
d = dfasmnt0081[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0081, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                 TableName
# 7533   Assessment        dbo  ASSESS_EOG_CopyJan212020

# %%
d = dfasmnt0082[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0082, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 7626   Assessment        dbo  ASSESS_EOG_RAW

# %%
d = dfasmnt0083[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0083, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 7719   Assessment        dbo  ASSESS_EOG_REP

# %%
d = dfasmnt0084[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0084, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName   TableName
# 7812   Assessment        dbo  ASSESS_G10

# %%
d = dfasmnt0085[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0085, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 7905   Assessment        dbo  ASSESS_G10_RAW

# %%
d = dfasmnt0086[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0086, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName          TableName
# 7998   Assessment        dbo  ASSESS_G10_RAW_BC

# %%
d = dfasmnt0087[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0087, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 8091   Assessment        dbo  ASSESS_G10_REP

# %%
d = dfasmnt0088[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0088, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 8184   Assessment        dbo  ASSESS_G10_SUM

# %%
d = dfasmnt0089[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0089, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                 TableName
# 8277   Assessment        dbo  ASSESS_G10_SUM_05Aug2020

# %%
d = dfasmnt0090[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0090, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName            TableName
# 8370   Assessment        dbo  ASSESS_G10_SUM_BKUP

# %%
d = dfasmnt0091[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0091, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName          TableName
# 8463   Assessment        dbo  ASSESS_G10_WAIVER

# %%
d = dfasmnt0092[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0092, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName   TableName
# 8556   Assessment        dbo  ASSESS_GAA

# %%
d = dfasmnt0093[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0093, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 8649   Assessment        dbo  ASSESS_GAA_2_0

# %%
d = dfasmnt0094[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0094, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 8742   Assessment        dbo  ASSESS_GAA_RAW

# %%
d = dfasmnt0095[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0095, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 8835   Assessment        dbo  ASSESS_GAA_RAW_2_0

# %%
d = dfasmnt0096[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0096, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName       TableName
# 8928   Assessment        dbo  ASSESS_GAA_REP

# %%
d = dfasmnt0097[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0097, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName        TableName
# 9021   Assessment        dbo  ASSESS_HSGWY_SC

# %%
d = dfasmnt0098[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0098, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName            TableName
# 9486   Assessment        dbo  ASSESS_HSGWY_SC_RAW

# %%
d = dfasmnt0099[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0099, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                   TableName
# 9579   Assessment        dbo  ASSESS_HSGWY_SC_RAW_SCORES

# %%
d = dfasmnt0100[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0100, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName            TableName
# 9672   Assessment        dbo  ASSESS_HSGWY_SC_REP

# %%
d = dfasmnt0101[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0101, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                     TableName
# 9114   Assessment        dbo  ASSESS_HSGWY_SCORES_KNO_TEMP

# %%
d = dfasmnt0102[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0102, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                         TableName
# 9207   Assessment        dbo  ASSESS_HSGWY_SCORES_ORG_CON_TEMP

# %%
d = dfasmnt0103[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0103, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                    TableName
# 9300   Assessment        dbo  ASSESS_HSGWY_SCORES_SS_TEMP

# %%
d = dfasmnt0104[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0104, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                 TableName
# 9393   Assessment        dbo  ASSESS_HSGWY_SCORES_TEMP

# %%
d = dfasmnt0105[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0105, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName        TableName
# 9765   Assessment        dbo  ASSESS_HSGWY_SS

# %%
d = dfasmnt0106[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0106, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName            TableName
# 9858   Assessment        dbo  ASSESS_HSGWY_SS_286

# %%
d = dfasmnt0107[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0107, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName            TableName
# 9951   Assessment        dbo  ASSESS_HSGWY_SS_RAW

# %%
d = dfasmnt0108[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0108, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                   TableName
# 10044   Assessment        dbo  ASSESS_HSGWY_SS_RAW_SCORES

# %%
d = dfasmnt0109[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0109, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 10137   Assessment        dbo  ASSESS_HSGWY_SS_REP

# %%
d = dfasmnt0110[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0110, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 10230   Assessment        dbo  ASSESS_ITB

# %%
d = dfasmnt0111[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0111, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 10323   Assessment        dbo  ASSESS_ITB_RAW

# %%
d = dfasmnt0112[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0112, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 10416   Assessment        dbo  ASSESS_ITB_RAW_RON

# %%
d = dfasmnt0113[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0113, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 10509   Assessment        dbo  ASSESS_ITB_REP

# %%
d = dfasmnt0114[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0114, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 10602   Assessment        dbo  ASSESS_PSAT_89

# %%
d = dfasmnt0115[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0115, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 10695   Assessment        dbo  ASSESS_PSAT_89_RAW

# %%
d = dfasmnt0116[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0116, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 10788   Assessment        dbo  ASSESS_PSAT_89_RAW_REP

# %%
d = dfasmnt0117[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0117, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 10881   Assessment        dbo  ASSESS_PSAT_NMSQT

# %%
d = dfasmnt0118[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0118, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 10974   Assessment        dbo  ASSESS_PSAT_NMSQT_RAW

# %%
d = dfasmnt0119[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0119, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 11067   Assessment        dbo  ASSESS_PSAT_NMSQT_RAW_REP

# %%
d = dfasmnt0120[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0120, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 11160   Assessment        dbo  ASSESS_SAT

# %%
d = dfasmnt0121[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0121, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 11253   Assessment        dbo  ASSESS_SAT_RAW

# %%
d = dfasmnt0122[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0122, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 11346   Assessment        dbo  ASSESS_SAT_RAW_REP

# %%
d = dfasmnt0123[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0123, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 59393   Assessment        dbo  assess_temp

# %%
d = dfasmnt0124[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0124, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 11439   Assessment        dbo  ASSESS_TEMP_EOG

# %%
d = dfasmnt0125[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0125, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 11532   Assessment        dbo  ASSESS_WR5

# %%
d = dfasmnt0126[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0126, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 11625   Assessment        dbo  ASSESS_WR5_RAW

# %%
d = dfasmnt0127[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0127, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 11718   Assessment        dbo  ASSESS_WR5_REP

# %%
d = dfasmnt0128[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0128, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 11811   Assessment        dbo  ASSESS_WR8

# %%
d = dfasmnt0129[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0129, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 11904   Assessment        dbo  ASSESS_WR8_RAW

# %%
d = dfasmnt0130[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0130, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 11997   Assessment        dbo  ASSESS_WR8_REP

# %%
d = dfasmnt0131[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0131, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 12090   Assessment        dbo  ASSESS_WRI

# %%
d = dfasmnt0132[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0132, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 12183   Assessment        dbo  ASSESS_WRI_RAW

# %%
d = dfasmnt0133[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0133, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 12276   Assessment        dbo  ASSESS_WRI_REP

# %%
d = dfasmnt0134[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0134, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                    TableName
# 12555   Assessment        dbo  AssessedSubject_FromSynergy

# %%
d = dfasmnt0135[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0135, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName                    TableName
# 4929   Assessment        dbo  ASSESSMENT_APP_SECURITY_OLD

# %%
d = dfasmnt0136[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0136, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName            TableName
# 5022   Assessment        dbo  ASSESSMENT_JOB_PARM

# %%
d = dfasmnt0137[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0137, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 14389   Assessment        dbo  ClassSize_PP_List

# %%
d = dfasmnt0138[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0138, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 14482   Assessment        dbo  ClassSize_Report

# %%
d = dfasmnt0139[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0139, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 14575   Assessment        dbo  ClassSize_Report_Avg

# %%
d = dfasmnt0140[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0140, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 14668   Assessment        dbo  ClassSize_Report_HS

# %%
d = dfasmnt0141[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0141, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 14761   Assessment        dbo  ClassSize_Report_MS

# %%
d = dfasmnt0142[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0142, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 14854   Assessment        dbo  ClassSize_Report_MSHS

# %%
d = dfasmnt0143[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0143, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 14947   Assessment        dbo  ClassSize_Report_PP

# %%
d = dfasmnt0144[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0144, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 15040   Assessment        dbo  ClassSize_Report_PP_Count

# %%
d = dfasmnt0145[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0145, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 15133   Assessment        dbo  ClassSize_Report_Special

# %%
d = dfasmnt0146[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0146, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 15226   Assessment        dbo  ClassSize_Report_StuCls_BySch

# %%
d = dfasmnt0147[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0147, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                         TableName
# 15319   Assessment        dbo  ClassSize_Report_StuCls_BySch_MS

# %%
d = dfasmnt0148[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0148, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                               TableName
# 15412   Assessment        dbo  ClassSize_Report_StuCls_BySch_WithZero

# %%
d = dfasmnt0149[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0149, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 15505   Assessment        dbo  ClassSize_Report_StuCls_Count

# %%
d = dfasmnt0150[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0150, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                         TableName
# 15598   Assessment        dbo  ClassSize_Report_StuCls_Count_HS

# %%
d = dfasmnt0151[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0151, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                         TableName
# 15691   Assessment        dbo  ClassSize_Report_StuCls_Count_MS

# %%
d = dfasmnt0152[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0152, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                               TableName
# 15784   Assessment        dbo  ClassSize_Report_StuCls_Count_WithZero

# %%
d = dfasmnt0153[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0153, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                        TableName
# 15877   Assessment        dbo  ClassSize_Report_StuCls_Summary

# %%
d = dfasmnt0154[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0154, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 15970   Assessment        dbo  ClassSize_Report_WithZero

# %%
d = dfasmnt0155[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0155, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 16063   Assessment        dbo  ClassSize_Totals_By_Grade

# %%
d = dfasmnt0156[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0156, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 16156   Assessment        dbo  ClassSize_Totals_By_Grade_HS

# %%
d = dfasmnt0157[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0157, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 16249   Assessment        dbo  ClassSize_Totals_By_Grade_MS

# %%
d = dfasmnt0158[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0158, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                           TableName
# 16342   Assessment        dbo  ClassSize_Totals_By_Grade_WithZero

# %%
d = dfasmnt0159[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0159, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 16435   Assessment        dbo  Classworks

# %%
d = dfasmnt0160[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0160, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 16528   Assessment        dbo  ClassworksClass

# %%
d = dfasmnt0161[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0161, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 16621   Assessment        dbo  ClassworksExtra

# %%
d = dfasmnt0162[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0162, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 16714   Assessment        dbo  ClassworksMaster

# %%
d = dfasmnt0163[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0163, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 16807   Assessment        dbo  ClassworksMasterAdd

# %%
d = dfasmnt0164[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0164, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 16900   Assessment        dbo  ClassworksMasterFile

# %%
d = dfasmnt0165[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0165, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 16993   Assessment        dbo  ClassworksSurvey

# %%
d = dfasmnt0166[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0166, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 17086   Assessment        dbo  ClassworksTSTList

# %%
d = dfasmnt0167[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0167, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 17179   Assessment        dbo  ClassworksUpdate

# %%
d = dfasmnt0168[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0168, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 17272   Assessment        dbo  CommonCoreFT_Parm

# %%
d = dfasmnt0169[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0169, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 17365   Assessment        dbo  ConnectEd_GCPSAdmin

# %%
d = dfasmnt0170[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0170, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 17458   Assessment        dbo  ConnectEd_Schools_old

# %%
d = dfasmnt0171[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0171, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 17551   Assessment        dbo  ConnectEd_Textbooks_blah

# %%
d = dfasmnt0172[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0172, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 13020   Assessment        dbo  CRCT_DATA_VIEW

# %%
d = dfasmnt0173[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0173, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 13392   Assessment        dbo  CRCT_SUBTEST_MAP

# %%
d = dfasmnt0174[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0174, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 13485   Assessment        dbo  CRCT_VIEW_ATTEMPT_NO

# %%
d = dfasmnt0175[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0175, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 13578   Assessment        dbo  CRCT_VIEW_SCALE_SCORE

# %%
d = dfasmnt0176[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0176, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 12834   Assessment        dbo  CRCTM_PREID_FILE_FROMSCH

# %%
d = dfasmnt0177[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0177, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 12927   Assessment        dbo  CRCTPermnumMatch20110520

# %%
d = dfasmnt0178[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0178, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 13671   Assessment        dbo  CUA_AKSDataStage

# %%
d = dfasmnt0179[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0179, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 13712   Assessment        dbo  CUA_AKSExcelDataStage

# %%
d = dfasmnt0180[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0180, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 13747   Assessment        dbo  CUA_AKSExcelLoad

# %%
d = dfasmnt0181[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0181, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 13782   Assessment        dbo  CUA_AKSLoad

# %%
d = dfasmnt0182[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0182, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 13828   Assessment        dbo  CUA_AKSReportData

# %%
d = dfasmnt0183[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0183, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 13868   Assessment        dbo  CUA_AKSStrand

# %%
d = dfasmnt0184[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0184, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 13892   Assessment        dbo  CUA_CourseAssgnment

# %%
d = dfasmnt0185[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0185, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 13923   Assessment        dbo  CUA_CourseNos

# %%
d = dfasmnt0186[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0186, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 13954   Assessment        dbo  CUA_DataStage

# %%
d = dfasmnt0187[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0187, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 14004   Assessment        dbo  CUA_GetMasterID

# %%
d = dfasmnt0188[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0188, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 14053   Assessment        dbo  CUA_GetMatchingID

# %%
d = dfasmnt0189[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0189, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 14102   Assessment        dbo  CUA_NEnrolled

# %%
d = dfasmnt0190[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0190, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 14233   Assessment        dbo  CUA_Report_Data

# %%
d = dfasmnt0191[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0191, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 14234   Assessment        dbo  CUA_Report_Dim

# %%
d = dfasmnt0192[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0192, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 14133   Assessment        dbo  CUA_ReportData

# %%
d = dfasmnt0193[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0193, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 14183   Assessment        dbo  CUA_ReportDim

# %%
d = dfasmnt0194[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0194, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 14235   Assessment        dbo  CUA_SchoolDim

# %%
d = dfasmnt0195[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0195, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 14285   Assessment        dbo  CUA_ScrGrpExcelLoad

# %%
d = dfasmnt0196[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0196, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 14320   Assessment        dbo  CUA_ScrGrpLoad

# %%
d = dfasmnt0197[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0197, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 14366   Assessment        dbo  CUA_TestCourseNos

# %%
d = dfasmnt0198[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0198, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 14384   Assessment        dbo  CUA_TestCourseNosNew

# %%
d = dfasmnt0199[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0199, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 17644   Assessment        dbo  D2LLogReport_Week8

# %%
d = dfasmnt0200[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0100, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 17737   Assessment        dbo  D2LLogSummary_Week8

# %%
d = dfasmnt0201[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0201, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 17830   Assessment        dbo  D2LPortalSpedReport

# %%
d = dfasmnt0202[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0202, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 17923   Assessment        dbo  D2LPortalSpedSummary

# %%
d = dfasmnt0203[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0203, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 18016   Assessment        dbo  D2LPortalUsageReport

# %%
d = dfasmnt0204[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0204, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                   TableName
# 18109   Assessment        dbo  D2LPortalUtizPgmLvlSummary

# %%
d = dfasmnt0205[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0205, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 18202   Assessment        dbo  D2LPortalUtizReport

# %%
d = dfasmnt0206[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0206, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 18295   Assessment        dbo  D2LPortalUtizSummary

# %%
d = dfasmnt0207[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0207, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 18388   Assessment        dbo  D2LUsage

# %%
d = dfasmnt0208[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0208, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 18481   Assessment        dbo  D2LUsage_Num

# %%
d = dfasmnt0209[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0209, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 18760   Assessment        dbo  DA_AKS_ANALYSIS_REPORT

# %%
d = dfasmnt0210[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0210, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 18853   Assessment        dbo  DA_AKS_ANALYSIS_REPORT_FINAL

# %%
d = dfasmnt0211[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0211, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 18946   Assessment        dbo  DA_AKS_Avg_2020

# %%
d = dfasmnt0212[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0212, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 19039   Assessment        dbo  DA_AKS_LOWEST_THREE

# %%
d = dfasmnt0213[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0213, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 19132   Assessment        dbo  DA_AKS_REPORT_DIM

# %%
d = dfasmnt0214[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0214, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 19225   Assessment        dbo  DA_AKS_REPORT_DIM_2018

# %%
d = dfasmnt0215[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0215, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 19292   Assessment        dbo  DA_AKS_REPORT_DIM_2019

# %%
d = dfasmnt0216[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0216, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 19363   Assessment        dbo  DA_AKS_REPORT_DIM_Temp

# %%
d = dfasmnt0217[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0217, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 20659   Assessment        dbo  DA_AKS_ScoreGroup_2018

# %%
d = dfasmnt0218[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0218, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 20732   Assessment        dbo  DA_AKS_ScoreGroup_2019

# %%
d = dfasmnt0219[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0219, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 20805   Assessment        dbo  DA_AKS_ScoreGroup_2020

# %%
d = dfasmnt0220[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0220, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                   TableName
# 20898   Assessment        dbo  DA_AKS_ScoreGroup_2020_Old

# %%
d = dfasmnt0221[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0221, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 19456   Assessment        dbo  DA_AKS_SCOREGROUP_REPORT

# %%
d = dfasmnt0222[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0222, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 19549   Assessment        dbo  DA_AKS_SCOREGROUP_REPORT_2018

# %%
d = dfasmnt0223[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0223, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 19616   Assessment        dbo  DA_AKS_SCOREGROUP_REPORT_2019

# %%
d = dfasmnt0224[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0224, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                       TableName
# 19687   Assessment        dbo  DA_AKS_SCOREGROUP_REPORT_FINAL

# %%
d = dfasmnt0225[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0225, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                            TableName
# 19780   Assessment        dbo  DA_AKS_SCOREGROUP_REPORT_FINAL_2018

# %%
d = dfasmnt0226[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0226, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                            TableName
# 19847   Assessment        dbo  DA_AKS_SCOREGROUP_REPORT_FINAL_2019

# %%
d = dfasmnt0227[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0227, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                           TableName
# 19918   Assessment        dbo  DA_AKS_SCOREGROUP_REPORT_FINAL_old

# %%
d = dfasmnt0228[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0228, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 20011   Assessment        dbo  DA_AKS_SCOREGROUP_REPORT_Old

# %%
d = dfasmnt0229[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0229, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 20991   Assessment        dbo  DA_AKS_Standard_2018

# %%
d = dfasmnt0230[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0230, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 21063   Assessment        dbo  DA_AKS_Standard_2019

# %%
d = dfasmnt0231[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0231, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 21135   Assessment        dbo  DA_AKS_Standard_2020

# %%
d = dfasmnt0232[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0232, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 21228   Assessment        dbo  DA_AKS_Standard_2020_Temp

# %%
d = dfasmnt0233[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0233, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                   TableName
# 21321   Assessment        dbo  DA_AKS_Standard_Items_2020

# %%
d = dfasmnt0234[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0234, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 20104   Assessment        dbo  DA_AKS_STANDARD_REPORT

# %%
d = dfasmnt0235[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0235, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                    TableName
# 20197   Assessment        dbo  DA_AKS_STANDARD_REPORT_2018

# %%
d = dfasmnt0236[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0236, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                    TableName
# 20264   Assessment        dbo  DA_AKS_STANDARD_REPORT_2019

# %%
d = dfasmnt0237[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0237, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 20335   Assessment        dbo  DA_AKS_STANDARD_REPORT_FINAL

# %%
d = dfasmnt0238[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0238, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                          TableName
# 20428   Assessment        dbo  DA_AKS_STANDARD_REPORT_FINAL_2018

# %%
d = dfasmnt0239[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0239, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                          TableName
# 20495   Assessment        dbo  DA_AKS_STANDARD_REPORT_FINAL_2019

# %%
d = dfasmnt0240[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0240, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                         TableName
# 20566   Assessment        dbo  DA_AKS_STANDARD_REPORT_FINAL_old

# %%
d = dfasmnt0241[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0241, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 21414   Assessment        dbo  DA_AKS_TOP_THREE

# %%
d = dfasmnt0242[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0242, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 21507   Assessment        dbo  DA_Cluster_Avg

# %%
d = dfasmnt0243[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0243, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 21600   Assessment        dbo  DA_Cluster_Schools

# %%
d = dfasmnt0244[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0244, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 21622   Assessment        dbo  DA_District_Avg

# %%
d = dfasmnt0245[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0245, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 21715   Assessment        dbo  DA_PERMNUM

# %%
d = dfasmnt0246[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0246, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 21808   Assessment        dbo  DA_REPORT_DATA

# %%
d = dfasmnt0247[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0247, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 21901   Assessment        dbo  DA_REPORT_DATA_1st_2020

# %%
d = dfasmnt0248[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0248, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                        TableName
# 21994   Assessment        dbo  DA_REPORT_DATA_2nd_PreTest_2020

# %%
d = dfasmnt0249[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0249, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 22087   Assessment        dbo  DA_REPORT_DATA_BOY_2020

# %%
d = dfasmnt0250[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0250, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 22180   Assessment        dbo  DA_REPORT_DATA_ERIC

# %%
d = dfasmnt0251[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0251, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                    TableName
# 22273   Assessment        dbo  DA_REPORT_DATA_MidYear_2020

# %%
d = dfasmnt0252[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0252, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 22366   Assessment        dbo  DA_REPORT_DIM

# %%
d = dfasmnt0253[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0253, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 22459   Assessment        dbo  DA_REPORT_DIM_2020

# %%
d = dfasmnt0254[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0254, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 22552   Assessment        dbo  DA_REPORT_DIM_TEMP

# %%
d = dfasmnt0255[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0255, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 22645   Assessment        dbo  DA_REQUEST_GRACE

# %%
d = dfasmnt0256[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0256, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 18574   Assessment        dbo  DATE_G10_TEMP

# %%
d = dfasmnt0257[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0257, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 22738   Assessment        dbo  DOE_LABELS

# %%
d = dfasmnt0258[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0258, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 22831   Assessment        dbo  DOE_LABELS_ACCESS

# %%
d = dfasmnt0259[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0259, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 22924   Assessment        dbo  DOE_LABELS_ACCESS_010518

# %%
d = dfasmnt0260[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0260, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 23017   Assessment        dbo  DOE_LABELS_ACCESS_070119

# %%
d = dfasmnt0261[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0261, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 23110   Assessment        dbo  DOE_LABELS_ACCESS_281116

# %%
d = dfasmnt0262[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0262, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 23203   Assessment        dbo  DOE_LABELS_ACCESS_281117

# %%
d = dfasmnt0263[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0263, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 23296   Assessment        dbo  DOE_LABELS_ACCESS_281118

# %%
d = dfasmnt0264[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0264, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 23389   Assessment        dbo  DOE_LABELS_CRCT

# %%
d = dfasmnt0265[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0265, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 23482   Assessment        dbo  DOE_LABELS_CRCTM

# %%
d = dfasmnt0266[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0266, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 23575   Assessment        dbo  DOE_LABELS_EOC

# %%
d = dfasmnt0267[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0267, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 23761   Assessment        dbo  DOE_LABELS_EOC_012517

# %%
d = dfasmnt0268[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0268, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 23854   Assessment        dbo  DOE_LABELS_EOC_012918

# %%
d = dfasmnt0269[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0269, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 23947   Assessment        dbo  DOE_LABELS_EOC_033018

# %%
d = dfasmnt0270[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0270, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 24040   Assessment        dbo  DOE_LABELS_EOC_041217

# %%
d = dfasmnt0271[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0271, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 24133   Assessment        dbo  DOE_LABELS_EOC_091918

# %%
d = dfasmnt0272[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0272, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 24226   Assessment        dbo  DOE_LABELS_EOC_092117

# %%
d = dfasmnt0273[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0273, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 24319   Assessment        dbo  DOE_LABELS_EOC_111518

# %%
d = dfasmnt0274[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0274, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 24412   Assessment        dbo  DOE_LABELS_EOC_TEMP_2019

# %%
d = dfasmnt0275[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0275, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 23668   Assessment        dbo  DOE_LABELS_EOCT

# %%
d = dfasmnt0276[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0276, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 24505   Assessment        dbo  DOE_LABELS_EOG

# %%
d = dfasmnt0277[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0277, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 24598   Assessment        dbo  DOE_LABELS_EOG_012918

# %%
d = dfasmnt0278[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0278, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 24691   Assessment        dbo  DOE_LABELS_EOG_032318

# %%
d = dfasmnt0279[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0279, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 24784   Assessment        dbo  DOE_LABELS_EOG_032417

# %%
d = dfasmnt0280[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0280, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 24877   Assessment        dbo  DOE_LABELS_EOG_041217

# %%
d = dfasmnt0281[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0281, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 24970   Assessment        dbo  DOE_LABELS_EOG_SUMMER

# %%
d = dfasmnt0282[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0282, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 25063   Assessment        dbo  DOE_LABELS_G10

# %%
d = dfasmnt0283[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0283, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 25156   Assessment        dbo  DOE_LABELS_G10_011020

# %%
d = dfasmnt0284[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0284, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 25249   Assessment        dbo  DOE_LABELS_G10_011520

# %%
d = dfasmnt0285[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0285, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 25342   Assessment        dbo  DOE_LABELS_G10_0130

# %%
d = dfasmnt0286[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0286, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 25397   Assessment        dbo  DOE_LABELS_G10_0130,18

# %%
d = dfasmnt0287[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0287, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 25435   Assessment        dbo  DOE_LABELS_G10_020520

# %%
d = dfasmnt0288[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0288, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 25528   Assessment        dbo  DOE_LABELS_G10_021120

# %%
d = dfasmnt0289[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0289, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 25621   Assessment        dbo  DOE_LABELS_G10_022017

# %%
d = dfasmnt0290[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0290, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 25714   Assessment        dbo  DOE_LABELS_G10_RETEST

# %%
d = dfasmnt0291[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0291, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 25807   Assessment        dbo  DOE_LABELS_G10_RETEST_011020

# %%
d = dfasmnt0292[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0292, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 25900   Assessment        dbo  DOE_LABELS_G10_RETEST_020419

# %%
d = dfasmnt0293[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0293, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 25993   Assessment        dbo  DOE_LABELS_G10_RETEST_081219

# %%
d = dfasmnt0294[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0294, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 26086   Assessment        dbo  DOE_LABELS_G10_RETEST_082018

# %%
d = dfasmnt0295[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0295, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 26179   Assessment        dbo  DOE_LABELS_G10_RETEST_082317

# %%
d = dfasmnt0296[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0296, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 26272   Assessment        dbo  DOE_LABELS_G10_RETEST_111218

# %%
d = dfasmnt0297[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0297, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 26365   Assessment        dbo  DOE_LABELS_G10_RETEST_111517

# %%
d = dfasmnt0298[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0298, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 26458   Assessment        dbo  DOE_LABELS_GRD3RD

# %%
d = dfasmnt0299[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0299, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 26551   Assessment        dbo  DOE_LABELS_HSGT

# %%
d = dfasmnt0300[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0300, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 26644   Assessment        dbo  DOE_LABELS_KGARTEN

# %%
d = dfasmnt0301[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0301, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 26737   Assessment        dbo  DOE_LABELS_WR58

# %%
d = dfasmnt0302[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0302, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 26830   Assessment        dbo  ECT_Duplicates_ECT201206LOAD

# %%
d = dfasmnt0303[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0303, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                         TableName
# 28504   Assessment        dbo  EdCloud_Import_BM_EXTRACT_032519

# %%
d = dfasmnt0304[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0304, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                           TableName
# 28597   Assessment        dbo  EdCloud_Import_BM_EXTRACT_1st_2020

# %%
d = dfasmnt0305[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0305, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                          TableName
# 28690   Assessment        dbo  EdCloud_Import_BM_EXTRACT_EOY1718

# %%
d = dfasmnt0306[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0306, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                              TableName
# 28783   Assessment        dbo  EdCloud_Import_BM_EXTRACT_EOY1718_NUM

# %%
d = dfasmnt0307[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0307, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                          TableName
# 28876   Assessment        dbo  EdCloud_Import_BM_EXTRACT_EOY1819

# %%
d = dfasmnt0308[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0308, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                              TableName
# 28969   Assessment        dbo  EdCloud_Import_BM_EXTRACT_EOY1819_NUM

# %%
d = dfasmnt0309[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0309, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                           TableName
# 29062   Assessment        dbo  EdCloud_Import_BM_EXTRACT_Session2

# %%
d = dfasmnt0310[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0310, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 27388   Assessment        dbo  EOC_PRELIM_2018

# %%
d = dfasmnt0311[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0311, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 27481   Assessment        dbo  EOC_PRELIM_2019

# %%
d = dfasmnt0312[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0312, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 27574   Assessment        dbo  EOC_REQUEST

# %%
d = dfasmnt0313[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0313, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 26923   Assessment        dbo  EOCT_DOE_TEMP

# %%
d = dfasmnt0314[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0314, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 59486   Assessment        dbo  eoct_doe_temp2

# %%
d = dfasmnt0315[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0315, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 27016   Assessment        dbo   EOCT_NT

# %%
d = dfasmnt0316[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0316, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 27109   Assessment        dbo  EOCT_NT_TEMP

# %%
d = dfasmnt0317[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0317, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 27853   Assessment        dbo  EOG_PRELIM_2018

# %%
d = dfasmnt0318[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0318, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 27946   Assessment        dbo  EOG_PRELIM_2019

# %%
d = dfasmnt0319[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0319, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 27667   Assessment        dbo  EOGOnlineIndicator2018

# %%
d = dfasmnt0320[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0320, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 27760   Assessment        dbo  EOGTestMode_2017

# %%
d = dfasmnt0321[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0321, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 28039   Assessment        dbo  EXAM_AUX_AUTH

# %%
d = dfasmnt0322[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0322, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 28132   Assessment        dbo  EXAM_AUX_LOG

# %%
d = dfasmnt0323[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0323, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 28225   Assessment        dbo  EXAM_STUDENT_AUX

# %%
d = dfasmnt0324[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0324, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 28318   Assessment        dbo  EXAM_VERSIONS

# %%
d = dfasmnt0325[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0325, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 29155   Assessment        dbo  FTE_ROSTER_HGT

# %%
d = dfasmnt0326[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0326, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 59579   Assessment        dbo  g10_temp

# %%
d = dfasmnt0327[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0327, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 29248   Assessment        dbo  GAA_SUBTEST_DIM

# %%
d = dfasmnt0328[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0328, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 29341   Assessment        dbo  GAA_SUBTEST_FACT

# %%
d = dfasmnt0329[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0329, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 29434   Assessment        dbo  GAA_SUBTEST_PERF_DIM

# %%
d = dfasmnt0330[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0330, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 29527   Assessment        dbo  GATEWAY_STRAND

# %%
d = dfasmnt0331[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0331, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 29713   Assessment        dbo  GATEWAY_STU_HGH

# %%
d = dfasmnt0332[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0332, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                         TableName
# 29806   Assessment        dbo  GCPS AKS Social Studies 20202021

# %%
d = dfasmnt0333[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0333, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 29899   Assessment        dbo  GRADUATION_SUMMARY

# %%
d = dfasmnt0334[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0334, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 29992   Assessment        dbo  GRADUATION_SUMMARY_BKUP

# %%
d = dfasmnt0335[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0335, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                        TableName
# 30317   Assessment        dbo  GWY_2019_SS_FieldTest_RawScores

# %%
d = dfasmnt0336[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0336, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 30410   Assessment        dbo  GWY_BARCODE_FILE

# %%
d = dfasmnt0337[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0337, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 30503   Assessment        dbo  GWY_INTERVENTION

# %%
d = dfasmnt0338[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0338, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 30596   Assessment        dbo  GWY_INTERVENTION_BKUP

# %%
d = dfasmnt0339[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0339, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 30689   Assessment        dbo  GWY_INTERVENTION_FROMSYNERGY

# %%
d = dfasmnt0340[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0340, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 30761   Assessment        dbo  GWY_OBJ_REF

# %%
d = dfasmnt0341[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0341, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 30854   Assessment        dbo  GWY_RETEST_ROSTER

# %%
d = dfasmnt0342[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0342, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 31412   Assessment        dbo  GWY_Scaling_Table

# %%
d = dfasmnt0343[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0343, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 30947   Assessment        dbo  GWY_SCANNER_FILE

# %%
d = dfasmnt0344[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0344, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 31040   Assessment        dbo  GWY_SCANNER_FILE_OLD

# %%
d = dfasmnt0345[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0345, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 31133   Assessment        dbo  GWY_SCANNER_SC_ALT_TEMP

# %%
d = dfasmnt0346[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0346, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 31226   Assessment        dbo  GWY_SCANNER_SS_ALT_TEMP

# %%
d = dfasmnt0347[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0347, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                          TableName
# 31505   Assessment        dbo  GWY_Science_and_SocialStudies_ISR

# %%
d = dfasmnt0348[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0348, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                                       TableName
# 31598   Assessment        dbo  GWY_Science_and_SocialStudies_ISR_GWY202001RET

# %%
d = dfasmnt0349[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0349, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                                        TableName
# 31691   Assessment        dbo  GWY_Science_and_SocialStudies_ISR_GWY202003LOAD

# %%
d = dfasmnt0350[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0350, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                     TableName
# 31784   Assessment        dbo  GWY_Writing_In_USHistory_ISR

# %%
d = dfasmnt0351[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0351, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 30038   Assessment        dbo  GWY10_DOMN_REF

# %%
d = dfasmnt0352[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0352, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 30131   Assessment        dbo  GWY10_STRAND_SCORES

# %%
d = dfasmnt0353[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0353, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 31970   Assessment        dbo  GwyRosterNinthGrdSci

# %%
d = dfasmnt0354[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0354, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 32063   Assessment        dbo  GwyRosterNinthGrdSoc

# %%
d = dfasmnt0355[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0355, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 32156   Assessment        dbo  HB91_STUDENT_LIST

# %%
d = dfasmnt0356[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0356, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 32249   Assessment        dbo  HRW_Classes

# %%
d = dfasmnt0357[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0357, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 32342   Assessment        dbo  HRW_Classes_0728

# %%
d = dfasmnt0358[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0358, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 32435   Assessment        dbo  HRW_Classes_BKUP20160725

# %%
d = dfasmnt0359[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0359, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 32528   Assessment        dbo  HRW_Classes_DailyFix

# %%
d = dfasmnt0360[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0360, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 32621   Assessment        dbo  HRW_Classes_Temp

# %%
d = dfasmnt0361[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0361, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 59672   Assessment        dbo  hrw_classesbkup0807

# %%
d = dfasmnt0362[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0362, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 32714   Assessment        dbo  HRW_Schools

# %%
d = dfasmnt0363[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0363, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 32807   Assessment        dbo  HRW_TBooks

# %%
d = dfasmnt0364[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0364, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 32900   Assessment        dbo  HRW_TextBooks_old

# %%
d = dfasmnt0365[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0365, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 32993   Assessment        dbo  HRW_Users

# %%
d = dfasmnt0366[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0366, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 33086   Assessment        dbo  HRW_Users_0728

# %%
d = dfasmnt0367[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0367, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 33179   Assessment        dbo  HRW_Users_BKUP20160725

# %%
d = dfasmnt0368[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0368, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 33365   Assessment        dbo  HRW_Users_dailyfix

# %%
d = dfasmnt0369[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0369, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 33272   Assessment        dbo  HRW_Users_Temp

# %%
d = dfasmnt0370[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0370, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 59765   Assessment        dbo  hrw_usersbkup0807

# %%
d = dfasmnt0371[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0371, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 33551   Assessment        dbo       HSR

# %%
d = dfasmnt0372[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0372, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 33644   Assessment        dbo  HSWR_DOE_LABELS

# %%
d = dfasmnt0373[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0373, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 33737   Assessment        dbo  IOWA_CoGAT_Report

# %%
d = dfasmnt0374[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0374, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 33830   Assessment        dbo  IOWA_CoGAT_Report_090320

# %%
d = dfasmnt0375[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0375, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 33923   Assessment        dbo  IOWA_CoGAT_Report_1216

# %%
d = dfasmnt0376[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0376, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 34016   Assessment        dbo  IOWA_CoGAT_Report_121619

# %%
d = dfasmnt0377[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0377, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 34109   Assessment        dbo  IOWA_CoGAT_Report_Bkup

# %%
d = dfasmnt0378[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0378, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 34202   Assessment        dbo  ITBSCogAT_PreID

# %%
d = dfasmnt0379[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0379, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 34295   Assessment        dbo  ITBSCogAT_PreID_CODES

# %%
d = dfasmnt0380[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0380, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                  TableName
# 34388   Assessment        dbo  ITBSCogAT_PreID_LOCATIONS

# %%
d = dfasmnt0381[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0381, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 59858   Assessment        dbo      junk

# %%
d = dfasmnt0382[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0382, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 34481   Assessment        dbo  KREP_OLR

# %%
d = dfasmnt0383[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0383, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 34574   Assessment        dbo  KREP_Report

# %%
d = dfasmnt0384[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0384, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 34667   Assessment        dbo  KREP_Report_Cluster

# %%
d = dfasmnt0385[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0385, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 34760   Assessment        dbo  KREP_Sch_Averages

# %%
d = dfasmnt0386[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0386, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 34853   Assessment        dbo  KREP_Scores

# %%
d = dfasmnt0387[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0387, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 34946   Assessment        dbo  KREP_Stu_70Plus

# %%
d = dfasmnt0388[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0388, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 35039   Assessment        dbo  LA_AVG_Temp

# %%
d = dfasmnt0389[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0389, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 35132   Assessment        dbo  Load_Key

# %%
d = dfasmnt0390[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0390, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 35225   Assessment        dbo  MA_AVG_Temp

# %%
d = dfasmnt0391[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0391, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 35318   Assessment        dbo  MikeTempLoadEOC

# %%
d = dfasmnt0392[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0392, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 35411   Assessment        dbo  MilestonesReport

# %%
d = dfasmnt0393[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0393, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 35504   Assessment        dbo  MilestonesReport_2016

# %%
d = dfasmnt0394[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0394, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 35690   Assessment        dbo  MirandaRequest

# %%
d = dfasmnt0395[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0395, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 35783   Assessment        dbo   Muntemp

# %%
d = dfasmnt0396[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0396, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 35876   Assessment        dbo   NewForm

# %%
d = dfasmnt0397[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0397, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 35957   Assessment        dbo  Nightly_CommonCoreFT

# %%
d = dfasmnt0398[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0398, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 59951   Assessment        dbo   nt_temp

# %%
d = dfasmnt0399[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0399, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 36050   Assessment        dbo  PEARSON_LABELS_EOCT

# %%
d = dfasmnt0400[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0400, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                    TableName
# 36143   Assessment        dbo  PEARSON_LABELS_EOCT_ARCHIVE

# %%
d = dfasmnt0401[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0401, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 60044   Assessment        dbo  permnum_mun

# %%
d = dfasmnt0402[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0402, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 37445   Assessment        dbo  Portal_Log_Permnum

# %%
d = dfasmnt0403[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0403, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 36887   Assessment        dbo  PortalDevices

# %%
d = dfasmnt0404[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0404, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 36980   Assessment        dbo  PortalDevicesReport

# %%
d = dfasmnt0405[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0405, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 37073   Assessment        dbo  PortalDevicesUpdate

# %%
d = dfasmnt0406[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0406, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 36794   Assessment        dbo  PortalDNLReport

# %%
d = dfasmnt0407[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0407, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 37166   Assessment        dbo  PortalEL_Report

# %%
d = dfasmnt0408[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0408, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 37259   Assessment        dbo  PortalLogReport_Week8

# %%
d = dfasmnt0409[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0409, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 37352   Assessment        dbo  PortalLogSummary_Week8

# %%
d = dfasmnt0410[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0410, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 36422   Assessment        dbo  PS_EMPLOYEES

# %%
d = dfasmnt0411[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0411, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 36515   Assessment        dbo  PS_EMPLOYEES_2021

# %%
d = dfasmnt0412[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0412, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 36608   Assessment        dbo  PS_EMPLOYEES_VICKIE

# %%
d = dfasmnt0413[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0413, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 36701   Assessment        dbo  PS_EMPLOYMENT

# %%
d = dfasmnt0414[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0414, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 36236   Assessment        dbo  PSAT_STRAND

# %%
d = dfasmnt0415[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0415, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 60137   Assessment        dbo  response

# %%
d = dfasmnt0416[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0416, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 40514   Assessment        dbo  Rising_12thGrd_Report

# %%
d = dfasmnt0417[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0417, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 40607   Assessment        dbo  Rising_9thGrd_Report

# %%
d = dfasmnt0418[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0418, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 37631   Assessment        dbo  ROSTER_ACCESS

# %%
d = dfasmnt0419[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0419, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 37724   Assessment        dbo  ROSTER_ARCHIVE_WR58

# %%
d = dfasmnt0420[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0420, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 37817   Assessment        dbo  ROSTER_CAR_FILE

# %%
d = dfasmnt0421[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0421, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 37910   Assessment        dbo  ROSTER_CAR_SUMMER

# %%
d = dfasmnt0422[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0422, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 38003   Assessment        dbo  ROSTER_COGAT

# %%
d = dfasmnt0423[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0423, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 38096   Assessment        dbo  ROSTER_CRCT

# %%
d = dfasmnt0424[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0424, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 38189   Assessment        dbo  ROSTER_CRCT_SUMMER

# %%
d = dfasmnt0425[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0425, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 38282   Assessment        dbo  ROSTER_CRCT_TCHNAME

# %%
d = dfasmnt0426[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0426, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 38375   Assessment        dbo  ROSTER_ENR_WR5

# %%
d = dfasmnt0427[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0427, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 38468   Assessment        dbo  ROSTER_ENR_WR8

# %%
d = dfasmnt0428[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0428, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 38561   Assessment        dbo  ROSTER_GRAD

# %%
d = dfasmnt0429[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0429, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 38654   Assessment        dbo  ROSTER_GRAD_FOR_SUMMARY

# %%
d = dfasmnt0430[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0430, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 38747   Assessment        dbo  ROSTER_GSC

# %%
d = dfasmnt0431[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0431, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 38840   Assessment        dbo  ROSTER_GSS

# %%
d = dfasmnt0432[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0432, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 38933   Assessment        dbo  ROSTER_GWY

# %%
d = dfasmnt0433[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0433, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 39026   Assessment        dbo  ROSTER_GWY_ALL

# %%
d = dfasmnt0434[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0434, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 39119   Assessment        dbo  ROSTER_GWY_CRS_LIST

# %%
d = dfasmnt0435[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0435, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 39212   Assessment        dbo  ROSTER_GWY_NINTHGRD

# %%
d = dfasmnt0436[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0436, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 39305   Assessment        dbo  ROSTER_GWY_OLD

# %%
d = dfasmnt0437[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0437, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 39398   Assessment        dbo  ROSTER_GWY_SC

# %%
d = dfasmnt0438[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0438, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 39491   Assessment        dbo  ROSTER_GWY_SS

# %%
d = dfasmnt0439[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0439, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 39584   Assessment        dbo  ROSTER_GWY_STATUS

# %%
d = dfasmnt0440[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0440, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 39677   Assessment        dbo  ROSTER_HGT

# %%
d = dfasmnt0441[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0441, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 39770   Assessment        dbo  ROSTER_IOWA

# %%
d = dfasmnt0442[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0442, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 39863   Assessment        dbo  ROSTER_ITBS

# %%
d = dfasmnt0443[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0443, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 39956   Assessment        dbo  ROSTER_MENU

# %%
d = dfasmnt0444[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0444, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 40049   Assessment        dbo  ROSTER_SUMMER_SCH

# %%
d = dfasmnt0445[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0445, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 40142   Assessment        dbo  ROSTER_WR58

# %%
d = dfasmnt0446[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0446, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 40235   Assessment        dbo  ROSTER_WR58_SUMMER

# %%
d = dfasmnt0447[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0447, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 40328   Assessment        dbo  ROSTER_WRI

# %%
d = dfasmnt0448[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0448, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 40421   Assessment        dbo  ROSTER_WRI3

# %%
d = dfasmnt0449[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0449, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 40700   Assessment        dbo  S2S_ATES

# %%
d = dfasmnt0450[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0450, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 40793   Assessment        dbo  S2S_ATES_APPEND

# %%
d = dfasmnt0451[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0451, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 40886   Assessment        dbo  S2S_ATES_DELETE

# %%
d = dfasmnt0452[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0452, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 40979   Assessment        dbo  S2S_ATPA

# %%
d = dfasmnt0453[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0453, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 41072   Assessment        dbo  S2S_ATPA_APPEND

# %%
d = dfasmnt0454[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0454, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 41165   Assessment        dbo  S2S_ATPA_DELETE

# %%
d = dfasmnt0455[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0455, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 41258   Assessment        dbo  SAT_REPORT_SESSION_1

# %%
d = dfasmnt0456[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0456, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 41351   Assessment        dbo  SAT_REPORT_SESSION_1_AVG

# %%
d = dfasmnt0457[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0457, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 41444   Assessment        dbo  SAT_REPORT_SESSION_1_ELIGIBLE

# %%
d = dfasmnt0458[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0458, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 41537   Assessment        dbo  SAT_REPORT_SESSION_2

# %%
d = dfasmnt0459[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0459, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 41630   Assessment        dbo  SAT_REPORT_SESSION_2_AVG

# %%
d = dfasmnt0460[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0460, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 41723   Assessment        dbo  SAT_REPORT_SESSION_2_ELIGIBLE

# %%
d = dfasmnt0461[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0461, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 41816   Assessment        dbo  SAT_REPORT_SESSION_3

# %%
d = dfasmnt0462[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0462, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 41909   Assessment        dbo  SAT_REPORT_SESSION_3_AVG

# %%
d = dfasmnt0463[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0463, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                      TableName
# 42002   Assessment        dbo  SAT_REPORT_SESSION_3_ELIGIBLE

# %%
d = dfasmnt0464[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0464, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                    TableName
# 47582   Assessment        dbo  SaturdayInterventionPermnum

# %%
d = dfasmnt0465[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0465, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 42095   Assessment        dbo  SCHOOL_ETS_CODES

# %%
d = dfasmnt0466[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0466, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 42188   Assessment        dbo       SEI

# %%
d = dfasmnt0467[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0467, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 47675   Assessment        dbo  Self_Contained

# %%
d = dfasmnt0468[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0468, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 47768   Assessment        dbo  Session3Eligible

# %%
d = dfasmnt0469[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0469, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 47861   Assessment        dbo  Session3FromSchool

# %%
d = dfasmnt0470[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0470, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 47954   Assessment        dbo  Session3Master

# %%
d = dfasmnt0471[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0471, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 48047   Assessment        dbo  Session3Temp

# %%
d = dfasmnt0472[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0472, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 42374   Assessment        dbo  SPG_Planning_EmpNOs

# %%
d = dfasmnt0473[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0473, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName  TableName
# 42281   Assessment        dbo  SPGTestID

# %%
d = dfasmnt0474[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0474, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 42467   Assessment        dbo    SSATTD

# %%
d = dfasmnt0475[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0475, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 48140   Assessment        dbo  StaffSurvey

# %%
d = dfasmnt0476[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0476, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 48233   Assessment        dbo  StaffSurveyDNM

# %%
d = dfasmnt0477[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0477, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 48326   Assessment        dbo  StaffSurveyDNM_1

# %%
d = dfasmnt0478[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0478, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 48419   Assessment        dbo  StaffSurveyDNM_2

# %%
d = dfasmnt0479[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0479, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 48512   Assessment        dbo  StaffSurveyDNM_3

# %%
d = dfasmnt0480[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0480, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 48605   Assessment        dbo  StaffSurveyDNM_4

# %%
d = dfasmnt0481[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0481, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 48698   Assessment        dbo  StaffSurveyDNM_5

# %%
d = dfasmnt0482[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0482, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 48791   Assessment        dbo  StaffSurveyReport

# %%
d = dfasmnt0483[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0483, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 48884   Assessment        dbo  StaffSurveyUpdate

# %%
d = dfasmnt0484[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0484, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 42560   Assessment        dbo  STEM_Permnum

# %%
d = dfasmnt0485[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0485, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 42653   Assessment        dbo  STU_ACC_TASK_SCR

# %%
d = dfasmnt0486[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0486, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 42746   Assessment        dbo  STU_ACC_TEST_SCR

# %%
d = dfasmnt0487[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0487, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 42839   Assessment        dbo  STU_ACT_STRND_SCR

# %%
d = dfasmnt0488[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0488, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 42932   Assessment        dbo  STU_ACT_TEST_SCR

# %%
d = dfasmnt0489[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0489, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 43025   Assessment        dbo  STU_AP_TEST_SCR

# %%
d = dfasmnt0490[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0490, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 43118   Assessment        dbo  STU_CAR_STRND_SCR

# %%
d = dfasmnt0491[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0491, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 43211   Assessment        dbo  STU_CAR_TEST_SCR

# %%
d = dfasmnt0492[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0492, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 43304   Assessment        dbo  STU_COGAT_TEST_SCR

# %%
d = dfasmnt0493[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0493, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 43397   Assessment        dbo  STU_CRCT_DOMN_SCR

# %%
d = dfasmnt0494[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0494, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 43490   Assessment        dbo  STU_CRCT_TEST_SCR

# %%
d = dfasmnt0495[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0495, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 43583   Assessment        dbo  STU_EOCT_STRND_SCR

# %%
d = dfasmnt0496[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0496, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 43676   Assessment        dbo  STU_EOCT_TEST_SCR

# %%
d = dfasmnt0497[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0497, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 43769   Assessment        dbo  STU_GWA5_DOMN_SCR

# %%
d = dfasmnt0498[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0498, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 43862   Assessment        dbo  STU_GWA5_TEST_SCR

# %%
d = dfasmnt0499[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0499, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 43955   Assessment        dbo  STU_GWA5_TEST_SCR_STG

# %%
d = dfasmnt0500[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0400, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 44048   Assessment        dbo  STU_GWA8_DOMN_SCR

# %%
d = dfasmnt0501[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0501, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 44141   Assessment        dbo  STU_GWA8_DOMN_SCR_STG

# %%
d = dfasmnt0502[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0502, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 44234   Assessment        dbo  STU_GWA8_TEST_SCR

# %%
d = dfasmnt0503[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0503, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 44327   Assessment        dbo  STU_GWA8_TEST_SCR_STG

# %%
d = dfasmnt0504[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0504, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 44420   Assessment        dbo  STU_GWY10_DOMN_SCR

# %%
d = dfasmnt0505[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0505, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 44513   Assessment        dbo  STU_GWY10_SUB_SCR

# %%
d = dfasmnt0506[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0506, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 44606   Assessment        dbo  STU_GWY4_OBJ_SCR

# %%
d = dfasmnt0507[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0507, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 44699   Assessment        dbo  STU_GWY4_TEST_SCR

# %%
d = dfasmnt0508[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0508, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 44792   Assessment        dbo  STU_GWY7_OBJ_SCR

# %%
d = dfasmnt0509[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0509, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 44885   Assessment        dbo  STU_GWY7_TEST_SCR

# %%
d = dfasmnt0510[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0510, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 44978   Assessment        dbo  STU_HSGT_STRND_SCR

# %%
d = dfasmnt0511[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0511, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 45071   Assessment        dbo  STU_HSGT_TEST_SCR

# %%
d = dfasmnt0512[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0512, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 45164   Assessment        dbo  STU_HSWT_DOMN_SCR

# %%
d = dfasmnt0513[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0513, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 45257   Assessment        dbo  STU_HSWT_TEST_SCR

# %%
d = dfasmnt0514[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0514, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 45350   Assessment        dbo  STU_ITBS_TEST_SCR

# %%
d = dfasmnt0515[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0515, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 45443   Assessment        dbo  STU_PSAT_STRND_SCR

# %%
d = dfasmnt0516[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0516, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 45536   Assessment        dbo  STU_PSAT_TEST_SCR

# %%
d = dfasmnt0517[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0517, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 45722   Assessment        dbo  STU_SAT_STRAND_SCR

# %%
d = dfasmnt0518[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0518, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 45815   Assessment        dbo  STU_SAT_TEST_SCR

# %%
d = dfasmnt0519[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0519, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 46001   Assessment        dbo  STU_ZONED_SCH

# %%
d = dfasmnt0520[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0520, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 48977   Assessment        dbo  StuDetail_Daily_Bkup

# %%
d = dfasmnt0521[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0521, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 46094   Assessment        dbo  SUBTEST_DATA

# %%
d = dfasmnt0522[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0522, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 46280   Assessment        dbo  SUBTEST_DIM

# %%
d = dfasmnt0523[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0523, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 46373   Assessment        dbo  SUBTEST_DIM_BKUP

# %%
d = dfasmnt0524[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0524, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 46466   Assessment        dbo  SUBTEST_FACT

# %%
d = dfasmnt0525[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0525, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 46559   Assessment        dbo  SUBTEST_FACT_121119

# %%
d = dfasmnt0526[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0526, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 46745   Assessment        dbo  SUBTEST_FACT_BKUP

# %%
d = dfasmnt0527[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0527, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 46838   Assessment        dbo  SUBTEST_MAP

# %%
d = dfasmnt0528[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0528, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 47024   Assessment        dbo  SUBTEST_PERF_DIM

# %%
d = dfasmnt0529[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0529, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 47117   Assessment        dbo  SUBTEST_PERF_DIM_BKUP

# %%
d = dfasmnt0530[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0530, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 47210   Assessment        dbo  SUBTEST_PERF_MAP

# %%
d = dfasmnt0531[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0531, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 47303   Assessment        dbo  SUBTEST_STRAND_DATA

# %%
d = dfasmnt0532[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0532, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 47396   Assessment        dbo  SUBTEST_STRAND_MAP

# %%
d = dfasmnt0533[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0533, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 47489   Assessment        dbo  SUBTEST_STRAND_PERF_MAP

# %%
d = dfasmnt0534[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0534, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 49070   Assessment        dbo  SummerStudentList

# %%
d = dfasmnt0535[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0535, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 49163   Assessment        dbo  Survey_Report_Codes

# %%
d = dfasmnt0536[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0536, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 49256   Assessment        dbo  Survey_Report_Codes_Old

# %%
d = dfasmnt0537[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0537, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 49349   Assessment        dbo  Survey_Report_Summary

# %%
d = dfasmnt0538[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0538, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 49442   Assessment        dbo  Survey_Respondent_Report

# %%
d = dfasmnt0539[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0539, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 49535   Assessment        dbo  Survey_Respondent_Status

# %%
d = dfasmnt0540[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0540, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 60230   Assessment        dbo  survey_responses

# %%
d = dfasmnt0541[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0541, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 49628   Assessment        dbo  Synergy_HomeTeacher_2019

# %%
d = dfasmnt0542[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0542, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 60323   Assessment        dbo  sysdiagrams

# %%
d = dfasmnt0543[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0543, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName   TableName
# 60416   Assessment        dbo  sysssislog

# %%
d = dfasmnt0544[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0544, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 60509   Assessment        dbo  tempconnected_0603

# %%
d = dfasmnt0545[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0545, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 49721   Assessment        dbo  TEMPHRWCLASSES

# %%
d = dfasmnt0546[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0546, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 49814   Assessment        dbo  TEMPHRWUSERS

# %%
d = dfasmnt0547[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0547, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 49907   Assessment        dbo  TEST_DEMO_ACC

# %%
d = dfasmnt0548[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0548, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 50000   Assessment        dbo  TEST_DEMO_ACC_2017

# %%
d = dfasmnt0549[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0549, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 50093   Assessment        dbo  TEST_DEMO_ACC_2017_RAW

# %%
d = dfasmnt0550[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0550, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 50186   Assessment        dbo  TEST_DEMO_CAR

# %%
d = dfasmnt0551[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0551, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 50279   Assessment        dbo  TEST_DEMO_G10

# %%
d = dfasmnt0552[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0552, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 50372   Assessment        dbo  TEST_DEMO_G10_MUNISH

# %%
d = dfasmnt0553[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0553, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 50465   Assessment        dbo  TEST_DEMO_G10_OLD

# %%
d = dfasmnt0554[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0554, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 50558   Assessment        dbo  TEST_DEMO_WR58

# %%
d = dfasmnt0555[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0555, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 50651   Assessment        dbo  TEST_DIM

# %%
d = dfasmnt0556[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0556, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 60602   Assessment        dbo  test_dim_bkup

# %%
d = dfasmnt0557[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0557, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 50744   Assessment        dbo  TEST_GWY_REP

# %%
d = dfasmnt0558[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0558, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 50837   Assessment        dbo  TEST_INP_G10

# %%
d = dfasmnt0559[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0559, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 50930   Assessment        dbo  TEST_MAP

# %%
d = dfasmnt0560[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0560, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 51023   Assessment        dbo  TEST_STU_ACC_OLD

# %%
d = dfasmnt0561[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0561, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 51116   Assessment        dbo  TEST_STU_ACC_OOD

# %%
d = dfasmnt0562[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0562, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 51209   Assessment        dbo  TEST_STU_ACC_Temp

# %%
d = dfasmnt0563[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0563, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 51302   Assessment        dbo  TEST_STU_ACT

# %%
d = dfasmnt0564[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0564, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 51395   Assessment        dbo  TEST_STU_ACT_OLD

# %%
d = dfasmnt0565[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0565, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 51488   Assessment        dbo  TEST_STU_ACT_Temp

# %%
d = dfasmnt0566[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0566, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 51581   Assessment        dbo  TEST_STU_APP

# %%
d = dfasmnt0567[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0567, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 51674   Assessment        dbo  TEST_STU_APP_Temp

# %%
d = dfasmnt0568[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0568, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 51767   Assessment        dbo  TEST_STU_CAR

# %%
d = dfasmnt0569[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0569, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 51860   Assessment        dbo  TEST_STU_CAR_Temp

# %%
d = dfasmnt0570[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0570, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 51953   Assessment        dbo  TEST_STU_COG

# %%
d = dfasmnt0571[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0571, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 52046   Assessment        dbo  TEST_STU_COG_STG

# %%
d = dfasmnt0572[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0572, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 52139   Assessment        dbo  TEST_STU_COG_Temp

# %%
d = dfasmnt0573[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0573, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 52232   Assessment        dbo  TEST_STU_CRCT_STRAND

# %%
d = dfasmnt0574[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0574, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 52325   Assessment        dbo  TEST_STU_CRT

# %%
d = dfasmnt0575[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0575, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 52418   Assessment        dbo  TEST_STU_CRT_BKP

# %%
d = dfasmnt0576[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0576, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 52511   Assessment        dbo  TEST_STU_CRT_JIC

# %%
d = dfasmnt0577[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0577, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 52604   Assessment        dbo  TEST_STU_CRT_JIC2

# %%
d = dfasmnt0578[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0578, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 52697   Assessment        dbo  TEST_STU_CRT_MAINFRAME

# %%
d = dfasmnt0579[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0579, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 52790   Assessment        dbo  TEST_STU_CRT_SP

# %%
d = dfasmnt0580[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0580, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 52883   Assessment        dbo  TEST_STU_CRT_Temp

# %%
d = dfasmnt0581[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0581, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 52976   Assessment        dbo  TEST_STU_ECT

# %%
d = dfasmnt0582[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0582, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 53069   Assessment        dbo  TEST_STU_ECT_JIC20130304

# %%
d = dfasmnt0583[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0583, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 53162   Assessment        dbo  TEST_STU_ECT_SUMMARY

# %%
d = dfasmnt0584[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0584, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 53255   Assessment        dbo  TEST_STU_ECT_Temp

# %%
d = dfasmnt0585[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0585, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 53348   Assessment        dbo  TEST_STU_EOC

# %%
d = dfasmnt0586[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0586, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 53441   Assessment        dbo  TEST_STU_G10

# %%
d = dfasmnt0587[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0587, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName               TableName
# 53534   Assessment        dbo  TEST_STU_G10_FIELDTEST

# %%
d = dfasmnt0588[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0588, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 53627   Assessment        dbo  TEST_STU_G10_SUM

# %%
d = dfasmnt0589[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0589, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 53720   Assessment        dbo  TEST_STU_G4

# %%
d = dfasmnt0590[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0590, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 53813   Assessment        dbo  TEST_STU_G7

# %%
d = dfasmnt0591[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0591, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 53906   Assessment        dbo  TEST_STU_GWY10_Temp

# %%
d = dfasmnt0592[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0592, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 53999   Assessment        dbo  TEST_STU_GWY4_Temp

# %%
d = dfasmnt0593[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0593, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 54092   Assessment        dbo  TEST_STU_GWY7_Temp

# %%
d = dfasmnt0594[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0594, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 54185   Assessment        dbo  TEST_STU_HGT

# %%
d = dfasmnt0595[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0595, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 54278   Assessment        dbo  TEST_STU_HGT_Temp

# %%
d = dfasmnt0596[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0596, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 54371   Assessment        dbo  TEST_STU_ITB

# %%
d = dfasmnt0597[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0597, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 54464   Assessment        dbo  TEST_STU_PSA

# %%
d = dfasmnt0598[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0598, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 54557   Assessment        dbo  TEST_STU_PSAT_Temp

# %%
d = dfasmnt0599[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0599, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 54650   Assessment        dbo  TEST_STU_SAT

# %%
d = dfasmnt0600[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0600, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 54743   Assessment        dbo  TEST_STU_SAT_Temp

# %%
d = dfasmnt0601[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0601, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 54836   Assessment        dbo  TEST_STU_WR5

# %%
d = dfasmnt0602[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0602, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 54929   Assessment        dbo  TEST_STU_WR58_DEM

# %%
d = dfasmnt0603[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0603, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 55022   Assessment        dbo  TEST_STU_WR8

# %%
d = dfasmnt0604[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0604, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 55115   Assessment        dbo  TEST_STU_WRI

# %%
d = dfasmnt0605[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0605, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 55208   Assessment        dbo  TEST_TAPE_ACC

# %%
d = dfasmnt0606[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0606, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 55301   Assessment        dbo  TEST_TAPE_ACC_REP

# %%
d = dfasmnt0607[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0607, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 55394   Assessment        dbo  TEST_TAPE_ACT

# %%
d = dfasmnt0608[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0608, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 55487   Assessment        dbo  TEST_TAPE_ACT_REP

# %%
d = dfasmnt0609[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0609, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 55580   Assessment        dbo  TEST_TAPE_APP

# %%
d = dfasmnt0610[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0610, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 55673   Assessment        dbo  TEST_TAPE_APP_REP

# %%
d = dfasmnt0611[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0611, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 55766   Assessment        dbo  TEST_TAPE_CAR

# %%
d = dfasmnt0612[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0612, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 55859   Assessment        dbo  TEST_TAPE_COG

# %%
d = dfasmnt0613[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0613, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 55952   Assessment        dbo  TEST_TAPE_CRT

# %%
d = dfasmnt0614[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0614, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 56045   Assessment        dbo  TEST_TAPE_CRT_BKP2012

# %%
d = dfasmnt0615[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0615, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 56138   Assessment        dbo  TEST_TAPE_CRT_PERMNUM

# %%
d = dfasmnt0616[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0616, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 56231   Assessment        dbo  TEST_TAPE_CRT_REP

# %%
d = dfasmnt0617[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0617, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 56324   Assessment        dbo  TEST_TAPE_ECT

# %%
d = dfasmnt0618[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0618, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 56417   Assessment        dbo  TEST_TAPE_ECT_BKP

# %%
d = dfasmnt0619[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0619, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 56510   Assessment        dbo  TEST_TAPE_ECT_REP

# %%
d = dfasmnt0620[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0620, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 56603   Assessment        dbo  TEST_TAPE_EOC

# %%
d = dfasmnt0621[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0621, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 56696   Assessment        dbo  TEST_TAPE_EOG

# %%
d = dfasmnt0622[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0622, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 56789   Assessment        dbo  TEST_TAPE_G10

# %%
d = dfasmnt0623[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0623, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 56882   Assessment        dbo  TEST_TAPE_G4

# %%
d = dfasmnt0624[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0624, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 56975   Assessment        dbo  TEST_TAPE_G7

# %%
d = dfasmnt0625[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0625, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 57068   Assessment        dbo  TEST_TAPE_HGT

# %%
d = dfasmnt0626[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0626, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 57161   Assessment        dbo  TEST_TAPE_HGT_REP

# %%
d = dfasmnt0627[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0627, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 57254   Assessment        dbo  TEST_TAPE_ITB

# %%
d = dfasmnt0628[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0628, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 57347   Assessment        dbo  TEST_TAPE_PSA

# %%
d = dfasmnt0629[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0629, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 57440   Assessment        dbo  TEST_TAPE_PSA_REP

# %%
d = dfasmnt0630[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0630, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 57533   Assessment        dbo  TEST_TAPE_SAT

# %%
d = dfasmnt0631[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0631, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 57626   Assessment        dbo  TEST_TAPE_SAT_REP

# %%
d = dfasmnt0632[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0632, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 57719   Assessment        dbo  TEST_TAPE_WR5

# %%
d = dfasmnt0633[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0633, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 57812   Assessment        dbo  TEST_TAPE_WR58_DEM

# %%
d = dfasmnt0634[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0634, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 57905   Assessment        dbo  TEST_TAPE_WR8

# %%
d = dfasmnt0635[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0635, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 57998   Assessment        dbo  TEST_TAPE_WRI

# %%
d = dfasmnt0636[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0636, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 58091   Assessment        dbo  TEST_TEMP_ECT_DELETES

# %%
d = dfasmnt0637[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0637, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 58184   Assessment        dbo  TEST_TEMP_ECT_LEX1

# %%
d = dfasmnt0638[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0638, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 58277   Assessment        dbo  TEST_TEMP_ECT_LEX2

# %%
d = dfasmnt0639[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0639, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName           TableName
# 58370   Assessment        dbo  TEST_TEMP_ECT_LEX3

# %%
d = dfasmnt0640[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0640, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 58463   Assessment        dbo  TEST_TEMP_ECT_LEXALL

# %%
d = dfasmnt0641[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0641, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 58556   Assessment        dbo  TEST_TEMP_EOC_DELETES

# %%
d = dfasmnt0642[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0642, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 58649   Assessment        dbo  TEST_TEMP_GWY

# %%
d = dfasmnt0643[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0643, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 58835   Assessment        dbo  Testing_Accom

# %%
d = dfasmnt0644[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0644, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                   TableName
# 58928   Assessment        dbo  Testing_Accommodation_2018

# %%
d = dfasmnt0645[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0645, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 59021   Assessment        dbo  ZONED_NEW_REPORT

# %%
d = dfasmnt0646[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0646, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 59114   Assessment        dbo  ZONED_SCH_REPORT

# %%
d = dfasmnt0647[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0647, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName           TableName
# 4557   Assessment     ETLREF  AP_COURSE_TEST_MAP

# %%
d = dfasmnt0648[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0648, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 13299   Assessment     ETLREF  CRCT_SUBTEST_MAP

# %%
d = dfasmnt0649[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0649, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 27295   Assessment     ETLREF  EOCT_TEST_MAP

# %%
d = dfasmnt0650[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0650, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                TableName
# 33458   Assessment     ETLREF  HSGT_TOTAL_RAW_POSSIBLE

# %%
d = dfasmnt0651[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0651, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 36329   Assessment     ETLREF   PSA_SCR

# %%
d = dfasmnt0652[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0652, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 45629   Assessment     ETLREF   STU_SAT

# %%
d = dfasmnt0653[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0653, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 46187   Assessment     ETLREF  SUBTEST_DIM

# %%
d = dfasmnt0654[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0654, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 46931   Assessment     ETLREF  SUBTEST_PERF_DIM

# %%
d = dfasmnt0655[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0655, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#     DatabaseName SchemaName     TableName
# 465   Assessment        ref  ACC_TASK_REF

# %%
d = dfasmnt0656[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0656, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#      DatabaseName SchemaName        TableName
# 4743   Assessment        ref  AP_TEST_SUBJ_CD

# %%
d = dfasmnt0657[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0657, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 12648   Assessment        ref  CAR_STRAND_MAP

# %%
d = dfasmnt0658[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0658, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 12741   Assessment        ref  CAR_SUB_REF

# %%
d = dfasmnt0659[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0659, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName          TableName
# 13113   Assessment        ref  CRCT_PERFRMNC_LVL

# %%
d = dfasmnt0660[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0660, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName        TableName
# 13206   Assessment        ref  CRCT_STRAND_MAP

# %%
d = dfasmnt0661[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0661, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName     TableName
# 18667   Assessment        ref  DATE_MAPPING

# %%
d = dfasmnt0662[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0662, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 27202   Assessment        ref  EOCT_STRND_REF

# %%
d = dfasmnt0663[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0663, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 28411   Assessment        ref  EXAM_VERSIONS

# %%
d = dfasmnt0664[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0664, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName       TableName
# 29620   Assessment        ref  GATEWAY_STRAND

# %%
d = dfasmnt0665[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0665, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 31319   Assessment        ref  GWY_SUB_REF

# %%
d = dfasmnt0666[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0666, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName      TableName
# 30224   Assessment        ref  GWY10_SUB_REF

# %%
d = dfasmnt0667[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0667, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName             TableName
# 45908   Assessment        ref  STU_TEST_CAR_CUT_SCR

# %%
d = dfasmnt0668[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0668, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName TableName
# 58742   Assessment        ref      Test

# %%
d = dfasmnt0669[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0669, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName    TableName
# 31877   Assessment        res  Grad_Survey

# %%
d = dfasmnt0670[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0670, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName              TableName
# 35597   Assessment        res  Military_Scholarships

# %%
d = dfasmnt0671[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0671, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName            TableName
# 37538   Assessment        res  Potential_Graduates

# %%
d = dfasmnt0672[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('Assmnt_{}_{}'.format(f,g))

fig = px.scatter(dfasmnt0672, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\Assessment\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName         TableName
# 46652   Assessment       Temp  SUBTEST_FACT_ACT

# %%
now01 = datetime.datetime.now()
print('Interactive Chart Creation - Process Complete: ', now01.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Interactive Chart Creation - Process Complete:  2021-05-11 11:30:05
