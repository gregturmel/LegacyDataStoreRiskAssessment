# %%
#Program Name: Daily-XChart-datapane_v1_single_multi_on_control
#Purpose:  Chart scatter line box aggr table data
#Author:  Greg Turmel, Director, Data Governance 
#Date:    2020.08.30 - 2021.06.30
#Errata:  0.1 Improvements can be made to script using for/looping through the databases

import os, sys, argparse, csv, pyodbc, sql, time, datetime
from datetime import datetime, timedelta
import sqlalchemy as db
from dotenv import load_dotenv # add this line
from matplotlib.backends.backend_pdf import PdfPages
import pandas as pd
import altair as alt
from altair import Chart, X, Y, Axis, SortField
from vega_datasets import data as vega_data
import datapane as dp
#import datatable as dt
import numpy as np
import matplotlib # notebook
import matplotlib.pyplot as plt
import seaborn as sns
#import chart_studio.plotly as py
import plotly.graph_objects as go
load_dotenv() # add this line
user = os.getenv('MySQLeUser')
password = os.getenv('MySQLeUserPass')
host = os.getenv('MySQLeHOST')
db = os.getenv('MySQLeDB')
# %matplotlib inline
# %load_ext sql

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=DEVODSSQL;'
                      'Database=Greg;'
                      'Trusted_Connection=yes;')

sql_query01 = pd.read_sql_query(''' 
select DISTINCT TableName
FROM [dbo].[tableRowCountControl]
ORDER BY TableName;     
                              '''
                              ,conn) # Load the list of distinct tables to graph

sql_query02 = pd.read_sql_query(''' 
select *
FROM [dbo].[tableRowCountControl]
ORDER BY TableName;     
                              '''
                              ,conn) # Load the list of distinct tables to graph

# %%
df = pd.DataFrame(sql_query02)
#df = df.astype({'TodaysDate':np.int64,'RecordCount':np.int64})
df['TodaysDate'] = pd.to_datetime(df['TodaysDate'].astype(str), format='%Y%m%d')
df = df.sort_values(by=['TableName','SchemaName','DatabaseName','TodaysDate'], ascending=[True,True,True,True])
df = df.reset_index(drop=True)

# %%
dfcntrl0001 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DataQualityException')]
dfcntrl0002 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DataQualityExceptionMessage')]
dfcntrl0003 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ETLCycle')]
dfcntrl0004 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'JobDesc')]
dfcntrl0005 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'JobInstance')]
dfcntrl0006 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'JobInstanceAudit')]
dfcntrl0007 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'JobMetric')]
dfcntrl0008 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'LastTableChange')]
dfcntrl0009 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'RowBusinessRule')]
dfcntrl0010 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'System')]
dfcntrl0011 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SystemEntity')]
dfcntrl0012 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DownstreamFeeds') & (df['TableName'] == 'EdCloud_Import_ALL_TESTS')]
dfcntrl0013 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DownstreamFeeds') & (df['TableName'] == 'EdCloud_Import_BM_EXTRACT')]
dfcntrl0014 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'Address_Dim')]
dfcntrl0015 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'Class_Dim')]
dfcntrl0016 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'Class_Fact')]
dfcntrl0017 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'ClassAttr_Dim')]
dfcntrl0018 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'ClassRoster_Dim')]
dfcntrl0019 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'ClassRoster_Fact')]
dfcntrl0020 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'ClassStaffing_Dim')]
dfcntrl0021 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'Course_Dim')]
dfcntrl0022 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'CourseAttr_Dim')]
dfcntrl0023 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'District_Dim')]
dfcntrl0024 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'Employee_Dim')]
dfcntrl0025 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'EmployeeAttr_Dim')]
dfcntrl0026 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'Ethnicity_Dim')]
dfcntrl0027 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'Guardian_Dim')]
dfcntrl0028 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'Guardianship_Dim')]
dfcntrl0029 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'School_Dim')]
dfcntrl0030 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'SchoolAttr_Dim')]
dfcntrl0031 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'SchoolStaffing_Dim')]
dfcntrl0032 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'Site_Dim')]
dfcntrl0033 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'SiteType_Dim')]
dfcntrl0034 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'Student_Dim')]
dfcntrl0035 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'StudentAttr_Dim')]
dfcntrl0036 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'DQL') & (df['TableName'] == 'Term_Dim')]
dfcntrl0037 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'PSoft') & (df['TableName'] == 'PS_GW_EE_COMP_INFO')]
dfcntrl0038 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'PSoft') & (df['TableName'] == 'PS_GW_JOB_FTE_SUM')]
dfcntrl0039 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'PSoft') & (df['TableName'] == 'PS_GW_JOB_LOCSM_VW')]
dfcntrl0040 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'PSoft') & (df['TableName'] == 'PS_GW_SISK12_STAFF')]
dfcntrl0041 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_ATT_CAL')]
dfcntrl0042 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_ATT_CAL_OPT')]
dfcntrl0043 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_ATT_CAL_TYPE')]
dfcntrl0044 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_CODE_ABS_REAS')]
dfcntrl0045 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_CODE_ABS_REAS_SCH_YR')]
dfcntrl0046 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_CODE_DISC')]
dfcntrl0047 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_CODE_DISP')]
dfcntrl0048 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_CODE_TRK_SCH_YR')]
dfcntrl0049 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_CRS')]
dfcntrl0050 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_GROUP')]
dfcntrl0051 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_NEED_DEF')]
dfcntrl0052 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_PARENT')]
dfcntrl0053 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_SCH')]
dfcntrl0054 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_SCH_ATT_CAL')]
dfcntrl0055 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_SCH_ATT_CAL_OPT')]
dfcntrl0056 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_SCH_ATT_CAL_TRK')]
dfcntrl0057 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_SCH_INCIDENT')]
dfcntrl0058 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_SCH_INCIDENT_LOCATION')]
dfcntrl0059 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_SCH_ROOM')]
dfcntrl0060 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_SCH_YR_CRS')]
dfcntrl0061 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_SCH_YR_FEE')]
dfcntrl0062 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_SCH_YR_OPT')]
dfcntrl0063 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_SCH_YR_SECT')]
dfcntrl0064 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_SCH_YR_SECT_STF')]
dfcntrl0065 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_SCH_YR_SECT_STF_HIS')]
dfcntrl0066 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_SCH_YR_TRM_CODES')]
dfcntrl0067 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_SCH_YR_TRM_DEF')]
dfcntrl0068 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_SECT_LCL_M_SCHD_ID')]
dfcntrl0069 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STAFF')]
dfcntrl0070 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STAFF_SCH_YR')]
dfcntrl0071 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU')]
dfcntrl0072 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_ATT_DAILY')]
dfcntrl0073 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_CLASS')]
dfcntrl0074 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_CRS_HIS')]
dfcntrl0075 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_EMG_CONTACT')]
dfcntrl0076 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_ENROLL')]
dfcntrl0077 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_ENROLL_ACTIVITY')]
dfcntrl0078 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_FEE')]
dfcntrl0079 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_FEE_PAYMENT')]
dfcntrl0080 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_FEE_SUM')]
dfcntrl0081 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_GPA')]
dfcntrl0082 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_GROUP')]
dfcntrl0083 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_GROUP_SCH_YR')]
dfcntrl0084 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_HEALTH')]
dfcntrl0085 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_HEALTH_CONDITION')]
dfcntrl0086 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_INC_DISCIPLINE')]
dfcntrl0087 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_INC_DISPOSITION')]
dfcntrl0088 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_INC_VIOL_DISC')]
dfcntrl0089 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_INC_VIOLATION')]
dfcntrl0090 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_OLD_SIS')]
dfcntrl0091 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_PARENT')]
dfcntrl0092 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_PGM_ELL')]
dfcntrl0093 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_PGM_ELL_HIS')]
dfcntrl0094 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_PGM_FRM')]
dfcntrl0095 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_PGM_GAT')]
dfcntrl0096 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_PGM_GAT_CAT_LST')]
dfcntrl0097 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_PGM_GAT_HIS')]
dfcntrl0098 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_PGM_MSC_HIS')]
dfcntrl0099 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_PHYSICIAN')]
dfcntrl0100 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_SCH_YR')]
dfcntrl0101 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_SECL_REST_STAFF')]
dfcntrl0102 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_SECLUSION_RESTRAINT')]
dfcntrl0103 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_TEST')]
dfcntrl0104 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_TEST_PART')]
dfcntrl0105 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_TEST_PART_SCORE')]
dfcntrl0106 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_STU_YR')]
dfcntrl0107 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_TEST')]
dfcntrl0108 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'EPC_TEST_PART')]
dfcntrl0109 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'ETLCurrentYearGU')]
dfcntrl0110 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'ETLDistrictGU')]
dfcntrl0111 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'ETLDistrictNumber')]
dfcntrl0112 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'ETLRunDate')]
dfcntrl0113 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'ETLSchoolImportListByType')]
dfcntrl0114 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'ETLTerms')]
dfcntrl0115 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'ETLXSTU_SCHYR_ENROLLMENT_SCHOOL')]
dfcntrl0116 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'ETLXSTU_SCHYR_SCHLIST_SCHOOL')]
dfcntrl0117 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'GCPS_STU_SECT_NEEDS')]
dfcntrl0118 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'REV_ADDRESS')]
dfcntrl0119 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'REV_APPLICATION')]
dfcntrl0120 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'REV_BOD_LOOKUP_DEF')]
dfcntrl0121 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'REV_BOD_LOOKUP_VALUES')]
dfcntrl0122 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'REV_ORGANIZATION')]
dfcntrl0123 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'REV_ORGANIZATION_YEAR')]
dfcntrl0124 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'REV_PERSON')]
dfcntrl0125 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'REV_PERSON_PHONE')]
dfcntrl0126 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'REV_PERSON_SECONDRY_ETH_LST')]
dfcntrl0127 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'REV_USER')]
dfcntrl0128 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'REV_YEAR')]
dfcntrl0129 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'SGM_ASSESSMENT_INFO')]
dfcntrl0130 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'SIF_22_SynergySchoolImportListByType')]
dfcntrl0131 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'UD_CRS')]
dfcntrl0132 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'UD_PARENT')]
dfcntrl0133 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'UD_STAFF')]
dfcntrl0134 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'UD_STU')]
dfcntrl0135 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'UD_STU_504')]
dfcntrl0136 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'UD_STU_ABS_NOT')]
dfcntrl0137 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'UD_STU_PGM_GAT')]
dfcntrl0138 = df[(df['DatabaseName'] == 'Control') & (df['SchemaName'] == 'rev') & (df['TableName'] == 'UD_STUDENT_ONETOMANY')]

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(df).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='Control All Tables'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(df, title='Control All Tables').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#Individual Tables - graphed with datapane and altair

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfcntrl0001).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='DataQualityException'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfcntrl0001, title='DataQualityException').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfcntrl0040).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='PS_GW_SISK12_STAFF'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfcntrl0040, title='PS_GW_SISK12_STAFF').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)
