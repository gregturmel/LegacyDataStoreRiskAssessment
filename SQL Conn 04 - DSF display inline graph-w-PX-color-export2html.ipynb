# %%
#Program Name: Graphing ODS Databases - SQL Conn 04 - DSF display inline graph-w-PX-color-export2html
#Purpose:  Chart scatter, line, box, aggr, violin, or bar with table data
#Author:  Greg Turmel, Director, Data Governance 
#Date:    2020.08.30 - 2021.06.30
#Errata:  0.1 Improvements can be made to script using for/looping through the databases

import os, time, datetime
import sqlalchemy as db
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import pyodbc 
import matplotlib
import plotly.express as px

#matplotlib.rcParams['figure.figsize'] = (30,5)
# %config InlineBackend.figure_format = 'retina'
from dotenv import load_dotenv # add this line
load_dotenv() # add this line
user = os.getenv('MySQLeUser')
password = os.getenv('MySQLeUserPass')
host = os.getenv('MySQLeHOST')
db = os.getenv('MySQLeDB')
# %matplotlib inline
# %load_ext sql

dt1 = time.strftime("%d/%m/%Y")
dt2 = time.strftime("%d.%m.%Y")
dt3 = pd.to_datetime('today')
dt4 = pd.Timestamp('today').strftime("%Y%m%d")
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=DEVODSSQL;'
                      'Database=Greg;'
                      'Trusted_Connection=yes;')

sql_query01 = pd.read_sql_query(''' 
select DISTINCT TableName
FROM [dbo].[tableRowCountDownstreamFeeds]
ORDER BY TableName;     
                              '''
                              ,conn) # Load the list of distinct tables to graph

sql_query02 = pd.read_sql_query(''' 
select *
FROM [dbo].[tableRowCountDownstreamFeeds]
ORDER BY TableName;     
                              '''
                              ,conn) # Load the list of distinct tables to graph

# %%
df = pd.DataFrame(sql_query02)
#df = df.astype({'TodaysDate':np.int64,'RecordCount':np.int64})
df['TodaysDate'] = pd.to_datetime(df['TodaysDate'].astype(str), format='%Y%m%d')
df = df.sort_values(by=['TableName','SchemaName','DatabaseName','TodaysDate'], ascending=[True,True,True,True])
df = df.reset_index(drop=True)

# %%
dfdsf0001 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'AD') & (df['TableName'] == 'ADProvisioning_Employees')]
dfdsf0002 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'AD') & (df['TableName'] == 'ADProvisioning_Students')]
dfdsf0003 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'AD') & (df['TableName'] == 'C_ENR_TBL_GSDR')]
dfdsf0004 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'AD') & (df['TableName'] == 'C_ENR_TBL_SYN')]
dfdsf0005 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'AD') & (df['TableName'] == 'Enrollment')]
dfdsf0006 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'AD') & (df['TableName'] == 'Enrollment_2019622_before_summer_change')]
dfdsf0007 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'AD') & (df['TableName'] == 'Enrollment_Delta')]
dfdsf0008 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'AD') & (df['TableName'] == 'Enrollment_EOY1415')]
dfdsf0009 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'AD') & (df['TableName'] == 'REF_ProcessLog')]
dfdsf0010 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'AD') & (df['TableName'] == 'REF_Users')]
dfdsf0011 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Cohort') & (df['TableName'] == 'ProjectedGradRateDistrictTotals')]
dfdsf0012 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFile') & (df['TableName'] == 'Course')]
dfdsf0013 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFile') & (df['TableName'] == 'Course_Gradebook_Template')]
dfdsf0014 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFile') & (df['TableName'] == 'Course_Job_Field')]
dfdsf0015 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFile') & (df['TableName'] == 'Course_Pathway')]
dfdsf0016 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFile') & (df['TableName'] == 'Course_School_Authorization')]
dfdsf0017 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFile') & (df['TableName'] == 'Course_SPG_Growth_Percentage')]
dfdsf0018 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFile') & (df['TableName'] == 'Course_SPG_Growth_Rubric')]
dfdsf0019 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFile') & (df['TableName'] == 'Course_Textbook')]
dfdsf0020 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFile') & (df['TableName'] == 'Course_Textbook_Manager_Department')]
dfdsf0021 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFile') & (df['TableName'] == 'Gradebook_Template')]
dfdsf0022 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFile') & (df['TableName'] == 'Job_Field')]
dfdsf0023 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFile') & (df['TableName'] == 'OLD_Concentration')]
dfdsf0024 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFile') & (df['TableName'] == 'OLD_Course_Concentration')]
dfdsf0025 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFile') & (df['TableName'] == 'Textbook')]
dfdsf0026 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFile') & (df['TableName'] == 'Textbook_Manager_Department')]
dfdsf0027 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFileNext') & (df['TableName'] == 'Course')]
dfdsf0028 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFileNext') & (df['TableName'] == 'Course_Gradebook_Template')]
dfdsf0029 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFileNext') & (df['TableName'] == 'Course_Job_Field')]
dfdsf0030 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFileNext') & (df['TableName'] == 'Course_Pathway')]
dfdsf0031 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFileNext') & (df['TableName'] == 'Course_School_Authorization')]
dfdsf0032 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFileNext') & (df['TableName'] == 'Course_School_Authorization_Temp')]
dfdsf0033 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFileNext') & (df['TableName'] == 'Course_SPG_Growth_Percentage')]
dfdsf0034 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFileNext') & (df['TableName'] == 'Course_SPG_Growth_Rubric')]
dfdsf0035 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFileNext') & (df['TableName'] == 'Course_Textbook')]
dfdsf0036 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFileNext') & (df['TableName'] == 'Course_Textbook_Manager_Department')]
dfdsf0037 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFileNext') & (df['TableName'] == 'Gradebook_Template')]
dfdsf0038 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFileNext') & (df['TableName'] == 'Job_Field')]
dfdsf0039 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFileNext') & (df['TableName'] == 'Textbook')]
dfdsf0040 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'CourseFileNext') & (df['TableName'] == 'Textbook_Manager_Department')]
dfdsf0041 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Cworks') & (df['TableName'] == 'ClassworksClass')]
dfdsf0042 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Cworks') & (df['TableName'] == 'classworksclass_TMP')]
dfdsf0043 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Cworks') & (df['TableName'] == 'ClassworksClassSummer')]
dfdsf0044 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Cworks') & (df['TableName'] == 'ClassworksSummerEmpSeq')]
dfdsf0045 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Cworks') & (df['TableName'] == 'ClassworksTSTList')]
dfdsf0046 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Cworks') & (df['TableName'] == 'ClassworksUpdate')]
dfdsf0047 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Cworks') & (df['TableName'] == 'ClassworksUser')]
dfdsf0048 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Cworks') & (df['TableName'] == 'classworksuser_TMP')]
dfdsf0049 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Cworks') & (df['TableName'] == 'ClassworksUserAdditional')]
dfdsf0050 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Cworks') & (df['TableName'] == 'ClassworksUserSummer')]
dfdsf0051 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'D2L_NON_TEACHING_STAFF')]
dfdsf0052 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_AllSchools_Usage')]
dfdsf0053 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_AllSchools_Usage_BKUP_20160817')]
dfdsf0054 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_AllSchools_Usage_BKUP_20170731')]
dfdsf0055 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_OrgRoleCrosswalk')]
dfdsf0056 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_SchoolPopulation')]
dfdsf0057 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_SchoolPopulation_BKUP_20160817')]
dfdsf0058 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_SchoolPopulation_BKUP_20170731')]
dfdsf0059 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_SchoolPopulationDtl')]
dfdsf0060 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_SchoolPopulationDtl_BKUP_20160817')]
dfdsf0061 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_SchoolPopulationDtl_BKUP_20170731')]
dfdsf0062 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_Reporting_TeacherSchedule')]
dfdsf0063 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_Usage')]
dfdsf0064 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_Usage_BKUP_20160817')]
dfdsf0065 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_Usage_BKUP_20170731')]
dfdsf0066 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_Usage_DLD')]
dfdsf0067 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_UsageDtl')]
dfdsf0068 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_UsageDtl_20180221')]
dfdsf0069 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_UsageDtl_BKUP_20160817')]
dfdsf0070 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_UsageDtl_BKUP_20170731')]
dfdsf0071 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'd2l_reporting_UsageDtl_BKUP_20180123')]
dfdsf0072 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'EARLY_PROVISIONING')]
dfdsf0073 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'GOC_Master')]
dfdsf0074 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'GOC_Master_Delta')]
dfdsf0075 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_ads_goc_AllGrades')]
dfdsf0076 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_ads_goc_AwardsIssued')]
dfdsf0077 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_ads_goc_CLOE')]
dfdsf0078 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_ads_goc_EnrollmentsandWithdrawals')]
dfdsf0079 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_ads_goc_FinalGrades')]
dfdsf0080 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_ads_goc_ImpersonatedSessionHistory')]
dfdsf0081 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_ads_goc_InstructorUsage')]
dfdsf0082 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_ads_goc_LearnerUsage')]
dfdsf0083 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_ActivityFeedCommentLog')]
dfdsf0084 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_ActivityFeedPostLog')]
dfdsf0085 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_Announcements')]
dfdsf0086 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_AssignmentSpecialAccess')]
dfdsf0087 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_AssignmentSubmissionDetails')]
dfdsf0088 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_AssignmentSubmissions')]
dfdsf0089 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_AssignmentSummary')]
dfdsf0090 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_AwardObjects')]
dfdsf0091 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_AwardsIssued')]
dfdsf0092 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_CalendarEvents')]
dfdsf0093 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_ChecklistCategoryDetails')]
dfdsf0094 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_ChecklistCompletions')]
dfdsf0095 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_ChecklistItemDetails')]
dfdsf0096 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_ChecklistObjects')]
dfdsf0097 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_ContentObjects')]
dfdsf0098 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_ContentUserCompletion')]
dfdsf0099 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_ContentUserProgress')]
dfdsf0100 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_CourseAccess')]
dfdsf0101 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_CourseAwards')]
dfdsf0102 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_CourseCopyLogs')]
dfdsf0103 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_DiscussionForums')]
dfdsf0104 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_DiscussionPosts')]
dfdsf0105 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_DiscussionPostsReadStatus')]
dfdsf0106 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_DiscussionTopics')]
dfdsf0107 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_DiscussionTopicUserScores')]
dfdsf0108 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_EnrollmentsandWithdrawals')]
dfdsf0109 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_ActivityExemptionsLog')]
dfdsf0110 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_ActivityFeedCommentLog')]
dfdsf0111 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_ActivityFeedPostLog')]
dfdsf0112 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_Announcements')]
dfdsf0113 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_AssignmentSpecialAccess')]
dfdsf0114 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_AssignmentSubmissionDetails')]
dfdsf0115 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_AssignmentSubmissions')]
dfdsf0116 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_AssignmentSummary')]
dfdsf0117 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_AttendanceDetails')]
dfdsf0118 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_AttendanceRegisters')]
dfdsf0119 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_AttendanceSchemes')]
dfdsf0120 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_AttendanceSessions')]
dfdsf0121 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_AttendanceSummary')]
dfdsf0122 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_AttendanceUserSessions')]
dfdsf0123 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_AwardObjects')]
dfdsf0124 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_AwardsIssued')]
dfdsf0125 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_CalendarEvents')]
dfdsf0126 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_ChatObjects')]
dfdsf0127 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_ChatSessionLog')]
dfdsf0128 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_ChecklistCategoryDetails')]
dfdsf0129 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_ChecklistCompletions')]
dfdsf0130 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_ChecklistItemDetails')]
dfdsf0131 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_ChecklistObjects')]
dfdsf0132 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_CompetencyActivities')]
dfdsf0133 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_CompetencyActivityLog')]
dfdsf0134 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_CompetencyActivityResults')]
dfdsf0135 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_CompetencyLog')]
dfdsf0136 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_CompetencyObjects')]
dfdsf0137 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_CompetencyStructure')]
dfdsf0138 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_ContentObjects')]
dfdsf0139 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_ContentUserCompletion')]
dfdsf0140 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_ContentUserProgress')]
dfdsf0141 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_CourseAccess')]
dfdsf0142 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_CourseAwards')]
dfdsf0143 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_CourseCopyLogs')]
dfdsf0144 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_DiscussionForums')]
dfdsf0145 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_DiscussionPosts')]
dfdsf0146 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_DiscussionPostsReadStatus')]
dfdsf0147 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_DiscussionTopics')]
dfdsf0148 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_DiscussionTopicUserScores')]
dfdsf0149 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_EnrollmentsandWithdrawals')]
dfdsf0150 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_GradebookSettings')]
dfdsf0151 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_GradeObjects')]
dfdsf0152 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_GradeObjectsLog')]
dfdsf0153 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_GradeObjectsLog_temp')]
dfdsf0154 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_GradeResults')]
dfdsf0155 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_GradeResults_temp')]
dfdsf0156 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_GradeSchemeRanges')]
dfdsf0157 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_GradeSchemes')]
dfdsf0158 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_IntelligentAgentObjects')]
dfdsf0159 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_IntelligentAgentRunLog')]
dfdsf0160 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_IntelligentAgentRuns')]
dfdsf0161 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_IntelligentAgentRunUsers')]
dfdsf0162 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_LTILinks')]
dfdsf0163 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_LTILinksShared')]
dfdsf0164 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_OrganizationalUnitAncestors')]
dfdsf0165 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_OrganizationalUnitDescendants')]
dfdsf0166 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_OrganizationalUnitParents')]
dfdsf0167 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_OrganizationalUnitRecentAccess')]
dfdsf0168 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_OrganizationalUnits')]
dfdsf0169 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_OrgUnitParents')]
dfdsf0170 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_PortfolioCategories')]
dfdsf0171 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_PortfolioEvidenceCategories')]
dfdsf0172 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_PortfolioEvidenceLog')]
dfdsf0173 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_PortfolioEvidenceObjects')]
dfdsf0174 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_PreRequisiteConditionsMet')]
dfdsf0175 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_QuestionLibrary')]
dfdsf0176 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_QuestionRelationships')]
dfdsf0177 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_QuizandSurveySectionObjects')]
dfdsf0178 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_QuizAttempts')]
dfdsf0179 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_QuizAttemptsLog')]
dfdsf0180 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_QuizAttemptsLog_temp')]
dfdsf0181 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_QuizObjects')]
dfdsf0182 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_QuizQuestionAnswerOptions')]
dfdsf0183 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_QuizQuestionAnswers')]
dfdsf0184 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_QuizQuestions')]
dfdsf0185 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_QuizSurveySections')]
dfdsf0186 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_QuizUserAnswerResponses')]
dfdsf0187 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_QuizUserAnswers')]
dfdsf0188 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_ReleaseConditionObjects')]
dfdsf0189 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_ReleaseConditionResults')]
dfdsf0190 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_RoleDetails')]
dfdsf0191 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_RubricAssessment')]
dfdsf0192 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_RubricAssessmentCriteria')]
dfdsf0193 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_RubricCriteriaLevels')]
dfdsf0194 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_RubricObjectCriteria')]
dfdsf0195 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_RubricObjectLevels')]
dfdsf0196 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_RubricObjects')]
dfdsf0197 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_SessionHistory')]
dfdsf0198 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_SurveyAttempts')]
dfdsf0199 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_SurveyQuestionAnswerOptions')]
dfdsf0200 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_SurveyQuestionAnswers')]
dfdsf0201 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_SurveyQuestions')]
dfdsf0202 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_SurveyUserAnswerResponses')]
dfdsf0203 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_SurveyUserAnswers')]
dfdsf0204 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_SystemAccessLog')]
dfdsf0205 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_SystemAccessLog_temp')]
dfdsf0206 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_Tools')]
dfdsf0207 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_TurnItInSubmissions')]
dfdsf0208 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_UserEnrollments')]
dfdsf0209 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_UserLogins')]
dfdsf0210 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_UserLogins_temp')]
dfdsf0211 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_goc_Users')]
dfdsf0212 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_GradebookSettings')]
dfdsf0213 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_GradeObjects')]
dfdsf0214 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_GradeObjectsLog')]
dfdsf0215 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_GradeResults')]
dfdsf0216 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_GradeSchemeRanges')]
dfdsf0217 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_GradeSchemes')]
dfdsf0218 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_IntelligentAgentObjects')]
dfdsf0219 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_IntelligentAgentRunLog')]
dfdsf0220 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_IntelligentAgentRuns')]
dfdsf0221 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_IntelligentAgentRunUsers')]
dfdsf0222 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_LTILaunches')]
dfdsf0223 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_LTILaunches_temp')]
dfdsf0224 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_LTILinks')]
dfdsf0225 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_LTILinksShared')]
dfdsf0226 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_OrganizationalUnitAncestors')]
dfdsf0227 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_OrganizationalUnitDescendants')]
dfdsf0228 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_OrganizationalUnitParents')]
dfdsf0229 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_OrganizationalUnitRecentAccess')]
dfdsf0230 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_OrganizationalUnits')]
dfdsf0231 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_OrgUnitParents')]
dfdsf0232 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_PortfolioCategories')]
dfdsf0233 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_PortfolioEvidenceCategories')]
dfdsf0234 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_PortfolioEvidenceLog')]
dfdsf0235 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_PortfolioEvidenceObjects')]
dfdsf0236 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_PreRequisiteConditionsMet')]
dfdsf0237 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_QuestionLibrary')]
dfdsf0238 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_QuestionRelationships')]
dfdsf0239 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_QuizandSurveySectionObjects')]
dfdsf0240 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_QuizAttempts')]
dfdsf0241 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_QuizAttemptsLog')]
dfdsf0242 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_QuizObjects')]
dfdsf0243 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_QuizQuestionAnswerOptions')]
dfdsf0244 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_QuizQuestionAnswers')]
dfdsf0245 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_QuizQuestions')]
dfdsf0246 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_QuizSurveySections')]
dfdsf0247 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_QuizUserAnswerResponses')]
dfdsf0248 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_QuizUserAnswers')]
dfdsf0249 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_ReleaseConditionObjects')]
dfdsf0250 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_ReleaseConditionResults')]
dfdsf0251 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_RoleDetails')]
dfdsf0252 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_RubricAssessment')]
dfdsf0253 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_RubricAssessmentCriteria')]
dfdsf0254 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_RubricCriteriaLevels')]
dfdsf0255 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_RubricObjectCriteria')]
dfdsf0256 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_RubricObjectLevels')]
dfdsf0257 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_RubricObjects')]
dfdsf0258 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_SessionHistory')]
dfdsf0259 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_SurveyAttempts')]
dfdsf0260 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_SurveyQuestionAnswerOptions')]
dfdsf0261 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_SurveyQuestionAnswers')]
dfdsf0262 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_SurveyQuestions')]
dfdsf0263 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_SurveyUserAnswerResponses')]
dfdsf0264 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_SurveyUserAnswers')]
dfdsf0265 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_SystemAccessLog')]
dfdsf0266 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_Tools')]
dfdsf0267 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_UserEnrollments')]
dfdsf0268 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_UserLogins')]
dfdsf0269 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_bds_Users')]
dfdsf0270 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_course_enrollments')]
dfdsf0271 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_course_offerings')]
dfdsf0272 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_orgUnits')]
dfdsf0273 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_qa_course_enrollments')]
dfdsf0274 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_qa_course_enrollments_temp')]
dfdsf0275 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_qa_course_offerings')]
dfdsf0276 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_qa_course_offerings_temp')]
dfdsf0277 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_qa_orgUnits')]
dfdsf0278 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_qa_orgUnits_temp')]
dfdsf0279 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_qa_school_enrollments')]
dfdsf0280 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_qa_section_classlist')]
dfdsf0281 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_qa_users')]
dfdsf0282 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_school_enrollments')]
dfdsf0283 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_section_classlist')]
dfdsf0284 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_users')]
dfdsf0285 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'import_users_temp')]
dfdsf0286 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Membership')]
dfdsf0287 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Membership_Delta')]
dfdsf0288 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'merge_course_qa_offerings_summary_temp')]
dfdsf0289 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'merge_qa_course_enrollments_summary_temp')]
dfdsf0290 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'merge_qa_orgUnits_summary_temp')]
dfdsf0291 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'MERGE_SUMMARY')]
dfdsf0292 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'REF_CIUsers')]
dfdsf0293 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'REF_CommCenterTeachers')]
dfdsf0294 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'REF_Config')]
dfdsf0295 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'REF_ContentCopyLog')]
dfdsf0296 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'REF_ContentCopyMap')]
dfdsf0297 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'REF_ExecJobCodes')]
dfdsf0298 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'REF_GOC_SM_Admins')]
dfdsf0299 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'REF_NonTeachers')]
dfdsf0300 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'REF_Safari_ViewPathCourses')]
dfdsf0301 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'REF_SafariAdministrators')]
dfdsf0302 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'REF_SafariGroupMembers')]
dfdsf0303 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'REF_Schools')]
dfdsf0304 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'REF_TrainingCourseTeachers')]
dfdsf0305 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'SASI_AMST_DUPS')]
dfdsf0306 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Schedule')]
dfdsf0307 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Schedule_Delta')]
dfdsf0308 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'SM_CLASSES')]
dfdsf0309 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'SM_CLASSES_EXPORT')]
dfdsf0310 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'SM_COURSERESOURCES')]
dfdsf0311 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'SM_COURSES')]
dfdsf0312 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'SM_COURSES_EXPORT')]
dfdsf0313 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'SM_ENROLLMENTS')]
dfdsf0314 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'SM_ENROLLMENTS_EXPORT')]
dfdsf0315 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'SM_ORGS')]
dfdsf0316 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'SM_ORGS_EXPORT')]
dfdsf0317 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'SM_RESOURCES')]
dfdsf0318 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'SM_RESOURCES_EXPORT')]
dfdsf0319 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'SM_USERS')]
dfdsf0320 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'SM_USERS_EXPORT')]
dfdsf0321 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'tbl_RptUserEnrollments')]
dfdsf0322 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'TMP_StaffEmail')]
dfdsf0323 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'TMP_Teacher_Schedule')]
dfdsf0324 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'TMP_Usage_Tables')]
dfdsf0325 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Usage__Assessments')]
dfdsf0326 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Usage__Calendar')]
dfdsf0327 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Usage__Discussions')]
dfdsf0328 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Usage__Dropbox')]
dfdsf0329 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Usage__Grades')]
dfdsf0330 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Usage__News')]
dfdsf0331 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Usage__Self_Assessments')]
dfdsf0332 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Usage__Sessions')]
dfdsf0333 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Usage__Surveys')]
dfdsf0334 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Usage_Assessments_OLD')]
dfdsf0335 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Usage_Calendar_OLD')]
dfdsf0336 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Usage_ContentDetails_Processing')]
dfdsf0337 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Usage_ContentProgress_Processing')]
dfdsf0338 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Usage_Discussions_OLD')]
dfdsf0339 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Usage_Dropbox_OLD')]
dfdsf0340 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Usage_Grades_OLD')]
dfdsf0341 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Usage_News_OLD')]
dfdsf0342 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Usage_Self_Assessments_OLD')]
dfdsf0343 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Usage_Sessions')]
dfdsf0344 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Usage_Surveys_OLD')]
dfdsf0345 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Users')]
dfdsf0346 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'Users_Delta')]
dfdsf0347 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'validation_enrollment')]
dfdsf0348 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'validation_membership')]
dfdsf0349 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'validation_qa_enrollment')]
dfdsf0350 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'validation_qa_membership')]
dfdsf0351 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'validation_qa_users')]
dfdsf0352 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'd2l') & (df['TableName'] == 'validation_users')]
dfdsf0353 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == '__MigrationHistory')]
dfdsf0354 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'adFeed_temp')]
dfdsf0355 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AftSch_Profile_WorkTbl')]
dfdsf0356 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'BM_EXTRACT_TEMP')]
dfdsf0357 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ContactCode')]
dfdsf0358 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'course_departments')]
dfdsf0359 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CourseFile_Changes')]
dfdsf0360 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CourseFile_Pathways_Import')]
dfdsf0361 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'coursetomasterid')]
dfdsf0362 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CoursetoMasterId2')]
dfdsf0363 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CSVFILE')]
dfdsf0364 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LGradebookPaths')]
dfdsf0365 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DavidTemp')]
dfdsf0366 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DestinySASISTAFF_P')]
dfdsf0367 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DestinyStudentEMH')]
dfdsf0368 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DestinyStudentEMH_TM')]
dfdsf0369 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DestinyStudentEMH2')]
dfdsf0370 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DestinyStudentP')]
dfdsf0371 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DestinyStudentP2')]
dfdsf0372 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DestinyStudentSS')]
dfdsf0373 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DestinyTextbook_ALL')]
dfdsf0374 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DestinyTextbook_E')]
dfdsf0375 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DestinyTextbook_HM')]
dfdsf0376 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DestinyTextbook_HM_temp')]
dfdsf0377 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DestinyTextbook_HM_temp2')]
dfdsf0378 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DestinyTextbook_HME')]
dfdsf0379 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DestinyTextbook_SS')]
dfdsf0380 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DigitalContent_Schedule_REF')]
dfdsf0381 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DuplPermnum')]
dfdsf0382 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Import_BM_EXTRACT')]
dfdsf0383 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Import_BM_EXTRACT_SRC')]
dfdsf0384 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Import_BM_STUDENTS_NO_SCORES')]
dfdsf0385 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Import_BM_TI_EXTRACT')]
dfdsf0386 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Import_BM_TPP')]
dfdsf0387 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Master_Schedule')]
dfdsf0388 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_REF_BM_Config')]
dfdsf0389 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_REF_SchoolNet_CentralOfficeGroups')]
dfdsf0390 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_REF_SchoolNet_StaffCode')]
dfdsf0391 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_REF_SuccessNet_Courses')]
dfdsf0392 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_REF_SuccessNet_TestCourses')]
dfdsf0393 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_REF_SuccessNet_Users')]
dfdsf0394 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_REF_TestStudents')]
dfdsf0395 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_SASI_AMST_DUPS')]
dfdsf0396 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Staff')]
dfdsf0397 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Staff_Schedule')]
dfdsf0398 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Students')]
dfdsf0399 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Students_Schedule')]
dfdsf0400 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ELEM_ASTU_AENRC')]
dfdsf0401 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'es_course_departments')]
dfdsf0402 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ES_Course_depts2011_12')]
dfdsf0403 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ES_Course_depts2012-13')]
dfdsf0404 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EXP_REG_STU')]
dfdsf0405 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EXP_REG_STU_EMH')]
dfdsf0406 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EXP_REG_STU_GSDR')]
dfdsf0407 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'exp_reg_stu_GSDR_EMH')]
dfdsf0408 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EXP_REG_STU_gsdrZone')]
dfdsf0409 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EXP_REG_STU_Zone')]
dfdsf0410 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EXP_REG_SUM')]
dfdsf0411 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'exp_regsum_GSDR')]
dfdsf0412 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'exp_regsumGSDR_EMH')]
dfdsf0413 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'exp_regsumGSDR_EMH_Mar02')]
dfdsf0414 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'exp_regsumGSDR_Zoned')]
dfdsf0415 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ExpandedCourseFile')]
dfdsf0416 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Fall 2018 Grade Conversion 2018-08-27')]
dfdsf0417 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FLATFILE')]
dfdsf0418 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'G_GTID')]
dfdsf0419 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GPLDaily_GSDR')]
dfdsf0420 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GSDR_ASTU_CURR')]
dfdsf0421 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GSDR_ASTU_CURR_20151217')]
dfdsf0422 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HS_Course_Depts2011-12')]
dfdsf0423 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HS_Course_depts2012-13')]
dfdsf0424 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Import')]
dfdsf0425 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'jean2DestinySchool')]
dfdsf0426 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'jeanDESTINY_SCHOOLS')]
dfdsf0427 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'JMS112017_exp_regsum_GSDR')]
dfdsf0428 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'LoadTbl')]
dfdsf0429 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_AftSch_Student_Data_Full_Intermediate_A')]
dfdsf0430 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_AftSch_Student_Data_Full_Intermediate_A_RNK')]
dfdsf0431 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_AftSch_Student_Data_Full_Intermediate_B')]
dfdsf0432 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_AftSch_Student_Data_Full_Result')]
dfdsf0433 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_Dups_From_Mapnet_AftSch_Student_Data_Full_Result')]
dfdsf0434 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_Dups_From_Mapnet_Student_Data_Full_Result')]
dfdsf0435 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_Emergency_Contact_Data_Intermediate_A')]
dfdsf0436 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_Emergency_Contact_Data_Intermediate_B')]
dfdsf0437 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_Emergency_Contact_Data_Intermediate_C')]
dfdsf0438 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_Emergency_Contact_Data_Result')]
dfdsf0439 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'mapnet_jeantest_student_data_full_result')]
dfdsf0440 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_NEXT_Student_Data_Full_Intermediate_A')]
dfdsf0441 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_NEXT_Student_Data_Full_Intermediate_B')]
dfdsf0442 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_NEXT_Year_Student_Data_Full_Result')]
dfdsf0443 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_Parent_Data_Intermediate_A')]
dfdsf0444 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_Parent_Data_Intermediate_B')]
dfdsf0445 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_Parent_Data_Intermediate_C')]
dfdsf0446 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_Parent_Data_Result')]
dfdsf0447 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_Planning_Student_Data_Full_Intermediate_A')]
dfdsf0448 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_Planning_Student_Data_Full_Intermediate_B')]
dfdsf0449 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_Planning_Student_Data_Full_Result')]
dfdsf0450 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_Student_Data_Full_Intermediate_A')]
dfdsf0451 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_Student_Data_Full_Intermediate_B')]
dfdsf0452 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Mapnet_Student_Data_Full_Result')]
dfdsf0453 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'members_tmp')]
dfdsf0454 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ms_course_departments')]
dfdsf0455 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MS_Course_Depts2011_12')]
dfdsf0456 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MS_Course_Depts2011_12_A')]
dfdsf0457 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MS_Course_Depts2012-13')]
dfdsf0458 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ref_digitalcontent_gradelevels')]
dfdsf0459 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ref_digitalcontent_hours')]
dfdsf0460 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ref_digitalcontent_subjects')]
dfdsf0461 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'saveeoct')]
dfdsf0462 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SchoolFoodNutritionDaily')]
dfdsf0463 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SchoolFoodNutritionDaily_GSDR')]
dfdsf0464 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SchoolFoodNutritionDaily_GSDR_Backup')]
dfdsf0465 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SchoolFoodNutritionDaily_GSDR_Temp')]
dfdsf0466 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SchoolFoodNutritionDaily_test')]
dfdsf0467 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SchoolRoster_Changes')]
dfdsf0468 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SFNTeacherDaily')]
dfdsf0469 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SFNTeacherDaily_Backup')]
dfdsf0470 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SFNTeacherDaily2')]
dfdsf0471 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Spring_Survey_Detail')]
dfdsf0472 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Staff_Email_Address')]
dfdsf0473 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'stusched')]
dfdsf0474 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'stusched2')]
dfdsf0475 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'surveymatched')]
dfdsf0476 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sysdiagrams')]
dfdsf0477 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'tb_Diffs')]
dfdsf0478 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_alttran')]
dfdsf0479 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_astp')]
dfdsf0480 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEMP_CENSUS')]
dfdsf0481 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_Gender')]
dfdsf0482 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_GiftedParticipation')]
dfdsf0483 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_Hull')]
dfdsf0484 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_IEP')]
dfdsf0485 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_MapnetStudent_Next')]
dfdsf0486 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_noDupl_sasi_acrs')]
dfdsf0487 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEMP_RIDER_BY_BUS')]
dfdsf0488 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEMP_TEST_TBL')]
dfdsf0489 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_TestGateFeed')]
dfdsf0490 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_TierAttend')]
dfdsf0491 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_TierAttnStu')]
dfdsf0492 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'temp_UATR')]
dfdsf0493 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEMP_USERS')]
dfdsf0494 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEMPSCHNUMDIFF')]
dfdsf0495 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEMPSCHNUMDIFF2')]
dfdsf0496 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEMPSPEDNotInSASI')]
dfdsf0497 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TempStuDetail')]
dfdsf0498 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'test_elements')]
dfdsf0499 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ACT_RAJ')]
dfdsf0500 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_HGT_RAJ')]
dfdsf0501 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_ECT_MARSHAL')]
dfdsf0502 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'testConv')]
dfdsf0503 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TestGateNew')]
dfdsf0504 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TestGateOld')]
dfdsf0505 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TMP_AD_DATA')]
dfdsf0506 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TMP_STU_EMAIL_GSDR')]
dfdsf0507 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TMP_STU_EMAIL_SYN')]
dfdsf0508 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TMP_TBL')]
dfdsf0509 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'tmp_test_tbl')]
dfdsf0510 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Vendor_Master_class')]
dfdsf0511 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'VendorFeedCheck')]
dfdsf0512 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'dc_resources')]
dfdsf0513 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_dbq_classes')]
dfdsf0514 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_dbq_DigitalContent_SRC')]
dfdsf0515 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_dbq_EDP_SRC')]
dfdsf0516 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_dbq_enrollments')]
dfdsf0517 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_dbq_GSDR_SRC')]
dfdsf0518 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_dbq_orgs')]
dfdsf0519 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_dbq_terms')]
dfdsf0520 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_dbq_users')]
dfdsf0521 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_gibbssmith_classes')]
dfdsf0522 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_gibbssmith_DigitalContent_SRC')]
dfdsf0523 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_gibbssmith_EDP_SRC')]
dfdsf0524 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_gibbssmith_enrollments')]
dfdsf0525 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_gibbssmith_orgs')]
dfdsf0526 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_gibbssmith_terms')]
dfdsf0527 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_gibbssmith_users')]
dfdsf0528 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_perfectionlearning_classes')]
dfdsf0529 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_perfectionlearning_DigitalContent_SRC')]
dfdsf0530 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_perfectionlearning_EDP_SRC')]
dfdsf0531 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_perfectionlearning_enrollments')]
dfdsf0532 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_perfectionlearning_orgs')]
dfdsf0533 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_perfectionlearning_terms')]
dfdsf0534 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_perfectionlearning_users')]
dfdsf0535 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_waterford_classes')]
dfdsf0536 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_waterford_EDP_SRC')]
dfdsf0537 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_waterford_enrollments')]
dfdsf0538 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_waterford_GSDR_SRC')]
dfdsf0539 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_waterford_orgs')]
dfdsf0540 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_waterford_terms')]
dfdsf0541 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'edp_validation_waterford_users')]
dfdsf0542 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'Membership')]
dfdsf0543 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'Membership_Delta')]
dfdsf0544 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'PortalResourceGroupings')]
dfdsf0545 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'PortalResourceMappings')]
dfdsf0546 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'PortalResources')]
dfdsf0547 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'PortalResourceUsage')]
dfdsf0548 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'REF_Config')]
dfdsf0549 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'REF_ConnectEd_Resources')]
dfdsf0550 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'REF_Employee_Provisioning')]
dfdsf0551 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'REF_IL_Schools')]
dfdsf0552 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'REF_Notes_Users')]
dfdsf0553 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'REF_PS_Classworks_Users')]
dfdsf0554 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'REF_Schools_MDR')]
dfdsf0555 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'REF_TestCourses')]
dfdsf0556 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'ResourceUsageStudent')]
dfdsf0557 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'SASI_AMST_DUPS')]
dfdsf0558 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'Schedule')]
dfdsf0559 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'Schedule_Delta')]
dfdsf0560 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'student_ebooks_ref')]
dfdsf0561 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'TMP_Classworks_REF')]
dfdsf0562 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'TMP_Classworks_Users')]
dfdsf0563 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'Users')]
dfdsf0564 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'DigitalContent') & (df['TableName'] == 'Users_Delta')]
dfdsf0565 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'HRW') & (df['TableName'] == 'HRW_Administrator')]
dfdsf0566 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'HRW') & (df['TableName'] == 'HRW_ApplicationUserID')]
dfdsf0567 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'HRW') & (df['TableName'] == 'HRW_Class')]
dfdsf0568 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'HRW') & (df['TableName'] == 'HRW_ClassEnrollment')]
dfdsf0569 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'HRW') & (df['TableName'] == 'HRW_Classes_Bkup')]
dfdsf0570 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'HRW') & (df['TableName'] == 'HRW_ClassProducts')]
dfdsf0571 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'HRW') & (df['TableName'] == 'HRW_Error_ApplicationUserID')]
dfdsf0572 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'HRW') & (df['TableName'] == 'HRW_Error_Class')]
dfdsf0573 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'HRW') & (df['TableName'] == 'HRW_Error_ClassEnrollment')]
dfdsf0574 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'HRW') & (df['TableName'] == 'HRW_Error_ClassProducts')]
dfdsf0575 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'HRW') & (df['TableName'] == 'HRW_Error_Students')]
dfdsf0576 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'HRW') & (df['TableName'] == 'HRW_Error_Teachers')]
dfdsf0577 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'HRW') & (df['TableName'] == 'HRW_MasterClass')]
dfdsf0578 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'HRW') & (df['TableName'] == 'HRW_Students')]
dfdsf0579 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'HRW') & (df['TableName'] == 'HRW_Teachers')]
dfdsf0580 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'HRW') & (df['TableName'] == 'HRW_TextBooks')]
dfdsf0581 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'HRW') & (df['TableName'] == 'HRW_Users_Bkup')]
dfdsf0582 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'HRW') & (df['TableName'] == 'TempHRWClasses')]
dfdsf0583 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'HRW') & (df['TableName'] == 'TempHRWUsers')]
dfdsf0584 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'IEP') & (df['TableName'] == 'IEP_iep_services_Plus')]
dfdsf0585 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'NotesImport') & (df['TableName'] == 'EmployeeEmailIDSource')]
dfdsf0586 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Portal') & (df['TableName'] == 'Textbook_Manager_Staff')]
dfdsf0587 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'PS_FUTURE')]
dfdsf0588 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'E200503809') & (df['TableName'] == 'Joindata')]
dfdsf0589 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Staging') & (df['TableName'] == 'Coursefile_Concentration')]
dfdsf0590 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Staging') & (df['TableName'] == 'Coursefile_Course')]
dfdsf0591 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Staging') & (df['TableName'] == 'Coursefile_Course_Concentration')]
dfdsf0592 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Staging') & (df['TableName'] == 'Coursefile_Course_Gradebook_Template')]
dfdsf0593 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Staging') & (df['TableName'] == 'Coursefile_Course_Job_Field')]
dfdsf0594 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Staging') & (df['TableName'] == 'Coursefile_Course_School_Authorization')]
dfdsf0595 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Staging') & (df['TableName'] == 'CourseFile_Course_SPG_Growth_Percentage')]
dfdsf0596 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Staging') & (df['TableName'] == 'CourseFile_Course_SPG_Growth_Rubric')]
dfdsf0597 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Staging') & (df['TableName'] == 'Coursefile_Course_Textbook')]
dfdsf0598 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Staging') & (df['TableName'] == 'Coursefile_Course_Textbook_Manager_Department')]
dfdsf0599 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Staging') & (df['TableName'] == 'Coursefile_Gradebook_Template')]
dfdsf0600 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Staging') & (df['TableName'] == 'Coursefile_Job_Field')]
dfdsf0601 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Staging') & (df['TableName'] == 'CourseFile_Pathway')]
dfdsf0602 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Staging') & (df['TableName'] == 'Coursefile_Textbook')]
dfdsf0603 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Staging') & (df['TableName'] == 'Coursefile_Textbook_Manager_Department')]
dfdsf0604 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'StagingNext') & (df['TableName'] == 'Coursefile_Course')]
dfdsf0605 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'StagingNext') & (df['TableName'] == 'Coursefile_Course_Gradebook_Template')]
dfdsf0606 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'StagingNext') & (df['TableName'] == 'Coursefile_Course_Job_Field')]
dfdsf0607 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'StagingNext') & (df['TableName'] == 'Coursefile_Course_School_Authorization')]
dfdsf0608 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'StagingNext') & (df['TableName'] == 'CourseFile_Course_SPG_Growth_Percentage')]
dfdsf0609 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'StagingNext') & (df['TableName'] == 'CourseFile_Course_SPG_Growth_Rubric')]
dfdsf0610 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'StagingNext') & (df['TableName'] == 'Coursefile_Course_Textbook')]
dfdsf0611 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'StagingNext') & (df['TableName'] == 'Coursefile_Course_Textbook_Manager_Department')]
dfdsf0612 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'StagingNext') & (df['TableName'] == 'Coursefile_Gradebook_Template')]
dfdsf0613 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'StagingNext') & (df['TableName'] == 'Coursefile_Job_Field')]
dfdsf0614 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'StagingNext') & (df['TableName'] == 'Coursefile_Pathway')]
dfdsf0615 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'StagingNext') & (df['TableName'] == 'Coursefile_Textbook')]
dfdsf0616 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'StagingNext') & (df['TableName'] == 'Coursefile_Textbook_Manager_Department')]
dfdsf0617 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Survey') & (df['TableName'] == 'EEP_Community_Engagement_Stage')]
dfdsf0618 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Survey') & (df['TableName'] == 'EEP_Educational_Opportunities_Stage')]
dfdsf0619 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Survey') & (df['TableName'] == 'EEP_Facilities_Resources_Stage')]
dfdsf0620 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Survey') & (df['TableName'] == 'EEP_Human_Resources_Stage')]
dfdsf0621 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Survey') & (df['TableName'] == 'EEP_Student_Support_Stage')]
dfdsf0622 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Survey') & (df['TableName'] == 'EEP_Teaching_Learning_Stage')]
dfdsf0623 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Survey') & (df['TableName'] == 'ParentSurvey_Stage')]
dfdsf0624 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Survey') & (df['TableName'] == 'ParentSurvey_Stage_2')]
dfdsf0625 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Survey') & (df['TableName'] == 'ParentSurvey_Stage_Failed_Import_Row')]
dfdsf0626 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Survey') & (df['TableName'] == 'ParentSurvey_Student')]
dfdsf0627 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Survey') & (df['TableName'] == 'ParentSurvey_Student_1')]
dfdsf0628 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Survey') & (df['TableName'] == 'ParentSurvey_Student_2')]
dfdsf0629 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Survey') & (df['TableName'] == 'ParentSurvey_Student_Invalid_Record')]
dfdsf0630 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Survey') & (df['TableName'] == 'Spring_Preference_Acknowledgement')]
dfdsf0631 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'Survey') & (df['TableName'] == 'Spring_Preference_Acknowledgement_Stage')]
dfdsf0632 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'TestConv') & (df['TableName'] == 'TestConversion')]
dfdsf0633 = df[(df['DatabaseName'] == 'DownstreamFeeds') & (df['SchemaName'] == 'TestConv') & (df['TableName'] == 'Tests')]

# %%
d = dfdsf0001[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0001, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#       DatabaseName SchemaName                 TableName
# 0  DownstreamFeeds         AD  ADProvisioning_Employees

# %%
d = dfdsf0002[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0002, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#        DatabaseName SchemaName                TableName
# 94  DownstreamFeeds         AD  ADProvisioning_Students

# %%
d = dfdsf0003[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0003, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#         DatabaseName SchemaName       TableName
# 396  DownstreamFeeds         AD  C_ENR_TBL_GSDR

# %%
d = dfdsf0004[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0004, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#         DatabaseName SchemaName      TableName
# 490  DownstreamFeeds         AD  C_ENR_TBL_SYN

# %%
d = dfdsf0005[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0005, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName   TableName
# 11100  DownstreamFeeds         AD  Enrollment

# %%
d = dfdsf0006[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0006, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                TableName
# 11194  DownstreamFeeds         AD  Enrollment_2019622_before_summer_change

# %%
d = dfdsf0007[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0007, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName         TableName
# 11288  DownstreamFeeds         AD  Enrollment_Delta

# %%
d = dfdsf0008[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0008, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName           TableName
# 11382  DownstreamFeeds         AD  Enrollment_EOY1415

# %%
d = dfdsf0009[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0009, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName       TableName
# 20320  DownstreamFeeds         AD  REF_ProcessLog

# %%
d = dfdsf0010[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0010, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  TableName
# 21072  DownstreamFeeds         AD  REF_Users

# %%
d = dfdsf0011[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0011, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                        TableName
# 19015  DownstreamFeeds     Cohort  ProjectedGradRateDistrictTotals

# %%
d = dfdsf0012[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0012, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName  SchemaName TableName
# 1430  DownstreamFeeds  CourseFile    Course

# %%
d = dfdsf0013[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0013, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName  SchemaName                  TableName
# 2276  DownstreamFeeds  CourseFile  Course_Gradebook_Template

# %%
d = dfdsf0014[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0014, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName  SchemaName         TableName
# 2464  DownstreamFeeds  CourseFile  Course_Job_Field

# %%
d = dfdsf0015[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0015, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName  SchemaName       TableName
# 2652  DownstreamFeeds  CourseFile  Course_Pathway

# %%
d = dfdsf0016[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0016, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName  SchemaName                    TableName
# 3216  DownstreamFeeds  CourseFile  Course_School_Authorization

# %%
d = dfdsf0017[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0017, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName  SchemaName                     TableName
# 2840  DownstreamFeeds  CourseFile  Course_SPG_Growth_Percentage

# %%
d = dfdsf0018[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0018, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName  SchemaName                 TableName
# 3028  DownstreamFeeds  CourseFile  Course_SPG_Growth_Rubric

# %%
d = dfdsf0019[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0019, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName  SchemaName        TableName
# 3498  DownstreamFeeds  CourseFile  Course_Textbook

# %%
d = dfdsf0020[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0020, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName  SchemaName                           TableName
# 3686  DownstreamFeeds  CourseFile  Course_Textbook_Manager_Department

# %%
d = dfdsf0021[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0021, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName  SchemaName           TableName
# 12322  DownstreamFeeds  CourseFile  Gradebook_Template

# %%
d = dfdsf0022[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0022, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName  SchemaName  TableName
# 14502  DownstreamFeeds  CourseFile  Job_Field

# %%
d = dfdsf0023[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0023, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName  SchemaName          TableName
# 17699  DownstreamFeeds  CourseFile  OLD_Concentration

# %%
d = dfdsf0024[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0024, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName  SchemaName                 TableName
# 17793  DownstreamFeeds  CourseFile  OLD_Course_Concentration

# %%
d = dfdsf0025[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0025, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName  SchemaName TableName
# 26451  DownstreamFeeds  CourseFile  Textbook

# %%
d = dfdsf0026[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0026, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName  SchemaName                    TableName
# 26639  DownstreamFeeds  CourseFile  Textbook_Manager_Department

# %%
d = dfdsf0027[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0027, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName      SchemaName TableName
# 1524  DownstreamFeeds  CourseFileNext    Course

# %%
d = dfdsf0028[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0028, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName      SchemaName                  TableName
# 2370  DownstreamFeeds  CourseFileNext  Course_Gradebook_Template

# %%
d = dfdsf0029[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0029, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName      SchemaName         TableName
# 2558  DownstreamFeeds  CourseFileNext  Course_Job_Field

# %%
d = dfdsf0030[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0030, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName      SchemaName       TableName
# 2746  DownstreamFeeds  CourseFileNext  Course_Pathway

# %%
d = dfdsf0031[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0031, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName      SchemaName                    TableName
# 3310  DownstreamFeeds  CourseFileNext  Course_School_Authorization

# %%
d = dfdsf0032[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0032, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName      SchemaName                         TableName
# 3404  DownstreamFeeds  CourseFileNext  Course_School_Authorization_Temp

# %%
d = dfdsf0033[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0033, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName      SchemaName                     TableName
# 2934  DownstreamFeeds  CourseFileNext  Course_SPG_Growth_Percentage

# %%
d = dfdsf0034[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0034, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName      SchemaName                 TableName
# 3122  DownstreamFeeds  CourseFileNext  Course_SPG_Growth_Rubric

# %%
d = dfdsf0035[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0035, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName      SchemaName        TableName
# 3592  DownstreamFeeds  CourseFileNext  Course_Textbook

# %%
d = dfdsf0036[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0036, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName      SchemaName                           TableName
# 3780  DownstreamFeeds  CourseFileNext  Course_Textbook_Manager_Department

# %%
d = dfdsf0037[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0037, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName           TableName
# 12416  DownstreamFeeds  CourseFileNext  Gradebook_Template

# %%
d = dfdsf0038[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0038, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName  TableName
# 14596  DownstreamFeeds  CourseFileNext  Job_Field

# %%
d = dfdsf0039[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0039, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName TableName
# 26545  DownstreamFeeds  CourseFileNext  Textbook

# %%
d = dfdsf0040[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0040, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                    TableName
# 26733  DownstreamFeeds  CourseFileNext  Textbook_Manager_Department

# %%
d = dfdsf0041[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0041, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#         DatabaseName SchemaName        TableName
# 584  DownstreamFeeds     Cworks  ClassworksClass

# %%
d = dfdsf0042[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0042, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName            TableName
# 29553  DownstreamFeeds     Cworks  classworksclass_TMP

# %%
d = dfdsf0043[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0043, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#         DatabaseName SchemaName              TableName
# 678  DownstreamFeeds     Cworks  ClassworksClassSummer

# %%
d = dfdsf0044[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0044, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#         DatabaseName SchemaName               TableName
# 772  DownstreamFeeds     Cworks  ClassworksSummerEmpSeq

# %%
d = dfdsf0045[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0045, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#         DatabaseName SchemaName          TableName
# 866  DownstreamFeeds     Cworks  ClassworksTSTList

# %%
d = dfdsf0046[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0046, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#         DatabaseName SchemaName         TableName
# 960  DownstreamFeeds     Cworks  ClassworksUpdate

# %%
d = dfdsf0047[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0047, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName       TableName
# 1054  DownstreamFeeds     Cworks  ClassworksUser

# %%
d = dfdsf0048[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0048, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName           TableName
# 29647  DownstreamFeeds     Cworks  classworksuser_TMP

# %%
d = dfdsf0049[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0049, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                 TableName
# 1148  DownstreamFeeds     Cworks  ClassworksUserAdditional

# %%
d = dfdsf0050[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0050, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName             TableName
# 1242  DownstreamFeeds     Cworks  ClassworksUserSummer

# %%
d = dfdsf0051[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0051, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName               TableName
# 6224  DownstreamFeeds        d2l  D2L_NON_TEACHING_STAFF

# %%
d = dfdsf0052[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0052, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                       TableName
# 30023  DownstreamFeeds        d2l  d2l_reporting_AllSchools_Usage

# %%
d = dfdsf0053[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0053, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  \
# 30117  DownstreamFeeds        d2l
#
#                                           TableName
# 30117  d2l_reporting_AllSchools_Usage_BKUP_20160817

# %%
d = dfdsf0054[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0054, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  \
# 30211  DownstreamFeeds        d2l
#
#                                           TableName
# 30211  d2l_reporting_AllSchools_Usage_BKUP_20170731

# %%
d = dfdsf0055[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0055, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                       TableName
# 30305  DownstreamFeeds        d2l  d2l_reporting_OrgRoleCrosswalk

# %%
d = dfdsf0056[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0056, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                       TableName
# 30399  DownstreamFeeds        d2l  d2l_reporting_SchoolPopulation

# %%
d = dfdsf0057[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0057, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  \
# 30775  DownstreamFeeds        d2l
#
#                                           TableName
# 30775  d2l_reporting_SchoolPopulation_BKUP_20160817

# %%
d = dfdsf0058[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0058, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  \
# 30869  DownstreamFeeds        d2l
#
#                                           TableName
# 30869  d2l_reporting_SchoolPopulation_BKUP_20170731

# %%
d = dfdsf0059[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0059, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                          TableName
# 30493  DownstreamFeeds        d2l  d2l_reporting_SchoolPopulationDtl

# %%
d = dfdsf0060[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0060, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  \
# 30587  DownstreamFeeds        d2l
#
#                                              TableName
# 30587  d2l_reporting_SchoolPopulationDtl_BKUP_20160817

# %%
d = dfdsf0061[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0061, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  \
# 30681  DownstreamFeeds        d2l
#
#                                              TableName
# 30681  d2l_reporting_SchoolPopulationDtl_BKUP_20170731

# %%
d = dfdsf0062[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0062, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                      TableName
# 29929  DownstreamFeeds        d2l  d2l_Reporting_TeacherSchedule

# %%
d = dfdsf0063[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0063, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName            TableName
# 30963  DownstreamFeeds        d2l  d2l_reporting_Usage

# %%
d = dfdsf0064[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0064, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                          TableName
# 31527  DownstreamFeeds        d2l  d2l_reporting_Usage_BKUP_20160817

# %%
d = dfdsf0065[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0065, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                          TableName
# 31621  DownstreamFeeds        d2l  d2l_reporting_Usage_BKUP_20170731

# %%
d = dfdsf0066[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0066, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                TableName
# 31715  DownstreamFeeds        d2l  d2l_reporting_Usage_DLD

# %%
d = dfdsf0067[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0067, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName               TableName
# 31057  DownstreamFeeds        d2l  d2l_reporting_UsageDtl

# %%
d = dfdsf0068[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0068, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                        TableName
# 31151  DownstreamFeeds        d2l  d2l_reporting_UsageDtl_20180221

# %%
d = dfdsf0069[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0069, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                             TableName
# 31245  DownstreamFeeds        d2l  d2l_reporting_UsageDtl_BKUP_20160817

# %%
d = dfdsf0070[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0070, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                             TableName
# 31339  DownstreamFeeds        d2l  d2l_reporting_UsageDtl_BKUP_20170731

# %%
d = dfdsf0071[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0071, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                             TableName
# 31433  DownstreamFeeds        d2l  d2l_reporting_UsageDtl_BKUP_20180123

# %%
d = dfdsf0072[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0072, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName           TableName
# 7903  DownstreamFeeds        d2l  EARLY_PROVISIONING

# %%
d = dfdsf0073[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0073, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName   TableName
# 11758  DownstreamFeeds        d2l  GOC_Master

# %%
d = dfdsf0074[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0074, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName         TableName
# 11852  DownstreamFeeds        d2l  GOC_Master_Delta

# %%
d = dfdsf0075[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0075, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                 TableName
# 34227  DownstreamFeeds        d2l  import_ads_goc_AllGrades

# %%
d = dfdsf0076[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0076, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                    TableName
# 34321  DownstreamFeeds        d2l  import_ads_goc_AwardsIssued

# %%
d = dfdsf0077[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0077, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName            TableName
# 34415  DownstreamFeeds        d2l  import_ads_goc_CLOE

# %%
d = dfdsf0078[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0078, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                 TableName
# 34509  DownstreamFeeds        d2l  import_ads_goc_EnrollmentsandWithdrawals

# %%
d = dfdsf0079[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0079, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                   TableName
# 34603  DownstreamFeeds        d2l  import_ads_goc_FinalGrades

# %%
d = dfdsf0080[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0080, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                  TableName
# 34697  DownstreamFeeds        d2l  import_ads_goc_ImpersonatedSessionHistory

# %%
d = dfdsf0081[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0081, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                       TableName
# 34791  DownstreamFeeds        d2l  import_ads_goc_InstructorUsage

# %%
d = dfdsf0082[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0082, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                    TableName
# 34885  DownstreamFeeds        d2l  import_ads_goc_LearnerUsage

# %%
d = dfdsf0083[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0083, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                          TableName
# 34979  DownstreamFeeds        d2l  import_bds_ActivityFeedCommentLog

# %%
d = dfdsf0084[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0084, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                       TableName
# 35073  DownstreamFeeds        d2l  import_bds_ActivityFeedPostLog

# %%
d = dfdsf0085[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0085, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                 TableName
# 35167  DownstreamFeeds        d2l  import_bds_Announcements

# %%
d = dfdsf0086[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0086, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                           TableName
# 35261  DownstreamFeeds        d2l  import_bds_AssignmentSpecialAccess

# %%
d = dfdsf0087[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0087, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                               TableName
# 35340  DownstreamFeeds        d2l  import_bds_AssignmentSubmissionDetails

# %%
d = dfdsf0088[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0088, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                         TableName
# 35434  DownstreamFeeds        d2l  import_bds_AssignmentSubmissions

# %%
d = dfdsf0089[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0089, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                     TableName
# 35528  DownstreamFeeds        d2l  import_bds_AssignmentSummary

# %%
d = dfdsf0090[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0090, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                TableName
# 35622  DownstreamFeeds        d2l  import_bds_AwardObjects

# %%
d = dfdsf0091[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0091, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                TableName
# 35716  DownstreamFeeds        d2l  import_bds_AwardsIssued

# %%
d = dfdsf0092[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0092, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                  TableName
# 35810  DownstreamFeeds        d2l  import_bds_CalendarEvents

# %%
d = dfdsf0093[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0093, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                            TableName
# 35904  DownstreamFeeds        d2l  import_bds_ChecklistCategoryDetails

# %%
d = dfdsf0094[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0094, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                        TableName
# 35998  DownstreamFeeds        d2l  import_bds_ChecklistCompletions

# %%
d = dfdsf0095[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0095, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                        TableName
# 36092  DownstreamFeeds        d2l  import_bds_ChecklistItemDetails

# %%
d = dfdsf0096[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0096, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                    TableName
# 36186  DownstreamFeeds        d2l  import_bds_ChecklistObjects

# %%
d = dfdsf0097[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0097, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                  TableName
# 36280  DownstreamFeeds        d2l  import_bds_ContentObjects

# %%
d = dfdsf0098[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0098, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                         TableName
# 36374  DownstreamFeeds        d2l  import_bds_ContentUserCompletion

# %%
d = dfdsf0099[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0099, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                       TableName
# 36468  DownstreamFeeds        d2l  import_bds_ContentUserProgress

# %%
d = dfdsf0100[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0100, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                TableName
# 36562  DownstreamFeeds        d2l  import_bds_CourseAccess

# %%
d = dfdsf0101[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0101, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                TableName
# 36656  DownstreamFeeds        d2l  import_bds_CourseAwards

# %%
d = dfdsf0102[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0102, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                  TableName
# 36750  DownstreamFeeds        d2l  import_bds_CourseCopyLogs

# %%
d = dfdsf0103[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0103, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                    TableName
# 36844  DownstreamFeeds        d2l  import_bds_DiscussionForums

# %%
d = dfdsf0104[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0104, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                   TableName
# 36938  DownstreamFeeds        d2l  import_bds_DiscussionPosts

# %%
d = dfdsf0105[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0105, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                             TableName
# 37032  DownstreamFeeds        d2l  import_bds_DiscussionPostsReadStatus

# %%
d = dfdsf0106[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0106, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                    TableName
# 37220  DownstreamFeeds        d2l  import_bds_DiscussionTopics

# %%
d = dfdsf0107[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0107, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                             TableName
# 37126  DownstreamFeeds        d2l  import_bds_DiscussionTopicUserScores

# %%
d = dfdsf0108[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0108, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                             TableName
# 37314  DownstreamFeeds        d2l  import_bds_EnrollmentsandWithdrawals

# %%
d = dfdsf0109[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0109, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                             TableName
# 42767  DownstreamFeeds        d2l  import_bds_goc_ActivityExemptionsLog

# %%
d = dfdsf0110[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0110, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                              TableName
# 42861  DownstreamFeeds        d2l  import_bds_goc_ActivityFeedCommentLog

# %%
d = dfdsf0111[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0111, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                           TableName
# 42955  DownstreamFeeds        d2l  import_bds_goc_ActivityFeedPostLog

# %%
d = dfdsf0112[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0112, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                     TableName
# 43049  DownstreamFeeds        d2l  import_bds_goc_Announcements

# %%
d = dfdsf0113[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0113, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                               TableName
# 43143  DownstreamFeeds        d2l  import_bds_goc_AssignmentSpecialAccess

# %%
d = dfdsf0114[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0114, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                   TableName
# 43223  DownstreamFeeds        d2l  import_bds_goc_AssignmentSubmissionDetails

# %%
d = dfdsf0115[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0115, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                             TableName
# 43317  DownstreamFeeds        d2l  import_bds_goc_AssignmentSubmissions

# %%
d = dfdsf0116[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0116, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                         TableName
# 43411  DownstreamFeeds        d2l  import_bds_goc_AssignmentSummary

# %%
d = dfdsf0117[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0117, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                         TableName
# 43505  DownstreamFeeds        d2l  import_bds_goc_AttendanceDetails

# %%
d = dfdsf0118[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0118, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                           TableName
# 43599  DownstreamFeeds        d2l  import_bds_goc_AttendanceRegisters

# %%
d = dfdsf0119[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0119, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                         TableName
# 43693  DownstreamFeeds        d2l  import_bds_goc_AttendanceSchemes

# %%
d = dfdsf0120[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0120, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                          TableName
# 43787  DownstreamFeeds        d2l  import_bds_goc_AttendanceSessions

# %%
d = dfdsf0121[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0121, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                         TableName
# 43881  DownstreamFeeds        d2l  import_bds_goc_AttendanceSummary

# %%
d = dfdsf0122[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0122, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                              TableName
# 43975  DownstreamFeeds        d2l  import_bds_goc_AttendanceUserSessions

# %%
d = dfdsf0123[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0123, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                    TableName
# 44069  DownstreamFeeds        d2l  import_bds_goc_AwardObjects

# %%
d = dfdsf0124[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0124, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                    TableName
# 44163  DownstreamFeeds        d2l  import_bds_goc_AwardsIssued

# %%
d = dfdsf0125[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0125, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                      TableName
# 44257  DownstreamFeeds        d2l  import_bds_goc_CalendarEvents

# %%
d = dfdsf0126[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0126, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                   TableName
# 44351  DownstreamFeeds        d2l  import_bds_goc_ChatObjects

# %%
d = dfdsf0127[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0127, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                      TableName
# 44445  DownstreamFeeds        d2l  import_bds_goc_ChatSessionLog

# %%
d = dfdsf0128[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0128, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                TableName
# 44539  DownstreamFeeds        d2l  import_bds_goc_ChecklistCategoryDetails

# %%
d = dfdsf0129[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0129, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                            TableName
# 44633  DownstreamFeeds        d2l  import_bds_goc_ChecklistCompletions

# %%
d = dfdsf0130[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0130, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                            TableName
# 44727  DownstreamFeeds        d2l  import_bds_goc_ChecklistItemDetails

# %%
d = dfdsf0131[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0131, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                        TableName
# 44821  DownstreamFeeds        d2l  import_bds_goc_ChecklistObjects

# %%
d = dfdsf0132[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0132, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                            TableName
# 44915  DownstreamFeeds        d2l  import_bds_goc_CompetencyActivities

# %%
d = dfdsf0133[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0133, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                             TableName
# 45009  DownstreamFeeds        d2l  import_bds_goc_CompetencyActivityLog

# %%
d = dfdsf0134[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0134, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                 TableName
# 45103  DownstreamFeeds        d2l  import_bds_goc_CompetencyActivityResults

# %%
d = dfdsf0135[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0135, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                     TableName
# 45197  DownstreamFeeds        d2l  import_bds_goc_CompetencyLog

# %%
d = dfdsf0136[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0136, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                         TableName
# 45291  DownstreamFeeds        d2l  import_bds_goc_CompetencyObjects

# %%
d = dfdsf0137[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0137, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                           TableName
# 45385  DownstreamFeeds        d2l  import_bds_goc_CompetencyStructure

# %%
d = dfdsf0138[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0138, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                      TableName
# 45479  DownstreamFeeds        d2l  import_bds_goc_ContentObjects

# %%
d = dfdsf0139[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0139, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                             TableName
# 45573  DownstreamFeeds        d2l  import_bds_goc_ContentUserCompletion

# %%
d = dfdsf0140[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0140, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                           TableName
# 45667  DownstreamFeeds        d2l  import_bds_goc_ContentUserProgress

# %%
d = dfdsf0141[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0141, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                    TableName
# 45761  DownstreamFeeds        d2l  import_bds_goc_CourseAccess

# %%
d = dfdsf0142[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0142, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                    TableName
# 45855  DownstreamFeeds        d2l  import_bds_goc_CourseAwards

# %%
d = dfdsf0143[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0143, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                      TableName
# 45949  DownstreamFeeds        d2l  import_bds_goc_CourseCopyLogs

# %%
d = dfdsf0144[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0144, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                        TableName
# 46043  DownstreamFeeds        d2l  import_bds_goc_DiscussionForums

# %%
d = dfdsf0145[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0145, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                       TableName
# 46137  DownstreamFeeds        d2l  import_bds_goc_DiscussionPosts

# %%
d = dfdsf0146[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0146, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                 TableName
# 46231  DownstreamFeeds        d2l  import_bds_goc_DiscussionPostsReadStatus

# %%
d = dfdsf0147[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0147, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                        TableName
# 46419  DownstreamFeeds        d2l  import_bds_goc_DiscussionTopics

# %%
d = dfdsf0148[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0148, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                 TableName
# 46325  DownstreamFeeds        d2l  import_bds_goc_DiscussionTopicUserScores

# %%
d = dfdsf0149[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0149, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                 TableName
# 46513  DownstreamFeeds        d2l  import_bds_goc_EnrollmentsandWithdrawals

# %%
d = dfdsf0150[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0150, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                         TableName
# 47079  DownstreamFeeds        d2l  import_bds_goc_GradebookSettings

# %%
d = dfdsf0151[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0151, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                    TableName
# 46607  DownstreamFeeds        d2l  import_bds_goc_GradeObjects

# %%
d = dfdsf0152[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0152, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                       TableName
# 46701  DownstreamFeeds        d2l  import_bds_goc_GradeObjectsLog

# %%
d = dfdsf0153[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0153, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                            TableName
# 46795  DownstreamFeeds        d2l  import_bds_goc_GradeObjectsLog_temp

# %%
d = dfdsf0154[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0154, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                    TableName
# 46796  DownstreamFeeds        d2l  import_bds_goc_GradeResults

# %%
d = dfdsf0155[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0155, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                         TableName
# 46890  DownstreamFeeds        d2l  import_bds_goc_GradeResults_temp

# %%
d = dfdsf0156[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0156, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                         TableName
# 46891  DownstreamFeeds        d2l  import_bds_goc_GradeSchemeRanges

# %%
d = dfdsf0157[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0157, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                    TableName
# 46985  DownstreamFeeds        d2l  import_bds_goc_GradeSchemes

# %%
d = dfdsf0158[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0158, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                               TableName
# 47173  DownstreamFeeds        d2l  import_bds_goc_IntelligentAgentObjects

# %%
d = dfdsf0159[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0159, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                              TableName
# 47267  DownstreamFeeds        d2l  import_bds_goc_IntelligentAgentRunLog

# %%
d = dfdsf0160[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0160, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                            TableName
# 47455  DownstreamFeeds        d2l  import_bds_goc_IntelligentAgentRuns

# %%
d = dfdsf0161[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0161, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                TableName
# 47361  DownstreamFeeds        d2l  import_bds_goc_IntelligentAgentRunUsers

# %%
d = dfdsf0162[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0162, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                TableName
# 47549  DownstreamFeeds        d2l  import_bds_goc_LTILinks

# %%
d = dfdsf0163[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0163, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                      TableName
# 47643  DownstreamFeeds        d2l  import_bds_goc_LTILinksShared

# %%
d = dfdsf0164[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0164, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                   TableName
# 47831  DownstreamFeeds        d2l  import_bds_goc_OrganizationalUnitAncestors

# %%
d = dfdsf0165[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0165, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  \
# 47925  DownstreamFeeds        d2l
#
#                                           TableName
# 47925  import_bds_goc_OrganizationalUnitDescendants

# %%
d = dfdsf0166[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0166, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                 TableName
# 48019  DownstreamFeeds        d2l  import_bds_goc_OrganizationalUnitParents

# %%
d = dfdsf0167[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0167, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  \
# 48113  DownstreamFeeds        d2l
#
#                                            TableName
# 48113  import_bds_goc_OrganizationalUnitRecentAccess

# %%
d = dfdsf0168[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0168, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                           TableName
# 48207  DownstreamFeeds        d2l  import_bds_goc_OrganizationalUnits

# %%
d = dfdsf0169[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0169, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                      TableName
# 47737  DownstreamFeeds        d2l  import_bds_goc_OrgUnitParents

# %%
d = dfdsf0170[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0170, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                           TableName
# 48301  DownstreamFeeds        d2l  import_bds_goc_PortfolioCategories

# %%
d = dfdsf0171[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0171, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                   TableName
# 48395  DownstreamFeeds        d2l  import_bds_goc_PortfolioEvidenceCategories

# %%
d = dfdsf0172[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0172, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                            TableName
# 48489  DownstreamFeeds        d2l  import_bds_goc_PortfolioEvidenceLog

# %%
d = dfdsf0173[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0173, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                TableName
# 48583  DownstreamFeeds        d2l  import_bds_goc_PortfolioEvidenceObjects

# %%
d = dfdsf0174[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0174, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                 TableName
# 48677  DownstreamFeeds        d2l  import_bds_goc_PreRequisiteConditionsMet

# %%
d = dfdsf0175[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0175, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                       TableName
# 48771  DownstreamFeeds        d2l  import_bds_goc_QuestionLibrary

# %%
d = dfdsf0176[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0176, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                             TableName
# 48865  DownstreamFeeds        d2l  import_bds_goc_QuestionRelationships

# %%
d = dfdsf0177[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0177, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                   TableName
# 49806  DownstreamFeeds        d2l  import_bds_goc_QuizandSurveySectionObjects

# %%
d = dfdsf0178[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0178, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                    TableName
# 48959  DownstreamFeeds        d2l  import_bds_goc_QuizAttempts

# %%
d = dfdsf0179[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0179, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                       TableName
# 49053  DownstreamFeeds        d2l  import_bds_goc_QuizAttemptsLog

# %%
d = dfdsf0180[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0180, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                            TableName
# 49147  DownstreamFeeds        d2l  import_bds_goc_QuizAttemptsLog_temp

# %%
d = dfdsf0181[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0181, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                   TableName
# 49148  DownstreamFeeds        d2l  import_bds_goc_QuizObjects

# %%
d = dfdsf0182[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0182, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                 TableName
# 49242  DownstreamFeeds        d2l  import_bds_goc_QuizQuestionAnswerOptions

# %%
d = dfdsf0183[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0183, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                           TableName
# 49336  DownstreamFeeds        d2l  import_bds_goc_QuizQuestionAnswers

# %%
d = dfdsf0184[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0184, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                     TableName
# 49430  DownstreamFeeds        d2l  import_bds_goc_QuizQuestions

# %%
d = dfdsf0185[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0185, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                          TableName
# 49524  DownstreamFeeds        d2l  import_bds_goc_QuizSurveySections

# %%
d = dfdsf0186[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0186, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                               TableName
# 49618  DownstreamFeeds        d2l  import_bds_goc_QuizUserAnswerResponses

# %%
d = dfdsf0187[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0187, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                       TableName
# 49712  DownstreamFeeds        d2l  import_bds_goc_QuizUserAnswers

# %%
d = dfdsf0188[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0188, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                               TableName
# 49900  DownstreamFeeds        d2l  import_bds_goc_ReleaseConditionObjects

# %%
d = dfdsf0189[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0189, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                               TableName
# 49994  DownstreamFeeds        d2l  import_bds_goc_ReleaseConditionResults

# %%
d = dfdsf0190[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0190, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                   TableName
# 50088  DownstreamFeeds        d2l  import_bds_goc_RoleDetails

# %%
d = dfdsf0191[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0191, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                        TableName
# 50182  DownstreamFeeds        d2l  import_bds_goc_RubricAssessment

# %%
d = dfdsf0192[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0192, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                TableName
# 50276  DownstreamFeeds        d2l  import_bds_goc_RubricAssessmentCriteria

# %%
d = dfdsf0193[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0193, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                            TableName
# 50370  DownstreamFeeds        d2l  import_bds_goc_RubricCriteriaLevels

# %%
d = dfdsf0194[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0194, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                            TableName
# 50464  DownstreamFeeds        d2l  import_bds_goc_RubricObjectCriteria

# %%
d = dfdsf0195[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0195, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                          TableName
# 50558  DownstreamFeeds        d2l  import_bds_goc_RubricObjectLevels

# %%
d = dfdsf0196[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0196, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                     TableName
# 50652  DownstreamFeeds        d2l  import_bds_goc_RubricObjects

# %%
d = dfdsf0197[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0197, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                      TableName
# 50746  DownstreamFeeds        d2l  import_bds_goc_SessionHistory

# %%
d = dfdsf0198[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0198, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                      TableName
# 50840  DownstreamFeeds        d2l  import_bds_goc_SurveyAttempts

# %%
d = dfdsf0199[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0199, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                   TableName
# 50934  DownstreamFeeds        d2l  import_bds_goc_SurveyQuestionAnswerOptions

# %%
d = dfdsf0200[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0100, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                             TableName
# 51028  DownstreamFeeds        d2l  import_bds_goc_SurveyQuestionAnswers

# %%
d = dfdsf0201[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0201, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                       TableName
# 51122  DownstreamFeeds        d2l  import_bds_goc_SurveyQuestions

# %%
d = dfdsf0202[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0202, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                 TableName
# 51216  DownstreamFeeds        d2l  import_bds_goc_SurveyUserAnswerResponses

# %%
d = dfdsf0203[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0203, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                         TableName
# 51310  DownstreamFeeds        d2l  import_bds_goc_SurveyUserAnswers

# %%
d = dfdsf0204[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0204, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                       TableName
# 51404  DownstreamFeeds        d2l  import_bds_goc_SystemAccessLog

# %%
d = dfdsf0205[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0205, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                            TableName
# 51498  DownstreamFeeds        d2l  import_bds_goc_SystemAccessLog_temp

# %%
d = dfdsf0206[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0206, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName             TableName
# 51499  DownstreamFeeds        d2l  import_bds_goc_Tools

# %%
d = dfdsf0207[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0207, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                           TableName
# 51593  DownstreamFeeds        d2l  import_bds_goc_TurnItInSubmissions

# %%
d = dfdsf0208[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0208, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                       TableName
# 51687  DownstreamFeeds        d2l  import_bds_goc_UserEnrollments

# %%
d = dfdsf0209[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0209, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                  TableName
# 51781  DownstreamFeeds        d2l  import_bds_goc_UserLogins

# %%
d = dfdsf0210[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0210, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                       TableName
# 51875  DownstreamFeeds        d2l  import_bds_goc_UserLogins_temp

# %%
d = dfdsf0211[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0211, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName             TableName
# 51876  DownstreamFeeds        d2l  import_bds_goc_Users

# %%
d = dfdsf0212[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0212, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                     TableName
# 37878  DownstreamFeeds        d2l  import_bds_GradebookSettings

# %%
d = dfdsf0213[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0213, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                TableName
# 37408  DownstreamFeeds        d2l  import_bds_GradeObjects

# %%
d = dfdsf0214[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0214, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                   TableName
# 37502  DownstreamFeeds        d2l  import_bds_GradeObjectsLog

# %%
d = dfdsf0215[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0215, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                TableName
# 37596  DownstreamFeeds        d2l  import_bds_GradeResults

# %%
d = dfdsf0216[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0216, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                     TableName
# 37690  DownstreamFeeds        d2l  import_bds_GradeSchemeRanges

# %%
d = dfdsf0217[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0217, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                TableName
# 37784  DownstreamFeeds        d2l  import_bds_GradeSchemes

# %%
d = dfdsf0218[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0218, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                           TableName
# 37972  DownstreamFeeds        d2l  import_bds_IntelligentAgentObjects

# %%
d = dfdsf0219[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0219, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                          TableName
# 38066  DownstreamFeeds        d2l  import_bds_IntelligentAgentRunLog

# %%
d = dfdsf0220[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0220, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                        TableName
# 38254  DownstreamFeeds        d2l  import_bds_IntelligentAgentRuns

# %%
d = dfdsf0221[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0221, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                            TableName
# 38160  DownstreamFeeds        d2l  import_bds_IntelligentAgentRunUsers

# %%
d = dfdsf0222[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0222, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName               TableName
# 38348  DownstreamFeeds        d2l  import_bds_LTILaunches

# %%
d = dfdsf0223[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0223, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                    TableName
# 38442  DownstreamFeeds        d2l  import_bds_LTILaunches_temp

# %%
d = dfdsf0224[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0224, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName            TableName
# 38443  DownstreamFeeds        d2l  import_bds_LTILinks

# %%
d = dfdsf0225[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0225, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                  TableName
# 38537  DownstreamFeeds        d2l  import_bds_LTILinksShared

# %%
d = dfdsf0226[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0226, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                               TableName
# 38725  DownstreamFeeds        d2l  import_bds_OrganizationalUnitAncestors

# %%
d = dfdsf0227[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0227, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                 TableName
# 38819  DownstreamFeeds        d2l  import_bds_OrganizationalUnitDescendants

# %%
d = dfdsf0228[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0228, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                             TableName
# 38913  DownstreamFeeds        d2l  import_bds_OrganizationalUnitParents

# %%
d = dfdsf0229[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0229, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                  TableName
# 39007  DownstreamFeeds        d2l  import_bds_OrganizationalUnitRecentAccess

# %%
d = dfdsf0230[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0230, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                       TableName
# 39101  DownstreamFeeds        d2l  import_bds_OrganizationalUnits

# %%
d = dfdsf0231[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0231, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                  TableName
# 38631  DownstreamFeeds        d2l  import_bds_OrgUnitParents

# %%
d = dfdsf0232[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0232, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                       TableName
# 39195  DownstreamFeeds        d2l  import_bds_PortfolioCategories

# %%
d = dfdsf0233[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0233, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                               TableName
# 39289  DownstreamFeeds        d2l  import_bds_PortfolioEvidenceCategories

# %%
d = dfdsf0234[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0234, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                        TableName
# 39383  DownstreamFeeds        d2l  import_bds_PortfolioEvidenceLog

# %%
d = dfdsf0235[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0235, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                            TableName
# 39477  DownstreamFeeds        d2l  import_bds_PortfolioEvidenceObjects

# %%
d = dfdsf0236[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0236, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                             TableName
# 39571  DownstreamFeeds        d2l  import_bds_PreRequisiteConditionsMet

# %%
d = dfdsf0237[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0237, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                   TableName
# 39665  DownstreamFeeds        d2l  import_bds_QuestionLibrary

# %%
d = dfdsf0238[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0238, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                         TableName
# 39759  DownstreamFeeds        d2l  import_bds_QuestionRelationships

# %%
d = dfdsf0239[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0239, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                               TableName
# 40699  DownstreamFeeds        d2l  import_bds_QuizandSurveySectionObjects

# %%
d = dfdsf0240[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0240, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                TableName
# 39853  DownstreamFeeds        d2l  import_bds_QuizAttempts

# %%
d = dfdsf0241[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0241, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                   TableName
# 39947  DownstreamFeeds        d2l  import_bds_QuizAttemptsLog

# %%
d = dfdsf0242[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0242, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName               TableName
# 40041  DownstreamFeeds        d2l  import_bds_QuizObjects

# %%
d = dfdsf0243[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0243, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                             TableName
# 40135  DownstreamFeeds        d2l  import_bds_QuizQuestionAnswerOptions

# %%
d = dfdsf0244[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0244, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                       TableName
# 40229  DownstreamFeeds        d2l  import_bds_QuizQuestionAnswers

# %%
d = dfdsf0245[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0245, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                 TableName
# 40323  DownstreamFeeds        d2l  import_bds_QuizQuestions

# %%
d = dfdsf0246[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0246, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                      TableName
# 40417  DownstreamFeeds        d2l  import_bds_QuizSurveySections

# %%
d = dfdsf0247[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0247, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                           TableName
# 40511  DownstreamFeeds        d2l  import_bds_QuizUserAnswerResponses

# %%
d = dfdsf0248[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0248, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                   TableName
# 40605  DownstreamFeeds        d2l  import_bds_QuizUserAnswers

# %%
d = dfdsf0249[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0249, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                           TableName
# 40793  DownstreamFeeds        d2l  import_bds_ReleaseConditionObjects

# %%
d = dfdsf0250[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0250, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                           TableName
# 40887  DownstreamFeeds        d2l  import_bds_ReleaseConditionResults

# %%
d = dfdsf0251[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0251, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName               TableName
# 40981  DownstreamFeeds        d2l  import_bds_RoleDetails

# %%
d = dfdsf0252[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0252, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                    TableName
# 41075  DownstreamFeeds        d2l  import_bds_RubricAssessment

# %%
d = dfdsf0253[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0253, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                            TableName
# 41169  DownstreamFeeds        d2l  import_bds_RubricAssessmentCriteria

# %%
d = dfdsf0254[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0254, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                        TableName
# 41263  DownstreamFeeds        d2l  import_bds_RubricCriteriaLevels

# %%
d = dfdsf0255[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0255, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                        TableName
# 41357  DownstreamFeeds        d2l  import_bds_RubricObjectCriteria

# %%
d = dfdsf0256[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0256, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                      TableName
# 41451  DownstreamFeeds        d2l  import_bds_RubricObjectLevels

# %%
d = dfdsf0257[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0257, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                 TableName
# 41545  DownstreamFeeds        d2l  import_bds_RubricObjects

# %%
d = dfdsf0258[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0258, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                  TableName
# 41639  DownstreamFeeds        d2l  import_bds_SessionHistory

# %%
d = dfdsf0259[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0259, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                  TableName
# 41733  DownstreamFeeds        d2l  import_bds_SurveyAttempts

# %%
d = dfdsf0260[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0260, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                               TableName
# 41827  DownstreamFeeds        d2l  import_bds_SurveyQuestionAnswerOptions

# %%
d = dfdsf0261[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0261, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                         TableName
# 41921  DownstreamFeeds        d2l  import_bds_SurveyQuestionAnswers

# %%
d = dfdsf0262[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0262, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                   TableName
# 42015  DownstreamFeeds        d2l  import_bds_SurveyQuestions

# %%
d = dfdsf0263[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0263, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                             TableName
# 42109  DownstreamFeeds        d2l  import_bds_SurveyUserAnswerResponses

# %%
d = dfdsf0264[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0264, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                     TableName
# 42203  DownstreamFeeds        d2l  import_bds_SurveyUserAnswers

# %%
d = dfdsf0265[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0265, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                   TableName
# 42297  DownstreamFeeds        d2l  import_bds_SystemAccessLog

# %%
d = dfdsf0266[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0266, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName         TableName
# 42391  DownstreamFeeds        d2l  import_bds_Tools

# %%
d = dfdsf0267[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0267, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                   TableName
# 42485  DownstreamFeeds        d2l  import_bds_UserEnrollments

# %%
d = dfdsf0268[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0268, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName              TableName
# 42579  DownstreamFeeds        d2l  import_bds_UserLogins

# %%
d = dfdsf0269[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0269, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName         TableName
# 42673  DownstreamFeeds        d2l  import_bds_Users

# %%
d = dfdsf0270[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0270, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                  TableName
# 51970  DownstreamFeeds        d2l  import_course_enrollments

# %%
d = dfdsf0271[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0271, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                TableName
# 52064  DownstreamFeeds        d2l  import_course_offerings

# %%
d = dfdsf0272[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0272, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName        TableName
# 52158  DownstreamFeeds        d2l  import_orgUnits

# %%
d = dfdsf0273[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0273, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                     TableName
# 52252  DownstreamFeeds        d2l  import_qa_course_enrollments

# %%
d = dfdsf0274[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0274, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                          TableName
# 52346  DownstreamFeeds        d2l  import_qa_course_enrollments_temp

# %%
d = dfdsf0275[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0275, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                   TableName
# 52440  DownstreamFeeds        d2l  import_qa_course_offerings

# %%
d = dfdsf0276[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0276, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                        TableName
# 52534  DownstreamFeeds        d2l  import_qa_course_offerings_temp

# %%
d = dfdsf0277[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0277, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName           TableName
# 52628  DownstreamFeeds        d2l  import_qa_orgUnits

# %%
d = dfdsf0278[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0278, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                TableName
# 52722  DownstreamFeeds        d2l  import_qa_orgUnits_temp

# %%
d = dfdsf0279[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0279, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                     TableName
# 52816  DownstreamFeeds        d2l  import_qa_school_enrollments

# %%
d = dfdsf0280[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0280, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                    TableName
# 52910  DownstreamFeeds        d2l  import_qa_section_classlist

# %%
d = dfdsf0281[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0281, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName        TableName
# 53004  DownstreamFeeds        d2l  import_qa_users

# %%
d = dfdsf0282[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0282, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                  TableName
# 53098  DownstreamFeeds        d2l  import_school_enrollments

# %%
d = dfdsf0283[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0283, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                 TableName
# 53192  DownstreamFeeds        d2l  import_section_classlist

# %%
d = dfdsf0284[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0284, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName     TableName
# 53286  DownstreamFeeds        d2l  import_users

# %%
d = dfdsf0285[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0285, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName          TableName
# 53380  DownstreamFeeds        d2l  import_users_temp

# %%
d = dfdsf0286[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0286, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName   TableName
# 17417  DownstreamFeeds        d2l  Membership

# %%
d = dfdsf0287[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0287, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName         TableName
# 17605  DownstreamFeeds        d2l  Membership_Delta

# %%
d = dfdsf0288[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0288, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                               TableName
# 53850  DownstreamFeeds        d2l  merge_course_qa_offerings_summary_temp

# %%
d = dfdsf0289[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0289, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                 TableName
# 53944  DownstreamFeeds        d2l  merge_qa_course_enrollments_summary_temp

# %%
d = dfdsf0290[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0290, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                       TableName
# 54038  DownstreamFeeds        d2l  merge_qa_orgUnits_summary_temp

# %%
d = dfdsf0291[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0291, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName      TableName
# 14878  DownstreamFeeds        d2l  MERGE_SUMMARY

# %%
d = dfdsf0292[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0292, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName    TableName
# 19109  DownstreamFeeds        d2l  REF_CIUsers

# %%
d = dfdsf0293[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0293, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName               TableName
# 19203  DownstreamFeeds        d2l  REF_CommCenterTeachers

# %%
d = dfdsf0294[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0294, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName   TableName
# 19391  DownstreamFeeds        d2l  REF_Config

# %%
d = dfdsf0295[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0295, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName           TableName
# 19579  DownstreamFeeds        d2l  REF_ContentCopyLog

# %%
d = dfdsf0296[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0296, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName           TableName
# 19614  DownstreamFeeds        d2l  REF_ContentCopyMap

# %%
d = dfdsf0297[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0297, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName         TableName
# 19756  DownstreamFeeds        d2l  REF_ExecJobCodes

# %%
d = dfdsf0298[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0298, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName          TableName
# 19850  DownstreamFeeds        d2l  REF_GOC_SM_Admins

# %%
d = dfdsf0299[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0299, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName        TableName
# 20038  DownstreamFeeds        d2l  REF_NonTeachers

# %%
d = dfdsf0300[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0300, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                   TableName
# 20602  DownstreamFeeds        d2l  REF_Safari_ViewPathCourses

# %%
d = dfdsf0301[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0301, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                 TableName
# 20414  DownstreamFeeds        d2l  REF_SafariAdministrators

# %%
d = dfdsf0302[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0302, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName               TableName
# 20508  DownstreamFeeds        d2l  REF_SafariGroupMembers

# %%
d = dfdsf0303[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0303, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName    TableName
# 20696  DownstreamFeeds        d2l  REF_Schools

# %%
d = dfdsf0304[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0304, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                   TableName
# 20978  DownstreamFeeds        d2l  REF_TrainingCourseTeachers

# %%
d = dfdsf0305[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0305, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName       TableName
# 21354  DownstreamFeeds        d2l  SASI_AMST_DUPS

# %%
d = dfdsf0306[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0306, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName TableName
# 22980  DownstreamFeeds        d2l  Schedule

# %%
d = dfdsf0307[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0307, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName       TableName
# 23168  DownstreamFeeds        d2l  Schedule_Delta

# %%
d = dfdsf0308[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0308, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName   TableName
# 21730  DownstreamFeeds        d2l  SM_CLASSES

# %%
d = dfdsf0309[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0309, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName          TableName
# 21824  DownstreamFeeds        d2l  SM_CLASSES_EXPORT

# %%
d = dfdsf0310[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0310, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName           TableName
# 21918  DownstreamFeeds        d2l  SM_COURSERESOURCES

# %%
d = dfdsf0311[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0311, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName   TableName
# 21979  DownstreamFeeds        d2l  SM_COURSES

# %%
d = dfdsf0312[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0312, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName          TableName
# 22040  DownstreamFeeds        d2l  SM_COURSES_EXPORT

# %%
d = dfdsf0313[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0313, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName       TableName
# 22134  DownstreamFeeds        d2l  SM_ENROLLMENTS

# %%
d = dfdsf0314[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0314, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName              TableName
# 22228  DownstreamFeeds        d2l  SM_ENROLLMENTS_EXPORT

# %%
d = dfdsf0315[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0315, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName TableName
# 22322  DownstreamFeeds        d2l   SM_ORGS

# %%
d = dfdsf0316[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0316, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName       TableName
# 22416  DownstreamFeeds        d2l  SM_ORGS_EXPORT

# %%
d = dfdsf0317[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0317, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName     TableName
# 22510  DownstreamFeeds        d2l  SM_RESOURCES

# %%
d = dfdsf0318[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0318, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName            TableName
# 22604  DownstreamFeeds        d2l  SM_RESOURCES_EXPORT

# %%
d = dfdsf0319[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0319, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName TableName
# 22698  DownstreamFeeds        d2l  SM_USERS

# %%
d = dfdsf0320[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0320, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName        TableName
# 22792  DownstreamFeeds        d2l  SM_USERS_EXPORT

# %%
d = dfdsf0321[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0321, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName               TableName
# 55103  DownstreamFeeds        d2l  tbl_RptUserEnrollments

# %%
d = dfdsf0322[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0322, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName       TableName
# 25531  DownstreamFeeds        d2l  TMP_StaffEmail

# %%
d = dfdsf0323[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0323, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName             TableName
# 25605  DownstreamFeeds        d2l  TMP_Teacher_Schedule

# %%
d = dfdsf0324[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0324, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName         TableName
# 25699  DownstreamFeeds        d2l  TMP_Usage_Tables

# %%
d = dfdsf0325[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0325, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName           TableName
# 27955  DownstreamFeeds        d2l  Usage__Assessments

# %%
d = dfdsf0326[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0326, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName        TableName
# 28049  DownstreamFeeds        d2l  Usage__Calendar

# %%
d = dfdsf0327[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0327, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName           TableName
# 28143  DownstreamFeeds        d2l  Usage__Discussions

# %%
d = dfdsf0328[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0328, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName       TableName
# 28237  DownstreamFeeds        d2l  Usage__Dropbox

# %%
d = dfdsf0329[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0329, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName      TableName
# 28331  DownstreamFeeds        d2l  Usage__Grades

# %%
d = dfdsf0330[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0330, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName    TableName
# 28425  DownstreamFeeds        d2l  Usage__News

# %%
d = dfdsf0331[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0331, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                TableName
# 28519  DownstreamFeeds        d2l  Usage__Self_Assessments

# %%
d = dfdsf0332[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0332, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName        TableName
# 28613  DownstreamFeeds        d2l  Usage__Sessions

# %%
d = dfdsf0333[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0333, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName       TableName
# 28707  DownstreamFeeds        d2l  Usage__Surveys

# %%
d = dfdsf0334[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0334, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName              TableName
# 26921  DownstreamFeeds        d2l  Usage_Assessments_OLD

# %%
d = dfdsf0335[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0335, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName           TableName
# 27015  DownstreamFeeds        d2l  Usage_Calendar_OLD

# %%
d = dfdsf0336[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0336, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                        TableName
# 27109  DownstreamFeeds        d2l  Usage_ContentDetails_Processing

# %%
d = dfdsf0337[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0337, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                         TableName
# 27203  DownstreamFeeds        d2l  Usage_ContentProgress_Processing

# %%
d = dfdsf0338[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0338, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName              TableName
# 27297  DownstreamFeeds        d2l  Usage_Discussions_OLD

# %%
d = dfdsf0339[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0339, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName          TableName
# 27391  DownstreamFeeds        d2l  Usage_Dropbox_OLD

# %%
d = dfdsf0340[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0340, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName         TableName
# 27485  DownstreamFeeds        d2l  Usage_Grades_OLD

# %%
d = dfdsf0341[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0341, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName       TableName
# 27579  DownstreamFeeds        d2l  Usage_News_OLD

# %%
d = dfdsf0342[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0342, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                   TableName
# 27673  DownstreamFeeds        d2l  Usage_Self_Assessments_OLD

# %%
d = dfdsf0343[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0343, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName       TableName
# 27767  DownstreamFeeds        d2l  Usage_Sessions

# %%
d = dfdsf0344[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0344, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName          TableName
# 27861  DownstreamFeeds        d2l  Usage_Surveys_OLD

# %%
d = dfdsf0345[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0345, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName TableName
# 28895  DownstreamFeeds        d2l     Users

# %%
d = dfdsf0346[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0346, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName    TableName
# 29083  DownstreamFeeds        d2l  Users_Delta

# %%
d = dfdsf0347[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0347, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName              TableName
# 56586  DownstreamFeeds        d2l  validation_enrollment

# %%
d = dfdsf0348[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0348, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName              TableName
# 56680  DownstreamFeeds        d2l  validation_membership

# %%
d = dfdsf0349[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0349, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                 TableName
# 56774  DownstreamFeeds        d2l  validation_qa_enrollment

# %%
d = dfdsf0350[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0350, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                 TableName
# 56868  DownstreamFeeds        d2l  validation_qa_membership

# %%
d = dfdsf0351[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0351, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName            TableName
# 56962  DownstreamFeeds        d2l  validation_qa_users

# %%
d = dfdsf0352[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0352, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName         TableName
# 57056  DownstreamFeeds        d2l  validation_users

# %%
d = dfdsf0353[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0353, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName           TableName
# 29365  DownstreamFeeds        dbo  __MigrationHistory

# %%
d = dfdsf0354[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0354, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName    TableName
# 29459  DownstreamFeeds        dbo  adFeed_temp

# %%
d = dfdsf0355[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0355, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#         DatabaseName SchemaName               TableName
# 188  DownstreamFeeds        dbo  AftSch_Profile_WorkTbl

# %%
d = dfdsf0356[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0356, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#         DatabaseName SchemaName        TableName
# 282  DownstreamFeeds        dbo  BM_EXTRACT_TEMP

# %%
d = dfdsf0357[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0357, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName    TableName
# 1336  DownstreamFeeds        dbo  ContactCode

# %%
d = dfdsf0358[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0358, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName           TableName
# 29741  DownstreamFeeds        dbo  course_departments

# %%
d = dfdsf0359[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0359, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName           TableName
# 1618  DownstreamFeeds        dbo  CourseFile_Changes

# %%
d = dfdsf0360[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0360, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                   TableName
# 2182  DownstreamFeeds        dbo  CourseFile_Pathways_Import

# %%
d = dfdsf0361[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0361, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName         TableName
# 29835  DownstreamFeeds        dbo  coursetomasterid

# %%
d = dfdsf0362[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0362, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName          TableName
# 6036  DownstreamFeeds        dbo  CoursetoMasterId2

# %%
d = dfdsf0363[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0363, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#         DatabaseName SchemaName TableName
# 302  DownstreamFeeds        dbo   CSVFILE

# %%
d = dfdsf0364[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0364, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName          TableName
# 6130  DownstreamFeeds        dbo  D2LGradebookPaths

# %%
d = dfdsf0365[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0365, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName  TableName
# 6318  DownstreamFeeds        dbo  DavidTemp

# %%
d = dfdsf0366[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0366, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName           TableName
# 6399  DownstreamFeeds        dbo  DestinySASISTAFF_P

# %%
d = dfdsf0367[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0367, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName          TableName
# 6493  DownstreamFeeds        dbo  DestinyStudentEMH

# %%
d = dfdsf0368[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0368, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName             TableName
# 6681  DownstreamFeeds        dbo  DestinyStudentEMH_TM

# %%
d = dfdsf0369[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0369, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName           TableName
# 6587  DownstreamFeeds        dbo  DestinyStudentEMH2

# %%
d = dfdsf0370[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0370, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName        TableName
# 6775  DownstreamFeeds        dbo  DestinyStudentP

# %%
d = dfdsf0371[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0371, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName         TableName
# 6869  DownstreamFeeds        dbo  DestinyStudentP2

# %%
d = dfdsf0372[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0372, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName         TableName
# 6963  DownstreamFeeds        dbo  DestinyStudentSS

# %%
d = dfdsf0373[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0373, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName            TableName
# 7057  DownstreamFeeds        dbo  DestinyTextbook_ALL

# %%
d = dfdsf0374[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0374, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName          TableName
# 7151  DownstreamFeeds        dbo  DestinyTextbook_E

# %%
d = dfdsf0375[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0375, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName           TableName
# 7245  DownstreamFeeds        dbo  DestinyTextbook_HM

# %%
d = dfdsf0376[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0376, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                TableName
# 7433  DownstreamFeeds        dbo  DestinyTextbook_HM_temp

# %%
d = dfdsf0377[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0377, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                 TableName
# 7527  DownstreamFeeds        dbo  DestinyTextbook_HM_temp2

# %%
d = dfdsf0378[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0378, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName            TableName
# 7339  DownstreamFeeds        dbo  DestinyTextbook_HME

# %%
d = dfdsf0379[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0379, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName           TableName
# 7621  DownstreamFeeds        dbo  DestinyTextbook_SS

# %%
d = dfdsf0380[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0380, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                    TableName
# 7715  DownstreamFeeds        dbo  DigitalContent_Schedule_REF

# %%
d = dfdsf0381[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0381, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName    TableName
# 7809  DownstreamFeeds        dbo  DuplPermnum

# %%
d = dfdsf0382[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0382, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                  TableName
# 9314  DownstreamFeeds        dbo  EdCloud_Import_BM_EXTRACT

# %%
d = dfdsf0383[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0383, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                      TableName
# 9408  DownstreamFeeds        dbo  EdCloud_Import_BM_EXTRACT_SRC

# %%
d = dfdsf0384[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0384, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                             TableName
# 9502  DownstreamFeeds        dbo  EdCloud_Import_BM_STUDENTS_NO_SCORES

# %%
d = dfdsf0385[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0385, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                     TableName
# 9596  DownstreamFeeds        dbo  EdCloud_Import_BM_TI_EXTRACT

# %%
d = dfdsf0386[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0386, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName              TableName
# 9690  DownstreamFeeds        dbo  EdCloud_Import_BM_TPP

# %%
d = dfdsf0387[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0387, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                TableName
# 9784  DownstreamFeeds        dbo  EdCloud_Master_Schedule

# %%
d = dfdsf0388[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0388, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName              TableName
# 9878  DownstreamFeeds        dbo  EdCloud_REF_BM_Config

# %%
d = dfdsf0389[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0389, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                                  TableName
# 9972  DownstreamFeeds        dbo  EdCloud_REF_SchoolNet_CentralOfficeGroups

# %%
d = dfdsf0390[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0390, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                        TableName
# 10066  DownstreamFeeds        dbo  EdCloud_REF_SchoolNet_StaffCode

# %%
d = dfdsf0391[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0391, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                       TableName
# 10160  DownstreamFeeds        dbo  EdCloud_REF_SuccessNet_Courses

# %%
d = dfdsf0392[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0392, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                           TableName
# 10254  DownstreamFeeds        dbo  EdCloud_REF_SuccessNet_TestCourses

# %%
d = dfdsf0393[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0393, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                     TableName
# 10348  DownstreamFeeds        dbo  EdCloud_REF_SuccessNet_Users

# %%
d = dfdsf0394[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0394, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                 TableName
# 10442  DownstreamFeeds        dbo  EdCloud_REF_TestStudents

# %%
d = dfdsf0395[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0395, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName               TableName
# 10536  DownstreamFeeds        dbo  EdCloud_SASI_AMST_DUPS

# %%
d = dfdsf0396[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0396, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName      TableName
# 10630  DownstreamFeeds        dbo  EdCloud_Staff

# %%
d = dfdsf0397[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0397, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName               TableName
# 10724  DownstreamFeeds        dbo  EdCloud_Staff_Schedule

# %%
d = dfdsf0398[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0398, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName         TableName
# 10818  DownstreamFeeds        dbo  EdCloud_Students

# %%
d = dfdsf0399[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0399, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                  TableName
# 10912  DownstreamFeeds        dbo  EdCloud_Students_Schedule

# %%
d = dfdsf0400[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0400, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName        TableName
# 8468  DownstreamFeeds        dbo  ELEM_ASTU_AENRC

# %%
d = dfdsf0401[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0401, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName              TableName
# 33663  DownstreamFeeds        dbo  es_course_departments

# %%
d = dfdsf0402[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0402, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName               TableName
# 8562  DownstreamFeeds        dbo  ES_Course_depts2011_12

# %%
d = dfdsf0403[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0403, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName               TableName
# 8656  DownstreamFeeds        dbo  ES_Course_depts2012-13

# %%
d = dfdsf0404[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0404, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName    TableName
# 8750  DownstreamFeeds        dbo  EXP_REG_STU

# %%
d = dfdsf0405[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0405, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName        TableName
# 8844  DownstreamFeeds        dbo  EXP_REG_STU_EMH

# %%
d = dfdsf0406[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0406, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName         TableName
# 8938  DownstreamFeeds        dbo  EXP_REG_STU_GSDR

# %%
d = dfdsf0407[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0407, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName             TableName
# 33757  DownstreamFeeds        dbo  exp_reg_stu_GSDR_EMH

# %%
d = dfdsf0408[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0408, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName             TableName
# 9126  DownstreamFeeds        dbo  EXP_REG_STU_gsdrZone

# %%
d = dfdsf0409[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0409, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName         TableName
# 9032  DownstreamFeeds        dbo  EXP_REG_STU_Zone

# %%
d = dfdsf0410[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0410, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName    TableName
# 9220  DownstreamFeeds        dbo  EXP_REG_SUM

# %%
d = dfdsf0411[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0411, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName        TableName
# 34133  DownstreamFeeds        dbo  exp_regsum_GSDR

# %%
d = dfdsf0412[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0412, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName           TableName
# 33851  DownstreamFeeds        dbo  exp_regsumGSDR_EMH

# %%
d = dfdsf0413[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0413, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                 TableName
# 33945  DownstreamFeeds        dbo  exp_regsumGSDR_EMH_Mar02

# %%
d = dfdsf0414[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0414, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName             TableName
# 34039  DownstreamFeeds        dbo  exp_regsumGSDR_Zoned

# %%
d = dfdsf0415[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0415, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName           TableName
# 11476  DownstreamFeeds        dbo  ExpandedCourseFile

# %%
d = dfdsf0416[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0416, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                              TableName
# 11664  DownstreamFeeds        dbo  Fall 2018 Grade Conversion 2018-08-27

# %%
d = dfdsf0417[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0417, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName TableName
# 11570  DownstreamFeeds        dbo  FLATFILE

# %%
d = dfdsf0418[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0418, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName TableName
# 12228  DownstreamFeeds        dbo    G_GTID

# %%
d = dfdsf0419[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0419, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName      TableName
# 11946  DownstreamFeeds        dbo  GPLDaily_GSDR

# %%
d = dfdsf0420[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0420, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName       TableName
# 12040  DownstreamFeeds        dbo  GSDR_ASTU_CURR

# %%
d = dfdsf0421[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0421, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                TableName
# 12134  DownstreamFeeds        dbo  GSDR_ASTU_CURR_20151217

# %%
d = dfdsf0422[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0422, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName               TableName
# 14108  DownstreamFeeds        dbo  HS_Course_Depts2011-12

# %%
d = dfdsf0423[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0423, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName               TableName
# 14202  DownstreamFeeds        dbo  HS_Course_depts2012-13

# %%
d = dfdsf0424[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0424, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName TableName
# 14314  DownstreamFeeds        dbo    Import

# %%
d = dfdsf0425[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0425, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName           TableName
# 53474  DownstreamFeeds        dbo  jean2DestinySchool

# %%
d = dfdsf0426[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0426, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName            TableName
# 53568  DownstreamFeeds        dbo  jeanDESTINY_SCHOOLS

# %%
d = dfdsf0427[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0427, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                  TableName
# 14408  DownstreamFeeds        dbo  JMS112017_exp_regsum_GSDR

# %%
d = dfdsf0428[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0428, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName TableName
# 14784  DownstreamFeeds        dbo   LoadTbl

# %%
d = dfdsf0429[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0429, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  \
# 15161  DownstreamFeeds        dbo
#
#                                             TableName
# 15161  Mapnet_AftSch_Student_Data_Full_Intermediate_A

# %%
d = dfdsf0430[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0430, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  \
# 15255  DownstreamFeeds        dbo
#
#                                                TableName
# 15255  Mapnet_AftSch_Student_Data_Full_Intermediate_A...

# %%
d = dfdsf0431[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0431, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  \
# 15349  DownstreamFeeds        dbo
#
#                                             TableName
# 15349  Mapnet_AftSch_Student_Data_Full_Intermediate_B

# %%
d = dfdsf0432[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0432, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                               TableName
# 15443  DownstreamFeeds        dbo  Mapnet_AftSch_Student_Data_Full_Result

# %%
d = dfdsf0433[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0433, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  \
# 15537  DownstreamFeeds        dbo
#
#                                                TableName
# 15537  Mapnet_Dups_From_Mapnet_AftSch_Student_Data_Fu...

# %%
d = dfdsf0434[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0434, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  \
# 15631  DownstreamFeeds        dbo
#
#                                               TableName
# 15631  Mapnet_Dups_From_Mapnet_Student_Data_Full_Result

# %%
d = dfdsf0435[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0435, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  \
# 15725  DownstreamFeeds        dbo
#
#                                           TableName
# 15725  Mapnet_Emergency_Contact_Data_Intermediate_A

# %%
d = dfdsf0436[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0436, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  \
# 15819  DownstreamFeeds        dbo
#
#                                           TableName
# 15819  Mapnet_Emergency_Contact_Data_Intermediate_B

# %%
d = dfdsf0437[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0437, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  \
# 15913  DownstreamFeeds        dbo
#
#                                           TableName
# 15913  Mapnet_Emergency_Contact_Data_Intermediate_C

# %%
d = dfdsf0438[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0438, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                             TableName
# 16007  DownstreamFeeds        dbo  Mapnet_Emergency_Contact_Data_Result

# %%
d = dfdsf0439[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0439, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                 TableName
# 53662  DownstreamFeeds        dbo  mapnet_jeantest_student_data_full_result

# %%
d = dfdsf0440[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0440, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  \
# 16101  DownstreamFeeds        dbo
#
#                                           TableName
# 16101  Mapnet_NEXT_Student_Data_Full_Intermediate_A

# %%
d = dfdsf0441[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0441, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  \
# 16195  DownstreamFeeds        dbo
#
#                                           TableName
# 16195  Mapnet_NEXT_Student_Data_Full_Intermediate_B

# %%
d = dfdsf0442[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0442, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                  TableName
# 16289  DownstreamFeeds        dbo  Mapnet_NEXT_Year_Student_Data_Full_Result

# %%
d = dfdsf0443[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0443, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                          TableName
# 16383  DownstreamFeeds        dbo  Mapnet_Parent_Data_Intermediate_A

# %%
d = dfdsf0444[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0444, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                          TableName
# 16477  DownstreamFeeds        dbo  Mapnet_Parent_Data_Intermediate_B

# %%
d = dfdsf0445[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0445, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                          TableName
# 16571  DownstreamFeeds        dbo  Mapnet_Parent_Data_Intermediate_C

# %%
d = dfdsf0446[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0446, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                  TableName
# 16665  DownstreamFeeds        dbo  Mapnet_Parent_Data_Result

# %%
d = dfdsf0447[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0447, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  \
# 16759  DownstreamFeeds        dbo
#
#                                               TableName
# 16759  Mapnet_Planning_Student_Data_Full_Intermediate_A

# %%
d = dfdsf0448[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0448, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  \
# 16853  DownstreamFeeds        dbo
#
#                                               TableName
# 16853  Mapnet_Planning_Student_Data_Full_Intermediate_B

# %%
d = dfdsf0449[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0449, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                 TableName
# 16947  DownstreamFeeds        dbo  Mapnet_Planning_Student_Data_Full_Result

# %%
d = dfdsf0450[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0450, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                TableName
# 17041  DownstreamFeeds        dbo  Mapnet_Student_Data_Full_Intermediate_A

# %%
d = dfdsf0451[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0451, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                TableName
# 17135  DownstreamFeeds        dbo  Mapnet_Student_Data_Full_Intermediate_B

# %%
d = dfdsf0452[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0452, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                        TableName
# 17229  DownstreamFeeds        dbo  Mapnet_Student_Data_Full_Result

# %%
d = dfdsf0453[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0453, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName    TableName
# 53756  DownstreamFeeds        dbo  members_tmp

# %%
d = dfdsf0454[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0454, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName              TableName
# 54132  DownstreamFeeds        dbo  ms_course_departments

# %%
d = dfdsf0455[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0455, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName               TableName
# 14879  DownstreamFeeds        dbo  MS_Course_Depts2011_12

# %%
d = dfdsf0456[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0456, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                 TableName
# 14973  DownstreamFeeds        dbo  MS_Course_Depts2011_12_A

# %%
d = dfdsf0457[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0457, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName               TableName
# 15067  DownstreamFeeds        dbo  MS_Course_Depts2012-13

# %%
d = dfdsf0458[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0458, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                       TableName
# 54226  DownstreamFeeds        dbo  ref_digitalcontent_gradelevels

# %%
d = dfdsf0459[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0459, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                 TableName
# 54320  DownstreamFeeds        dbo  ref_digitalcontent_hours

# %%
d = dfdsf0460[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0460, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                    TableName
# 54414  DownstreamFeeds        dbo  ref_digitalcontent_subjects

# %%
d = dfdsf0461[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0461, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName TableName
# 54508  DownstreamFeeds        dbo  saveeoct

# %%
d = dfdsf0462[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0462, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                 TableName
# 23262  DownstreamFeeds        dbo  SchoolFoodNutritionDaily

# %%
d = dfdsf0463[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0463, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                      TableName
# 23356  DownstreamFeeds        dbo  SchoolFoodNutritionDaily_GSDR

# %%
d = dfdsf0464[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0464, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                             TableName
# 23450  DownstreamFeeds        dbo  SchoolFoodNutritionDaily_GSDR_Backup

# %%
d = dfdsf0465[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0465, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                           TableName
# 23544  DownstreamFeeds        dbo  SchoolFoodNutritionDaily_GSDR_Temp

# %%
d = dfdsf0466[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0466, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                      TableName
# 23638  DownstreamFeeds        dbo  SchoolFoodNutritionDaily_test

# %%
d = dfdsf0467[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0467, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName             TableName
# 23732  DownstreamFeeds        dbo  SchoolRoster_Changes

# %%
d = dfdsf0468[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0468, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName        TableName
# 21448  DownstreamFeeds        dbo  SFNTeacherDaily

# %%
d = dfdsf0469[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0469, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName               TableName
# 21636  DownstreamFeeds        dbo  SFNTeacherDaily_Backup

# %%
d = dfdsf0470[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0470, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName         TableName
# 21542  DownstreamFeeds        dbo  SFNTeacherDaily2

# %%
d = dfdsf0471[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0471, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName             TableName
# 24014  DownstreamFeeds        dbo  Spring_Survey_Detail

# %%
d = dfdsf0472[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0472, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName            TableName
# 24090  DownstreamFeeds        dbo  Staff_Email_Address

# %%
d = dfdsf0473[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0473, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName TableName
# 54633  DownstreamFeeds        dbo  stusched

# %%
d = dfdsf0474[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0474, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  TableName
# 54727  DownstreamFeeds        dbo  stusched2

# %%
d = dfdsf0475[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0475, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName      TableName
# 54821  DownstreamFeeds        dbo  surveymatched

# %%
d = dfdsf0476[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0476, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName    TableName
# 54915  DownstreamFeeds        dbo  sysdiagrams

# %%
d = dfdsf0477[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0477, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName TableName
# 55009  DownstreamFeeds        dbo  tb_Diffs

# %%
d = dfdsf0478[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0478, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName     TableName
# 56043  DownstreamFeeds        dbo  temp_alttran

# %%
d = dfdsf0479[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0479, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  TableName
# 56137  DownstreamFeeds        dbo  temp_astp

# %%
d = dfdsf0480[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0480, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName    TableName
# 24466  DownstreamFeeds        dbo  TEMP_CENSUS

# %%
d = dfdsf0481[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0481, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName    TableName
# 55197  DownstreamFeeds        dbo  temp_Gender

# %%
d = dfdsf0482[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0482, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                 TableName
# 55291  DownstreamFeeds        dbo  temp_GiftedParticipation

# %%
d = dfdsf0483[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0483, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  TableName
# 55385  DownstreamFeeds        dbo  temp_Hull

# %%
d = dfdsf0484[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0484, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName TableName
# 55479  DownstreamFeeds        dbo  temp_IEP

# %%
d = dfdsf0485[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0485, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                TableName
# 55573  DownstreamFeeds        dbo  temp_MapnetStudent_Next

# %%
d = dfdsf0486[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0486, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName              TableName
# 56231  DownstreamFeeds        dbo  temp_noDupl_sasi_acrs

# %%
d = dfdsf0487[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0487, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName          TableName
# 24560  DownstreamFeeds        dbo  TEMP_RIDER_BY_BUS

# %%
d = dfdsf0488[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0488, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName      TableName
# 24654  DownstreamFeeds        dbo  TEMP_TEST_TBL

# %%
d = dfdsf0489[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0489, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName          TableName
# 55667  DownstreamFeeds        dbo  temp_TestGateFeed

# %%
d = dfdsf0490[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0490, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName        TableName
# 55761  DownstreamFeeds        dbo  temp_TierAttend

# %%
d = dfdsf0491[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0491, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName         TableName
# 55855  DownstreamFeeds        dbo  temp_TierAttnStu

# %%
d = dfdsf0492[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0492, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  TableName
# 55949  DownstreamFeeds        dbo  temp_UATR

# %%
d = dfdsf0493[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0493, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName   TableName
# 24748  DownstreamFeeds        dbo  TEMP_USERS

# %%
d = dfdsf0494[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0494, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName       TableName
# 24184  DownstreamFeeds        dbo  TEMPSCHNUMDIFF

# %%
d = dfdsf0495[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0495, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName        TableName
# 24278  DownstreamFeeds        dbo  TEMPSCHNUMDIFF2

# %%
d = dfdsf0496[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0496, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName          TableName
# 24372  DownstreamFeeds        dbo  TEMPSPEDNotInSASI

# %%
d = dfdsf0497[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0497, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName      TableName
# 25981  DownstreamFeeds        dbo  TempStuDetail

# %%
d = dfdsf0498[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0498, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName      TableName
# 56419  DownstreamFeeds        dbo  test_elements

# %%
d = dfdsf0499[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0499, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName         TableName
# 24842  DownstreamFeeds        dbo  TEST_STU_ACT_RAJ

# %%
d = dfdsf0500[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0400, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName         TableName
# 24936  DownstreamFeeds        dbo  TEST_STU_HGT_RAJ

# %%
d = dfdsf0501[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0501, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName              TableName
# 25030  DownstreamFeeds        dbo  TEST_TAPE_ECT_MARSHAL

# %%
d = dfdsf0502[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0502, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName TableName
# 56325  DownstreamFeeds        dbo  testConv

# %%
d = dfdsf0503[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0503, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName    TableName
# 26169  DownstreamFeeds        dbo  TestGateNew

# %%
d = dfdsf0504[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0504, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName    TableName
# 26263  DownstreamFeeds        dbo  TestGateOld

# %%
d = dfdsf0505[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0505, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName    TableName
# 25124  DownstreamFeeds        dbo  TMP_AD_DATA

# %%
d = dfdsf0506[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0506, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName           TableName
# 25385  DownstreamFeeds        dbo  TMP_STU_EMAIL_GSDR

# %%
d = dfdsf0507[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0507, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName          TableName
# 25458  DownstreamFeeds        dbo  TMP_STU_EMAIL_SYN

# %%
d = dfdsf0508[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0508, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName TableName
# 25532  DownstreamFeeds        dbo   TMP_TBL

# %%
d = dfdsf0509[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0509, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName     TableName
# 56513  DownstreamFeeds        dbo  tmp_test_tbl

# %%
d = dfdsf0510[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0510, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName            TableName
# 29271  DownstreamFeeds        dbo  Vendor_Master_class

# %%
d = dfdsf0511[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0511, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName        TableName
# 29177  DownstreamFeeds        dbo  VendorFeedCheck

# %%
d = dfdsf0512[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0512, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName     TableName
# 31809  DownstreamFeeds  DigitalContent  dc_resources

# %%
d = dfdsf0513[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0513, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                   TableName
# 32057  DownstreamFeeds  DigitalContent  edp_validation_dbq_classes

# %%
d = dfdsf0514[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0514, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                              TableName
# 31840  DownstreamFeeds  DigitalContent  edp_validation_dbq_DigitalContent_SRC

# %%
d = dfdsf0515[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0515, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                   TableName
# 31869  DownstreamFeeds  DigitalContent  edp_validation_dbq_EDP_SRC

# %%
d = dfdsf0516[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0516, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                       TableName
# 32151  DownstreamFeeds  DigitalContent  edp_validation_dbq_enrollments

# %%
d = dfdsf0517[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0517, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                    TableName
# 31963  DownstreamFeeds  DigitalContent  edp_validation_dbq_GSDR_SRC

# %%
d = dfdsf0518[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0518, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                TableName
# 32245  DownstreamFeeds  DigitalContent  edp_validation_dbq_orgs

# %%
d = dfdsf0519[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0519, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                 TableName
# 32339  DownstreamFeeds  DigitalContent  edp_validation_dbq_terms

# %%
d = dfdsf0520[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0520, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                 TableName
# 32433  DownstreamFeeds  DigitalContent  edp_validation_dbq_users

# %%
d = dfdsf0521[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0521, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                          TableName
# 32581  DownstreamFeeds  DigitalContent  edp_validation_gibbssmith_classes

# %%
d = dfdsf0522[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0522, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName  \
# 32527  DownstreamFeeds  DigitalContent
#
#                                           TableName
# 32527  edp_validation_gibbssmith_DigitalContent_SRC

# %%
d = dfdsf0523[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0523, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                          TableName
# 32554  DownstreamFeeds  DigitalContent  edp_validation_gibbssmith_EDP_SRC

# %%
d = dfdsf0524[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0524, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                              TableName
# 32611  DownstreamFeeds  DigitalContent  edp_validation_gibbssmith_enrollments

# %%
d = dfdsf0525[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0525, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                       TableName
# 32640  DownstreamFeeds  DigitalContent  edp_validation_gibbssmith_orgs

# %%
d = dfdsf0526[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0526, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                        TableName
# 32669  DownstreamFeeds  DigitalContent  edp_validation_gibbssmith_terms

# %%
d = dfdsf0527[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0527, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                        TableName
# 32698  DownstreamFeeds  DigitalContent  edp_validation_gibbssmith_users

# %%
d = dfdsf0528[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0528, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName  \
# 32785  DownstreamFeeds  DigitalContent
#
#                                        TableName
# 32785  edp_validation_perfectionlearning_classes

# %%
d = dfdsf0529[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0529, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName  \
# 32727  DownstreamFeeds  DigitalContent
#
#                                                TableName
# 32727  edp_validation_perfectionlearning_DigitalConte...

# %%
d = dfdsf0530[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0530, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName  \
# 32756  DownstreamFeeds  DigitalContent
#
#                                        TableName
# 32756  edp_validation_perfectionlearning_EDP_SRC

# %%
d = dfdsf0531[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0531, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName  \
# 32829  DownstreamFeeds  DigitalContent
#
#                                            TableName
# 32829  edp_validation_perfectionlearning_enrollments

# %%
d = dfdsf0532[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0532, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                               TableName
# 32873  DownstreamFeeds  DigitalContent  edp_validation_perfectionlearning_orgs

# %%
d = dfdsf0533[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0533, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName  \
# 32917  DownstreamFeeds  DigitalContent
#
#                                      TableName
# 32917  edp_validation_perfectionlearning_terms

# %%
d = dfdsf0534[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0534, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName  \
# 32961  DownstreamFeeds  DigitalContent
#
#                                      TableName
# 32961  edp_validation_perfectionlearning_users

# %%
d = dfdsf0535[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0535, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                         TableName
# 33193  DownstreamFeeds  DigitalContent  edp_validation_waterford_classes

# %%
d = dfdsf0536[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0536, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                         TableName
# 33005  DownstreamFeeds  DigitalContent  edp_validation_waterford_EDP_SRC

# %%
d = dfdsf0537[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0537, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                             TableName
# 33287  DownstreamFeeds  DigitalContent  edp_validation_waterford_enrollments

# %%
d = dfdsf0538[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0538, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                          TableName
# 33099  DownstreamFeeds  DigitalContent  edp_validation_waterford_GSDR_SRC

# %%
d = dfdsf0539[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0539, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                      TableName
# 33381  DownstreamFeeds  DigitalContent  edp_validation_waterford_orgs

# %%
d = dfdsf0540[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0540, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                       TableName
# 33475  DownstreamFeeds  DigitalContent  edp_validation_waterford_terms

# %%
d = dfdsf0541[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0541, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                       TableName
# 33569  DownstreamFeeds  DigitalContent  edp_validation_waterford_users

# %%
d = dfdsf0542[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0542, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName   TableName
# 17323  DownstreamFeeds  DigitalContent  Membership

# %%
d = dfdsf0543[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0543, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName         TableName
# 17511  DownstreamFeeds  DigitalContent  Membership_Delta

# %%
d = dfdsf0544[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0544, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                TableName
# 18639  DownstreamFeeds  DigitalContent  PortalResourceGroupings

# %%
d = dfdsf0545[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0545, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName               TableName
# 18733  DownstreamFeeds  DigitalContent  PortalResourceMappings

# %%
d = dfdsf0546[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0546, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName        TableName
# 18921  DownstreamFeeds  DigitalContent  PortalResources

# %%
d = dfdsf0547[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0547, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName            TableName
# 18827  DownstreamFeeds  DigitalContent  PortalResourceUsage

# %%
d = dfdsf0548[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0548, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName   TableName
# 19297  DownstreamFeeds  DigitalContent  REF_Config

# %%
d = dfdsf0549[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0549, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                TableName
# 19485  DownstreamFeeds  DigitalContent  REF_ConnectEd_Resources

# %%
d = dfdsf0550[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0550, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                  TableName
# 19662  DownstreamFeeds  DigitalContent  REF_Employee_Provisioning

# %%
d = dfdsf0551[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0551, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName       TableName
# 19944  DownstreamFeeds  DigitalContent  REF_IL_Schools

# %%
d = dfdsf0552[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0552, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName        TableName
# 20132  DownstreamFeeds  DigitalContent  REF_Notes_Users

# %%
d = dfdsf0553[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0553, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName                TableName
# 20226  DownstreamFeeds  DigitalContent  REF_PS_Classworks_Users

# %%
d = dfdsf0554[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0554, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName        TableName
# 20790  DownstreamFeeds  DigitalContent  REF_Schools_MDR

# %%
d = dfdsf0555[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0555, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName        TableName
# 20884  DownstreamFeeds  DigitalContent  REF_TestCourses

# %%
d = dfdsf0556[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0556, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName             TableName
# 21166  DownstreamFeeds  DigitalContent  ResourceUsageStudent

# %%
d = dfdsf0557[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0557, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName       TableName
# 21260  DownstreamFeeds  DigitalContent  SASI_AMST_DUPS

# %%
d = dfdsf0558[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0558, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName TableName
# 22886  DownstreamFeeds  DigitalContent  Schedule

# %%
d = dfdsf0559[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0559, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName       TableName
# 23074  DownstreamFeeds  DigitalContent  Schedule_Delta

# %%
d = dfdsf0560[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0560, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName           TableName
# 54602  DownstreamFeeds  DigitalContent  student_ebooks_ref

# %%
d = dfdsf0561[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0561, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName           TableName
# 25197  DownstreamFeeds  DigitalContent  TMP_Classworks_REF

# %%
d = dfdsf0562[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0562, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName             TableName
# 25291  DownstreamFeeds  DigitalContent  TMP_Classworks_Users

# %%
d = dfdsf0563[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0563, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName TableName
# 28801  DownstreamFeeds  DigitalContent     Users

# %%
d = dfdsf0564[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0564, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName      SchemaName    TableName
# 28989  DownstreamFeeds  DigitalContent  Users_Delta

# %%
d = dfdsf0565[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0565, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName          TableName
# 12510  DownstreamFeeds        HRW  HRW_Administrator

# %%
d = dfdsf0566[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0566, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName              TableName
# 12604  DownstreamFeeds        HRW  HRW_ApplicationUserID

# %%
d = dfdsf0567[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0567, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  TableName
# 12698  DownstreamFeeds        HRW  HRW_Class

# %%
d = dfdsf0568[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0568, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName            TableName
# 12792  DownstreamFeeds        HRW  HRW_ClassEnrollment

# %%
d = dfdsf0569[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0569, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName         TableName
# 12980  DownstreamFeeds        HRW  HRW_Classes_Bkup

# %%
d = dfdsf0570[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0570, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName          TableName
# 12886  DownstreamFeeds        HRW  HRW_ClassProducts

# %%
d = dfdsf0571[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0571, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                    TableName
# 13074  DownstreamFeeds        HRW  HRW_Error_ApplicationUserID

# %%
d = dfdsf0572[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0572, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName        TableName
# 13168  DownstreamFeeds        HRW  HRW_Error_Class

# %%
d = dfdsf0573[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0573, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                  TableName
# 13262  DownstreamFeeds        HRW  HRW_Error_ClassEnrollment

# %%
d = dfdsf0574[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0574, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                TableName
# 13356  DownstreamFeeds        HRW  HRW_Error_ClassProducts

# %%
d = dfdsf0575[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0575, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName           TableName
# 13450  DownstreamFeeds        HRW  HRW_Error_Students

# %%
d = dfdsf0576[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0576, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName           TableName
# 13544  DownstreamFeeds        HRW  HRW_Error_Teachers

# %%
d = dfdsf0577[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0577, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName        TableName
# 13638  DownstreamFeeds        HRW  HRW_MasterClass

# %%
d = dfdsf0578[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0578, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName     TableName
# 13732  DownstreamFeeds        HRW  HRW_Students

# %%
d = dfdsf0579[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0579, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName     TableName
# 13826  DownstreamFeeds        HRW  HRW_Teachers

# %%
d = dfdsf0580[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0580, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName      TableName
# 13920  DownstreamFeeds        HRW  HRW_TextBooks

# %%
d = dfdsf0581[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0581, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName       TableName
# 14014  DownstreamFeeds        HRW  HRW_Users_Bkup

# %%
d = dfdsf0582[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0582, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName       TableName
# 25793  DownstreamFeeds        HRW  TempHRWClasses

# %%
d = dfdsf0583[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0583, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName     TableName
# 25887  DownstreamFeeds        HRW  TempHRWUsers

# %%
d = dfdsf0584[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0584, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName              TableName
# 14296  DownstreamFeeds        IEP  IEP_iep_services_Plus

# %%
d = dfdsf0585[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0585, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName   SchemaName              TableName
# 11006  DownstreamFeeds  NotesImport  EmployeeEmailIDSource

# %%
d = dfdsf0586[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0586, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName               TableName
# 26827  DownstreamFeeds     Portal  Textbook_Manager_Staff

# %%
d = dfdsf0587[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0587, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName  TableName
# 17887  DownstreamFeeds        ref  PS_FUTURE

# %% [markdown]
# d = dfdsf0588[['DatabaseName', 'SchemaName','TableName']]#.format(z)
# d = d.drop_duplicates()
# e = d['DatabaseName'].values[0]
# f = d['SchemaName'].values[0]
# g = d['TableName'].values[0]
# print (d)
# FileName = ('DSF_{}_{}'.format(f,g))
#
# fig = px.scatter(dfdsf0588, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
# fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
# fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
# fig.update_xaxes(title_font=dict(size=18, color='crimson'))
# fig.update_yaxes(title_font=dict(size=18, color='crimson'))
# fig.update_xaxes(ticks="inside")
# fig.update_yaxes(ticks="inside")
# fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
# fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
# fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
# #fig.show()
# fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
# plt.close()

# %%
d = dfdsf0589[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0589, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                 TableName
# 3874  DownstreamFeeds    Staging  Coursefile_Concentration

# %%
d = dfdsf0590[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0590, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName          TableName
# 3968  DownstreamFeeds    Staging  Coursefile_Course

# %%
d = dfdsf0591[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0591, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                        TableName
# 4156  DownstreamFeeds    Staging  Coursefile_Course_Concentration

# %%
d = dfdsf0592[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0592, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                             TableName
# 4250  DownstreamFeeds    Staging  Coursefile_Course_Gradebook_Template

# %%
d = dfdsf0593[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0593, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                    TableName
# 4438  DownstreamFeeds    Staging  Coursefile_Course_Job_Field

# %%
d = dfdsf0594[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0594, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                               TableName
# 4626  DownstreamFeeds    Staging  Coursefile_Course_School_Authorization

# %%
d = dfdsf0595[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0595, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                                TableName
# 1712  DownstreamFeeds    Staging  CourseFile_Course_SPG_Growth_Percentage

# %%
d = dfdsf0596[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0596, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                            TableName
# 1900  DownstreamFeeds    Staging  CourseFile_Course_SPG_Growth_Rubric

# %%
d = dfdsf0597[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0597, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                   TableName
# 4814  DownstreamFeeds    Staging  Coursefile_Course_Textbook

# %%
d = dfdsf0598[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0598, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName  \
# 5002  DownstreamFeeds    Staging
#
#                                           TableName
# 5002  Coursefile_Course_Textbook_Manager_Department

# %%
d = dfdsf0599[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0599, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                      TableName
# 5190  DownstreamFeeds    Staging  Coursefile_Gradebook_Template

# %%
d = dfdsf0600[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0600, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName             TableName
# 5378  DownstreamFeeds    Staging  Coursefile_Job_Field

# %%
d = dfdsf0601[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0601, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName           TableName
# 2088  DownstreamFeeds    Staging  CourseFile_Pathway

# %%
d = dfdsf0602[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0602, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName            TableName
# 5660  DownstreamFeeds    Staging  Coursefile_Textbook

# %%
d = dfdsf0603[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0603, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                               TableName
# 5848  DownstreamFeeds    Staging  Coursefile_Textbook_Manager_Department

# %%
d = dfdsf0604[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0604, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName   SchemaName          TableName
# 4062  DownstreamFeeds  StagingNext  Coursefile_Course

# %%
d = dfdsf0605[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0605, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName   SchemaName                             TableName
# 4344  DownstreamFeeds  StagingNext  Coursefile_Course_Gradebook_Template

# %%
d = dfdsf0606[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0606, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName   SchemaName                    TableName
# 4532  DownstreamFeeds  StagingNext  Coursefile_Course_Job_Field

# %%
d = dfdsf0607[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0607, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName   SchemaName                               TableName
# 4720  DownstreamFeeds  StagingNext  Coursefile_Course_School_Authorization

# %%
d = dfdsf0608[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0608, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName   SchemaName                                TableName
# 1806  DownstreamFeeds  StagingNext  CourseFile_Course_SPG_Growth_Percentage

# %%
d = dfdsf0609[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0609, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName   SchemaName                            TableName
# 1994  DownstreamFeeds  StagingNext  CourseFile_Course_SPG_Growth_Rubric

# %%
d = dfdsf0610[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0610, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName   SchemaName                   TableName
# 4908  DownstreamFeeds  StagingNext  Coursefile_Course_Textbook

# %%
d = dfdsf0611[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0611, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName   SchemaName  \
# 5096  DownstreamFeeds  StagingNext
#
#                                           TableName
# 5096  Coursefile_Course_Textbook_Manager_Department

# %%
d = dfdsf0612[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0612, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName   SchemaName                      TableName
# 5284  DownstreamFeeds  StagingNext  Coursefile_Gradebook_Template

# %%
d = dfdsf0613[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0613, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName   SchemaName             TableName
# 5472  DownstreamFeeds  StagingNext  Coursefile_Job_Field

# %%
d = dfdsf0614[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0614, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName   SchemaName           TableName
# 5566  DownstreamFeeds  StagingNext  Coursefile_Pathway

# %%
d = dfdsf0615[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0615, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName   SchemaName            TableName
# 5754  DownstreamFeeds  StagingNext  Coursefile_Textbook

# %%
d = dfdsf0616[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0616, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName   SchemaName                               TableName
# 5942  DownstreamFeeds  StagingNext  Coursefile_Textbook_Manager_Department

# %%
d = dfdsf0617[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0617, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                       TableName
# 7904  DownstreamFeeds     Survey  EEP_Community_Engagement_Stage

# %%
d = dfdsf0618[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0618, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                            TableName
# 7998  DownstreamFeeds     Survey  EEP_Educational_Opportunities_Stage

# %%
d = dfdsf0619[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0619, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                       TableName
# 8092  DownstreamFeeds     Survey  EEP_Facilities_Resources_Stage

# %%
d = dfdsf0620[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0620, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                  TableName
# 8186  DownstreamFeeds     Survey  EEP_Human_Resources_Stage

# %%
d = dfdsf0621[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0621, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                  TableName
# 8280  DownstreamFeeds     Survey  EEP_Student_Support_Stage

# %%
d = dfdsf0622[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0622, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#          DatabaseName SchemaName                    TableName
# 8374  DownstreamFeeds     Survey  EEP_Teaching_Learning_Stage

# %%
d = dfdsf0623[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0623, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName           TableName
# 17981  DownstreamFeeds     Survey  ParentSurvey_Stage

# %%
d = dfdsf0624[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0624, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName             TableName
# 18075  DownstreamFeeds     Survey  ParentSurvey_Stage_2

# %%
d = dfdsf0625[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0625, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                             TableName
# 18169  DownstreamFeeds     Survey  ParentSurvey_Stage_Failed_Import_Row

# %%
d = dfdsf0626[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0626, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName             TableName
# 18263  DownstreamFeeds     Survey  ParentSurvey_Student

# %%
d = dfdsf0627[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0627, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName               TableName
# 18357  DownstreamFeeds     Survey  ParentSurvey_Student_1

# %%
d = dfdsf0628[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0628, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName               TableName
# 18451  DownstreamFeeds     Survey  ParentSurvey_Student_2

# %%
d = dfdsf0629[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0629, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                            TableName
# 18545  DownstreamFeeds     Survey  ParentSurvey_Student_Invalid_Record

# %%
d = dfdsf0630[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0630, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                          TableName
# 23826  DownstreamFeeds     Survey  Spring_Preference_Acknowledgement

# %%
d = dfdsf0631[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0631, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName                                TableName
# 23920  DownstreamFeeds     Survey  Spring_Preference_Acknowledgement_Stage

# %%
d = dfdsf0632[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0632, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName       TableName
# 26075  DownstreamFeeds   TestConv  TestConversion

# %%
d = dfdsf0633[['DatabaseName', 'SchemaName','TableName']]#.format(z)
d = d.drop_duplicates()
e = d['DatabaseName'].values[0]
f = d['SchemaName'].values[0]
g = d['TableName'].values[0]
print (d)
FileName = ('DSF_{}_{}'.format(f,g))

fig = px.scatter(dfdsf0633, x = 'TodaysDate', y='RecordCount', size = 'RecordCount', color = 'RecordCount')#.format(z)
fig.update_layout(title = '{0},{1},{2}'.format(e,f,g))
fig.update_layout(yaxis_zeroline=False, xaxis_zeroline=False)
fig.update_xaxes(title_font=dict(size=18, color='crimson'))
fig.update_yaxes(title_font=dict(size=18, color='crimson'))
fig.update_xaxes(ticks="inside")
fig.update_yaxes(ticks="inside")
fig.update_xaxes(tickangle=45, tickfont=dict(color='crimson', size=14))
fig.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Pink')
fig.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True, gridcolor='Red')
#fig.show()
fig.write_html(r'C:\Users\eeeeeeeeee\Documents\JupyterAnacondaPythonNotebooks\Daily\Charts_px\DSF\{}.html'.format(FileName))
plt.close()
# Out:
#           DatabaseName SchemaName TableName
# 26357  DownstreamFeeds   TestConv     Tests

# %%
now01 = datetime.datetime.now()
print('Interactive Chart Creation - Process Complete: ', now01.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Interactive Chart Creation - Process Complete:  2021-05-11 13:34:36
