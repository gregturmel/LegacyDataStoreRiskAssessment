# %%
#Program Name: Daily-XChart-datapane_v1_single_multi_on_assmnt
#Purpose:  Chart scatter line box aggr table data
#Author:  Greg Turmel, Director, Data Governance 
#Date:    2020.08.30 - 2021.06.30
#Errata:  0.1 Improvements can be made to script using for/looping through the databases

import os, sys, argparse, csv, pyodbc, sql, time, datetime
from datetime import datetime, timedelta
import sqlalchemy as db
from dotenv import load_dotenv # add this line
from matplotlib.backends.backend_pdf import PdfPages
import pandas as pd
import altair as alt
from altair import Chart, X, Y, Axis, SortField
from vega_datasets import data as vega_data
import datapane as dp
#import datatable as dt
import numpy as np
import matplotlib # notebook
import matplotlib.pyplot as plt
import seaborn as sns
#import chart_studio.plotly as py
import plotly.graph_objects as go
load_dotenv() # add this line
user = os.getenv('MySQLeUser')
password = os.getenv('MySQLeUserPass')
host = os.getenv('MySQLeHOST')
db = os.getenv('MySQLeDB')
# %matplotlib inline
# %load_ext sql

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=DEVODSSQL;'
                      'Database=Greg;'
                      'Trusted_Connection=yes;')

sql_query01 = pd.read_sql_query(''' 
select DISTINCT TableName
FROM [dbo].[tableRowCountAssessment]
ORDER BY TableName;     
                              '''
                              ,conn) # Load the list of distinct tables to graph

sql_query02 = pd.read_sql_query(''' 
select *
FROM [dbo].[tableRowCountAssessment]
ORDER BY TableName;     
                              '''
                              ,conn) # Load the list of distinct tables to graph

# %%
df = pd.DataFrame(sql_query02)
#df = df.astype({'TodaysDate':np.int64,'RecordCount':np.int64})
df['TodaysDate'] = pd.to_datetime(df['TodaysDate'].astype(str), format='%Y%m%d')
df = df.sort_values(by=['TableName','SchemaName','DatabaseName','TodaysDate'], ascending=[True,True,True,True])
df = df.reset_index(drop=True)

# %%
dfassmnt0001 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AA_BioChem_CRS_List')]
dfassmnt0002 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'aaaa')]
dfassmnt0003 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'aaaUpform')]
dfassmnt0004 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ACCESS_2016_2017')]
dfassmnt0005 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ACCESS_ELL_StrandPossibleScores')]
dfassmnt0006 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ACCESS_SUBTEST_DIM')]
dfassmnt0007 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ACCESS_SUBTEST_FACT')]
dfassmnt0008 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_ASSESSMENT_REPORT')]
dfassmnt0009 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_ASSESSMENT_REPORT_2')]
dfassmnt0010 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_ASSESSMENT_REPORT_240119')]
dfassmnt0011 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_ASSESSMENT_REPORT_GRD5')]
dfassmnt0012 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_ASSESSMENT_REPORT_GRD7')]
dfassmnt0013 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_ASSESSMENT_REPORT_GRD9')]
dfassmnt0014 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_ELA_AVG')]
dfassmnt0015 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_EOC_ALG1516')]
dfassmnt0016 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_EOC_ALG1617')]
dfassmnt0017 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_EOC_REPORT_1516')]
dfassmnt0018 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_EOC_REPORT_1617')]
dfassmnt0019 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_INTERIM_REPORT')]
dfassmnt0020 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_PHONE_INFO')]
dfassmnt0021 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_SAT_REPORT')]
dfassmnt0022 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_SAT_REPORT_2')]
dfassmnt0023 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_SAT_REPORT_3')]
dfassmnt0024 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_SAT_REPORT_3_WITHCONTACT')]
dfassmnt0025 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_SPECIALED_REPORT')]
dfassmnt0026 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADHOC_SPECIALED_REPORT_1718')]
dfassmnt0027 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ADMIN_TEST_DATE_DESC')]
dfassmnt0028 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Advisement')]
dfassmnt0029 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS')]
dfassmnt0030 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_20180622')]
dfassmnt0031 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_Archive')]
dfassmnt0032 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_GEMS_Comments')]
dfassmnt0033 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_GEMS_Comments_Archive')]
dfassmnt0034 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_GEMS_Review')]
dfassmnt0035 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_GEMS_Review_Archive')]
dfassmnt0036 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_GEMS_Review_BK112017')]
dfassmnt0037 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_GEMS_Schools')]
dfassmnt0038 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_Rev_Subject_Course')]
dfassmnt0039 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_Rev_Subject_Course_BKP')]
dfassmnt0040 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_Rev_Subject_Course_BKP2')]
dfassmnt0041 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_Rev_Subject_Course_BKP20150706')]
dfassmnt0042 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_Rev_Subject_Course_BKP3')]
dfassmnt0043 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_Rev_Subject_Course_T1')]
dfassmnt0044 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_Rev_Subject_Course_T1_BKP')]
dfassmnt0045 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_Rev_Subject_Course_T1_BKP2')]
dfassmnt0046 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_Rev_Subject_Course_T1_BKP20150706')]
dfassmnt0047 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AKS_Rev_Subject_Course_Temp')]
dfassmnt0048 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Analytics_Roster')]
dfassmnt0049 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AP_COURSE_TEST_MAP')]
dfassmnt0050 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'APP_CODE_COURSE')]
dfassmnt0051 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'APP_CODE_COURSE_12092019')]
dfassmnt0052 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'APP_CODE_NAME')]
dfassmnt0053 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'APP_GROUP_OLD')]
dfassmnt0054 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ARTICULATION_DATA')]
dfassmnt0055 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ACC')]
dfassmnt0056 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ACC_ALT')]
dfassmnt0057 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ACC_ALT_RAW')]
dfassmnt0058 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ACC_ALT_REP')]
dfassmnt0059 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ACC_RAW')]
dfassmnt0060 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ACC_REP')]
dfassmnt0061 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ACT')]
dfassmnt0062 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ACT_RAW')]
dfassmnt0063 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ACT_RAW_JIC')]
dfassmnt0064 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ACT_REP')]
dfassmnt0065 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_COG')]
dfassmnt0066 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_COG_BKP')]
dfassmnt0067 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_COG_RAW')]
dfassmnt0068 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_COG_RAW_BKP_II')]
dfassmnt0069 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_COG_RAW_BKP_III')]
dfassmnt0070 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_COG_REP')]
dfassmnt0071 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_COG_REP_BKP')]
dfassmnt0072 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_CRM')]
dfassmnt0073 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_CRM_RAW')]
dfassmnt0074 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_CRM_REP')]
dfassmnt0075 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_EOC')]
dfassmnt0076 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_EOC_CopyJan212020')]
dfassmnt0077 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_EOC_Jul24')]
dfassmnt0078 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_EOC_RAW')]
dfassmnt0079 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_EOC_REP')]
dfassmnt0080 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_EOG')]
dfassmnt0081 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_EOG_CopyJan212020')]
dfassmnt0082 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_EOG_RAW')]
dfassmnt0083 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_EOG_REP')]
dfassmnt0084 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_G10')]
dfassmnt0085 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_G10_RAW')]
dfassmnt0086 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_G10_RAW_BC')]
dfassmnt0087 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_G10_REP')]
dfassmnt0088 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_G10_SUM')]
dfassmnt0089 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_G10_SUM_05Aug2020')]
dfassmnt0090 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_G10_SUM_BKUP')]
dfassmnt0091 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_G10_WAIVER')]
dfassmnt0092 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_GAA')]
dfassmnt0093 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_GAA_2_0')]
dfassmnt0094 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_GAA_RAW')]
dfassmnt0095 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_GAA_RAW_2_0')]
dfassmnt0096 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_GAA_REP')]
dfassmnt0097 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SC')]
dfassmnt0098 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SC_RAW')]
dfassmnt0099 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SC_RAW_SCORES')]
dfassmnt0100 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SC_REP')]
dfassmnt0101 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SCORES_KNO_TEMP')]
dfassmnt0102 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SCORES_ORG_CON_TEMP')]
dfassmnt0103 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SCORES_SS_TEMP')]
dfassmnt0104 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SCORES_TEMP')]
dfassmnt0105 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SS')]
dfassmnt0106 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SS_286')]
dfassmnt0107 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SS_RAW')]
dfassmnt0108 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SS_RAW_SCORES')]
dfassmnt0109 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_HSGWY_SS_REP')]
dfassmnt0110 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ITB')]
dfassmnt0111 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ITB_RAW')]
dfassmnt0112 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ITB_RAW_RON')]
dfassmnt0113 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_ITB_REP')]
dfassmnt0114 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_PSAT_89')]
dfassmnt0115 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_PSAT_89_RAW')]
dfassmnt0116 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_PSAT_89_RAW_REP')]
dfassmnt0117 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_PSAT_NMSQT')]
dfassmnt0118 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_PSAT_NMSQT_RAW')]
dfassmnt0119 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_PSAT_NMSQT_RAW_REP')]
dfassmnt0120 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_SAT')]
dfassmnt0121 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_SAT_RAW')]
dfassmnt0122 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_SAT_RAW_REP')]
dfassmnt0123 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'assess_temp')]
dfassmnt0124 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_TEMP_EOG')]
dfassmnt0125 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_WR5')]
dfassmnt0126 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_WR5_RAW')]
dfassmnt0127 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_WR5_REP')]
dfassmnt0128 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_WR8')]
dfassmnt0129 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_WR8_RAW')]
dfassmnt0130 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_WR8_REP')]
dfassmnt0131 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_WRI')]
dfassmnt0132 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_WRI_RAW')]
dfassmnt0133 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESS_WRI_REP')]
dfassmnt0134 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'AssessedSubject_FromSynergy')]
dfassmnt0135 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESSMENT_APP_SECURITY_OLD')]
dfassmnt0136 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ASSESSMENT_JOB_PARM')]
dfassmnt0137 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_PP_List')]
dfassmnt0138 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report')]
dfassmnt0139 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_Avg')]
dfassmnt0140 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_HS')]
dfassmnt0141 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_MS')]
dfassmnt0142 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_MSHS')]
dfassmnt0143 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_PP')]
dfassmnt0144 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_PP_Count')]
dfassmnt0145 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_Special')]
dfassmnt0146 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_StuCls_BySch')]
dfassmnt0147 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_StuCls_BySch_MS')]
dfassmnt0148 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_StuCls_BySch_WithZero')]
dfassmnt0149 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_StuCls_Count')]
dfassmnt0150 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_StuCls_Count_HS')]
dfassmnt0151 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_StuCls_Count_MS')]
dfassmnt0152 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_StuCls_Count_WithZero')]
dfassmnt0153 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_StuCls_Summary')]
dfassmnt0154 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Report_WithZero')]
dfassmnt0155 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Totals_By_Grade')]
dfassmnt0156 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Totals_By_Grade_HS')]
dfassmnt0157 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Totals_By_Grade_MS')]
dfassmnt0158 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassSize_Totals_By_Grade_WithZero')]
dfassmnt0159 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Classworks')]
dfassmnt0160 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassworksClass')]
dfassmnt0161 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassworksExtra')]
dfassmnt0162 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassworksMaster')]
dfassmnt0163 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassworksMasterAdd')]
dfassmnt0164 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassworksMasterFile')]
dfassmnt0165 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassworksSurvey')]
dfassmnt0166 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassworksTSTList')]
dfassmnt0167 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ClassworksUpdate')]
dfassmnt0168 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CommonCoreFT_Parm')]
dfassmnt0169 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ConnectEd_GCPSAdmin')]
dfassmnt0170 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ConnectEd_Schools_old')]
dfassmnt0171 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ConnectEd_Textbooks_blah')]
dfassmnt0172 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CRCT_DATA_VIEW')]
dfassmnt0173 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CRCT_SUBTEST_MAP')]
dfassmnt0174 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CRCT_VIEW_ATTEMPT_NO')]
dfassmnt0175 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CRCT_VIEW_SCALE_SCORE')]
dfassmnt0176 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CRCTM_PREID_FILE_FROMSCH')]
dfassmnt0177 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CRCTPermnumMatch20110520')]
dfassmnt0178 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_AKSDataStage')]
dfassmnt0179 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_AKSExcelDataStage')]
dfassmnt0180 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_AKSExcelLoad')]
dfassmnt0181 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_AKSLoad')]
dfassmnt0182 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_AKSReportData')]
dfassmnt0183 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_AKSStrand')]
dfassmnt0184 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_CourseAssgnment')]
dfassmnt0185 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_CourseNos')]
dfassmnt0186 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_DataStage')]
dfassmnt0187 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_GetMasterID')]
dfassmnt0188 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_GetMatchingID')]
dfassmnt0189 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_NEnrolled')]
dfassmnt0190 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_Report_Data')]
dfassmnt0191 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_Report_Dim')]
dfassmnt0192 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_ReportData')]
dfassmnt0193 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_ReportDim')]
dfassmnt0194 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_SchoolDim')]
dfassmnt0195 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_ScrGrpExcelLoad')]
dfassmnt0196 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_ScrGrpLoad')]
dfassmnt0197 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_TestCourseNos')]
dfassmnt0198 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'CUA_TestCourseNosNew')]
dfassmnt0199 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LLogReport_Week8')]
dfassmnt0200 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LLogSummary_Week8')]
dfassmnt0201 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LPortalSpedReport')]
dfassmnt0202 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LPortalSpedSummary')]
dfassmnt0203 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LPortalUsageReport')]
dfassmnt0204 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LPortalUtizPgmLvlSummary')]
dfassmnt0205 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LPortalUtizReport')]
dfassmnt0206 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LPortalUtizSummary')]
dfassmnt0207 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LUsage')]
dfassmnt0208 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'D2LUsage_Num')]
dfassmnt0209 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_ANALYSIS_REPORT')]
dfassmnt0210 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_ANALYSIS_REPORT_FINAL')]
dfassmnt0211 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_Avg_2020')]
dfassmnt0212 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_LOWEST_THREE')]
dfassmnt0213 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_REPORT_DIM')]
dfassmnt0214 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_REPORT_DIM_2018')]
dfassmnt0215 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_REPORT_DIM_2019')]
dfassmnt0216 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_REPORT_DIM_Temp')]
dfassmnt0217 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_ScoreGroup_2018')]
dfassmnt0218 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_ScoreGroup_2019')]
dfassmnt0219 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_ScoreGroup_2020')]
dfassmnt0220 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_ScoreGroup_2020_Old')]
dfassmnt0221 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_SCOREGROUP_REPORT')]
dfassmnt0222 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_SCOREGROUP_REPORT_2018')]
dfassmnt0223 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_SCOREGROUP_REPORT_2019')]
dfassmnt0224 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_SCOREGROUP_REPORT_FINAL')]
dfassmnt0225 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_SCOREGROUP_REPORT_FINAL_2018')]
dfassmnt0226 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_SCOREGROUP_REPORT_FINAL_2019')]
dfassmnt0227 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_SCOREGROUP_REPORT_FINAL_old')]
dfassmnt0228 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_SCOREGROUP_REPORT_Old')]
dfassmnt0229 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_Standard_2018')]
dfassmnt0230 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_Standard_2019')]
dfassmnt0231 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_Standard_2020')]
dfassmnt0232 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_Standard_2020_Temp')]
dfassmnt0233 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_Standard_Items_2020')]
dfassmnt0234 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_STANDARD_REPORT')]
dfassmnt0235 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_STANDARD_REPORT_2018')]
dfassmnt0236 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_STANDARD_REPORT_2019')]
dfassmnt0237 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_STANDARD_REPORT_FINAL')]
dfassmnt0238 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_STANDARD_REPORT_FINAL_2018')]
dfassmnt0239 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_STANDARD_REPORT_FINAL_2019')]
dfassmnt0240 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_STANDARD_REPORT_FINAL_old')]
dfassmnt0241 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_AKS_TOP_THREE')]
dfassmnt0242 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_Cluster_Avg')]
dfassmnt0243 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_Cluster_Schools')]
dfassmnt0244 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_District_Avg')]
dfassmnt0245 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_PERMNUM')]
dfassmnt0246 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_REPORT_DATA')]
dfassmnt0247 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_REPORT_DATA_1st_2020')]
dfassmnt0248 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_REPORT_DATA_2nd_PreTest_2020')]
dfassmnt0249 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_REPORT_DATA_BOY_2020')]
dfassmnt0250 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_REPORT_DATA_ERIC')]
dfassmnt0251 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_REPORT_DATA_MidYear_2020')]
dfassmnt0252 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_REPORT_DIM')]
dfassmnt0253 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_REPORT_DIM_2020')]
dfassmnt0254 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_REPORT_DIM_TEMP')]
dfassmnt0255 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DA_REQUEST_GRACE')]
dfassmnt0256 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DATE_G10_TEMP')]
dfassmnt0257 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS')]
dfassmnt0258 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_ACCESS')]
dfassmnt0259 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_ACCESS_010518')]
dfassmnt0260 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_ACCESS_070119')]
dfassmnt0261 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_ACCESS_281116')]
dfassmnt0262 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_ACCESS_281117')]
dfassmnt0263 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_ACCESS_281118')]
dfassmnt0264 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_CRCT')]
dfassmnt0265 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_CRCTM')]
dfassmnt0266 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOC')]
dfassmnt0267 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOC_012517')]
dfassmnt0268 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOC_012918')]
dfassmnt0269 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOC_033018')]
dfassmnt0270 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOC_041217')]
dfassmnt0271 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOC_091918')]
dfassmnt0272 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOC_092117')]
dfassmnt0273 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOC_111518')]
dfassmnt0274 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOC_TEMP_2019')]
dfassmnt0275 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOCT')]
dfassmnt0276 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOG')]
dfassmnt0277 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOG_012918')]
dfassmnt0278 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOG_032318')]
dfassmnt0279 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOG_032417')]
dfassmnt0280 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOG_041217')]
dfassmnt0281 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_EOG_SUMMER')]
dfassmnt0282 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10')]
dfassmnt0283 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_011020')]
dfassmnt0284 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_011520')]
dfassmnt0285 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_0130')]
dfassmnt0286 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_0130,18')]
dfassmnt0287 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_020520')]
dfassmnt0288 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_021120')]
dfassmnt0289 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_022017')]
dfassmnt0290 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_RETEST')]
dfassmnt0291 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_RETEST_011020')]
dfassmnt0292 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_RETEST_020419')]
dfassmnt0293 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_RETEST_081219')]
dfassmnt0294 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_RETEST_082018')]
dfassmnt0295 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_RETEST_082317')]
dfassmnt0296 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_RETEST_111218')]
dfassmnt0297 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_G10_RETEST_111517')]
dfassmnt0298 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_GRD3RD')]
dfassmnt0299 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_HSGT')]
dfassmnt0300 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_KGARTEN')]
dfassmnt0301 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DOE_LABELS_WR58')]
dfassmnt0302 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ECT_Duplicates_ECT201206LOAD')]
dfassmnt0303 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Import_BM_EXTRACT_032519')]
dfassmnt0304 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Import_BM_EXTRACT_1st_2020')]
dfassmnt0305 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Import_BM_EXTRACT_EOY1718')]
dfassmnt0306 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Import_BM_EXTRACT_EOY1718_NUM')]
dfassmnt0307 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Import_BM_EXTRACT_EOY1819')]
dfassmnt0308 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Import_BM_EXTRACT_EOY1819_NUM')]
dfassmnt0309 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EdCloud_Import_BM_EXTRACT_Session2')]
dfassmnt0310 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOC_PRELIM_2018')]
dfassmnt0311 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOC_PRELIM_2019')]
dfassmnt0312 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOC_REQUEST')]
dfassmnt0313 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOCT_DOE_TEMP')]
dfassmnt0314 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'eoct_doe_temp2')]
dfassmnt0315 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOCT_NT')]
dfassmnt0316 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOCT_NT_TEMP')]
dfassmnt0317 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOG_PRELIM_2018')]
dfassmnt0318 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOG_PRELIM_2019')]
dfassmnt0319 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOGOnlineIndicator2018')]
dfassmnt0320 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EOGTestMode_2017')]
dfassmnt0321 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EXAM_AUX_AUTH')]
dfassmnt0322 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EXAM_AUX_LOG')]
dfassmnt0323 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EXAM_STUDENT_AUX')]
dfassmnt0324 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'EXAM_VERSIONS')]
dfassmnt0325 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'FTE_ROSTER_HGT')]
dfassmnt0326 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'g10_temp')]
dfassmnt0327 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GAA_SUBTEST_DIM')]
dfassmnt0328 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GAA_SUBTEST_FACT')]
dfassmnt0329 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GAA_SUBTEST_PERF_DIM')]
dfassmnt0330 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GATEWAY_STRAND')]
dfassmnt0331 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GATEWAY_STU_HGH')]
dfassmnt0332 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GCPS AKS Social Studies 20202021')]
dfassmnt0333 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GRADUATION_SUMMARY')]
dfassmnt0334 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GRADUATION_SUMMARY_BKUP')]
dfassmnt0335 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_2019_SS_FieldTest_RawScores')]
dfassmnt0336 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_BARCODE_FILE')]
dfassmnt0337 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_INTERVENTION')]
dfassmnt0338 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_INTERVENTION_BKUP')]
dfassmnt0339 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_INTERVENTION_FROMSYNERGY')]
dfassmnt0340 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_OBJ_REF')]
dfassmnt0341 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_RETEST_ROSTER')]
dfassmnt0342 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_Scaling_Table')]
dfassmnt0343 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_SCANNER_FILE')]
dfassmnt0344 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_SCANNER_FILE_OLD')]
dfassmnt0345 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_SCANNER_SC_ALT_TEMP')]
dfassmnt0346 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_SCANNER_SS_ALT_TEMP')]
dfassmnt0347 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_Science_and_SocialStudies_ISR')]
dfassmnt0348 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_Science_and_SocialStudies_ISR_GWY202001RET')]
dfassmnt0349 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_Science_and_SocialStudies_ISR_GWY202003LOAD')]
dfassmnt0350 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY_Writing_In_USHistory_ISR')]
dfassmnt0351 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY10_DOMN_REF')]
dfassmnt0352 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GWY10_STRAND_SCORES')]
dfassmnt0353 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GwyRosterNinthGrdSci')]
dfassmnt0354 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'GwyRosterNinthGrdSoc')]
dfassmnt0355 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HB91_STUDENT_LIST')]
dfassmnt0356 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_Classes')]
dfassmnt0357 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_Classes_0728')]
dfassmnt0358 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_Classes_BKUP20160725')]
dfassmnt0359 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_Classes_DailyFix')]
dfassmnt0360 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_Classes_Temp')]
dfassmnt0361 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'hrw_classesbkup0807')]
dfassmnt0362 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_Schools')]
dfassmnt0363 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_TBooks')]
dfassmnt0364 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_TextBooks_old')]
dfassmnt0365 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_Users')]
dfassmnt0366 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_Users_0728')]
dfassmnt0367 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_Users_BKUP20160725')]
dfassmnt0368 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_Users_dailyfix')]
dfassmnt0369 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HRW_Users_Temp')]
dfassmnt0370 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'hrw_usersbkup0807')]
dfassmnt0371 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HSR')]
dfassmnt0372 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'HSWR_DOE_LABELS')]
dfassmnt0373 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'IOWA_CoGAT_Report')]
dfassmnt0374 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'IOWA_CoGAT_Report_090320')]
dfassmnt0375 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'IOWA_CoGAT_Report_1216')]
dfassmnt0376 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'IOWA_CoGAT_Report_121619')]
dfassmnt0377 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'IOWA_CoGAT_Report_Bkup')]
dfassmnt0378 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ITBSCogAT_PreID')]
dfassmnt0379 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ITBSCogAT_PreID_CODES')]
dfassmnt0380 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ITBSCogAT_PreID_LOCATIONS')]
dfassmnt0381 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'junk')]
dfassmnt0382 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'KREP_OLR')]
dfassmnt0383 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'KREP_Report')]
dfassmnt0384 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'KREP_Report_Cluster')]
dfassmnt0385 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'KREP_Sch_Averages')]
dfassmnt0386 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'KREP_Scores')]
dfassmnt0387 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'KREP_Stu_70Plus')]
dfassmnt0388 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'LA_AVG_Temp')]
dfassmnt0389 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Load_Key')]
dfassmnt0390 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MA_AVG_Temp')]
dfassmnt0391 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MikeTempLoadEOC')]
dfassmnt0392 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MilestonesReport')]
dfassmnt0393 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MilestonesReport_2016')]
dfassmnt0394 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MirandaRequest')]
dfassmnt0395 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Muntemp')]
dfassmnt0396 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'NewForm')]
dfassmnt0397 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Nightly_CommonCoreFT')]
dfassmnt0398 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'nt_temp')]
dfassmnt0399 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PEARSON_LABELS_EOCT')]
dfassmnt0400 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PEARSON_LABELS_EOCT_ARCHIVE')]
dfassmnt0401 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'permnum_mun')]
dfassmnt0402 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Portal_Log_Permnum')]
dfassmnt0403 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PortalDevices')]
dfassmnt0404 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PortalDevicesReport')]
dfassmnt0405 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PortalDevicesUpdate')]
dfassmnt0406 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PortalDNLReport')]
dfassmnt0407 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PortalEL_Report')]
dfassmnt0408 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PortalLogReport_Week8')]
dfassmnt0409 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PortalLogSummary_Week8')]
dfassmnt0410 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PS_EMPLOYEES')]
dfassmnt0411 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PS_EMPLOYEES_2021')]
dfassmnt0412 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PS_EMPLOYEES_VICKIE')]
dfassmnt0413 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PS_EMPLOYMENT')]
dfassmnt0414 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PSAT_STRAND')]
dfassmnt0415 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'response')]
dfassmnt0416 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Rising_12thGrd_Report')]
dfassmnt0417 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Rising_9thGrd_Report')]
dfassmnt0418 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_ACCESS')]
dfassmnt0419 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_ARCHIVE_WR58')]
dfassmnt0420 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_CAR_FILE')]
dfassmnt0421 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_CAR_SUMMER')]
dfassmnt0422 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_COGAT')]
dfassmnt0423 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_CRCT')]
dfassmnt0424 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_CRCT_SUMMER')]
dfassmnt0425 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_CRCT_TCHNAME')]
dfassmnt0426 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_ENR_WR5')]
dfassmnt0427 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_ENR_WR8')]
dfassmnt0428 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GRAD')]
dfassmnt0429 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GRAD_FOR_SUMMARY')]
dfassmnt0430 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GSC')]
dfassmnt0431 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GSS')]
dfassmnt0432 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GWY')]
dfassmnt0433 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GWY_ALL')]
dfassmnt0434 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GWY_CRS_LIST')]
dfassmnt0435 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GWY_NINTHGRD')]
dfassmnt0436 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GWY_OLD')]
dfassmnt0437 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GWY_SC')]
dfassmnt0438 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GWY_SS')]
dfassmnt0439 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_GWY_STATUS')]
dfassmnt0440 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_HGT')]
dfassmnt0441 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_IOWA')]
dfassmnt0442 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_ITBS')]
dfassmnt0443 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_MENU')]
dfassmnt0444 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_SUMMER_SCH')]
dfassmnt0445 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_WR58')]
dfassmnt0446 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_WR58_SUMMER')]
dfassmnt0447 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_WRI')]
dfassmnt0448 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ROSTER_WRI3')]
dfassmnt0449 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'S2S_ATES')]
dfassmnt0450 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'S2S_ATES_APPEND')]
dfassmnt0451 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'S2S_ATES_DELETE')]
dfassmnt0452 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'S2S_ATPA')]
dfassmnt0453 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'S2S_ATPA_APPEND')]
dfassmnt0454 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'S2S_ATPA_DELETE')]
dfassmnt0455 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_1')]
dfassmnt0456 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_1_AVG')]
dfassmnt0457 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_1_ELIGIBLE')]
dfassmnt0458 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_2')]
dfassmnt0459 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_2_AVG')]
dfassmnt0460 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_2_ELIGIBLE')]
dfassmnt0461 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_3')]
dfassmnt0462 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_3_AVG')]
dfassmnt0463 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SAT_REPORT_SESSION_3_ELIGIBLE')]
dfassmnt0464 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SaturdayInterventionPermnum')]
dfassmnt0465 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SCHOOL_ETS_CODES')]
dfassmnt0466 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SEI')]
dfassmnt0467 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Self_Contained')]
dfassmnt0468 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Session3Eligible')]
dfassmnt0469 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Session3FromSchool')]
dfassmnt0470 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Session3Master')]
dfassmnt0471 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Session3Temp')]
dfassmnt0472 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SPG_Planning_EmpNOs')]
dfassmnt0473 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SPGTestID')]
dfassmnt0474 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SSATTD')]
dfassmnt0475 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StaffSurvey')]
dfassmnt0476 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StaffSurveyDNM')]
dfassmnt0477 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StaffSurveyDNM_1')]
dfassmnt0478 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StaffSurveyDNM_2')]
dfassmnt0479 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StaffSurveyDNM_3')]
dfassmnt0480 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StaffSurveyDNM_4')]
dfassmnt0481 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StaffSurveyDNM_5')]
dfassmnt0482 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StaffSurveyReport')]
dfassmnt0483 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StaffSurveyUpdate')]
dfassmnt0484 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STEM_Permnum')]
dfassmnt0485 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_ACC_TASK_SCR')]
dfassmnt0486 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_ACC_TEST_SCR')]
dfassmnt0487 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_ACT_STRND_SCR')]
dfassmnt0488 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_ACT_TEST_SCR')]
dfassmnt0489 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_AP_TEST_SCR')]
dfassmnt0490 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_CAR_STRND_SCR')]
dfassmnt0491 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_CAR_TEST_SCR')]
dfassmnt0492 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_COGAT_TEST_SCR')]
dfassmnt0493 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_CRCT_DOMN_SCR')]
dfassmnt0494 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_CRCT_TEST_SCR')]
dfassmnt0495 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_EOCT_STRND_SCR')]
dfassmnt0496 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_EOCT_TEST_SCR')]
dfassmnt0497 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWA5_DOMN_SCR')]
dfassmnt0498 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWA5_TEST_SCR')]
dfassmnt0499 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWA5_TEST_SCR_STG')]
dfassmnt0500 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWA8_DOMN_SCR')]
dfassmnt0501 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWA8_DOMN_SCR_STG')]
dfassmnt0502 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWA8_TEST_SCR')]
dfassmnt0503 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWA8_TEST_SCR_STG')]
dfassmnt0504 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWY10_DOMN_SCR')]
dfassmnt0505 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWY10_SUB_SCR')]
dfassmnt0506 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWY4_OBJ_SCR')]
dfassmnt0507 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWY4_TEST_SCR')]
dfassmnt0508 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWY7_OBJ_SCR')]
dfassmnt0509 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_GWY7_TEST_SCR')]
dfassmnt0510 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_HSGT_STRND_SCR')]
dfassmnt0511 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_HSGT_TEST_SCR')]
dfassmnt0512 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_HSWT_DOMN_SCR')]
dfassmnt0513 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_HSWT_TEST_SCR')]
dfassmnt0514 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_ITBS_TEST_SCR')]
dfassmnt0515 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_PSAT_STRND_SCR')]
dfassmnt0516 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_PSAT_TEST_SCR')]
dfassmnt0517 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_SAT_STRAND_SCR')]
dfassmnt0518 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_SAT_TEST_SCR')]
dfassmnt0519 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_ZONED_SCH')]
dfassmnt0520 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StuDetail_Daily_Bkup')]
dfassmnt0521 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_DATA')]
dfassmnt0522 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_DIM')]
dfassmnt0523 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_DIM_BKUP')]
dfassmnt0524 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_FACT')]
dfassmnt0525 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_FACT_121119')]
dfassmnt0526 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_FACT_BKUP')]
dfassmnt0527 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_MAP')]
dfassmnt0528 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_PERF_DIM')]
dfassmnt0529 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_PERF_DIM_BKUP')]
dfassmnt0530 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_PERF_MAP')]
dfassmnt0531 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_STRAND_DATA')]
dfassmnt0532 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_STRAND_MAP')]
dfassmnt0533 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SUBTEST_STRAND_PERF_MAP')]
dfassmnt0534 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SummerStudentList')]
dfassmnt0535 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Survey_Report_Codes')]
dfassmnt0536 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Survey_Report_Codes_Old')]
dfassmnt0537 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Survey_Report_Summary')]
dfassmnt0538 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Survey_Respondent_Report')]
dfassmnt0539 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Survey_Respondent_Status')]
dfassmnt0540 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'survey_responses')]
dfassmnt0541 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Synergy_HomeTeacher_2019')]
dfassmnt0542 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sysdiagrams')]
dfassmnt0543 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sysssislog')]
dfassmnt0544 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'tempconnected_0603')]
dfassmnt0545 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEMPHRWCLASSES')]
dfassmnt0546 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEMPHRWUSERS')]
dfassmnt0547 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_DEMO_ACC')]
dfassmnt0548 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_DEMO_ACC_2017')]
dfassmnt0549 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_DEMO_ACC_2017_RAW')]
dfassmnt0550 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_DEMO_CAR')]
dfassmnt0551 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_DEMO_G10')]
dfassmnt0552 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_DEMO_G10_MUNISH')]
dfassmnt0553 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_DEMO_G10_OLD')]
dfassmnt0554 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_DEMO_WR58')]
dfassmnt0555 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_DIM')]
dfassmnt0556 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'test_dim_bkup')]
dfassmnt0557 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_GWY_REP')]
dfassmnt0558 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_INP_G10')]
dfassmnt0559 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_MAP')]
dfassmnt0560 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ACC_OLD')]
dfassmnt0561 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ACC_OOD')]
dfassmnt0562 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ACC_Temp')]
dfassmnt0563 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ACT')]
dfassmnt0564 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ACT_OLD')]
dfassmnt0565 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ACT_Temp')]
dfassmnt0566 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_APP')]
dfassmnt0567 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_APP_Temp')]
dfassmnt0568 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_CAR')]
dfassmnt0569 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_CAR_Temp')]
dfassmnt0570 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_COG')]
dfassmnt0571 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_COG_STG')]
dfassmnt0572 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_COG_Temp')]
dfassmnt0573 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_CRCT_STRAND')]
dfassmnt0574 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_CRT')]
dfassmnt0575 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_CRT_BKP')]
dfassmnt0576 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_CRT_JIC')]
dfassmnt0577 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_CRT_JIC2')]
dfassmnt0578 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_CRT_MAINFRAME')]
dfassmnt0579 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_CRT_SP')]
dfassmnt0580 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_CRT_Temp')]
dfassmnt0581 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ECT')]
dfassmnt0582 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ECT_JIC20130304')]
dfassmnt0583 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ECT_SUMMARY')]
dfassmnt0584 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ECT_Temp')]
dfassmnt0585 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_EOC')]
dfassmnt0586 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_G10')]
dfassmnt0587 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_G10_FIELDTEST')]
dfassmnt0588 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_G10_SUM')]
dfassmnt0589 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_G4')]
dfassmnt0590 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_G7')]
dfassmnt0591 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_GWY10_Temp')]
dfassmnt0592 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_GWY4_Temp')]
dfassmnt0593 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_GWY7_Temp')]
dfassmnt0594 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_HGT')]
dfassmnt0595 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_HGT_Temp')]
dfassmnt0596 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_ITB')]
dfassmnt0597 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_PSA')]
dfassmnt0598 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_PSAT_Temp')]
dfassmnt0599 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_SAT')]
dfassmnt0600 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_SAT_Temp')]
dfassmnt0601 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_WR5')]
dfassmnt0602 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_WR58_DEM')]
dfassmnt0603 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_WR8')]
dfassmnt0604 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_STU_WRI')]
dfassmnt0605 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_ACC')]
dfassmnt0606 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_ACC_REP')]
dfassmnt0607 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_ACT')]
dfassmnt0608 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_ACT_REP')]
dfassmnt0609 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_APP')]
dfassmnt0610 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_APP_REP')]
dfassmnt0611 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_CAR')]
dfassmnt0612 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_COG')]
dfassmnt0613 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_CRT')]
dfassmnt0614 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_CRT_BKP2012')]
dfassmnt0615 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_CRT_PERMNUM')]
dfassmnt0616 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_CRT_REP')]
dfassmnt0617 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_ECT')]
dfassmnt0618 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_ECT_BKP')]
dfassmnt0619 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_ECT_REP')]
dfassmnt0620 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_EOC')]
dfassmnt0621 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_EOG')]
dfassmnt0622 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_G10')]
dfassmnt0623 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_G4')]
dfassmnt0624 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_G7')]
dfassmnt0625 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_HGT')]
dfassmnt0626 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_HGT_REP')]
dfassmnt0627 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_ITB')]
dfassmnt0628 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_PSA')]
dfassmnt0629 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_PSA_REP')]
dfassmnt0630 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_SAT')]
dfassmnt0631 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_SAT_REP')]
dfassmnt0632 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_WR5')]
dfassmnt0633 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_WR58_DEM')]
dfassmnt0634 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_WR8')]
dfassmnt0635 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TAPE_WRI')]
dfassmnt0636 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TEMP_ECT_DELETES')]
dfassmnt0637 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TEMP_ECT_LEX1')]
dfassmnt0638 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TEMP_ECT_LEX2')]
dfassmnt0639 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TEMP_ECT_LEX3')]
dfassmnt0640 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TEMP_ECT_LEXALL')]
dfassmnt0641 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TEMP_EOC_DELETES')]
dfassmnt0642 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'TEST_TEMP_GWY')]
dfassmnt0643 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Testing_Accom')]
dfassmnt0644 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'Testing_Accommodation_2018')]
dfassmnt0645 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ZONED_NEW_REPORT')]
dfassmnt0646 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ZONED_SCH_REPORT')]
dfassmnt0647 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ETLREF') & (df['TableName'] == 'AP_COURSE_TEST_MAP')]
dfassmnt0648 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ETLREF') & (df['TableName'] == 'CRCT_SUBTEST_MAP')]
dfassmnt0649 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ETLREF') & (df['TableName'] == 'EOCT_TEST_MAP')]
dfassmnt0650 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ETLREF') & (df['TableName'] == 'HSGT_TOTAL_RAW_POSSIBLE')]
dfassmnt0651 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ETLREF') & (df['TableName'] == 'PSA_SCR')]
dfassmnt0652 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ETLREF') & (df['TableName'] == 'STU_SAT')]
dfassmnt0653 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ETLREF') & (df['TableName'] == 'SUBTEST_DIM')]
dfassmnt0654 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ETLREF') & (df['TableName'] == 'SUBTEST_PERF_DIM')]
dfassmnt0655 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'ACC_TASK_REF')]
dfassmnt0656 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'AP_TEST_SUBJ_CD')]
dfassmnt0657 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'CAR_STRAND_MAP')]
dfassmnt0658 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'CAR_SUB_REF')]
dfassmnt0659 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'CRCT_PERFRMNC_LVL')]
dfassmnt0660 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'CRCT_STRAND_MAP')]
dfassmnt0661 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'DATE_MAPPING')]
dfassmnt0662 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'EOCT_STRND_REF')]
dfassmnt0663 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'EXAM_VERSIONS')]
dfassmnt0664 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'GATEWAY_STRAND')]
dfassmnt0665 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'GWY_SUB_REF')]
dfassmnt0666 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'GWY10_SUB_REF')]
dfassmnt0667 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'STU_TEST_CAR_CUT_SCR')]
dfassmnt0668 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'ref') & (df['TableName'] == 'Test')]
dfassmnt0669 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'res') & (df['TableName'] == 'Grad_Survey')]
dfassmnt0670 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'res') & (df['TableName'] == 'Military_Scholarships')]
dfassmnt0671 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'res') & (df['TableName'] == 'Potential_Graduates')]
dfassmnt0672 = df[(df['DatabaseName'] == 'Assessment') & (df['SchemaName'] == 'Temp') & (df['TableName'] == 'SUBTEST_FACT_ACT')]

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(df).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='Assessment All Tables'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(df, title='Assessment All Tables').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# #Individual Tables - graphed with datapane and altair

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfassmnt0029).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='AKS'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfassmnt0029, title='AKS').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfassmnt0117).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='ASSESS_PSAT_NMSQT'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfassmnt0117, title='ASSESS_PSAT_NMSQT').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfassmnt0178).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='CUA_AKSDataStage'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfassmnt0178, title='CUA_AKSDataStage').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfassmnt0339).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='GWY_INTERVENTION_FROMSYNERGY'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfassmnt0339, title='GWY_INTERVENTION_FROMSYNERGY').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfassmnt0423).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='ROSTER_CRCT'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfassmnt0423, title='ROSTER_CRCT').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)
