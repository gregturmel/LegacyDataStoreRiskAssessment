# %%
#Program Name: Daily-XChart-datapane_v1_single_multi_on_pprod
#Purpose:  Chart scatter line box aggr table data
#Author:  Greg Turmel, Director, Data Governance 
#Date:    2020.08.30 - 2021.06.30
#Errata:  0.1 Improvements can be made to script using for/looping through the databases

import os, sys, argparse, csv, pyodbc, sql, time, datetime
from datetime import datetime, timedelta
import sqlalchemy as db
from dotenv import load_dotenv # add this line
from matplotlib.backends.backend_pdf import PdfPages
import pandas as pd
import altair as alt
from altair import Chart, X, Y, Axis, SortField
from vega_datasets import data as vega_data
import datapane as dp
#import datatable as dt
import numpy as np
import matplotlib # notebook
import matplotlib.pyplot as plt
import seaborn as sns
#import chart_studio.plotly as py
import plotly.graph_objects as go
load_dotenv() # add this line
user = os.getenv('MySQLeUser')
password = os.getenv('MySQLeUserPass')
host = os.getenv('MySQLeHOST')
db = os.getenv('MySQLeDB')
# %matplotlib inline
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=DEVODSSQL;'
                      'Database=Greg;'
                      'Trusted_Connection=yes;')

sql_query01 = pd.read_sql_query(''' 
select DISTINCT TableName
FROM [dbo].[tableRowCountPPROD]
ORDER BY TableName;     
                              '''
                              ,conn) # Load the list of distinct tables to graph

sql_query02 = pd.read_sql_query(''' 
select *
FROM [dbo].[tableRowCountPPROD]
ORDER BY TableName;     
                              '''
                              ,conn) # Load the list of distinct tables to graph

# %%
df = pd.DataFrame(sql_query02)
#df = df.astype({'TodaysDate':np.int64,'RecordCount':np.int64})
df['TodaysDate'] = pd.to_datetime(df['TodaysDate'].astype(str), format='%Y%m%d')
df = df.sort_values(by=['TableName','SchemaName','DatabaseName','TodaysDate'], ascending=[True,True,True,True])
df = df.reset_index(drop=True)

# %%
dfpp0001 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'DisciplineCodeCorrections')]
dfpp0002 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'ERROR_LOG')]
dfpp0003 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'jcs_sportalusage_test')]
dfpp0004 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'MealPay')]
dfpp0005 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'missingpermnums')]
dfpp0006 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'parent_surveys_bak_greg_201702026')]
dfpp0007 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'parentNotFound')]
dfpp0008 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'parents_to_delete')]
dfpp0009 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'PPROD_PPIGP_igpro_icgr_dupes')]
dfpp0010 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'SPortalLogins')]
dfpp0011 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'stu_rltn_20160726')]
dfpp0012 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'STU_SUBT_HIST_Errors')]
dfpp0013 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'StudentEmail')]
dfpp0014 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'students_to_delete')]
dfpp0015 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'stulist')]
dfpp0016 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'survey_responses_bak_greg_201702026')]
dfpp0017 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'sysdiagrams')]
dfpp0018 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'test_trm')]
dfpp0019 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'testme_CRS_MSTR_SCHD')]
dfpp0020 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'dbo') & (df['TableName'] == 'work_stu_curr_schd')]
dfpp0021 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'Admin_User')]
dfpp0022 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'ClassSchedule')]
dfpp0023 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'CompareDiffs')]
dfpp0024 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'CompareDiffs2DB2')]
dfpp0025 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'crs_mstr_schd')]
dfpp0026 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'emp_email_backup')]
dfpp0027 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'Empl_Sch')]
dfpp0028 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'Employee_Email')]
dfpp0029 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'Employee_Email_Test')]
dfpp0030 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'freeze_schedule_schools')]
dfpp0031 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'GradeBookAverages')]
dfpp0032 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'Help_Contexts')]
dfpp0033 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'Help_Question_Contexts')]
dfpp0034 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'Help_Questions')]
dfpp0035 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'LANG_HEADER')]
dfpp0036 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'LAST_PRNT_COMM')]
dfpp0037 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'LastAccessed')]
dfpp0038 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'LDAPUsers')]
dfpp0039 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'LDAPUsersNotActivated')]
dfpp0040 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'LOADDETAIL')]
dfpp0041 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'LOADREADYOLD')]
dfpp0042 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'Parent_Delete')]
dfpp0043 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'parent_surveys')]
dfpp0044 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'PRNT_ACCT_LOG')]
dfpp0045 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'PRNT_EMAIL_CHANGE_HISTORY')]
dfpp0046 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'REFRESH_STATUS')]
dfpp0047 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'RPTActiveStudent')]
dfpp0048 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'save_Admin_User')]
dfpp0049 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_ABS_HST')]
dfpp0050 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_ABS_HST_BACKUP')]
dfpp0051 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_ALRT')]
dfpp0052 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_ATT_MO_SUM')]
dfpp0053 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_ATT_SUM')]
dfpp0054 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_BookCharges')]
dfpp0055 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_BookCheckOuts')]
dfpp0056 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'stu_businfo')]
dfpp0057 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_CheckInCheckOut')]
dfpp0058 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_CRS_HS_SUM')]
dfpp0059 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_CRS_HST')]
dfpp0060 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'stu_crs_hst_oldlogic')]
dfpp0061 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_CRS_MS_SUM')]
dfpp0062 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_CRS_STS')]
dfpp0063 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_CURR_SCHD')]
dfpp0064 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_CURR_SCHD_20161222')]
dfpp0065 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'stu_curr_schd_ALAN')]
dfpp0066 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'stu_curr_schd_backup')]
dfpp0067 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'Stu_Curr_Schd_Cotchr')]
dfpp0068 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'stu_curr_schd_igpro')]
dfpp0069 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_CURR_SCHD_SUM')]
dfpp0070 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_DSCP_DISP')]
dfpp0071 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_DSCP_HST')]
dfpp0072 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_Fees')]
dfpp0073 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_IGP_CLS_NOTE')]
dfpp0074 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_IGP_STU_NOTE')]
dfpp0075 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_IGP_TASK')]
dfpp0076 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'stu_igp_task_20161222')]
dfpp0077 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'stu_igp_task_20190906_partial')]
dfpp0078 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_MEALPAY')]
dfpp0079 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_PERIOD_ATTENDANCE')]
dfpp0080 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_PGM')]
dfpp0081 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'stu_prfl')]
dfpp0082 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_PRNT_COM_MAX')]
dfpp0083 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_PRNT_COMM')]
dfpp0084 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_RLTN')]
dfpp0085 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'stu_rltn_support')]
dfpp0086 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_SUBT_HIST_Errors')]
dfpp0087 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_SUBT_HST')]
dfpp0088 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'STU_TEST_GUIDE')]
dfpp0089 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'Student_Delete')]
dfpp0090 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'stulist')]
dfpp0091 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'survey_headers')]
dfpp0092 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'survey_options')]
dfpp0093 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'survey_question_types')]
dfpp0094 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'survey_questions')]
dfpp0095 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'survey_responses')]
dfpp0096 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'SYS_ACCESS_LOG')]
dfpp0097 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'SYS_ACCESS_LOG_BACKUP')]
dfpp0098 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'SYS_ACCESS_LOG_MAX')]
dfpp0099 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'Tchr_Stu')]
dfpp0100 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PP') & (df['TableName'] == 'User_Stu')]
dfpp0101 = df[(df['DatabaseName'] == 'PPROD') & (df['SchemaName'] == 'PPETL') & (df['TableName'] == 'SUBT_NM_MAP')]

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(df).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='PPROD All Tables'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(df, title='PPROD All Tables').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#Individual Tables - graphed with datapane and altair

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfpp0010).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='SPortalLogins'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfpp0010, title='SPortalLogins').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfpp0020).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='work_stu_curr_schd'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfpp0020, title='work_stu_curr_schd').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfpp0022).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='ClassSchedule'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfpp0022, title='ClassSchedule').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfpp0025).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='crs_mstr_schd'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfpp0025, title='crs_mstr_schd').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfpp0049).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='STU_ABS_HST'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfpp0049, title='STU_ABS_HST').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfpp0051).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='STU_ALRT'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfpp0051, title='STU_ALRT').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)

# %%
#alt.data_transformers.enable("json", urlpath="/user-redirect/files/")
alt.data_transformers.enable('json')
selection = alt.selection_multi();
alt.Chart(dfpp0054).mark_point(filled=True).encode(
    alt.X('TodaysDate', scale=alt.Scale(zero=False)),
    alt.Y('RecordCount', scale=alt.Scale(zero=False)),
    alt.Size('RecordCount:Q'),
    alt.OpacityValue(0.5),
    alt.Order('RecordCount:Q', sort='descending'),
    tooltip = [alt.Tooltip('TodaysDate:T'),
               alt.Tooltip('RecordCount:Q'),
               alt.Tooltip('DatabaseName:N'),
               alt.Tooltip('SchemaName:N'),
               alt.Tooltip('TableName:N'),
              ],
    color=alt.condition(selection, 'cluster:N', alt.value('grey'))
).add_selection(selection).properties(
    title='STU_BookCharges'
).properties(
    width=750,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
hover = alt.selection_multi(on='mouseover', nearest=True, empty='none')

base = alt.Chart(dfpp0054, title='STU_BookCharges').encode(
       alt.X('TodaysDate:T')
       #title.configure_title(fontSize=24)
    
).properties(
    width=750, height=300,
)
points = base.mark_point().add_selection(
    hover
)

line_A = base.mark_line(color='#5276A7').encode(
    alt.Y('average(RecordCount):Q', axis=alt.Axis(titleColor='#5276A7'))
)

line_B = base.mark_line(color='#F18727').encode(
    alt.Y('average(Ddifference):Q', axis=alt.Axis(titleColor='#F18727'))
)
alt.layer(line_A, line_B).resolve_scale(y='independent').interactive()
# Out:
# alt.LayerChart(...)
